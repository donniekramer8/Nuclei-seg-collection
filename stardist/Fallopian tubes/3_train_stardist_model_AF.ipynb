# %%
# pip install gputools
# pip install scikit-tensor-py3

from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import numpy as np
import matplotlib
matplotlib.rcParams["image.interpolation"] = 'nearest'
import matplotlib.pyplot as plt
import os
from PIL import Image
import tensorflow as tf
from glob import glob
from tqdm import tqdm
from tifffile import imread
from csbdeep.utils import Path, normalize

from stardist import fill_label_holes, random_label_cmap, calculate_extents, gputools_available
from stardist.matching import matching, matching_dataset
from stardist.models import Config2D, StarDist2D, StarDistData2D

# %%
#Random color map labels
np.random.seed(42)
lbl_cmap = random_label_cmap()

# %%
pth=r'\\10.99.68.178\andreex\data\Stardist'
pthtraining= os.path.join(pth,'Training')
pthtesting= os.path.join(pth,'Testing')
pthmodels= os.path.join(pth,'models')
pthfiles= os.path.join(pth,'files')
pthHE= os.path.join(pthtraining,'H&E_tiles')
pthmasks= os.path.join(pthtraining,'Mask_tiles')

# %%
training_HE_tiles_pths = sorted(glob(os.path.join(pthHE,'*.tif')))
training_mask_tiles_pths = sorted(glob(os.path.join(pthmasks,'*.tif')))

# %%
HE_original_tiles = list(map(imread,training_HE_tiles_pths))
mask_original_tiles = list(map(imread,training_mask_tiles_pths))

# %%
def augment_images(HE_tiles, mask_tiles):
  """
  Augments a set of HE images and corresponding mask labels by rotating and flipping them.

  Args:
    HE_tiles: A list of NumPy arrays representing the HE images.
    mask_tiles: A list of NumPy arrays representing the mask labels for the HE images.

  Returns:
    HE_aug: A list of NumPy arrays representing the augmented HE images.
    mask_aug: A list of NumPy arrays representing the augmented mask labels.
  """

  HE_aug = [[] for _ in range(len(HE_tiles))]
  mask_aug = [[] for _ in range(len(mask_tiles))]

  for i in range(len(HE_tiles)):
    im = Image.fromarray(HE_tiles[i])
    lbl = Image.fromarray(mask_tiles[i])

    # Rotate the image and label 90 degrees three times.
    for _ in range(3):
      im = im.rotate(90)
      HE_aug[i].append(im)
      lbl = lbl.rotate(90)
      mask_aug[i].append(lbl)

    # Flip the image and label horizontally.
    im = Image.fromarray(HE_tiles[i])
    flipped_im = im.transpose(Image.FLIP_LEFT_RIGHT)

    lbl = Image.fromarray(mask_tiles[i])
    flipped_lbl = lbl.transpose(Image.FLIP_LEFT_RIGHT)

    HE_aug[i].append(flipped_im)
    mask_aug[i].append(flipped_lbl)

    # Rotate the flipped image and label 90 degrees three times.
    for _ in range(3):
      flipped_im = flipped_im.rotate(90)
      HE_aug[i].append(flipped_im)
      flipped_lbl = flipped_lbl.rotate(90)
      mask_aug[i].append(flipped_lbl)

  return HE_aug, mask_aug

# %%
HE_aug, mask_aug = augment_images(HE_original_tiles, mask_original_tiles)

# %%
#Normalize input images and fill holes in masks
HE_original_tiles = [x/255 for x in HE_original_tiles]  # no norm, just divide by 255 to get into (0,1) range
mask_original_tiles = [fill_label_holes(y) for y in mask_original_tiles]  # fills holes in annotations if there are any

# %%
def normalize_images(images, masks):
  
  normalized_masks = [[] for i in range(len(masks))]
  normalized_images = [[] for i in range(len(images))]
  
  for i in range(len(masks)):
      masks_list = masks[i]
      images_list = images[i]
      
      for j in range(len(images_list)):
          im = images_list[j]
          im = np.asarray(im)
          im = im/255
          normalized_images[i].append(im)
      
      for j in range(len(masks_list)):
          im = masks_list[j]
          im = np.asarray(im)
          im = fill_label_holes(im)
          normalized_masks[i].append(im)
          
  return normalized_images, normalized_masks

# %%
HE_aug_norm, mask_aug_norm = normalize_images(HE_aug, mask_aug)

# %%
def split_augmented_data(HE_aug_norm_list, mask_aug_norm_list):
  """
  Splits augmented HE images and mask images into training and validation sets.

  Args:
    HE_aug_norm: A list of NumPy arrays representing the normalized augmented HE images.
    mask_aug_norm: A list of NumPy arrays representing the normalized augmented mask images.

  Returns:
    X_trn, Y_trn, X_val, Y_val: Training and validation sets of HE images and mask images.
  """

  # Create empty lists to store the training and validation sets.
  X_trn = []
  Y_trn = []
  X_val = []
  Y_val = []
  
  for i in range(len(HE_aug_norm_list)):
    HE_aug_norm = HE_aug_norm_list[i]
    mask_aug_norm = mask_aug_norm_list[i]
  
    # Assert that there is enough training data.
    assert len(HE_aug_norm) > 1, "not enough training data"
  
    # Create a random number generator with a fixed seed for reproducibility.
    rng = np.random.RandomState(42)
  
    # Permute the indices of the augmented data.
    ind = rng.permutation(len(HE_aug_norm))
  
    # Split the indices into training and validation indices.
    n_val = max(1, int(round(0.15 * len(ind))))
    ind_trn, ind_val = ind[:-n_val], ind[-n_val:]
  
    # Split the augmented data into training and validation sets.
    for kk in ind_trn:
      X_trn.append(HE_aug_norm[kk])
      Y_trn.append(mask_aug_norm[kk])
  
    for lol in ind_val:
      X_val.append(HE_aug_norm[lol])
      Y_val.append(mask_aug_norm[lol])
  
  print(f'number of images: {len(HE_aug_norm_list*len(HE_aug_norm_list[0]))}')
  print(f'- training: {len(X_trn)}')
  print(f'- validation: {len(X_val)}')
  
  X_trn = [np.array(x) for x in X_trn]
  Y_trn = [np.array(y) for y in Y_trn]
  
  X_val = [np.array(x) for x in X_val]
  Y_val = [np.array(y) for y in Y_val]
  
  # Return the training and validation sets.
  return X_trn, Y_trn, X_val, Y_val

# %%
HE_trn, mask_trn, HE_val, mask_val = split_augmented_data(HE_aug_norm, mask_aug_norm)
# Out:
# number of images: 84
# - training: 72
# - validation: 12

# %%
#PLot image and label for some images - sanity check
def show_tile_segmented(tile, segmented, **kwargs):
    """Plot large image at different resolutions."""
    fig, ax = plt.subplots(1, 2, figsize=(16/2, 8/2))

    # Plot the original image on the left
    ax[0].imshow(tile, **kwargs)

    # Plot the cropped image on the right
    ax[1].imshow(segmented, **kwargs)

    ax[0].axis('off')
    ax[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
i = 10

img, lbl = HE_val[i], mask_val[i]
assert img.ndim in (2,3)
img = img if (img.ndim==2 or img.shape[-1]==3) else img[...,0]
show_tile_segmented(img,lbl)

# %%
if tf.config.list_physical_devices('GPU'):
    print("GPU is available")
else:
    print("GPU is not available")
    
print(tf.__version__)

#Define the config by setting some parameter values
# 32 is a good default choice (see 1_data.ipynb)
n_rays = 32  #Number of radial directions for the star-convex polygon.

# Use OpenCL-based computations for data generator during training (requires 'gputools')
use_gpu = True and gputools_available()

# Predict on subsampled grid for increased efficiency and larger field of view
grid = (2,2)

n_channel = 1 if HE_trn[0].ndim == 2 else HE_trn[0].shape[-1]  #If no third dim. then number of channels = 1. Otherwise get the num channels from the last dim.


conf = Config2D (
    n_rays       = n_rays,
    grid         = grid,
    use_gpu      = use_gpu,
    n_channel_in = n_channel,
)
# print(conf)
vars(conf)
# Out:
# GPU is available
# 2.10.1
# Warning: Could not find scikit-tensor which is needed for separable approximations...
# If you want to compute separable approximations, please install it with
# pip install scikit-tensor-py3
# {'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 3,
#  'n_channel_out': 33,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'n_rays': 32,
#  'grid': (2, 2),
#  'backbone': 'unet',
#  'n_classes': None,
#  'unet_n_depth': 3,
#  'unet_kernel_size': (3, 3),
#  'unet_n_filter_base': 32,
#  'unet_n_conv_per_depth': 2,
#  'unet_pool': (2, 2),
#  'unet_activation': 'relu',
#  'unet_last_activation': 'relu',
#  'unet_batch_norm': False,
#  'unet_dropout': 0.0,
#  'unet_prefix': '',
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, 3),
#  'net_mask_shape': (None, None, 1),
#  'train_shape_completion': False,
#  'train_completion_crop': 32,
#  'train_patch_size': (256, 256),
#  'train_background_reg': 0.0001,
#  'train_foreground_only': 0.9,
#  'train_sample_cache': True,
#  'train_dist_loss': 'mae',
#  'train_loss_weights': (1, 0.2),
#  'train_class_weights': (1, 1),
#  'train_epochs': 400,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0003,
#  'train_batch_size': 4,
#  'train_n_val_patches': None,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 40, 'min_delta': 0},
#  'use_gpu': True}

# %%
print(n_channel)
# Out:
# 3

# %%
#Start from 40x H&E pre-trained model to the specified directory
import copy
import json

def load_justin_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = load_model(r'\\10.99.68.178\andreex\students\Donald Monkey fetus\stardist\Model_00')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_published_he_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = StarDist2D.from_pretrained('2D_versatile_he')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_model(model_path: str) -> StarDist2D:
    # Load StarDist model weights, configurations, and thresholds
    with open(model_path + '\\config.json', 'r') as f:
        config = json.load(f)
    with open(model_path + '\\thresholds.json', 'r') as f:
        thresh = json.load(f)
    model = StarDist2D(config=Config2D(**config), basedir=model_path, name='offshoot_model')
    model.thresholds = thresh
    print('Overriding defaults:', model.thresholds, '\n')
    model.load_weights(model_path + '\\weights_best.h5')
    return model

def configure_model_for_training(model: StarDist2D,
                                 epochs: int = 25, learning_rate: float = 1e-6,
                                 batch_size: int = 4, patch_size: list[int,int] = [256, 256]) -> StarDist2D:
    model.config.train_epochs = epochs
    model.config.train_learning_rate = learning_rate
    model.config.train_batch_size = batch_size
    model.config.train_patch_size = patch_size
    return model

# %%
# pth_save = r'C:\Users\Donald\PycharmProjects\monkey_nuc_segment\stardist'
# outnm = 'monkey_tile_trained_v5'  # make sure to change!

nm='monkey_fallopian_tube_AF_'
dt='_11_03_2023'
lrlbl='_1e-4'
outnm = nm + dt + lrlbl
model = load_published_he_model(pthmodels, outnm)

model.config.train_learning_rate = 1e-4
model.config.train_patch_size = (256,256)
model.config.train_reduce_lr={'factor': 0.5, 'patience': 10, 'min_delta': 0}
print(model.config)
# Out:
# Found model '2D_versatile_he' for 'StarDist2D'.
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.692478, nms_thresh=0.3.
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# Config2D(n_dim=2, axes='YXC', n_channel_in=3, n_channel_out=33, train_checkpoint='weights_best.h5', train_checkpoint_last='weights_last.h5', train_checkpoint_epoch='weights_now.h5', n_rays=32, grid=(2, 2), backbone='unet', n_classes=None, unet_n_depth=3, unet_kernel_size=(3, 3), unet_n_filter_base=32, unet_n_conv_per_depth=2, unet_pool=(2, 2), unet_activation='relu', unet_last_activation='relu', unet_batch_norm=False, unet_dropout=0.0, unet_prefix='', net_conv_after_unet=128, net_input_shape=(None, None, 3), net_mask_shape=(None, None, 1), train_shape_completion=False, train_completion_crop=32, train_patch_size=(256, 256), train_background_reg=0.0001, train_foreground_only=0.9, train_sample_cache=True, train_dist_loss='mae', train_loss_weights=(1, 0.2), train_class_weights=(1, 1), train_epochs=400, train_steps_per_epoch=100, train_learning_rate=0.0001, train_batch_size=4, train_n_val_patches=None, train_tensorboard=True, train_reduce_lr={'factor': 0.5, 'patience': 10, 'min_delta': 0}, use_gpu=True)

# %%
# model.train(X_trn, Y_trn, validation_data=(X_val,Y_val), augmenter=augmenter, epochs=10, steps_per_epoch=100, train_learning_rate=10e-6)
model.train(HE_trn, 
            mask_trn,
            validation_data=(HE_val,mask_val),
            epochs=200,
            steps_per_epoch=10)
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x00000167D88A13A0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000167D88A13A0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow | AutoGraph could not transform <function _gcd_import at 0x00000167D88A13A0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000167D88A13A0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x00000167D88A13A0> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000167D88A13A0>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 1s 5ms/step loss: 0.6353 - prob_loss: 0.2613 - dist_loss: 1.8701 - prob_kld: 0.1308 - dist_relevant_mae: 1.8697 - dist_relev
# 10/10 [==============================] - 28s 581ms/step - loss: 0.6353 - prob_loss: 0.2613 - dist_loss: 1.8701 - prob_kld: 0.1308 - dist_relevant_mae: 1.8697 - dist_relevant_mse: 8.9528 - dist_dist_iou_metric: 0.5542 - val_loss: 0.5611 - val_prob_loss: 0.2367 - val_dist_loss: 1.6223 - val_prob_kld: 0.1028 - val_dist_relevant_mae: 1.6220 - val_dist_relevant_mse: 6.1549 - val_dist_dist_iou_metric: 0.5817 - lr: 1.0000e-04
# Epoch 2/200
# 3/3 [==============================] - 0s 11ms/steploss: 0.5602 - prob_loss: 0.2376 - dist_loss: 1.6132 - prob_kld: 0.0995 - dist_relevant_mae: 1.6129 - dist_relev
# 10/10 [==============================] - 4s 431ms/step - loss: 0.5602 - prob_loss: 0.2376 - dist_loss: 1.6132 - prob_kld: 0.0995 - dist_relevant_mae: 1.6129 - dist_relevant_mse: 6.1154 - dist_dist_iou_metric: 0.5836 - val_loss: 0.5305 - val_prob_loss: 0.2213 - val_dist_loss: 1.5458 - val_prob_kld: 0.0874 - val_dist_relevant_mae: 1.5455 - val_dist_relevant_mse: 5.8913 - val_dist_dist_iou_metric: 0.5946 - lr: 1.0000e-04
# Epoch 3/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.5392 - prob_loss: 0.2409 - dist_loss: 1.4912 - prob_kld: 0.0952 - dist_relevant_mae: 1.4910 - dist_relev
# 10/10 [==============================] - 4s 399ms/step - loss: 0.5392 - prob_loss: 0.2409 - dist_loss: 1.4912 - prob_kld: 0.0952 - dist_relevant_mae: 1.4910 - dist_relevant_mse: 5.5419 - dist_dist_iou_metric: 0.6075 - val_loss: 0.5179 - val_prob_loss: 0.2166 - val_dist_loss: 1.5064 - val_prob_kld: 0.0827 - val_dist_relevant_mae: 1.5061 - val_dist_relevant_mse: 5.6585 - val_dist_dist_iou_metric: 0.6099 - lr: 1.0000e-04
# Epoch 4/200
# 3/3 [==============================] - 0s 16ms/steploss: 0.5108 - prob_loss: 0.2128 - dist_loss: 1.4900 - prob_kld: 0.0772 - dist_relevant_mae: 1.4898 - dist_relev
# 10/10 [==============================] - 5s 519ms/step - loss: 0.5108 - prob_loss: 0.2128 - dist_loss: 1.4900 - prob_kld: 0.0772 - dist_relevant_mae: 1.4898 - dist_relevant_mse: 5.5318 - dist_dist_iou_metric: 0.6126 - val_loss: 0.5089 - val_prob_loss: 0.2137 - val_dist_loss: 1.4759 - val_prob_kld: 0.0798 - val_dist_relevant_mae: 1.4756 - val_dist_relevant_mse: 5.4480 - val_dist_dist_iou_metric: 0.6125 - lr: 1.0000e-04
# Epoch 5/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.5156 - prob_loss: 0.2205 - dist_loss: 1.4755 - prob_kld: 0.0868 - dist_relevant_mae: 1.4752 - dist_relev
# 10/10 [==============================] - 5s 518ms/step - loss: 0.5156 - prob_loss: 0.2205 - dist_loss: 1.4755 - prob_kld: 0.0868 - dist_relevant_mae: 1.4752 - dist_relevant_mse: 5.3636 - dist_dist_iou_metric: 0.6075 - val_loss: 0.5068 - val_prob_loss: 0.2117 - val_dist_loss: 1.4754 - val_prob_kld: 0.0778 - val_dist_relevant_mae: 1.4752 - val_dist_relevant_mse: 5.4219 - val_dist_dist_iou_metric: 0.6006 - lr: 1.0000e-04
# Epoch 6/200
# 3/3 [==============================] - 0s 10ms/steploss: 0.4795 - prob_loss: 0.1969 - dist_loss: 1.4129 - prob_kld: 0.0721 - dist_relevant_mae: 1.4126 - dist_relev
# 10/10 [==============================] - 5s 511ms/step - loss: 0.4795 - prob_loss: 0.1969 - dist_loss: 1.4129 - prob_kld: 0.0721 - dist_relevant_mae: 1.4126 - dist_relevant_mse: 5.0982 - dist_dist_iou_metric: 0.6297 - val_loss: 0.4989 - val_prob_loss: 0.2102 - val_dist_loss: 1.4435 - val_prob_kld: 0.0763 - val_dist_relevant_mae: 1.4432 - val_dist_relevant_mse: 5.2735 - val_dist_dist_iou_metric: 0.6235 - lr: 1.0000e-04
# Epoch 7/200
# 3/3 [==============================] - 0s 17ms/steploss: 0.5251 - prob_loss: 0.2366 - dist_loss: 1.4426 - prob_kld: 0.0861 - dist_relevant_mae: 1.4423 - dist_relev
# 10/10 [==============================] - 5s 556ms/step - loss: 0.5251 - prob_loss: 0.2366 - dist_loss: 1.4426 - prob_kld: 0.0861 - dist_relevant_mae: 1.4423 - dist_relevant_mse: 5.0843 - dist_dist_iou_metric: 0.6149 - val_loss: 0.4965 - val_prob_loss: 0.2095 - val_dist_loss: 1.4351 - val_prob_kld: 0.0756 - val_dist_relevant_mae: 1.4348 - val_dist_relevant_mse: 5.2158 - val_dist_dist_iou_metric: 0.6120 - lr: 1.0000e-04
# Epoch 8/200
# 3/3 [==============================] - 0s 11ms/steploss: 0.5296 - prob_loss: 0.2425 - dist_loss: 1.4354 - prob_kld: 0.0853 - dist_relevant_mae: 1.4351 - dist_relev
# 10/10 [==============================] - 5s 503ms/step - loss: 0.5296 - prob_loss: 0.2425 - dist_loss: 1.4354 - prob_kld: 0.0853 - dist_relevant_mae: 1.4351 - dist_relevant_mse: 5.0787 - dist_dist_iou_metric: 0.6240 - val_loss: 0.4912 - val_prob_loss: 0.2086 - val_dist_loss: 1.4130 - val_prob_kld: 0.0747 - val_dist_relevant_mae: 1.4127 - val_dist_relevant_mse: 5.0782 - val_dist_dist_iou_metric: 0.6275 - lr: 1.0000e-04
# Epoch 9/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4453 - prob_loss: 0.1830 - dist_loss: 1.3115 - prob_kld: 0.0686 - dist_relevant_mae: 1.3112 - dist_relev
# 10/10 [==============================] - 4s 418ms/step - loss: 0.4453 - prob_loss: 0.1830 - dist_loss: 1.3115 - prob_kld: 0.0686 - dist_relevant_mae: 1.3112 - dist_relevant_mse: 4.3577 - dist_dist_iou_metric: 0.6402 - val_loss: 0.4888 - val_prob_loss: 0.2079 - val_dist_loss: 1.4048 - val_prob_kld: 0.0740 - val_dist_relevant_mae: 1.4045 - val_dist_relevant_mse: 5.0156 - val_dist_dist_iou_metric: 0.6228 - lr: 1.0000e-04
# Epoch 10/200
# 3/3 [==============================] - 0s 33ms/steploss: 0.4949 - prob_loss: 0.2250 - dist_loss: 1.3498 - prob_kld: 0
# 10/10 [==============================] - 7s 721ms/step - loss: 0.4949 - prob_loss: 0.2250 - dist_loss: 1.3498 - prob_kld: 0.0756 - dist_relevant_mae: 1.3495 - dist_relevant_mse: 4.5312 - dist_dist_iou_metric: 0.6363 - val_loss: 0.4868 - val_prob_loss: 0.2074 - val_dist_loss: 1.3973 - val_prob_kld: 0.0735 - val_dist_relevant_mae: 1.3970 - val_dist_relevant_mse: 4.9769 - val_dist_dist_iou_metric: 0.6217 - lr: 1.0000e-04
# Epoch 11/200
# 3/3 [==============================] - 0s 17ms/steploss: 0.4780 - prob_loss: 0.2005 - dist_loss: 1.3876 - prob_kld: 0.0766 - dist_relevant_mae: 1.3873 - dist_relev
# 10/10 [==============================] - 6s 610ms/step - loss: 0.4780 - prob_loss: 0.2005 - dist_loss: 1.3876 - prob_kld: 0.0766 - dist_relevant_mae: 1.3873 - dist_relevant_mse: 4.8087 - dist_dist_iou_metric: 0.6263 - val_loss: 0.4854 - val_prob_loss: 0.2069 - val_dist_loss: 1.3926 - val_prob_kld: 0.0730 - val_dist_relevant_mae: 1.3923 - val_dist_relevant_mse: 4.9574 - val_dist_dist_iou_metric: 0.6346 - lr: 1.0000e-04
# Epoch 12/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.5212 - prob_loss: 0.2427 - dist_loss: 1.3927 - prob_kld: 0.0833 - dist_relevant_mae: 1.3925 - dist_relev
# 10/10 [==============================] - 4s 449ms/step - loss: 0.5212 - prob_loss: 0.2427 - dist_loss: 1.3927 - prob_kld: 0.0833 - dist_relevant_mae: 1.3925 - dist_relevant_mse: 4.7287 - dist_dist_iou_metric: 0.6287 - val_loss: 0.4831 - val_prob_loss: 0.2065 - val_dist_loss: 1.3832 - val_prob_kld: 0.0726 - val_dist_relevant_mae: 1.3829 - val_dist_relevant_mse: 4.8654 - val_dist_dist_iou_metric: 0.6234 - lr: 1.0000e-04
# Epoch 13/200
# 3/3 [==============================] - 0s 8ms/step loss: 0.4239 - prob_loss: 0.1751 - dist_loss: 1.2445 - prob_kld: 0.0619 - dist_relevant_mae: 1.2442 - dist_relev
# 10/10 [==============================] - 3s 271ms/step - loss: 0.4239 - prob_loss: 0.1751 - dist_loss: 1.2445 - prob_kld: 0.0619 - dist_relevant_mae: 1.2442 - dist_relevant_mse: 3.8768 - dist_dist_iou_metric: 0.6511 - val_loss: 0.4805 - val_prob_loss: 0.2059 - val_dist_loss: 1.3731 - val_prob_kld: 0.0720 - val_dist_relevant_mae: 1.3728 - val_dist_relevant_mse: 4.8369 - val_dist_dist_iou_metric: 0.6297 - lr: 1.0000e-04
# Epoch 14/200
# 3/3 [==============================] - 0s 7ms/step loss: 0.4957 - prob_loss: 0.2244 - dist_loss: 1.3565 - prob_kld: 0.0790 - dist_relevant_mae: 1.3563 - dist_relev
# 10/10 [==============================] - 2s 255ms/step - loss: 0.4957 - prob_loss: 0.2244 - dist_loss: 1.3565 - prob_kld: 0.0790 - dist_relevant_mae: 1.3563 - dist_relevant_mse: 4.5818 - dist_dist_iou_metric: 0.6329 - val_loss: 0.4780 - val_prob_loss: 0.2054 - val_dist_loss: 1.3633 - val_prob_kld: 0.0715 - val_dist_relevant_mae: 1.3630 - val_dist_relevant_mse: 4.7724 - val_dist_dist_iou_metric: 0.6324 - lr: 1.0000e-04
# Epoch 15/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4779 - prob_loss: 0.1982 - dist_loss: 1.3983 - prob_kld: 0.0666 - dist_relevant_mae: 1.3981 - dist_relev
# 10/10 [==============================] - 2s 257ms/step - loss: 0.4779 - prob_loss: 0.1982 - dist_loss: 1.3983 - prob_kld: 0.0666 - dist_relevant_mae: 1.3981 - dist_relevant_mse: 4.9075 - dist_dist_iou_metric: 0.6333 - val_loss: 0.4774 - val_prob_loss: 0.2052 - val_dist_loss: 1.3610 - val_prob_kld: 0.0713 - val_dist_relevant_mae: 1.3607 - val_dist_relevant_mse: 4.7591 - val_dist_dist_iou_metric: 0.6370 - lr: 1.0000e-04
# Epoch 16/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4802 - prob_loss: 0.2150 - dist_loss: 1.3259 - prob_kld: 0.0783 - dist_relevant_mae: 1.3256 - dist_relev
# 10/10 [==============================] - 3s 361ms/step - loss: 0.4802 - prob_loss: 0.2150 - dist_loss: 1.3259 - prob_kld: 0.0783 - dist_relevant_mae: 1.3256 - dist_relevant_mse: 4.3852 - dist_dist_iou_metric: 0.6387 - val_loss: 0.4783 - val_prob_loss: 0.2054 - val_dist_loss: 1.3641 - val_prob_kld: 0.0715 - val_dist_relevant_mae: 1.3639 - val_dist_relevant_mse: 4.7602 - val_dist_dist_iou_metric: 0.6262 - lr: 1.0000e-04
# Epoch 17/200
# 3/3 [==============================] - 0s 27ms/steploss: 0.4641 - prob_loss: 0.2093 - dist_loss: 1.2739 - prob_kld: 0
# 10/10 [==============================] - 3s 352ms/step - loss: 0.4641 - prob_loss: 0.2093 - dist_loss: 1.2739 - prob_kld: 0.0745 - dist_relevant_mae: 1.2736 - dist_relevant_mse: 4.0033 - dist_dist_iou_metric: 0.6493 - val_loss: 0.4743 - val_prob_loss: 0.2045 - val_dist_loss: 1.3493 - val_prob_kld: 0.0706 - val_dist_relevant_mae: 1.3491 - val_dist_relevant_mse: 4.6693 - val_dist_dist_iou_metric: 0.6363 - lr: 1.0000e-04
# Epoch 18/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4707 - prob_loss: 0.2136 - dist_loss: 1.2854 - prob_kld: 0.0719 - dist_relevant_mae: 1.2852 - dist_relev
# 10/10 [==============================] - 5s 508ms/step - loss: 0.4707 - prob_loss: 0.2136 - dist_loss: 1.2854 - prob_kld: 0.0719 - dist_relevant_mae: 1.2852 - dist_relevant_mse: 4.1550 - dist_dist_iou_metric: 0.6476 - val_loss: 0.4731 - val_prob_loss: 0.2041 - val_dist_loss: 1.3450 - val_prob_kld: 0.0702 - val_dist_relevant_mae: 1.3447 - val_dist_relevant_mse: 4.6414 - val_dist_dist_iou_metric: 0.6377 - lr: 1.0000e-04
# Epoch 19/200
# 3/3 [==============================] - 0s 7ms/step loss: 0.4884 - prob_loss: 0.2310 - dist_loss: 1.2869 - prob_kld: 0.0775 - dist_relevant_mae: 1.2866 - dist_relev
# 10/10 [==============================] - 2s 265ms/step - loss: 0.4884 - prob_loss: 0.2310 - dist_loss: 1.2869 - prob_kld: 0.0775 - dist_relevant_mae: 1.2866 - dist_relevant_mse: 4.1449 - dist_dist_iou_metric: 0.6452 - val_loss: 0.4725 - val_prob_loss: 0.2037 - val_dist_loss: 1.3441 - val_prob_kld: 0.0698 - val_dist_relevant_mae: 1.3438 - val_dist_relevant_mse: 4.6483 - val_dist_dist_iou_metric: 0.6408 - lr: 1.0000e-04
# Epoch 20/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4457 - prob_loss: 0.1852 - dist_loss: 1.3028 - prob_kld: 0.0660 - dist_relevant_mae: 1.3025 - dist_relev
# 10/10 [==============================] - 2s 235ms/step - loss: 0.4457 - prob_loss: 0.1852 - dist_loss: 1.3028 - prob_kld: 0.0660 - dist_relevant_mae: 1.3025 - dist_relevant_mse: 4.2776 - dist_dist_iou_metric: 0.6431 - val_loss: 0.4715 - val_prob_loss: 0.2034 - val_dist_loss: 1.3406 - val_prob_kld: 0.0695 - val_dist_relevant_mae: 1.3404 - val_dist_relevant_mse: 4.6080 - val_dist_dist_iou_metric: 0.6360 - lr: 1.0000e-04
# Epoch 21/200
# 3/3 [==============================] - 0s 8ms/step loss: 0.4952 - prob_loss: 0.2290 - dist_loss: 1.3309 - prob_kld: 0.0744 - dist_relevant_mae: 1.3306 - dist_relev
# 10/10 [==============================] - 2s 227ms/step - loss: 0.4952 - prob_loss: 0.2290 - dist_loss: 1.3309 - prob_kld: 0.0744 - dist_relevant_mae: 1.3306 - dist_relevant_mse: 4.5124 - dist_dist_iou_metric: 0.6462 - val_loss: 0.4707 - val_prob_loss: 0.2030 - val_dist_loss: 1.3387 - val_prob_kld: 0.0691 - val_dist_relevant_mae: 1.3385 - val_dist_relevant_mse: 4.6189 - val_dist_dist_iou_metric: 0.6403 - lr: 1.0000e-04
# Epoch 22/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4438 - prob_loss: 0.1929 - dist_loss: 1.2548 - prob_kld: 0.0675 - dist_relevant_mae: 1.2545 - dist_relev
# 10/10 [==============================] - 2s 228ms/step - loss: 0.4438 - prob_loss: 0.1929 - dist_loss: 1.2548 - prob_kld: 0.0675 - dist_relevant_mae: 1.2545 - dist_relevant_mse: 3.9962 - dist_dist_iou_metric: 0.6573 - val_loss: 0.4695 - val_prob_loss: 0.2027 - val_dist_loss: 1.3342 - val_prob_kld: 0.0688 - val_dist_relevant_mae: 1.3339 - val_dist_relevant_mse: 4.5764 - val_dist_dist_iou_metric: 0.6372 - lr: 1.0000e-04
# Epoch 23/200
# 3/3 [==============================] - 0s 20ms/steploss: 0.4968 - prob_loss: 0.2346 - dist_loss: 1.3106 - prob_kld: 0.0793 - dist_relevant_mae: 1.3103 - dist_relev
# 10/10 [==============================] - 2s 249ms/step - loss: 0.4968 - prob_loss: 0.2346 - dist_loss: 1.3106 - prob_kld: 0.0793 - dist_relevant_mae: 1.3103 - dist_relevant_mse: 4.3618 - dist_dist_iou_metric: 0.6450 - val_loss: 0.4698 - val_prob_loss: 0.2027 - val_dist_loss: 1.3356 - val_prob_kld: 0.0688 - val_dist_relevant_mae: 1.3354 - val_dist_relevant_mse: 4.6024 - val_dist_dist_iou_metric: 0.6342 - lr: 1.0000e-04
# Epoch 24/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4270 - prob_loss: 0.1811 - dist_loss: 1.2295 - prob_kld: 0.0607 - dist_relevant_mae: 1.2292 - dist_relev
# 10/10 [==============================] - 2s 217ms/step - loss: 0.4270 - prob_loss: 0.1811 - dist_loss: 1.2295 - prob_kld: 0.0607 - dist_relevant_mae: 1.2292 - dist_relevant_mse: 3.8091 - dist_dist_iou_metric: 0.6593 - val_loss: 0.4687 - val_prob_loss: 0.2025 - val_dist_loss: 1.3311 - val_prob_kld: 0.0686 - val_dist_relevant_mae: 1.3309 - val_dist_relevant_mse: 4.5668 - val_dist_dist_iou_metric: 0.6457 - lr: 1.0000e-04
# Epoch 25/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4625 - prob_loss: 0.2067 - dist_loss: 1.2790 - prob_kld: 0.0720 - dist_relevant_mae: 1.2787 - dist_relev
# 10/10 [==============================] - 2s 245ms/step - loss: 0.4625 - prob_loss: 0.2067 - dist_loss: 1.2790 - prob_kld: 0.0720 - dist_relevant_mae: 1.2787 - dist_relevant_mse: 4.1273 - dist_dist_iou_metric: 0.6450 - val_loss: 0.4684 - val_prob_loss: 0.2021 - val_dist_loss: 1.3314 - val_prob_kld: 0.0682 - val_dist_relevant_mae: 1.3311 - val_dist_relevant_mse: 4.5715 - val_dist_dist_iou_metric: 0.6350 - lr: 1.0000e-04
# Epoch 26/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4618 - prob_loss: 0.2014 - dist_loss: 1.3023 - prob_kld: 0.0658 - dist_relevant_mae: 1.3021 - dist_relev
# 10/10 [==============================] - 2s 252ms/step - loss: 0.4618 - prob_loss: 0.2014 - dist_loss: 1.3023 - prob_kld: 0.0658 - dist_relevant_mae: 1.3021 - dist_relevant_mse: 4.3206 - dist_dist_iou_metric: 0.6563 - val_loss: 0.4667 - val_prob_loss: 0.2019 - val_dist_loss: 1.3240 - val_prob_kld: 0.0680 - val_dist_relevant_mae: 1.3237 - val_dist_relevant_mse: 4.5445 - val_dist_dist_iou_metric: 0.6390 - lr: 1.0000e-04
# Epoch 27/200
# 3/3 [==============================] - 0s 7ms/step loss: 0.4641 - prob_loss: 0.2084 - dist_loss: 1.2788 - prob_kld: 0.0712 - dist_relevant_mae: 1.2786 - dist_relev
# 10/10 [==============================] - 3s 290ms/step - loss: 0.4641 - prob_loss: 0.2084 - dist_loss: 1.2788 - prob_kld: 0.0712 - dist_relevant_mae: 1.2786 - dist_relevant_mse: 4.0574 - dist_dist_iou_metric: 0.6446 - val_loss: 0.4660 - val_prob_loss: 0.2017 - val_dist_loss: 1.3218 - val_prob_kld: 0.0678 - val_dist_relevant_mae: 1.3215 - val_dist_relevant_mse: 4.5288 - val_dist_dist_iou_metric: 0.6422 - lr: 1.0000e-04
# Epoch 28/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4141 - prob_loss: 0.1745 - dist_loss: 1.1982 - prob_kld: 0.0540 - dist_relevant_mae: 1.1979 - dist_relev
# 10/10 [==============================] - 3s 292ms/step - loss: 0.4141 - prob_loss: 0.1745 - dist_loss: 1.1982 - prob_kld: 0.0540 - dist_relevant_mae: 1.1979 - dist_relevant_mse: 3.7351 - dist_dist_iou_metric: 0.6703 - val_loss: 0.4659 - val_prob_loss: 0.2015 - val_dist_loss: 1.3217 - val_prob_kld: 0.0676 - val_dist_relevant_mae: 1.3214 - val_dist_relevant_mse: 4.5468 - val_dist_dist_iou_metric: 0.6436 - lr: 1.0000e-04
# Epoch 29/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4867 - prob_loss: 0.2231 - dist_loss: 1.3179 - prob_kld: 0.0791 - dist_relevant_mae: 1.3176 - dist_relev
# 10/10 [==============================] - 3s 310ms/step - loss: 0.4867 - prob_loss: 0.2231 - dist_loss: 1.3179 - prob_kld: 0.0791 - dist_relevant_mae: 1.3176 - dist_relevant_mse: 4.3359 - dist_dist_iou_metric: 0.6441 - val_loss: 0.4658 - val_prob_loss: 0.2019 - val_dist_loss: 1.3195 - val_prob_kld: 0.0680 - val_dist_relevant_mae: 1.3192 - val_dist_relevant_mse: 4.5327 - val_dist_dist_iou_metric: 0.6410 - lr: 1.0000e-04
# Epoch 30/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4702 - prob_loss: 0.2138 - dist_loss: 1.2822 - prob_kld: 0.0759 - dist_relevant_mae: 1.2819 - dist_relev
# 10/10 [==============================] - 4s 429ms/step - loss: 0.4702 - prob_loss: 0.2138 - dist_loss: 1.2822 - prob_kld: 0.0759 - dist_relevant_mae: 1.2819 - dist_relevant_mse: 4.0951 - dist_dist_iou_metric: 0.6369 - val_loss: 0.4647 - val_prob_loss: 0.2011 - val_dist_loss: 1.3176 - val_prob_kld: 0.0673 - val_dist_relevant_mae: 1.3173 - val_dist_relevant_mse: 4.5107 - val_dist_dist_iou_metric: 0.6419 - lr: 1.0000e-04
# Epoch 31/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4618 - prob_loss: 0.2134 - dist_loss: 1.2417 - prob_kld: 0.0654 - dist_relevant_mae: 1.2415 - dist_relev
# 10/10 [==============================] - 2s 259ms/step - loss: 0.4618 - prob_loss: 0.2134 - dist_loss: 1.2417 - prob_kld: 0.0654 - dist_relevant_mae: 1.2415 - dist_relevant_mse: 3.8879 - dist_dist_iou_metric: 0.6589 - val_loss: 0.4643 - val_prob_loss: 0.2010 - val_dist_loss: 1.3167 - val_prob_kld: 0.0671 - val_dist_relevant_mae: 1.3165 - val_dist_relevant_mse: 4.5210 - val_dist_dist_iou_metric: 0.6407 - lr: 1.0000e-04
# Epoch 32/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4521 - prob_loss: 0.2049 - dist_loss: 1.2360 - prob_kld: 0.0690 - dist_relevant_mae: 1.2358 - dist_relev
# 10/10 [==============================] - 2s 229ms/step - loss: 0.4521 - prob_loss: 0.2049 - dist_loss: 1.2360 - prob_kld: 0.0690 - dist_relevant_mae: 1.2358 - dist_relevant_mse: 3.8993 - dist_dist_iou_metric: 0.6558 - val_loss: 0.4631 - val_prob_loss: 0.2005 - val_dist_loss: 1.3131 - val_prob_kld: 0.0666 - val_dist_relevant_mae: 1.3128 - val_dist_relevant_mse: 4.4848 - val_dist_dist_iou_metric: 0.6454 - lr: 1.0000e-04
# Epoch 33/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4261 - prob_loss: 0.1789 - dist_loss: 1.2358 - prob_kld: 0.0629 - dist_relevant_mae: 1.2356 - dist_relev
# 10/10 [==============================] - 3s 357ms/step - loss: 0.4261 - prob_loss: 0.1789 - dist_loss: 1.2358 - prob_kld: 0.0629 - dist_relevant_mae: 1.2356 - dist_relevant_mse: 3.9118 - dist_dist_iou_metric: 0.6544 - val_loss: 0.4629 - val_prob_loss: 0.2005 - val_dist_loss: 1.3117 - val_prob_kld: 0.0666 - val_dist_relevant_mae: 1.3115 - val_dist_relevant_mse: 4.4913 - val_dist_dist_iou_metric: 0.6413 - lr: 1.0000e-04
# Epoch 34/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4602 - prob_loss: 0.2133 - dist_loss: 1.2344 - prob_kld: 0.0666 - dist_relevant_mae: 1.2341 - dist_relev
# 10/10 [==============================] - 5s 511ms/step - loss: 0.4602 - prob_loss: 0.2133 - dist_loss: 1.2344 - prob_kld: 0.0666 - dist_relevant_mae: 1.2341 - dist_relevant_mse: 3.8800 - dist_dist_iou_metric: 0.6659 - val_loss: 0.4636 - val_prob_loss: 0.2005 - val_dist_loss: 1.3153 - val_prob_kld: 0.0666 - val_dist_relevant_mae: 1.3151 - val_dist_relevant_mse: 4.4999 - val_dist_dist_iou_metric: 0.6441 - lr: 1.0000e-04
# Epoch 35/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4886 - prob_loss: 0.2318 - dist_loss: 1.2842 - prob_kld: 0.0765 - dist_relevant_mae: 1.2840 - dist_relev
# 10/10 [==============================] - 4s 390ms/step - loss: 0.4886 - prob_loss: 0.2318 - dist_loss: 1.2842 - prob_kld: 0.0765 - dist_relevant_mae: 1.2840 - dist_relevant_mse: 4.1837 - dist_dist_iou_metric: 0.6425 - val_loss: 0.4610 - val_prob_loss: 0.1999 - val_dist_loss: 1.3058 - val_prob_kld: 0.0660 - val_dist_relevant_mae: 1.3056 - val_dist_relevant_mse: 4.4490 - val_dist_dist_iou_metric: 0.6452 - lr: 1.0000e-04
# Epoch 36/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4341 - prob_loss: 0.1898 - dist_loss: 1.2218 - prob_kld: 0.0635 - dist_relevant_mae: 1.2216 - dist_relev
# 10/10 [==============================] - 3s 336ms/step - loss: 0.4341 - prob_loss: 0.1898 - dist_loss: 1.2218 - prob_kld: 0.0635 - dist_relevant_mae: 1.2216 - dist_relevant_mse: 3.7527 - dist_dist_iou_metric: 0.6543 - val_loss: 0.4611 - val_prob_loss: 0.1999 - val_dist_loss: 1.3062 - val_prob_kld: 0.0660 - val_dist_relevant_mae: 1.3060 - val_dist_relevant_mse: 4.4318 - val_dist_dist_iou_metric: 0.6448 - lr: 1.0000e-04
# Epoch 37/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4366 - prob_loss: 0.1974 - dist_loss: 1.1958 - prob_kld: 0.0654 - dist_relevant_mae: 1.1956 - dist_relev
# 10/10 [==============================] - 3s 353ms/step - loss: 0.4366 - prob_loss: 0.1974 - dist_loss: 1.1958 - prob_kld: 0.0654 - dist_relevant_mae: 1.1956 - dist_relevant_mse: 3.5292 - dist_dist_iou_metric: 0.6680 - val_loss: 0.4609 - val_prob_loss: 0.1996 - val_dist_loss: 1.3064 - val_prob_kld: 0.0657 - val_dist_relevant_mae: 1.3061 - val_dist_relevant_mse: 4.4664 - val_dist_dist_iou_metric: 0.6427 - lr: 1.0000e-04
# Epoch 38/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4557 - prob_loss: 0.2039 - dist_loss: 1.2586 - prob_kld: 0.0652 - dist_relevant_mae: 1.2584 - dist_relev
# 10/10 [==============================] - 3s 277ms/step - loss: 0.4557 - prob_loss: 0.2039 - dist_loss: 1.2586 - prob_kld: 0.0652 - dist_relevant_mae: 1.2584 - dist_relevant_mse: 4.0846 - dist_dist_iou_metric: 0.6513 - val_loss: 0.4594 - val_prob_loss: 0.1993 - val_dist_loss: 1.3005 - val_prob_kld: 0.0654 - val_dist_relevant_mae: 1.3003 - val_dist_relevant_mse: 4.4248 - val_dist_dist_iou_metric: 0.6466 - lr: 1.0000e-04
# Epoch 39/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4372 - prob_loss: 0.1971 - dist_loss: 1.2005 - prob_kld: 0.0640 - dist_relevant_mae: 1.2002 - dist_relev
# 10/10 [==============================] - 3s 301ms/step - loss: 0.4372 - prob_loss: 0.1971 - dist_loss: 1.2005 - prob_kld: 0.0640 - dist_relevant_mae: 1.2002 - dist_relevant_mse: 3.6319 - dist_dist_iou_metric: 0.6626 - val_loss: 0.4594 - val_prob_loss: 0.1992 - val_dist_loss: 1.3008 - val_prob_kld: 0.0653 - val_dist_relevant_mae: 1.3005 - val_dist_relevant_mse: 4.4158 - val_dist_dist_iou_metric: 0.6469 - lr: 1.0000e-04
# Epoch 40/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4390 - prob_loss: 0.1953 - dist_loss: 1.2187 - prob_kld: 0.0599 - dist_relevant_mae: 1.2185 - dist_relev
# 10/10 [==============================] - 3s 283ms/step - loss: 0.4390 - prob_loss: 0.1953 - dist_loss: 1.2187 - prob_kld: 0.0599 - dist_relevant_mae: 1.2185 - dist_relevant_mse: 3.8111 - dist_dist_iou_metric: 0.6706 - val_loss: 0.4605 - val_prob_loss: 0.1993 - val_dist_loss: 1.3063 - val_prob_kld: 0.0654 - val_dist_relevant_mae: 1.3061 - val_dist_relevant_mse: 4.4751 - val_dist_dist_iou_metric: 0.6402 - lr: 1.0000e-04
# Epoch 41/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4724 - prob_loss: 0.2229 - dist_loss: 1.2479 - prob_kld: 0.0724 - dist_relevant_mae: 1.2476 - dist_relev
# 10/10 [==============================] - 3s 276ms/step - loss: 0.4724 - prob_loss: 0.2229 - dist_loss: 1.2479 - prob_kld: 0.0724 - dist_relevant_mae: 1.2476 - dist_relevant_mse: 3.9791 - dist_dist_iou_metric: 0.6447 - val_loss: 0.4577 - val_prob_loss: 0.1988 - val_dist_loss: 1.2943 - val_prob_kld: 0.0649 - val_dist_relevant_mae: 1.2940 - val_dist_relevant_mse: 4.3812 - val_dist_dist_iou_metric: 0.6474 - lr: 1.0000e-04
# Epoch 42/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.4493 - prob_loss: 0.1989 - dist_loss: 1.2518 - prob_kld: 0.0677 - dist_relevant_mae: 1.2516 - dist_relev
# 10/10 [==============================] - 3s 299ms/step - loss: 0.4493 - prob_loss: 0.1989 - dist_loss: 1.2518 - prob_kld: 0.0677 - dist_relevant_mae: 1.2516 - dist_relevant_mse: 3.9409 - dist_dist_iou_metric: 0.6600 - val_loss: 0.4583 - val_prob_loss: 0.1987 - val_dist_loss: 1.2977 - val_prob_kld: 0.0649 - val_dist_relevant_mae: 1.2975 - val_dist_relevant_mse: 4.4022 - val_dist_dist_iou_metric: 0.6432 - lr: 1.0000e-04
# Epoch 43/200
# 3/3 [==============================] - 0s 8ms/step loss: 0.4385 - prob_loss: 0.1980 - dist_loss: 1.2025 - prob_kld: 0.0612 - dist_relevant_mae: 1.2022 - dist_relev
# 10/10 [==============================] - 5s 504ms/step - loss: 0.4385 - prob_loss: 0.1980 - dist_loss: 1.2025 - prob_kld: 0.0612 - dist_relevant_mae: 1.2022 - dist_relevant_mse: 3.7043 - dist_dist_iou_metric: 0.6647 - val_loss: 0.4582 - val_prob_loss: 0.1985 - val_dist_loss: 1.2981 - val_prob_kld: 0.0647 - val_dist_relevant_mae: 1.2978 - val_dist_relevant_mse: 4.4109 - val_dist_dist_iou_metric: 0.6450 - lr: 1.0000e-04
# Epoch 44/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4660 - prob_loss: 0.2158 - dist_loss: 1.2508 - prob_kld: 0.0698 - dist_relevant_mae: 1.2505 - dist_relev
# 10/10 [==============================] - 3s 266ms/step - loss: 0.4660 - prob_loss: 0.2158 - dist_loss: 1.2508 - prob_kld: 0.0698 - dist_relevant_mae: 1.2505 - dist_relevant_mse: 3.9291 - dist_dist_iou_metric: 0.6526 - val_loss: 0.4567 - val_prob_loss: 0.1982 - val_dist_loss: 1.2929 - val_prob_kld: 0.0643 - val_dist_relevant_mae: 1.2927 - val_dist_relevant_mse: 4.3850 - val_dist_dist_iou_metric: 0.6488 - lr: 1.0000e-04
# Epoch 45/200
# 3/3 [==============================] - 0s 7ms/step loss: 0.4285 - prob_loss: 0.1899 - dist_loss: 1.1931 - prob_kld: 0.0612 - dist_relevant_mae: 1.1928 - dist_relev
# 10/10 [==============================] - 4s 416ms/step - loss: 0.4285 - prob_loss: 0.1899 - dist_loss: 1.1931 - prob_kld: 0.0612 - dist_relevant_mae: 1.1928 - dist_relevant_mse: 3.5966 - dist_dist_iou_metric: 0.6605 - val_loss: 0.4561 - val_prob_loss: 0.1980 - val_dist_loss: 1.2902 - val_prob_kld: 0.0642 - val_dist_relevant_mae: 1.2899 - val_dist_relevant_mse: 4.3541 - val_dist_dist_iou_metric: 0.6481 - lr: 1.0000e-04
# Epoch 46/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4531 - prob_loss: 0.1991 - dist_loss: 1.2701 - prob_kld: 0.0635 - dist_relevant_mae: 1.2698 - dist_relev
# 10/10 [==============================] - 6s 607ms/step - loss: 0.4531 - prob_loss: 0.1991 - dist_loss: 1.2701 - prob_kld: 0.0635 - dist_relevant_mae: 1.2698 - dist_relevant_mse: 4.1120 - dist_dist_iou_metric: 0.6564 - val_loss: 0.4565 - val_prob_loss: 0.1979 - val_dist_loss: 1.2930 - val_prob_kld: 0.0640 - val_dist_relevant_mae: 1.2927 - val_dist_relevant_mse: 4.4021 - val_dist_dist_iou_metric: 0.6448 - lr: 1.0000e-04
# Epoch 47/200
# 3/3 [==============================] - 0s 7ms/step loss: 0.4396 - prob_loss: 0.2060 - dist_loss: 1.1678 - prob_kld: 0.0662 - dist_relevant_mae: 1.1676 - dist_relev
# 10/10 [==============================] - 5s 525ms/step - loss: 0.4396 - prob_loss: 0.2060 - dist_loss: 1.1678 - prob_kld: 0.0662 - dist_relevant_mae: 1.1676 - dist_relevant_mse: 3.4379 - dist_dist_iou_metric: 0.6576 - val_loss: 0.4551 - val_prob_loss: 0.1977 - val_dist_loss: 1.2873 - val_prob_kld: 0.0638 - val_dist_relevant_mae: 1.2870 - val_dist_relevant_mse: 4.3607 - val_dist_dist_iou_metric: 0.6484 - lr: 1.0000e-04
# Epoch 48/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4306 - prob_loss: 0.1916 - dist_loss: 1.1951 - prob_kld: 0.0595 - dist_relevant_mae: 1.1949 - dist_relev
# 10/10 [==============================] - 2s 230ms/step - loss: 0.4306 - prob_loss: 0.1916 - dist_loss: 1.1951 - prob_kld: 0.0595 - dist_relevant_mae: 1.1949 - dist_relevant_mse: 3.6662 - dist_dist_iou_metric: 0.6733 - val_loss: 0.4546 - val_prob_loss: 0.1975 - val_dist_loss: 1.2858 - val_prob_kld: 0.0636 - val_dist_relevant_mae: 1.2855 - val_dist_relevant_mse: 4.3455 - val_dist_dist_iou_metric: 0.6475 - lr: 1.0000e-04
# Epoch 49/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4371 - prob_loss: 0.1908 - dist_loss: 1.2314 - prob_kld: 0.0603 - dist_relevant_mae: 1.2311 - dist_relev
# 10/10 [==============================] - 2s 228ms/step - loss: 0.4371 - prob_loss: 0.1908 - dist_loss: 1.2314 - prob_kld: 0.0603 - dist_relevant_mae: 1.2311 - dist_relevant_mse: 3.9736 - dist_dist_iou_metric: 0.6678 - val_loss: 0.4545 - val_prob_loss: 0.1974 - val_dist_loss: 1.2856 - val_prob_kld: 0.0635 - val_dist_relevant_mae: 1.2853 - val_dist_relevant_mse: 4.3379 - val_dist_dist_iou_metric: 0.6463 - lr: 1.0000e-04
# Epoch 50/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4422 - prob_loss: 0.1956 - dist_loss: 1.2328 - prob_kld: 0.0620 - dist_relevant_mae: 1.2326 - dist_relev
# 10/10 [==============================] - 2s 221ms/step - loss: 0.4422 - prob_loss: 0.1956 - dist_loss: 1.2328 - prob_kld: 0.0620 - dist_relevant_mae: 1.2326 - dist_relevant_mse: 3.8867 - dist_dist_iou_metric: 0.6634 - val_loss: 0.4551 - val_prob_loss: 0.1978 - val_dist_loss: 1.2865 - val_prob_kld: 0.0639 - val_dist_relevant_mae: 1.2862 - val_dist_relevant_mse: 4.3470 - val_dist_dist_iou_metric: 0.6503 - lr: 1.0000e-04
# Epoch 51/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4751 - prob_loss: 0.2280 - dist_loss: 1.2355 - prob_kld: 0.0718 - dist_relevant_mae: 1.2353 - dist_relev
# 10/10 [==============================] - 2s 232ms/step - loss: 0.4751 - prob_loss: 0.2280 - dist_loss: 1.2355 - prob_kld: 0.0718 - dist_relevant_mae: 1.2353 - dist_relevant_mse: 3.9030 - dist_dist_iou_metric: 0.6531 - val_loss: 0.4539 - val_prob_loss: 0.1969 - val_dist_loss: 1.2850 - val_prob_kld: 0.0630 - val_dist_relevant_mae: 1.2848 - val_dist_relevant_mse: 4.3449 - val_dist_dist_iou_metric: 0.6474 - lr: 1.0000e-04
# Epoch 52/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4093 - prob_loss: 0.1783 - dist_loss: 1.1554 - prob_kld: 0.0589 - dist_relevant_mae: 1.1551 - dist_relev
# 10/10 [==============================] - 2s 225ms/step - loss: 0.4093 - prob_loss: 0.1783 - dist_loss: 1.1554 - prob_kld: 0.0589 - dist_relevant_mae: 1.1551 - dist_relevant_mse: 3.3601 - dist_dist_iou_metric: 0.6636 - val_loss: 0.4530 - val_prob_loss: 0.1970 - val_dist_loss: 1.2801 - val_prob_kld: 0.0631 - val_dist_relevant_mae: 1.2799 - val_dist_relevant_mse: 4.2993 - val_dist_dist_iou_metric: 0.6528 - lr: 1.0000e-04
# Epoch 53/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4393 - prob_loss: 0.1993 - dist_loss: 1.2000 - prob_kld: 0.0572 - dist_relevant_mae: 1.1998 - dist_relev
# 10/10 [==============================] - 2s 227ms/step - loss: 0.4393 - prob_loss: 0.1993 - dist_loss: 1.2000 - prob_kld: 0.0572 - dist_relevant_mae: 1.1998 - dist_relevant_mse: 3.7520 - dist_dist_iou_metric: 0.6732 - val_loss: 0.4532 - val_prob_loss: 0.1969 - val_dist_loss: 1.2817 - val_prob_kld: 0.0630 - val_dist_relevant_mae: 1.2814 - val_dist_relevant_mse: 4.3213 - val_dist_dist_iou_metric: 0.6496 - lr: 1.0000e-04
# Epoch 54/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4487 - prob_loss: 0.2154 - dist_loss: 1.1669 - prob_kld: 0.0693 - dist_relevant_mae: 1.1666 - dist_relev
# 10/10 [==============================] - 2s 237ms/step - loss: 0.4487 - prob_loss: 0.2154 - dist_loss: 1.1669 - prob_kld: 0.0693 - dist_relevant_mae: 1.1666 - dist_relevant_mse: 3.4314 - dist_dist_iou_metric: 0.6684 - val_loss: 0.4526 - val_prob_loss: 0.1968 - val_dist_loss: 1.2791 - val_prob_kld: 0.0629 - val_dist_relevant_mae: 1.2789 - val_dist_relevant_mse: 4.2956 - val_dist_dist_iou_metric: 0.6482 - lr: 1.0000e-04
# Epoch 55/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4515 - prob_loss: 0.2082 - dist_loss: 1.2165 - prob_kld: 0.0632 - dist_relevant_mae: 1.2162 - dist_relev
# 10/10 [==============================] - 2s 246ms/step - loss: 0.4515 - prob_loss: 0.2082 - dist_loss: 1.2165 - prob_kld: 0.0632 - dist_relevant_mae: 1.2162 - dist_relevant_mse: 3.8716 - dist_dist_iou_metric: 0.6711 - val_loss: 0.4516 - val_prob_loss: 0.1964 - val_dist_loss: 1.2762 - val_prob_kld: 0.0625 - val_dist_relevant_mae: 1.2760 - val_dist_relevant_mse: 4.2853 - val_dist_dist_iou_metric: 0.6515 - lr: 1.0000e-04
# Epoch 56/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4545 - prob_loss: 0.2201 - dist_loss: 1.1720 - prob_kld: 0.0672 - dist_relevant_mae: 1.1718 - dist_relev
# 10/10 [==============================] - 2s 221ms/step - loss: 0.4545 - prob_loss: 0.2201 - dist_loss: 1.1720 - prob_kld: 0.0672 - dist_relevant_mae: 1.1718 - dist_relevant_mse: 3.4676 - dist_dist_iou_metric: 0.6679 - val_loss: 0.4526 - val_prob_loss: 0.1963 - val_dist_loss: 1.2813 - val_prob_kld: 0.0624 - val_dist_relevant_mae: 1.2811 - val_dist_relevant_mse: 4.3143 - val_dist_dist_iou_metric: 0.6475 - lr: 1.0000e-04
# Epoch 57/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4456 - prob_loss: 0.2074 - dist_loss: 1.1912 - prob_kld: 0.0678 - dist_relevant_mae: 1.1910 - dist_relev
# 10/10 [==============================] - 2s 243ms/step - loss: 0.4456 - prob_loss: 0.2074 - dist_loss: 1.1912 - prob_kld: 0.0678 - dist_relevant_mae: 1.1910 - dist_relevant_mse: 3.6032 - dist_dist_iou_metric: 0.6572 - val_loss: 0.4511 - val_prob_loss: 0.1961 - val_dist_loss: 1.2752 - val_prob_kld: 0.0622 - val_dist_relevant_mae: 1.2749 - val_dist_relevant_mse: 4.2787 - val_dist_dist_iou_metric: 0.6508 - lr: 1.0000e-04
# Epoch 58/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.3908 - prob_loss: 0.1618 - dist_loss: 1.1450 - prob_kld: 0.0484 - dist_relevant_mae: 1.1447 - dist_relev
# 10/10 [==============================] - 2s 206ms/step - loss: 0.3908 - prob_loss: 0.1618 - dist_loss: 1.1450 - prob_kld: 0.0484 - dist_relevant_mae: 1.1447 - dist_relevant_mse: 3.3944 - dist_dist_iou_metric: 0.6921 - val_loss: 0.4514 - val_prob_loss: 0.1963 - val_dist_loss: 1.2758 - val_prob_kld: 0.0624 - val_dist_relevant_mae: 1.2756 - val_dist_relevant_mse: 4.2916 - val_dist_dist_iou_metric: 0.6509 - lr: 1.0000e-04
# Epoch 59/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4311 - prob_loss: 0.1878 - dist_loss: 1.2165 - prob_kld: 0.0562 - dist_relevant_mae: 1.2162 - dist_relev
# 10/10 [==============================] - 2s 227ms/step - loss: 0.4311 - prob_loss: 0.1878 - dist_loss: 1.2165 - prob_kld: 0.0562 - dist_relevant_mae: 1.2162 - dist_relevant_mse: 3.8257 - dist_dist_iou_metric: 0.6702 - val_loss: 0.4504 - val_prob_loss: 0.1960 - val_dist_loss: 1.2718 - val_prob_kld: 0.0621 - val_dist_relevant_mae: 1.2715 - val_dist_relevant_mse: 4.2501 - val_dist_dist_iou_metric: 0.6508 - lr: 1.0000e-04
# Epoch 60/200
# 3/3 [==============================] - 0s 12ms/steploss: 0.4387 - prob_loss: 0.1995 - dist_loss: 1.1963 - prob_kld: 0.0608 - dist_relevant_mae: 1.1960 - dist_relev
# 10/10 [==============================] - 2s 233ms/step - loss: 0.4387 - prob_loss: 0.1995 - dist_loss: 1.1963 - prob_kld: 0.0608 - dist_relevant_mae: 1.1960 - dist_relevant_mse: 3.7149 - dist_dist_iou_metric: 0.6702 - val_loss: 0.4505 - val_prob_loss: 0.1958 - val_dist_loss: 1.2737 - val_prob_kld: 0.0619 - val_dist_relevant_mae: 1.2735 - val_dist_relevant_mse: 4.2887 - val_dist_dist_iou_metric: 0.6492 - lr: 1.0000e-04
# Epoch 61/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4468 - prob_loss: 0.2101 - dist_loss: 1.1834 - prob_kld: 0.0674 - dist_relevant_mae: 1.1831 - dist_relev
# 10/10 [==============================] - 3s 267ms/step - loss: 0.4468 - prob_loss: 0.2101 - dist_loss: 1.1834 - prob_kld: 0.0674 - dist_relevant_mae: 1.1831 - dist_relevant_mse: 3.4769 - dist_dist_iou_metric: 0.6553 - val_loss: 0.4497 - val_prob_loss: 0.1956 - val_dist_loss: 1.2703 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.2701 - val_dist_relevant_mse: 4.2512 - val_dist_dist_iou_metric: 0.6533 - lr: 1.0000e-04
# Epoch 62/200
# 3/3 [==============================] - 0s 3ms/step loss: 0.4361 - prob_loss: 0.1860 - dist_loss: 1.2506 - prob_kld: 0.0562 - dist_relevant_mae: 1.2503 - dist_relev
# 10/10 [==============================] - 2s 218ms/step - loss: 0.4361 - prob_loss: 0.1860 - dist_loss: 1.2506 - prob_kld: 0.0562 - dist_relevant_mae: 1.2503 - dist_relevant_mse: 4.0362 - dist_dist_iou_metric: 0.6672 - val_loss: 0.4498 - val_prob_loss: 0.1956 - val_dist_loss: 1.2713 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.2710 - val_dist_relevant_mse: 4.2653 - val_dist_dist_iou_metric: 0.6519 - lr: 1.0000e-04
# Epoch 63/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4418 - prob_loss: 0.2093 - dist_loss: 1.1623 - prob_kld: 0.0642 - dist_relevant_mae: 1.1621 - dist_relev
# 10/10 [==============================] - 2s 236ms/step - loss: 0.4418 - prob_loss: 0.2093 - dist_loss: 1.1623 - prob_kld: 0.0642 - dist_relevant_mae: 1.1621 - dist_relevant_mse: 3.4666 - dist_dist_iou_metric: 0.6727 - val_loss: 0.4485 - val_prob_loss: 0.1953 - val_dist_loss: 1.2662 - val_prob_kld: 0.0614 - val_dist_relevant_mae: 1.2660 - val_dist_relevant_mse: 4.2290 - val_dist_dist_iou_metric: 0.6511 - lr: 1.0000e-04
# Epoch 64/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4459 - prob_loss: 0.2023 - dist_loss: 1.2179 - prob_kld: 0.0619 - dist_relevant_mae: 1.2176 - dist_relev
# 10/10 [==============================] - 2s 229ms/step - loss: 0.4459 - prob_loss: 0.2023 - dist_loss: 1.2179 - prob_kld: 0.0619 - dist_relevant_mae: 1.2176 - dist_relevant_mse: 3.7452 - dist_dist_iou_metric: 0.6624 - val_loss: 0.4487 - val_prob_loss: 0.1953 - val_dist_loss: 1.2673 - val_prob_kld: 0.0614 - val_dist_relevant_mae: 1.2671 - val_dist_relevant_mse: 4.2426 - val_dist_dist_iou_metric: 0.6513 - lr: 1.0000e-04
# Epoch 65/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4421 - prob_loss: 0.2085 - dist_loss: 1.1682 - prob_kld: 0.0627 - dist_relevant_mae: 1.1680 - dist_relev
# 10/10 [==============================] - 2s 246ms/step - loss: 0.4421 - prob_loss: 0.2085 - dist_loss: 1.1682 - prob_kld: 0.0627 - dist_relevant_mae: 1.1680 - dist_relevant_mse: 3.5269 - dist_dist_iou_metric: 0.6705 - val_loss: 0.4483 - val_prob_loss: 0.1952 - val_dist_loss: 1.2657 - val_prob_kld: 0.0613 - val_dist_relevant_mae: 1.2655 - val_dist_relevant_mse: 4.2318 - val_dist_dist_iou_metric: 0.6513 - lr: 1.0000e-04
# Epoch 66/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4104 - prob_loss: 0.1855 - dist_loss: 1.1242 - prob_kld: 0.0580 - dist_relevant_mae: 1.1239 - dist_relev
# 10/10 [==============================] - 2s 227ms/step - loss: 0.4104 - prob_loss: 0.1855 - dist_loss: 1.1242 - prob_kld: 0.0580 - dist_relevant_mae: 1.1239 - dist_relevant_mse: 3.2174 - dist_dist_iou_metric: 0.6807 - val_loss: 0.4480 - val_prob_loss: 0.1951 - val_dist_loss: 1.2646 - val_prob_kld: 0.0612 - val_dist_relevant_mae: 1.2643 - val_dist_relevant_mse: 4.2110 - val_dist_dist_iou_metric: 0.6503 - lr: 1.0000e-04
# Epoch 67/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4188 - prob_loss: 0.1841 - dist_loss: 1.1738 - prob_kld: 0.0547 - dist_relevant_mae: 1.1735 - dist_relev
# 10/10 [==============================] - 2s 211ms/step - loss: 0.4188 - prob_loss: 0.1841 - dist_loss: 1.1738 - prob_kld: 0.0547 - dist_relevant_mae: 1.1735 - dist_relevant_mse: 3.5331 - dist_dist_iou_metric: 0.6752 - val_loss: 0.4497 - val_prob_loss: 0.1952 - val_dist_loss: 1.2726 - val_prob_kld: 0.0613 - val_dist_relevant_mae: 1.2724 - val_dist_relevant_mse: 4.2719 - val_dist_dist_iou_metric: 0.6453 - lr: 1.0000e-04
# Epoch 68/200
# 3/3 [==============================] - 0s 7ms/step loss: 0.4328 - prob_loss: 0.2068 - dist_loss: 1.1299 - prob_kld: 0.0639 - dist_relevant_mae: 1.1297 - dist_relev
# 10/10 [==============================] - 2s 223ms/step - loss: 0.4328 - prob_loss: 0.2068 - dist_loss: 1.1299 - prob_kld: 0.0639 - dist_relevant_mae: 1.1297 - dist_relevant_mse: 3.2288 - dist_dist_iou_metric: 0.6752 - val_loss: 0.4484 - val_prob_loss: 0.1953 - val_dist_loss: 1.2657 - val_prob_kld: 0.0614 - val_dist_relevant_mae: 1.2654 - val_dist_relevant_mse: 4.2268 - val_dist_dist_iou_metric: 0.6479 - lr: 1.0000e-04
# Epoch 69/200
# 3/3 [==============================] - 0s 7ms/step loss: 0.4345 - prob_loss: 0.1992 - dist_loss: 1.1766 - prob_kld: 0.0587 - dist_relevant_mae: 1.1763 - dist_relev
# 10/10 [==============================] - 3s 290ms/step - loss: 0.4345 - prob_loss: 0.1992 - dist_loss: 1.1766 - prob_kld: 0.0587 - dist_relevant_mae: 1.1763 - dist_relevant_mse: 3.5958 - dist_dist_iou_metric: 0.6764 - val_loss: 0.4479 - val_prob_loss: 0.1948 - val_dist_loss: 1.2652 - val_prob_kld: 0.0609 - val_dist_relevant_mae: 1.2650 - val_dist_relevant_mse: 4.2194 - val_dist_dist_iou_metric: 0.6479 - lr: 1.0000e-04
# Epoch 70/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4450 - prob_loss: 0.2073 - dist_loss: 1.1884 - prob_kld: 0.0626 - dist_relevant_mae: 1.1882 - dist_relev
# 10/10 [==============================] - 3s 323ms/step - loss: 0.4450 - prob_loss: 0.2073 - dist_loss: 1.1884 - prob_kld: 0.0626 - dist_relevant_mae: 1.1882 - dist_relevant_mse: 3.6190 - dist_dist_iou_metric: 0.6750 - val_loss: 0.4472 - val_prob_loss: 0.1948 - val_dist_loss: 1.2617 - val_prob_kld: 0.0609 - val_dist_relevant_mae: 1.2615 - val_dist_relevant_mse: 4.2263 - val_dist_dist_iou_metric: 0.6509 - lr: 1.0000e-04
# Epoch 71/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3996 - prob_loss: 0.1670 - dist_loss: 1.1629 - prob_kld: 0.0546 - dist_relevant_mae: 1.1626 - dist_relev
# 10/10 [==============================] - 2s 214ms/step - loss: 0.3996 - prob_loss: 0.1670 - dist_loss: 1.1629 - prob_kld: 0.0546 - dist_relevant_mae: 1.1626 - dist_relevant_mse: 3.3698 - dist_dist_iou_metric: 0.6728 - val_loss: 0.4503 - val_prob_loss: 0.1957 - val_dist_loss: 1.2726 - val_prob_kld: 0.0618 - val_dist_relevant_mae: 1.2724 - val_dist_relevant_mse: 4.2730 - val_dist_dist_iou_metric: 0.6442 - lr: 1.0000e-04
# Epoch 72/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4412 - prob_loss: 0.2073 - dist_loss: 1.1696 - prob_kld: 0.0592 - dist_relevant_mae: 1.1694 - dist_relev
# 10/10 [==============================] - 2s 214ms/step - loss: 0.4412 - prob_loss: 0.2073 - dist_loss: 1.1696 - prob_kld: 0.0592 - dist_relevant_mae: 1.1694 - dist_relevant_mse: 3.5775 - dist_dist_iou_metric: 0.6714 - val_loss: 0.4476 - val_prob_loss: 0.1946 - val_dist_loss: 1.2649 - val_prob_kld: 0.0607 - val_dist_relevant_mae: 1.2647 - val_dist_relevant_mse: 4.2414 - val_dist_dist_iou_metric: 0.6497 - lr: 1.0000e-04
# Epoch 73/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4227 - prob_loss: 0.1923 - dist_loss: 1.1520 - prob_kld: 0.0585 - dist_relevant_mae: 1.1518 - dist_relev
# 10/10 [==============================] - 2s 245ms/step - loss: 0.4227 - prob_loss: 0.1923 - dist_loss: 1.1520 - prob_kld: 0.0585 - dist_relevant_mae: 1.1518 - dist_relevant_mse: 3.4024 - dist_dist_iou_metric: 0.6740 - val_loss: 0.4470 - val_prob_loss: 0.1947 - val_dist_loss: 1.2615 - val_prob_kld: 0.0608 - val_dist_relevant_mae: 1.2613 - val_dist_relevant_mse: 4.2193 - val_dist_dist_iou_metric: 0.6579 - lr: 1.0000e-04
# Epoch 74/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4461 - prob_loss: 0.2013 - dist_loss: 1.2242 - prob_kld: 0.0603 - dist_relevant_mae: 1.2240 - dist_relev
# 10/10 [==============================] - 2s 239ms/step - loss: 0.4461 - prob_loss: 0.2013 - dist_loss: 1.2242 - prob_kld: 0.0603 - dist_relevant_mae: 1.2240 - dist_relevant_mse: 3.8969 - dist_dist_iou_metric: 0.6601 - val_loss: 0.4468 - val_prob_loss: 0.1946 - val_dist_loss: 1.2611 - val_prob_kld: 0.0607 - val_dist_relevant_mae: 1.2609 - val_dist_relevant_mse: 4.2275 - val_dist_dist_iou_metric: 0.6578 - lr: 1.0000e-04
# Epoch 75/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4229 - prob_loss: 0.1926 - dist_loss: 1.1514 - prob_kld: 0.0600 - dist_relevant_mae: 1.1511 - dist_relev
# 10/10 [==============================] - 2s 215ms/step - loss: 0.4229 - prob_loss: 0.1926 - dist_loss: 1.1514 - prob_kld: 0.0600 - dist_relevant_mae: 1.1511 - dist_relevant_mse: 3.3690 - dist_dist_iou_metric: 0.6664 - val_loss: 0.4479 - val_prob_loss: 0.1946 - val_dist_loss: 1.2663 - val_prob_kld: 0.0607 - val_dist_relevant_mae: 1.2661 - val_dist_relevant_mse: 4.2425 - val_dist_dist_iou_metric: 0.6523 - lr: 1.0000e-04
# Epoch 76/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4175 - prob_loss: 0.1935 - dist_loss: 1.1203 - prob_kld: 0.0552 - dist_relevant_mae: 1.1201 - dist_relev
# 10/10 [==============================] - 2s 233ms/step - loss: 0.4175 - prob_loss: 0.1935 - dist_loss: 1.1203 - prob_kld: 0.0552 - dist_relevant_mae: 1.1201 - dist_relevant_mse: 3.2539 - dist_dist_iou_metric: 0.6864 - val_loss: 0.4455 - val_prob_loss: 0.1943 - val_dist_loss: 1.2557 - val_prob_kld: 0.0605 - val_dist_relevant_mae: 1.2555 - val_dist_relevant_mse: 4.1876 - val_dist_dist_iou_metric: 0.6502 - lr: 1.0000e-04
# Epoch 77/200
# 3/3 [==============================] - 0s 3ms/step loss: 0.4303 - prob_loss: 0.1921 - dist_loss: 1.1908 - prob_kld: 0.0594 - dist_relevant_mae: 1.1905 - dist_relev
# 10/10 [==============================] - 2s 222ms/step - loss: 0.4303 - prob_loss: 0.1921 - dist_loss: 1.1908 - prob_kld: 0.0594 - dist_relevant_mae: 1.1905 - dist_relevant_mse: 3.6172 - dist_dist_iou_metric: 0.6679 - val_loss: 0.4475 - val_prob_loss: 0.1945 - val_dist_loss: 1.2653 - val_prob_kld: 0.0606 - val_dist_relevant_mae: 1.2651 - val_dist_relevant_mse: 4.2224 - val_dist_dist_iou_metric: 0.6465 - lr: 1.0000e-04
# Epoch 78/200
# ...
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3676 - prob_loss: 0.1749 - dist_loss: 0.9634 - prob_kld: 0.0442 - dist_relevant_mae: 0.9631 - dist_relevant_mse: 2.3613 - dist_dist_iou_metric: 0.7213 - val_loss: 0.4392 - val_prob_loss: 0.1930 - val_dist_loss: 1.2311 - val_prob_kld: 0.0591 - val_dist_relevant_mae: 1.2309 - val_dist_relevant_mse: 4.1291 - val_dist_dist_iou_metric: 0.6583 - lr: 6.2500e-06
# Epoch 176/200
# 3/3 [==============================] - 0s 3ms/step loss: 0.3842 - prob_loss: 0.1767 - dist_loss: 1.0376 - prob_kld: 0.0500 - dist_relevant_mae: 1.0374 - dist_relev
# 10/10 [==============================] - 2s 187ms/step - loss: 0.3842 - prob_loss: 0.1767 - dist_loss: 1.0376 - prob_kld: 0.0500 - dist_relevant_mae: 1.0374 - dist_relevant_mse: 2.7269 - dist_dist_iou_metric: 0.6934 - val_loss: 0.4392 - val_prob_loss: 0.1930 - val_dist_loss: 1.2310 - val_prob_kld: 0.0591 - val_dist_relevant_mae: 1.2307 - val_dist_relevant_mse: 4.1284 - val_dist_dist_iou_metric: 0.6587 - lr: 6.2500e-06
# Epoch 177/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3977 - prob_loss: 0.1837 - dist_loss: 1.0697 - prob_kld: 0.0468 - dist_relevant_mae: 1.0695 - dist_relevant_mse: 3.0633 - dist_dist_iou_metric: 0.7063
# Epoch 177: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 3/3 [==============================] - 0s 3ms/step
# 10/10 [==============================] - 2s 195ms/step - loss: 0.3977 - prob_loss: 0.1837 - dist_loss: 1.0697 - prob_kld: 0.0468 - dist_relevant_mae: 1.0695 - dist_relevant_mse: 3.0633 - dist_dist_iou_metric: 0.7063 - val_loss: 0.4389 - val_prob_loss: 0.1928 - val_dist_loss: 1.2305 - val_prob_kld: 0.0589 - val_dist_relevant_mae: 1.2303 - val_dist_relevant_mse: 4.1294 - val_dist_dist_iou_metric: 0.6584 - lr: 6.2500e-06
# Epoch 178/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4246 - prob_loss: 0.2140 - dist_loss: 1.0529 - prob_kld: 0.0570 - dist_relevant_mae: 1.0526 - dist_relev
# 10/10 [==============================] - 2s 179ms/step - loss: 0.4246 - prob_loss: 0.2140 - dist_loss: 1.0529 - prob_kld: 0.0570 - dist_relevant_mae: 1.0526 - dist_relevant_mse: 2.8801 - dist_dist_iou_metric: 0.6892 - val_loss: 0.4389 - val_prob_loss: 0.1928 - val_dist_loss: 1.2306 - val_prob_kld: 0.0589 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1297 - val_dist_dist_iou_metric: 0.6585 - lr: 3.1250e-06
# Epoch 179/200
# 3/3 [==============================] - 0s 6ms/step loss: 0.4130 - prob_loss: 0.1980 - dist_loss: 1.0749 - prob_kld: 0.0495 - dist_relevant_mae: 1.0746 - dist_relev
# 10/10 [==============================] - 2s 197ms/step - loss: 0.4130 - prob_loss: 0.1980 - dist_loss: 1.0749 - prob_kld: 0.0495 - dist_relevant_mae: 1.0746 - dist_relevant_mse: 3.0329 - dist_dist_iou_metric: 0.7010 - val_loss: 0.4389 - val_prob_loss: 0.1929 - val_dist_loss: 1.2305 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2302 - val_dist_relevant_mse: 4.1285 - val_dist_dist_iou_metric: 0.6590 - lr: 3.1250e-06
# Epoch 180/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3724 - prob_loss: 0.1657 - dist_loss: 1.0334 - prob_kld: 0.0489 - dist_relevant_mae: 1.0332 - dist_relev
# 10/10 [==============================] - 2s 180ms/step - loss: 0.3724 - prob_loss: 0.1657 - dist_loss: 1.0334 - prob_kld: 0.0489 - dist_relevant_mae: 1.0332 - dist_relevant_mse: 2.7485 - dist_dist_iou_metric: 0.6908 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2307 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1300 - val_dist_dist_iou_metric: 0.6587 - lr: 3.1250e-06
# Epoch 181/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3932 - prob_loss: 0.1858 - dist_loss: 1.0373 - prob_kld: 0.0495 - dist_relevant_mae: 1.0371 - dist_relev
# 10/10 [==============================] - 2s 186ms/step - loss: 0.3932 - prob_loss: 0.1858 - dist_loss: 1.0373 - prob_kld: 0.0495 - dist_relevant_mae: 1.0371 - dist_relevant_mse: 2.7661 - dist_dist_iou_metric: 0.7038 - val_loss: 0.4391 - val_prob_loss: 0.1929 - val_dist_loss: 1.2310 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2308 - val_dist_relevant_mse: 4.1318 - val_dist_dist_iou_metric: 0.6588 - lr: 3.1250e-06
# Epoch 182/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3727 - prob_loss: 0.1713 - dist_loss: 1.0072 - prob_kld: 0.0461 - dist_relevant_mae: 1.0070 - dist_relev
# 10/10 [==============================] - 2s 177ms/step - loss: 0.3727 - prob_loss: 0.1713 - dist_loss: 1.0072 - prob_kld: 0.0461 - dist_relevant_mae: 1.0070 - dist_relevant_mse: 2.6287 - dist_dist_iou_metric: 0.7053 - val_loss: 0.4391 - val_prob_loss: 0.1929 - val_dist_loss: 1.2309 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2307 - val_dist_relevant_mse: 4.1313 - val_dist_dist_iou_metric: 0.6588 - lr: 3.1250e-06
# Epoch 183/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3962 - prob_loss: 0.1895 - dist_loss: 1.0333 - prob_kld: 0.0509 - dist_relevant_mae: 1.0331 - dist_relev
# 10/10 [==============================] - 2s 193ms/step - loss: 0.3962 - prob_loss: 0.1895 - dist_loss: 1.0333 - prob_kld: 0.0509 - dist_relevant_mae: 1.0331 - dist_relevant_mse: 2.7468 - dist_dist_iou_metric: 0.6983 - val_loss: 0.4391 - val_prob_loss: 0.1929 - val_dist_loss: 1.2309 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2307 - val_dist_relevant_mse: 4.1306 - val_dist_dist_iou_metric: 0.6587 - lr: 3.1250e-06
# Epoch 184/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4210 - prob_loss: 0.2069 - dist_loss: 1.0702 - prob_kld: 0.0555 - dist_relevant_mae: 1.0700 - dist_relev
# 10/10 [==============================] - 2s 195ms/step - loss: 0.4210 - prob_loss: 0.2069 - dist_loss: 1.0702 - prob_kld: 0.0555 - dist_relevant_mae: 1.0700 - dist_relevant_mse: 2.9833 - dist_dist_iou_metric: 0.6945 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2306 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1290 - val_dist_dist_iou_metric: 0.6590 - lr: 3.1250e-06
# Epoch 185/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3647 - prob_loss: 0.1662 - dist_loss: 0.9924 - prob_kld: 0.0425 - dist_relevant_mae: 0.9922 - dist_relev
# 10/10 [==============================] - 2s 181ms/step - loss: 0.3647 - prob_loss: 0.1662 - dist_loss: 0.9924 - prob_kld: 0.0425 - dist_relevant_mae: 0.9922 - dist_relevant_mse: 2.5267 - dist_dist_iou_metric: 0.7125 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2306 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1294 - val_dist_dist_iou_metric: 0.6588 - lr: 3.1250e-06
# Epoch 186/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4154 - prob_loss: 0.2045 - dist_loss: 1.0545 - prob_kld: 0.0567 - dist_relevant_mae: 1.0543 - dist_relev
# 10/10 [==============================] - 2s 189ms/step - loss: 0.4154 - prob_loss: 0.2045 - dist_loss: 1.0545 - prob_kld: 0.0567 - dist_relevant_mae: 1.0543 - dist_relevant_mse: 2.8117 - dist_dist_iou_metric: 0.6929 - val_loss: 0.4391 - val_prob_loss: 0.1929 - val_dist_loss: 1.2308 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2306 - val_dist_relevant_mse: 4.1313 - val_dist_dist_iou_metric: 0.6584 - lr: 3.1250e-06
# Epoch 187/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3742 - prob_loss: 0.1718 - dist_loss: 1.0117 - prob_kld: 0.0456 - dist_relevant_mae: 1.0115 - dist_relevant_mse: 2.6371 - dist_dist_iou_metric: 0.7069
# Epoch 187: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 3/3 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 2s 199ms/step - loss: 0.3742 - prob_loss: 0.1718 - dist_loss: 1.0117 - prob_kld: 0.0456 - dist_relevant_mae: 1.0115 - dist_relevant_mse: 2.6371 - dist_dist_iou_metric: 0.7069 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2306 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1293 - val_dist_dist_iou_metric: 0.6589 - lr: 3.1250e-06
# Epoch 188/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4064 - prob_loss: 0.2023 - dist_loss: 1.0204 - prob_kld: 0.0519 - dist_relevant_mae: 1.0201 - dist_relev
# 10/10 [==============================] - 2s 181ms/step - loss: 0.4064 - prob_loss: 0.2023 - dist_loss: 1.0204 - prob_kld: 0.0519 - dist_relevant_mae: 1.0201 - dist_relevant_mse: 2.6595 - dist_dist_iou_metric: 0.7104 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2306 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1295 - val_dist_dist_iou_metric: 0.6588 - lr: 1.5625e-06
# Epoch 189/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3955 - prob_loss: 0.1854 - dist_loss: 1.0505 - prob_kld: 0.0504 - dist_relevant_mae: 1.0503 - dist_relev
# 10/10 [==============================] - 2s 200ms/step - loss: 0.3955 - prob_loss: 0.1854 - dist_loss: 1.0505 - prob_kld: 0.0504 - dist_relevant_mae: 1.0503 - dist_relevant_mse: 2.8561 - dist_dist_iou_metric: 0.7003 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2306 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1298 - val_dist_dist_iou_metric: 0.6587 - lr: 1.5625e-06
# Epoch 190/200
# 3/3 [==============================] - 0s 5ms/step loss: 0.3825 - prob_loss: 0.1723 - dist_loss: 1.0506 - prob_kld: 0.0434 - dist_relevant_mae: 1.0504 - dist_relev
# 10/10 [==============================] - 2s 182ms/step - loss: 0.3825 - prob_loss: 0.1723 - dist_loss: 1.0506 - prob_kld: 0.0434 - dist_relevant_mae: 1.0504 - dist_relevant_mse: 2.8673 - dist_dist_iou_metric: 0.7065 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2306 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1306 - val_dist_dist_iou_metric: 0.6590 - lr: 1.5625e-06
# Epoch 191/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4020 - prob_loss: 0.1970 - dist_loss: 1.0250 - prob_kld: 0.0540 - dist_relevant_mae: 1.0247 - dist_relev
# 10/10 [==============================] - 2s 177ms/step - loss: 0.4020 - prob_loss: 0.1970 - dist_loss: 1.0250 - prob_kld: 0.0540 - dist_relevant_mae: 1.0247 - dist_relevant_mse: 2.6824 - dist_dist_iou_metric: 0.6954 - val_loss: 0.4391 - val_prob_loss: 0.1929 - val_dist_loss: 1.2308 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2306 - val_dist_relevant_mse: 4.1324 - val_dist_dist_iou_metric: 0.6588 - lr: 1.5625e-06
# Epoch 192/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3879 - prob_loss: 0.1811 - dist_loss: 1.0341 - prob_kld: 0.0487 - dist_relevant_mae: 1.0338 - dist_relev
# 10/10 [==============================] - 2s 197ms/step - loss: 0.3879 - prob_loss: 0.1811 - dist_loss: 1.0341 - prob_kld: 0.0487 - dist_relevant_mae: 1.0338 - dist_relevant_mse: 2.7464 - dist_dist_iou_metric: 0.7038 - val_loss: 0.4391 - val_prob_loss: 0.1929 - val_dist_loss: 1.2309 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2307 - val_dist_relevant_mse: 4.1339 - val_dist_dist_iou_metric: 0.6587 - lr: 1.5625e-06
# Epoch 193/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3976 - prob_loss: 0.1832 - dist_loss: 1.0719 - prob_kld: 0.0482 - dist_relevant_mae: 1.0716 - dist_relev
# 10/10 [==============================] - 2s 190ms/step - loss: 0.3976 - prob_loss: 0.1832 - dist_loss: 1.0719 - prob_kld: 0.0482 - dist_relevant_mae: 1.0716 - dist_relevant_mse: 3.0581 - dist_dist_iou_metric: 0.6977 - val_loss: 0.4392 - val_prob_loss: 0.1929 - val_dist_loss: 1.2311 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2308 - val_dist_relevant_mse: 4.1347 - val_dist_dist_iou_metric: 0.6586 - lr: 1.5625e-06
# Epoch 194/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4036 - prob_loss: 0.2052 - dist_loss: 0.9920 - prob_kld: 0.0548 - dist_relevant_mae: 0.9918 - dist_relev
# 10/10 [==============================] - 2s 180ms/step - loss: 0.4036 - prob_loss: 0.2052 - dist_loss: 0.9920 - prob_kld: 0.0548 - dist_relevant_mae: 0.9918 - dist_relevant_mse: 2.4973 - dist_dist_iou_metric: 0.7057 - val_loss: 0.4391 - val_prob_loss: 0.1929 - val_dist_loss: 1.2310 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2308 - val_dist_relevant_mse: 4.1338 - val_dist_dist_iou_metric: 0.6587 - lr: 1.5625e-06
# Epoch 195/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.3931 - prob_loss: 0.1819 - dist_loss: 1.0559 - prob_kld: 0.0490 - dist_relevant_mae: 1.0557 - dist_relev
# 10/10 [==============================] - 2s 188ms/step - loss: 0.3931 - prob_loss: 0.1819 - dist_loss: 1.0559 - prob_kld: 0.0490 - dist_relevant_mae: 1.0557 - dist_relevant_mse: 2.8846 - dist_dist_iou_metric: 0.6933 - val_loss: 0.4391 - val_prob_loss: 0.1929 - val_dist_loss: 1.2308 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2306 - val_dist_relevant_mse: 4.1313 - val_dist_dist_iou_metric: 0.6589 - lr: 1.5625e-06
# Epoch 196/200
# 3/3 [==============================] - 0s 3ms/step loss: 0.3973 - prob_loss: 0.1902 - dist_loss: 1.0351 - prob_kld: 0.0493 - dist_relevant_mae: 1.0348 - dist_relev
# 10/10 [==============================] - 2s 174ms/step - loss: 0.3973 - prob_loss: 0.1902 - dist_loss: 1.0351 - prob_kld: 0.0493 - dist_relevant_mae: 1.0348 - dist_relevant_mse: 2.7568 - dist_dist_iou_metric: 0.7027 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2307 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2305 - val_dist_relevant_mse: 4.1302 - val_dist_dist_iou_metric: 0.6589 - lr: 1.5625e-06
# Epoch 197/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3652 - prob_loss: 0.1575 - dist_loss: 1.0386 - prob_kld: 0.0450 - dist_relevant_mae: 1.0384 - dist_relevant_mse: 2.7754 - dist_dist_iou_metric: 0.6964
# Epoch 197: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 3/3 [==============================] - 0s 5ms/step
# 10/10 [==============================] - 2s 200ms/step - loss: 0.3652 - prob_loss: 0.1575 - dist_loss: 1.0386 - prob_kld: 0.0450 - dist_relevant_mae: 1.0384 - dist_relevant_mse: 2.7754 - dist_dist_iou_metric: 0.6964 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2307 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1296 - val_dist_dist_iou_metric: 0.6589 - lr: 1.5625e-06
# Epoch 198/200
# 3/3 [==============================] - 0s 4ms/step loss: 0.4156 - prob_loss: 0.2104 - dist_loss: 1.0260 - prob_kld: 0.0545 - dist_relevant_mae: 1.0257 - dist_relev
# 10/10 [==============================] - 2s 201ms/step - loss: 0.4156 - prob_loss: 0.2104 - dist_loss: 1.0260 - prob_kld: 0.0545 - dist_relevant_mae: 1.0257 - dist_relevant_mse: 2.6896 - dist_dist_iou_metric: 0.7085 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2307 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2304 - val_dist_relevant_mse: 4.1297 - val_dist_dist_iou_metric: 0.6587 - lr: 7.8125e-07
# Epoch 199/200
# 3/3 [==============================] - 0s 3ms/step loss: 0.3926 - prob_loss: 0.1832 - dist_loss: 1.0470 - prob_kld: 0.0489 - dist_relevant_mae: 1.0467 - dist_relev
# 10/10 [==============================] - 2s 189ms/step - loss: 0.3926 - prob_loss: 0.1832 - dist_loss: 1.0470 - prob_kld: 0.0489 - dist_relevant_mae: 1.0467 - dist_relevant_mse: 2.8043 - dist_dist_iou_metric: 0.6991 - val_loss: 0.4390 - val_prob_loss: 0.1929 - val_dist_loss: 1.2307 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2305 - val_dist_relevant_mse: 4.1300 - val_dist_dist_iou_metric: 0.6587 - lr: 7.8125e-07
# Epoch 200/200
# 3/3 [==============================] - 0s 3ms/step loss: 0.3804 - prob_loss: 0.1770 - dist_loss: 1.0171 - prob_kld: 0.0467 - dist_relevant_mae: 1.0169 - dist_relev
# 10/10 [==============================] - 2s 179ms/step - loss: 0.3804 - prob_loss: 0.1770 - dist_loss: 1.0171 - prob_kld: 0.0467 - dist_relevant_mae: 1.0169 - dist_relevant_mse: 2.7188 - dist_dist_iou_metric: 0.7046 - val_loss: 0.4391 - val_prob_loss: 0.1929 - val_dist_loss: 1.2307 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.2305 - val_dist_relevant_mse: 4.1301 - val_dist_dist_iou_metric: 0.6586 - lr: 7.8125e-07
# Loading network weights from 'weights_best.h5'.

# %%
#Optimize the thresolds using the trained model
model.optimize_thresholds(HE_val, mask_val)
# Out:
# NMS threshold = 0.3:  75%|███████▌  | 15/20 [00:06<00:02,  2.41it/s, 0.633 -> 0.652]
# NMS threshold = 0.4:  75%|███████▌  | 15/20 [00:04<00:01,  3.15it/s, 0.633 -> 0.645]
# NMS threshold = 0.5:  75%|███████▌  | 15/20 [00:04<00:01,  3.23it/s, 0.682 -> 0.644]
# Using optimized values: prob_thresh=0.634991, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# {'prob': 0.63499129199699, 'nms': 0.3}

# %%
model
# Out:
# StarDist2D(monkey_fallopian_tube_AF__11_03_2023_1e-4): YXC → YXC
# ├─ Directory: \\10.99.68.178\andreex\data\Stardist\models\monkey_fallopian_tube_AF__11_03_2023_1e-4
# └─ Config2D(n_dim=2, axes='YXC', n_channel_in=3, n_channel_out=33, train_checkpoint='weights_best.h5', train_checkpoint_last='weights_last.h5', train_checkpoint_epoch='weights_now.h5', n_rays=32, grid=(2, 2), backbone='unet', n_classes=None, unet_n_depth=3, unet_kernel_size=(3, 3), unet_n_filter_base=32, unet_n_conv_per_depth=2, unet_pool=(2, 2), unet_activation='relu', unet_last_activation='relu', unet_batch_norm=False, unet_dropout=0.0, unet_prefix='', net_conv_after_unet=128, net_input_shape=(None, None, 3), net_mask_shape=(None, None, 1), train_shape_completion=False, train_completion_crop=32, train_patch_size=(256, 256), train_background_reg=0.0001, train_foreground_only=0.9, train_sample_cache=True, train_dist_loss='mae', train_loss_weights=(1, 0.2), train_class_weights=(1, 1), train_epochs=400, train_steps_per_epoch=100, train_learning_rate=0.0001, train_batch_size=4, train_n_val_patches=None, train_tensorboard=True, train_reduce_lr={'factor': 0.5, 'patience': 10, 'min_delta': 0, 'verbose': True}, use_gpu=True)

# %%
#Predict on validation images
mask_val_pred = [model.predict_instances(x, n_tiles=model._guess_n_tiles(x), show_tile_progress=False)[0]
              for x in tqdm(HE_val)]
# Out:
# 100%|██████████| 12/12 [00:01<00:00,  7.98it/s]

# %%
ind = 3

cropped_img = HE_val[ind]
cropped_lbl = mask_val_pred[ind]
cropped_lbl_gt = mask_val[ind]

fig, ax = plt.subplots(1,3,figsize = (16, 8))
ax[0].imshow(cropped_img)
ax[0].axis('off')
ax[0].set_title('H&E')

ax[1].imshow(cropped_img)
ax[1].imshow(cropped_lbl_gt, cmap=lbl_cmap, alpha=0.5)
ax[1].axis('off')
ax[1].set_title('Ground Truth')

ax[2].imshow(cropped_img)
ax[2].imshow(cropped_lbl, cmap=lbl_cmap, alpha=0.5)
ax[2].axis('off')
ax[2].set_title('Predicted')
plt.show()

# %%
pth_DK_model=r'\\10.99.68.178\andreex\data\Stardist\models\monkey_fallopian_tube11_02_2023_lr_5e-5'
modelDK = load_model(pth_DK_model)

# %%
#Optimize the thresolds using the trained model
# modelDK.optimize_thresholds(HE_val, mask_val)

# %%
#Predict on validation images
mask_val_predDK = [modelDK.predict_instances(x, n_tiles=model._guess_n_tiles(x), show_tile_progress=False)[0]
              for x in tqdm(HE_val)]

# %%
# ind = 8
cropped_lblDK = mask_val_predDK[ind]

fig, ax = plt.subplots(1,3,figsize = (16, 8))
ax[0].imshow(cropped_img)
ax[0].imshow(cropped_lbl_gt, cmap=lbl_cmap, alpha=0.3)
ax[0].axis('off')
ax[0].set_title('Ground Truth')

ax[1].imshow(cropped_img)
ax[1].imshow(cropped_lbl, cmap=lbl_cmap, alpha=0.3)
ax[1].axis('off')
ax[1].set_title('ANDRE MODEL')

ax[2].imshow(cropped_img)
ax[2].imshow(cropped_lblDK, cmap=lbl_cmap, alpha=0.3)
ax[2].axis('off')
ax[2].set_title('DONALD MODEL')
plt.show()
