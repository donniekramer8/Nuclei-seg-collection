# %%
from tifffile import imread
import os
from matplotlib import pyplot as plt
import json
import geojson
from scipy.io import loadmat
import h5py
import numpy as np

# %%
# pth_WSI_segmentations = r'\\10.99.68.178\andreex\data\Stardist\PDAC model\maybe_all_tiles_donald\test_WSI\StarDist_2_9_24\json'
#pth_WSI_segmentations = r'\\10.99.68.178\andre\Eduarda PDAC\immune_cell_pipeline\star_dist_Donald_model\StarDist_1_29_23\json'

pth_WSI_segmentations = r'\\10.162.80.16\Andre_expansion\data\monkey_fetus\Stardist\StarDist_12_25_23\json'
#npdi_im_path = r'\\10.162.80.16\Andre_expansion\data\PDAC purity\NDPI\pdac purity'

# %%
json_pth_list = sorted([os.path.join(pth_WSI_segmentations,file) for file in os.listdir(pth_WSI_segmentations) if file.endswith(".json")])
print(json_pth_list)
# Out:
# ['\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0001.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0002.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0003.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0004.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0005.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0006.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0007.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0008.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0009.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0010.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0011.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0012.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0013.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0014.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0015.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0016.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0017.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0018.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0019.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0020.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0021.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0023.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0024.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0025.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0026.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0027.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0028.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0029.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0030.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0031.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0032.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0033.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0034.json', '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDi ...

# %%
def get_ds_data(segmentation_data, ds):
    data_list = []
    for data in segmentation_data:
        centroid = data['centroid'][0]
        contour = data['contour'][0]
    
        #print(centroid)
        #print(contour)
        
        ds_centroid = [int(c/ds) for c in centroid]
        ds_contour = [[value / ds for value in sublist] for sublist in contour]
        ds_contour = [[round(x,2), round(y,2)] for x, y in zip(ds_contour[0], ds_contour[1])]
        #ds_contour = ds_contour[0:-1:4]  # make shape have 8 points instead of 32
        
        #print(ds_centroid)
        #print(ds_contour)
        
        dat = [ds_centroid, ds_contour]
        data_list.append(dat)
    return data_list

# %%
json_pth_list[609]
# Out:
# '\\\\10.162.80.16\\Andre_expansion\\data\\monkey_fetus\\Stardist\\StarDist_12_25_23\\json\\monkey_fetus_40_0612.json'

# %%
# out_pth = r'\\10.99.68.178\andreex\data\Stardist\PDAC model\maybe_all_tiles_donald\test_WSI\StarDist_2_9_24\json\partial_jsons'

out_pth = r'\\10.162.80.16\Andre_expansion\data\monkey_fetus\Stardist\StarDist_12_25_23\downsampled_jsons\32_polys_20x'

# ds_amt = 4 # 2.5x
# ds_amt = 2/0.4416  # 5x
# ds_amt = 1/0.4416 # 10x
ds_amt = 1 # 20x

# for p, file in enumerate(json_pth_list):
for p, file in enumerate([json_pth_list[609]]):
    nm = file.split('\\')[-1]
    new_fn = os.path.join(out_pth, nm[:-5] + '.geojson')
    print(f'{p} / {len(json_pth_list)}')
    print(nm)
    
    if not os.path.exists(new_fn):
    
        segmentation_data = json.load(open(file))
        
        data_list = get_ds_data(segmentation_data, ds_amt)
    
        GEOdata = []
        
        for j, (centroid, contour) in enumerate(data_list):
            
            #if j == 100000:
            #    break
            
            centroid = [centroid[0] + 0, centroid[1] + 0]
            # xy coordinates are swapped, so I reverse them here with xy[::-1]
            # note: add 1 to coords to fix 0 indexing vs 1 index offset
            contour = [[coord+0 for coord in xy[::-1]] for xy in contour]  # Convert coordinates to integers
            contour.append(contour[0]) # stardist doesn't close the circle, needed for qupath
        
            # Create a new dictionary for each contour
            dict_data = {
                "type": "Feature",
                "id": "PathCellObject",
                "geometry": {
                    "type": "Polygon",
                    "coordinates": [contour]
                },
                "properties": {
                    'objectType': 'annotation',
                    'classification': {'name': 'Nuclei', 'color': [97, 214, 59]}
                }
            }
        
            GEOdata.append(dict_data)
        
        with open(new_fn,'w') as outfile:
            geojson.dump(GEOdata,outfile)
        print('Finished',new_fn)
    
    else:
        print(f'skipping {new_fn}')
# Out:
# 0 / 1154
# monkey_fetus_40_0612.json
# Finished \\10.162.80.16\Andre_expansion\data\monkey_fetus\Stardist\StarDist_12_25_23\downsampled_jsons\32_polys_20x\monkey_fetus_40_0612.geojson
