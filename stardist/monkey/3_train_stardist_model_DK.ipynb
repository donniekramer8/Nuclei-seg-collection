# %%
# pip install gputools
# pip install scikit-tensor-py3

from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import numpy as np
import matplotlib
matplotlib.rcParams["image.interpolation"] = 'nearest'
import matplotlib.pyplot as plt
import os
from PIL import Image
import tensorflow as tf
from glob import glob
from tqdm import tqdm
from tifffile import imread
import struct
import cv2
import pandas as pd

from stardist import fill_label_holes, random_label_cmap, calculate_extents, gputools_available
from stardist.models import Config2D, StarDist2D, StarDistData2D

# %%
#Random color map labels
np.random.seed(42)
lbl_cmap = random_label_cmap()

# %%
pth=r'\\10.99.68.178\andreex\data\Stardist\qupath_training_annotations'
pthtraining= os.path.join(pth,'Training')
pthtesting= os.path.join(pth,'Testing')
pthmodels= os.path.join(pth,'models')
pthfiles= os.path.join(pth,'files')

pthHE= r'\\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles'
pthmasks= r'\\10.99.68.178\andreex\data\Stardist\Training\masks'

# %%
pthmodels
# Out:
# '\\\\10.99.68.178\\andreex\\data\\Stardist\\qupath_training_annotations\\models'

# %%
training_HE_tiles_pths = sorted(glob(os.path.join(pthHE,'*.tif')))
training_mask_tiles_pths = sorted(glob(os.path.join(pthmasks,'*.tif')))

# %%
training_HE_tiles_pths
# Out:
# ['\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_117.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_157.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_217.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_271.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_331.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_377.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_439.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_479.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_523.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_565.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0105_ecm.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0271_eye.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0371_Lung.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0400_spinalcord.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0420_brain.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0431_GI.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0432_bone.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0450_heart.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0451_kidney.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0507_Thyroid.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0519_Ganglion.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0531_kidney.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0532_heart.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0612_brain.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0640_bone.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0642_bone2.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0725_gonad.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0730_kidney.tif']

# %%
HE_original_tiles = list(map(imread,training_HE_tiles_pths))
mask_original_tiles = list(map(imread,training_mask_tiles_pths))

# %%
print(len(HE_original_tiles))
print(len(mask_original_tiles))
# Out:
# 28
# 28

# %%
def augment_images(HE_tiles, mask_tiles):
  """
  Augments a set of HE images and corresponding mask labels by rotating and flipping them.

  Args:
    HE_tiles: A list of NumPy arrays representing the HE images.
    mask_tiles: A list of NumPy arrays representing the mask labels for the HE images.

  Returns:
    HE_aug: A list of NumPy arrays representing the augmented HE images.
    mask_aug: A list of NumPy arrays representing the augmented mask labels.
  """

  HE_aug = [[] for _ in range(len(HE_tiles))]
  mask_aug = [[] for _ in range(len(mask_tiles))]

  for i in range(len(HE_tiles)):
    im = Image.fromarray(HE_tiles[i])
    lbl = Image.fromarray(mask_tiles[i])

    # Rotate the image and label 90 degrees three times.
    for _ in range(3):
      im = im.rotate(90)
      HE_aug[i].append(im)
      lbl = lbl.rotate(90)
      mask_aug[i].append(lbl)

    # Flip the image and label horizontally.
    im = Image.fromarray(HE_tiles[i])
    flipped_im = im.transpose(Image.FLIP_LEFT_RIGHT)

    lbl = Image.fromarray(mask_tiles[i])
    flipped_lbl = lbl.transpose(Image.FLIP_LEFT_RIGHT)

    HE_aug[i].append(flipped_im)
    mask_aug[i].append(flipped_lbl)

    # Rotate the flipped image and label 90 degrees three times.
    for _ in range(3):
      flipped_im = flipped_im.rotate(90)
      HE_aug[i].append(flipped_im)
      flipped_lbl = flipped_lbl.rotate(90)
      mask_aug[i].append(flipped_lbl)

  return HE_aug, mask_aug

# %%
HE_aug, mask_aug = augment_images(HE_original_tiles, mask_original_tiles)

# %%
#Normalize input images and fill holes in masks
HE_original_tiles = [x/255 for x in HE_original_tiles]  # no norm, just divide by 255 to get into (0,1) range
mask_original_tiles = [fill_label_holes(y) for y in mask_original_tiles]  # fills holes in annotations if there are any

# %%
def normalize_images(images, masks):
  
  normalized_masks = [[] for i in range(len(masks))]
  normalized_images = [[] for i in range(len(images))]
  
  for i in range(len(masks)):
      masks_list = masks[i]
      images_list = images[i]
      
      for j in range(len(images_list)):
          im = images_list[j]
          im = np.asarray(im)
          im = im/255
          normalized_images[i].append(im)
      
      for j in range(len(masks_list)):
          im = masks_list[j]
          im = np.asarray(im)
          im = fill_label_holes(im)
          normalized_masks[i].append(im)
          
  return normalized_images, normalized_masks

# %%
HE_aug_norm, mask_aug_norm = normalize_images(HE_aug, mask_aug)

# %%
def split_augmented_data(HE_aug_norm_list, mask_aug_norm_list):
  """
  Splits augmented HE images and mask images into training and validation sets.

  Args:
    HE_aug_norm: A list of NumPy arrays representing the normalized augmented HE images.
    mask_aug_norm: A list of NumPy arrays representing the normalized augmented mask images.

  Returns:
    X_trn, Y_trn, X_val, Y_val: Training and validation sets of HE images and mask images.
  """

  # Create empty lists to store the training and validation sets.
  X_trn = []
  Y_trn = []
  X_val = []
  Y_val = []
  
  for i in range(len(HE_aug_norm_list)):
    HE_aug_norm = HE_aug_norm_list[i]
    mask_aug_norm = mask_aug_norm_list[i]

    # Assert that there is enough training data.
    assert len(HE_aug_norm) > 1, "not enough training data"

    # Create a random number generator with a fixed seed for reproducibility.
    rng = np.random.RandomState(42)

    # Permute the indices of the augmented data.
    ind = rng.permutation(len(HE_aug_norm))

    # Split the indices into training and validation indices.
    n_val = max(1, int(round(0.15 * len(ind))))
    ind_trn, ind_val = ind[:-n_val], ind[-n_val:]

    # Split the augmented data into training and validation sets.
    for kk in ind_trn:
      X_trn.append(HE_aug_norm[kk])
      Y_trn.append(mask_aug_norm[kk])

    for lol in ind_val:
      X_val.append(HE_aug_norm[lol])
      Y_val.append(mask_aug_norm[lol])
  
  print(f'number of images: {len(HE_aug_norm_list*len(HE_aug_norm_list[0]))}')
  print(f'- training: {len(X_trn)}')
  print(f'- validation: {len(X_val)}')
  
  X_trn = [np.array(x) for x in X_trn]
  Y_trn = [np.array(y) for y in Y_trn]
  
  X_val = [np.array(x) for x in X_val]
  Y_val = [np.array(y) for y in Y_val]
  
  # Return the training and validation sets.
  return X_trn, Y_trn, X_val, Y_val

# %%
HE_trn, mask_trn, HE_val, mask_val = split_augmented_data(HE_aug_norm, mask_aug_norm)
# Out:
# number of images: 196
# - training: 168
# - validation: 28

# %%
#PLot image and label for some images - sanity check
def show_tile_segmented(tile, segmented, **kwargs):
    """Plot large image at different resolutions."""
    fig, ax = plt.subplots(1, 2, figsize=(16/2, 8/2))

    # Plot the original image on the left
    ax[0].imshow(tile, **kwargs)

    # Plot the cropped image on the right
    ax[1].imshow(segmented, **kwargs)

    ax[0].axis('off')
    ax[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
i = 20

# %%
i
# Out:
# 20

# %%
i += 1

img, lbl = HE_val[i], mask_val[i]
assert img.ndim in (2,3)
img = img if (img.ndim==2 or img.shape[-1]==3) else img[...,0]
show_tile_segmented(img,lbl)

# %%
if tf.config.list_physical_devices('GPU'):
    print("GPU is available")
else:
    print("GPU is not available")
    
print(tf.__version__)

#Define the config by setting some parameter values
# 32 is a good default choice (see 1_data.ipynb)
n_rays = 32  #Number of radial directions for the star-convex polygon.

# Use OpenCL-based computations for data generator during training (requires 'gputools')
use_gpu = True and gputools_available()

# Predict on subsampled grid for increased efficiency and larger field of view
grid = (2,2)

n_channel = 1 if HE_trn[0].ndim == 2 else HE_trn[0].shape[-1]  #If no third dim. then number of channels = 1. Otherwise get the num channels from the last dim.


conf = Config2D (
    n_rays       = n_rays,
    grid         = grid,
    use_gpu      = use_gpu,
    n_channel_in = n_channel,
)
# print(conf)
vars(conf)
# Out:
# GPU is available
# 2.9.3
# Warning: Could not find scikit-tensor which is needed for separable approximations...
# If you want to compute separable approximations, please install it with
# pip install scikit-tensor-py3
# {'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 3,
#  'n_channel_out': 33,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'n_rays': 32,
#  'grid': (2, 2),
#  'backbone': 'unet',
#  'n_classes': None,
#  'unet_n_depth': 3,
#  'unet_kernel_size': (3, 3),
#  'unet_n_filter_base': 32,
#  'unet_n_conv_per_depth': 2,
#  'unet_pool': (2, 2),
#  'unet_activation': 'relu',
#  'unet_last_activation': 'relu',
#  'unet_batch_norm': False,
#  'unet_dropout': 0.0,
#  'unet_prefix': '',
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, 3),
#  'net_mask_shape': (None, None, 1),
#  'train_shape_completion': False,
#  'train_completion_crop': 32,
#  'train_patch_size': (256, 256),
#  'train_background_reg': 0.0001,
#  'train_foreground_only': 0.9,
#  'train_sample_cache': True,
#  'train_dist_loss': 'mae',
#  'train_loss_weights': (1, 0.2),
#  'train_class_weights': (1, 1),
#  'train_epochs': 400,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0003,
#  'train_batch_size': 4,
#  'train_n_val_patches': None,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 40, 'min_delta': 0},
#  'use_gpu': True}

# %%
#Start from 40x H&E pre-trained model to the specified directory
import copy
import json

def load_justin_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = load_model(r'\\10.99.68.178\andreex\students\Donald Monkey fetus\stardist\Model_00')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_published_he_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = StarDist2D.from_pretrained('2D_versatile_he')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_model(model_path: str) -> StarDist2D:
    # Load StarDist model weights, configurations, and thresholds
    with open(model_path + '\\config.json', 'r') as f:
        config = json.load(f)
    with open(model_path + '\\thresholds.json', 'r') as f:
        thresh = json.load(f)
    model = StarDist2D(config=Config2D(**config), basedir=model_path, name='offshoot_model')
    model.thresholds = thresh
    print('Overriding defaults:', model.thresholds, '\n')
    model.load_weights(model_path + '\\weights_best.h5')
    return model

def configure_model_for_training(model: StarDist2D,
                                 epochs: int = 25, learning_rate: float = 1e-6,
                                 batch_size: int = 4, patch_size: list[int,int] = [256, 256]) -> StarDist2D:
    model.config.train_epochs = epochs
    model.config.train_learning_rate = learning_rate
    model.config.train_batch_size = batch_size
    model.config.train_patch_size = patch_size
    return model

# %%
from tensorflow.python.summary.summary_iterator import summary_iterator

def get_loss_data(pth_training_log, pth_out) -> list:

    # event_file = r"\\10.99.68.178\andreex\data\Stardist\models\monkey_ft_11_02_2023_lr_1e-4_epochs_200_pt_10\logs\train\events.out.tfevents.1698964029.WPC-C13.20400.7.v2"

    loss_values = []

    for summary in summary_iterator(pth_training_log):
        for value in summary.summary.value:
            if value.tag == 'epoch_loss':
                loss = struct.unpack('f', value.tensor.tensor_content)[0]
                loss_values.append(loss)

    out_txt_name = f"{pth_out}\loss.txt"

    with open(out_txt_name, 'w') as f:
        f.write('\n'.join(map(str, loss_values)) + '\n')

    return loss_values

# %%
lr = 0.001
epochs = 400
patience = 40

nm='monkey_ft_'
dt='11_21_2023'
outnm = nm + dt + '_lr_' + str(lr) + '_epochs_' + str(epochs) + '_pt_' + str(patience)
print(outnm)
# Out:
# monkey_ft_11_21_2023_lr_0.001_epochs_400_pt_40

# %%
model = load_published_he_model(pthmodels, outnm)
model.config.train_learning_rate = lr
model.config.train_patch_size = (256,256)
model.config.train_reduce_lr={'factor': 0.5, 'patience': patience, 'min_delta': 0}
model.train(HE_trn, mask_trn, validation_data=(HE_val,mask_val), epochs=epochs, steps_per_epoch=100)
model.optimize_thresholds(HE_val, mask_val)

pth_log_train = fr"{pthmodels}\{outnm}\logs\train"

pth_log = glob(os.path.join(pth_log_train,'*.v2'))[0]
loss = get_loss_data(str(pth_log), pth_log_train)
# Out:
# Found model '2D_versatile_he' for 'StarDist2D'.
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.692478, nms_thresh=0.3.
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# Epoch 1/400
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x0000017D95341310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x0000017D95341310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow | AutoGraph could not transform <function _gcd_import at 0x0000017D95341310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x0000017D95341310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x0000017D95341310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x0000017D95341310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5832 - prob_loss: 0.2526 - dist_loss: 1.6530 - prob_kld: 0.1007 - dist_relevant_mae: 1.6527 - dist_relev
# 100/100 [==============================] - 9s 65ms/step - loss: 0.5830 - prob_loss: 0.2528 - dist_loss: 1.6510 - prob_kld: 0.1005 - dist_relevant_mae: 1.6507 - dist_relevant_mse: 7.0456 - dist_dist_iou_metric: 0.5935 - val_loss: 0.5203 - val_prob_loss: 0.2324 - val_dist_loss: 1.4396 - val_prob_kld: 0.0783 - val_dist_relevant_mae: 1.4393 - val_dist_relevant_mse: 5.3913 - val_dist_dist_iou_metric: 0.6296 - lr: 0.0010
# Epoch 2/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5169 - prob_loss: 0.2313 - dist_loss: 1.4280 - prob_kld: 0.0781 - dist_relevant_mae: 1.4277 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.5169 - prob_loss: 0.2313 - dist_loss: 1.4280 - prob_kld: 0.0781 - dist_relevant_mae: 1.4277 - dist_relevant_mse: 5.4025 - dist_dist_iou_metric: 0.6361 - val_loss: 0.5008 - val_prob_loss: 0.2273 - val_dist_loss: 1.3675 - val_prob_kld: 0.0731 - val_dist_relevant_mae: 1.3672 - val_dist_relevant_mse: 4.9860 - val_dist_dist_iou_metric: 0.6478 - lr: 0.0010
# Epoch 3/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5065 - prob_loss: 0.2295 - dist_loss: 1.3850 - prob_kld: 0.0755 - dist_relevant_mae: 1.3847 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.5072 - prob_loss: 0.2299 - dist_loss: 1.3865 - prob_kld: 0.0755 - dist_relevant_mae: 1.3862 - dist_relevant_mse: 5.0311 - dist_dist_iou_metric: 0.6429 - val_loss: 0.4969 - val_prob_loss: 0.2249 - val_dist_loss: 1.3602 - val_prob_kld: 0.0707 - val_dist_relevant_mae: 1.3599 - val_dist_relevant_mse: 4.9785 - val_dist_dist_iou_metric: 0.6333 - lr: 0.0010
# Epoch 4/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4975 - prob_loss: 0.2272 - dist_loss: 1.3515 - prob_kld: 0.0725 - dist_relevant_mae: 1.3512 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4972 - prob_loss: 0.2272 - dist_loss: 1.3497 - prob_kld: 0.0728 - dist_relevant_mae: 1.3494 - dist_relevant_mse: 4.9130 - dist_dist_iou_metric: 0.6530 - val_loss: 0.5416 - val_prob_loss: 0.2337 - val_dist_loss: 1.5391 - val_prob_kld: 0.0796 - val_dist_relevant_mae: 1.5388 - val_dist_relevant_mse: 5.9188 - val_dist_dist_iou_metric: 0.5987 - lr: 0.0010
# Epoch 5/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4866 - prob_loss: 0.2229 - dist_loss: 1.3186 - prob_kld: 0.0705 - dist_relevant_mae: 1.3182 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4866 - prob_loss: 0.2229 - dist_loss: 1.3186 - prob_kld: 0.0705 - dist_relevant_mae: 1.3182 - dist_relevant_mse: 4.7659 - dist_dist_iou_metric: 0.6571 - val_loss: 0.4873 - val_prob_loss: 0.2221 - val_dist_loss: 1.3261 - val_prob_kld: 0.0680 - val_dist_relevant_mae: 1.3258 - val_dist_relevant_mse: 4.7762 - val_dist_dist_iou_metric: 0.6442 - lr: 0.0010
# Epoch 6/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4740 - prob_loss: 0.2216 - dist_loss: 1.2621 - prob_kld: 0.0678 - dist_relevant_mae: 1.2618 - dist_relev
# 100/100 [==============================] - 4s 38ms/step - loss: 0.4740 - prob_loss: 0.2216 - dist_loss: 1.2621 - prob_kld: 0.0678 - dist_relevant_mae: 1.2618 - dist_relevant_mse: 4.3269 - dist_dist_iou_metric: 0.6684 - val_loss: 0.4841 - val_prob_loss: 0.2225 - val_dist_loss: 1.3078 - val_prob_kld: 0.0684 - val_dist_relevant_mae: 1.3075 - val_dist_relevant_mse: 4.6806 - val_dist_dist_iou_metric: 0.6595 - lr: 0.0010
# Epoch 7/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4648 - prob_loss: 0.2158 - dist_loss: 1.2449 - prob_kld: 0.0659 - dist_relevant_mae: 1.2446 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4660 - prob_loss: 0.2170 - dist_loss: 1.2451 - prob_kld: 0.0661 - dist_relevant_mae: 1.2448 - dist_relevant_mse: 4.2323 - dist_dist_iou_metric: 0.6747 - val_loss: 0.4784 - val_prob_loss: 0.2210 - val_dist_loss: 1.2871 - val_prob_kld: 0.0668 - val_dist_relevant_mae: 1.2868 - val_dist_relevant_mse: 4.5982 - val_dist_dist_iou_metric: 0.6599 - lr: 0.0010
# Epoch 8/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4614 - prob_loss: 0.2189 - dist_loss: 1.2128 - prob_kld: 0.0653 - dist_relevant_mae: 1.2125 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4614 - prob_loss: 0.2188 - dist_loss: 1.2130 - prob_kld: 0.0653 - dist_relevant_mae: 1.2127 - dist_relevant_mse: 4.0375 - dist_dist_iou_metric: 0.6792 - val_loss: 0.4753 - val_prob_loss: 0.2206 - val_dist_loss: 1.2733 - val_prob_kld: 0.0665 - val_dist_relevant_mae: 1.2729 - val_dist_relevant_mse: 4.5562 - val_dist_dist_iou_metric: 0.6716 - lr: 0.0010
# Epoch 9/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4591 - prob_loss: 0.2213 - dist_loss: 1.1888 - prob_kld: 0.0645 - dist_relevant_mae: 1.1885 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.4594 - prob_loss: 0.2213 - dist_loss: 1.1904 - prob_kld: 0.0645 - dist_relevant_mae: 1.1901 - dist_relevant_mse: 3.8503 - dist_dist_iou_metric: 0.6842 - val_loss: 0.4709 - val_prob_loss: 0.2199 - val_dist_loss: 1.2550 - val_prob_kld: 0.0658 - val_dist_relevant_mae: 1.2547 - val_dist_relevant_mse: 4.4896 - val_dist_dist_iou_metric: 0.6754 - lr: 0.0010
# Epoch 10/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4535 - prob_loss: 0.2128 - dist_loss: 1.2034 - prob_kld: 0.0619 - dist_relevant_mae: 1.2031 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4537 - prob_loss: 0.2126 - dist_loss: 1.2055 - prob_kld: 0.0619 - dist_relevant_mae: 1.2052 - dist_relevant_mse: 4.0068 - dist_dist_iou_metric: 0.6830 - val_loss: 0.4721 - val_prob_loss: 0.2191 - val_dist_loss: 1.2651 - val_prob_kld: 0.0650 - val_dist_relevant_mae: 1.2648 - val_dist_relevant_mse: 4.5487 - val_dist_dist_iou_metric: 0.6741 - lr: 0.0010
# Epoch 11/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4530 - prob_loss: 0.2157 - dist_loss: 1.1868 - prob_kld: 0.0622 - dist_relevant_mae: 1.1865 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4525 - prob_loss: 0.2153 - dist_loss: 1.1864 - prob_kld: 0.0621 - dist_relevant_mae: 1.1861 - dist_relevant_mse: 3.8345 - dist_dist_iou_metric: 0.6835 - val_loss: 0.4782 - val_prob_loss: 0.2210 - val_dist_loss: 1.2862 - val_prob_kld: 0.0668 - val_dist_relevant_mae: 1.2859 - val_dist_relevant_mse: 4.7698 - val_dist_dist_iou_metric: 0.6595 - lr: 0.0010
# Epoch 12/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4478 - prob_loss: 0.2148 - dist_loss: 1.1649 - prob_kld: 0.0615 - dist_relevant_mae: 1.1646 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4478 - prob_loss: 0.2148 - dist_loss: 1.1649 - prob_kld: 0.0615 - dist_relevant_mae: 1.1646 - dist_relevant_mse: 3.6946 - dist_dist_iou_metric: 0.6892 - val_loss: 0.4720 - val_prob_loss: 0.2192 - val_dist_loss: 1.2642 - val_prob_kld: 0.0650 - val_dist_relevant_mae: 1.2639 - val_dist_relevant_mse: 4.6092 - val_dist_dist_iou_metric: 0.6723 - lr: 0.0010
# Epoch 13/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4346 - prob_loss: 0.2133 - dist_loss: 1.1062 - prob_kld: 0.0585 - dist_relevant_mae: 1.1059 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4341 - prob_loss: 0.2127 - dist_loss: 1.1071 - prob_kld: 0.0583 - dist_relevant_mae: 1.1068 - dist_relevant_mse: 3.3847 - dist_dist_iou_metric: 0.7006 - val_loss: 0.4677 - val_prob_loss: 0.2187 - val_dist_loss: 1.2446 - val_prob_kld: 0.0646 - val_dist_relevant_mae: 1.2444 - val_dist_relevant_mse: 4.4840 - val_dist_dist_iou_metric: 0.6718 - lr: 0.0010
# Epoch 14/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4272 - prob_loss: 0.2072 - dist_loss: 1.1001 - prob_kld: 0.0570 - dist_relevant_mae: 1.0998 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4276 - prob_loss: 0.2074 - dist_loss: 1.1007 - prob_kld: 0.0570 - dist_relevant_mae: 1.1005 - dist_relevant_mse: 3.3447 - dist_dist_iou_metric: 0.7017 - val_loss: 0.4701 - val_prob_loss: 0.2190 - val_dist_loss: 1.2553 - val_prob_kld: 0.0649 - val_dist_relevant_mae: 1.2550 - val_dist_relevant_mse: 4.6040 - val_dist_dist_iou_metric: 0.6704 - lr: 0.0010
# Epoch 15/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4334 - prob_loss: 0.2172 - dist_loss: 1.0810 - prob_kld: 0.0578 - dist_relevant_mae: 1.0808 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.4330 - prob_loss: 0.2167 - dist_loss: 1.0813 - prob_kld: 0.0578 - dist_relevant_mae: 1.0810 - dist_relevant_mse: 3.1945 - dist_dist_iou_metric: 0.7068 - val_loss: 0.4768 - val_prob_loss: 0.2212 - val_dist_loss: 1.2781 - val_prob_kld: 0.0671 - val_dist_relevant_mae: 1.2778 - val_dist_relevant_mse: 4.6989 - val_dist_dist_iou_metric: 0.6552 - lr: 0.0010
# Epoch 16/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4246 - prob_loss: 0.2058 - dist_loss: 1.0942 - prob_kld: 0.0559 - dist_relevant_mae: 1.0939 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4248 - prob_loss: 0.2058 - dist_loss: 1.0953 - prob_kld: 0.0559 - dist_relevant_mae: 1.0950 - dist_relevant_mse: 3.2821 - dist_dist_iou_metric: 0.7029 - val_loss: 0.4756 - val_prob_loss: 0.2214 - val_dist_loss: 1.2710 - val_prob_kld: 0.0672 - val_dist_relevant_mae: 1.2706 - val_dist_relevant_mse: 4.5679 - val_dist_dist_iou_metric: 0.6766 - lr: 0.0010
# Epoch 17/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4260 - prob_loss: 0.2111 - dist_loss: 1.0747 - prob_kld: 0.0565 - dist_relevant_mae: 1.0745 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4261 - prob_loss: 0.2114 - dist_loss: 1.0732 - prob_kld: 0.0565 - dist_relevant_mae: 1.0730 - dist_relevant_mse: 3.1364 - dist_dist_iou_metric: 0.7065 - val_loss: 0.4703 - val_prob_loss: 0.2216 - val_dist_loss: 1.2436 - val_prob_kld: 0.0675 - val_dist_relevant_mae: 1.2433 - val_dist_relevant_mse: 4.5404 - val_dist_dist_iou_metric: 0.6777 - lr: 0.0010
# Epoch 18/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4161 - prob_loss: 0.2057 - dist_loss: 1.0519 - prob_kld: 0.0533 - dist_relevant_mae: 1.0517 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4153 - prob_loss: 0.2053 - dist_loss: 1.0499 - prob_kld: 0.0532 - dist_relevant_mae: 1.0496 - dist_relevant_mse: 3.0254 - dist_dist_iou_metric: 0.7141 - val_loss: 0.4724 - val_prob_loss: 0.2219 - val_dist_loss: 1.2526 - val_prob_kld: 0.0678 - val_dist_relevant_mae: 1.2523 - val_dist_relevant_mse: 4.5922 - val_dist_dist_iou_metric: 0.6767 - lr: 0.0010
# Epoch 19/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4168 - prob_loss: 0.2083 - dist_loss: 1.0424 - prob_kld: 0.0534 - dist_relevant_mae: 1.0421 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4178 - prob_loss: 0.2088 - dist_loss: 1.0448 - prob_kld: 0.0536 - dist_relevant_mae: 1.0445 - dist_relevant_mse: 3.0207 - dist_dist_iou_metric: 0.7143 - val_loss: 0.4690 - val_prob_loss: 0.2200 - val_dist_loss: 1.2452 - val_prob_kld: 0.0659 - val_dist_relevant_mae: 1.2450 - val_dist_relevant_mse: 4.5350 - val_dist_dist_iou_metric: 0.6734 - lr: 0.0010
# Epoch 20/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4071 - prob_loss: 0.2041 - dist_loss: 1.0146 - prob_kld: 0.0517 - dist_relevant_mae: 1.0144 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.4071 - prob_loss: 0.2041 - dist_loss: 1.0146 - prob_kld: 0.0517 - dist_relevant_mae: 1.0144 - dist_relevant_mse: 2.8328 - dist_dist_iou_metric: 0.7197 - val_loss: 0.4715 - val_prob_loss: 0.2226 - val_dist_loss: 1.2449 - val_prob_kld: 0.0684 - val_dist_relevant_mae: 1.2446 - val_dist_relevant_mse: 4.5659 - val_dist_dist_iou_metric: 0.6769 - lr: 0.0010
# Epoch 21/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4082 - prob_loss: 0.2051 - dist_loss: 1.0156 - prob_kld: 0.0516 - dist_relevant_mae: 1.0153 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4077 - prob_loss: 0.2048 - dist_loss: 1.0142 - prob_kld: 0.0515 - dist_relevant_mae: 1.0139 - dist_relevant_mse: 2.8007 - dist_dist_iou_metric: 0.7208 - val_loss: 0.4782 - val_prob_loss: 0.2221 - val_dist_loss: 1.2805 - val_prob_kld: 0.0680 - val_dist_relevant_mae: 1.2801 - val_dist_relevant_mse: 4.7750 - val_dist_dist_iou_metric: 0.6736 - lr: 0.0010
# Epoch 22/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4062 - prob_loss: 0.2045 - dist_loss: 1.0085 - prob_kld: 0.0514 - dist_relevant_mae: 1.0082 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4069 - prob_loss: 0.2056 - dist_loss: 1.0068 - prob_kld: 0.0517 - dist_relevant_mae: 1.0065 - dist_relevant_mse: 2.7897 - dist_dist_iou_metric: 0.7213 - val_loss: 0.4708 - val_prob_loss: 0.2210 - val_dist_loss: 1.2489 - val_prob_kld: 0.0669 - val_dist_relevant_mae: 1.2486 - val_dist_relevant_mse: 4.6394 - val_dist_dist_iou_metric: 0.6805 - lr: 0.0010
# Epoch 23/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4035 - prob_loss: 0.2022 - dist_loss: 1.0061 - prob_kld: 0.0500 - dist_relevant_mae: 1.0058 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4030 - prob_loss: 0.2019 - dist_loss: 1.0053 - prob_kld: 0.0499 - dist_relevant_mae: 1.0050 - dist_relevant_mse: 2.8009 - dist_dist_iou_metric: 0.7245 - val_loss: 0.4729 - val_prob_loss: 0.2208 - val_dist_loss: 1.2604 - val_prob_kld: 0.0667 - val_dist_relevant_mae: 1.2601 - val_dist_relevant_mse: 4.6780 - val_dist_dist_iou_metric: 0.6729 - lr: 0.0010
# Epoch 24/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4016 - prob_loss: 0.2035 - dist_loss: 0.9906 - prob_kld: 0.0499 - dist_relevant_mae: 0.9904 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4009 - prob_loss: 0.2031 - dist_loss: 0.9891 - prob_kld: 0.0497 - dist_relevant_mae: 0.9888 - dist_relevant_mse: 2.6879 - dist_dist_iou_metric: 0.7273 - val_loss: 0.4755 - val_prob_loss: 0.2220 - val_dist_loss: 1.2674 - val_prob_kld: 0.0679 - val_dist_relevant_mae: 1.2672 - val_dist_relevant_mse: 4.7467 - val_dist_dist_iou_metric: 0.6725 - lr: 0.0010
# Epoch 25/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4001 - prob_loss: 0.2034 - dist_loss: 0.9837 - prob_kld: 0.0491 - dist_relevant_mae: 0.9834 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.4002 - prob_loss: 0.2034 - dist_loss: 0.9843 - prob_kld: 0.0491 - dist_relevant_mae: 0.9840 - dist_relevant_mse: 2.7148 - dist_dist_iou_metric: 0.7304 - val_loss: 0.4841 - val_prob_loss: 0.2242 - val_dist_loss: 1.2995 - val_prob_kld: 0.0701 - val_dist_relevant_mae: 1.2993 - val_dist_relevant_mse: 4.7722 - val_dist_dist_iou_metric: 0.6546 - lr: 0.0010
# Epoch 26/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3943 - prob_loss: 0.1991 - dist_loss: 0.9759 - prob_kld: 0.0481 - dist_relevant_mae: 0.9757 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3952 - prob_loss: 0.1996 - dist_loss: 0.9781 - prob_kld: 0.0481 - dist_relevant_mae: 0.9778 - dist_relevant_mse: 2.6219 - dist_dist_iou_metric: 0.7277 - val_loss: 0.4717 - val_prob_loss: 0.2209 - val_dist_loss: 1.2543 - val_prob_kld: 0.0667 - val_dist_relevant_mae: 1.2540 - val_dist_relevant_mse: 4.6846 - val_dist_dist_iou_metric: 0.6735 - lr: 0.0010
# Epoch 27/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3945 - prob_loss: 0.2036 - dist_loss: 0.9549 - prob_kld: 0.0472 - dist_relevant_mae: 0.9546 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3944 - prob_loss: 0.2037 - dist_loss: 0.9538 - prob_kld: 0.0472 - dist_relevant_mae: 0.9535 - dist_relevant_mse: 2.5198 - dist_dist_iou_metric: 0.7358 - val_loss: 0.4776 - val_prob_loss: 0.2250 - val_dist_loss: 1.2630 - val_prob_kld: 0.0709 - val_dist_relevant_mae: 1.2627 - val_dist_relevant_mse: 4.7051 - val_dist_dist_iou_metric: 0.6683 - lr: 0.0010
# Epoch 28/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3963 - prob_loss: 0.2025 - dist_loss: 0.9686 - prob_kld: 0.0490 - dist_relevant_mae: 0.9684 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3961 - prob_loss: 0.2015 - dist_loss: 0.9733 - prob_kld: 0.0488 - dist_relevant_mae: 0.9730 - dist_relevant_mse: 2.6255 - dist_dist_iou_metric: 0.7317 - val_loss: 0.4881 - val_prob_loss: 0.2276 - val_dist_loss: 1.3024 - val_prob_kld: 0.0735 - val_dist_relevant_mae: 1.3021 - val_dist_relevant_mse: 5.0237 - val_dist_dist_iou_metric: 0.6679 - lr: 0.0010
# Epoch 29/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3981 - prob_loss: 0.2023 - dist_loss: 0.9786 - prob_kld: 0.0489 - dist_relevant_mae: 0.9784 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3983 - prob_loss: 0.2028 - dist_loss: 0.9775 - prob_kld: 0.0489 - dist_relevant_mae: 0.9772 - dist_relevant_mse: 2.6325 - dist_dist_iou_metric: 0.7308 - val_loss: 0.4764 - val_prob_loss: 0.2241 - val_dist_loss: 1.2611 - val_prob_kld: 0.0700 - val_dist_relevant_mae: 1.2608 - val_dist_relevant_mse: 4.8328 - val_dist_dist_iou_metric: 0.6748 - lr: 0.0010
# Epoch 30/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3855 - prob_loss: 0.1970 - dist_loss: 0.9425 - prob_kld: 0.0447 - dist_relevant_mae: 0.9422 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3850 - prob_loss: 0.1968 - dist_loss: 0.9413 - prob_kld: 0.0446 - dist_relevant_mae: 0.9410 - dist_relevant_mse: 2.4560 - dist_dist_iou_metric: 0.7377 - val_loss: 0.4814 - val_prob_loss: 0.2265 - val_dist_loss: 1.2742 - val_prob_kld: 0.0724 - val_dist_relevant_mae: 1.2740 - val_dist_relevant_mse: 4.8246 - val_dist_dist_iou_metric: 0.6634 - lr: 0.0010
# Epoch 31/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3930 - prob_loss: 0.2001 - dist_loss: 0.9643 - prob_kld: 0.0467 - dist_relevant_mae: 0.9640 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3927 - prob_loss: 0.2003 - dist_loss: 0.9620 - prob_kld: 0.0467 - dist_relevant_mae: 0.9617 - dist_relevant_mse: 2.5422 - dist_dist_iou_metric: 0.7336 - val_loss: 0.4795 - val_prob_loss: 0.2242 - val_dist_loss: 1.2766 - val_prob_kld: 0.0701 - val_dist_relevant_mae: 1.2763 - val_dist_relevant_mse: 4.8837 - val_dist_dist_iou_metric: 0.6653 - lr: 0.0010
# Epoch 32/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3827 - prob_loss: 0.1996 - dist_loss: 0.9153 - prob_kld: 0.0450 - dist_relevant_mae: 0.9151 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3824 - prob_loss: 0.1994 - dist_loss: 0.9149 - prob_kld: 0.0450 - dist_relevant_mae: 0.9146 - dist_relevant_mse: 2.3083 - dist_dist_iou_metric: 0.7432 - val_loss: 0.4748 - val_prob_loss: 0.2226 - val_dist_loss: 1.2608 - val_prob_kld: 0.0685 - val_dist_relevant_mae: 1.2606 - val_dist_relevant_mse: 4.7989 - val_dist_dist_iou_metric: 0.6738 - lr: 0.0010
# Epoch 33/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3786 - prob_loss: 0.1941 - dist_loss: 0.9225 - prob_kld: 0.0431 - dist_relevant_mae: 0.9223 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3803 - prob_loss: 0.1954 - dist_loss: 0.9245 - prob_kld: 0.0433 - dist_relevant_mae: 0.9242 - dist_relevant_mse: 2.3689 - dist_dist_iou_metric: 0.7426 - val_loss: 0.4845 - val_prob_loss: 0.2241 - val_dist_loss: 1.3020 - val_prob_kld: 0.0700 - val_dist_relevant_mae: 1.3017 - val_dist_relevant_mse: 4.9250 - val_dist_dist_iou_metric: 0.6531 - lr: 0.0010
# Epoch 34/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3800 - prob_loss: 0.1979 - dist_loss: 0.9106 - prob_kld: 0.0442 - dist_relevant_mae: 0.9103 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3800 - prob_loss: 0.1981 - dist_loss: 0.9093 - prob_kld: 0.0442 - dist_relevant_mae: 0.9091 - dist_relevant_mse: 2.2882 - dist_dist_iou_metric: 0.7437 - val_loss: 0.4778 - val_prob_loss: 0.2247 - val_dist_loss: 1.2655 - val_prob_kld: 0.0706 - val_dist_relevant_mae: 1.2652 - val_dist_relevant_mse: 4.8548 - val_dist_dist_iou_metric: 0.6700 - lr: 0.0010
# Epoch 35/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3781 - prob_loss: 0.1974 - dist_loss: 0.9036 - prob_kld: 0.0425 - dist_relevant_mae: 0.9033 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3781 - prob_loss: 0.1970 - dist_loss: 0.9057 - prob_kld: 0.0425 - dist_relevant_mae: 0.9054 - dist_relevant_mse: 2.3215 - dist_dist_iou_metric: 0.7498 - val_loss: 0.4779 - val_prob_loss: 0.2254 - val_dist_loss: 1.2625 - val_prob_kld: 0.0713 - val_dist_relevant_mae: 1.2622 - val_dist_relevant_mse: 4.8111 - val_dist_dist_iou_metric: 0.6775 - lr: 0.0010
# Epoch 36/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3751 - prob_loss: 0.1960 - dist_loss: 0.8955 - prob_kld: 0.0432 - dist_relevant_mae: 0.8952 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3749 - prob_loss: 0.1960 - dist_loss: 0.8944 - prob_kld: 0.0431 - dist_relevant_mae: 0.8942 - dist_relevant_mse: 2.2474 - dist_dist_iou_metric: 0.7489 - val_loss: 0.4768 - val_prob_loss: 0.2252 - val_dist_loss: 1.2579 - val_prob_kld: 0.0711 - val_dist_relevant_mae: 1.2576 - val_dist_relevant_mse: 4.7570 - val_dist_dist_iou_metric: 0.6718 - lr: 0.0010
# Epoch 37/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3710 - prob_loss: 0.1938 - dist_loss: 0.8864 - prob_kld: 0.0421 - dist_relevant_mae: 0.8861 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3713 - prob_loss: 0.1940 - dist_loss: 0.8866 - prob_kld: 0.0421 - dist_relevant_mae: 0.8863 - dist_relevant_mse: 2.2153 - dist_dist_iou_metric: 0.7501 - val_loss: 0.4823 - val_prob_loss: 0.2269 - val_dist_loss: 1.2769 - val_prob_kld: 0.0728 - val_dist_relevant_mae: 1.2766 - val_dist_relevant_mse: 4.8661 - val_dist_dist_iou_metric: 0.6708 - lr: 0.0010
# Epoch 38/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3701 - prob_loss: 0.1925 - dist_loss: 0.8877 - prob_kld: 0.0413 - dist_relevant_mae: 0.8874 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3699 - prob_loss: 0.1925 - dist_loss: 0.8871 - prob_kld: 0.0414 - dist_relevant_mae: 0.8869 - dist_relevant_mse: 2.1977 - dist_dist_iou_metric: 0.7520 - val_loss: 0.4832 - val_prob_loss: 0.2254 - val_dist_loss: 1.2895 - val_prob_kld: 0.0712 - val_dist_relevant_mae: 1.2892 - val_dist_relevant_mse: 5.0829 - val_dist_dist_iou_metric: 0.6655 - lr: 0.0010
# Epoch 39/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3767 - prob_loss: 0.1995 - dist_loss: 0.8859 - prob_kld: 0.0432 - dist_relevant_mae: 0.8856 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3759 - prob_loss: 0.1991 - dist_loss: 0.8841 - prob_kld: 0.0431 - dist_relevant_mae: 0.8838 - dist_relevant_mse: 2.1878 - dist_dist_iou_metric: 0.7511 - val_loss: 0.4820 - val_prob_loss: 0.2292 - val_dist_loss: 1.2640 - val_prob_kld: 0.0751 - val_dist_relevant_mae: 1.2637 - val_dist_relevant_mse: 4.8547 - val_dist_dist_iou_metric: 0.6729 - lr: 0.0010
# Epoch 40/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3673 - prob_loss: 0.1933 - dist_loss: 0.8702 - prob_kld: 0.0413 - dist_relevant_mae: 0.8699 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3665 - prob_loss: 0.1924 - dist_loss: 0.8704 - prob_kld: 0.0411 - dist_relevant_mae: 0.8701 - dist_relevant_mse: 2.1547 - dist_dist_iou_metric: 0.7552 - val_loss: 0.4819 - val_prob_loss: 0.2291 - val_dist_loss: 1.2642 - val_prob_kld: 0.0749 - val_dist_relevant_mae: 1.2640 - val_dist_relevant_mse: 4.8991 - val_dist_dist_iou_metric: 0.6762 - lr: 0.0010
# Epoch 41/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3717 - prob_loss: 0.1956 - dist_loss: 0.8805 - prob_kld: 0.0414 - dist_relevant_mae: 0.8803 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3721 - prob_loss: 0.1960 - dist_loss: 0.8802 - prob_kld: 0.0415 - dist_relevant_mae: 0.8799 - dist_relevant_mse: 2.2029 - dist_dist_iou_metric: 0.7537 - val_loss: 0.4836 - val_prob_loss: 0.2241 - val_dist_loss: 1.2971 - val_prob_kld: 0.0700 - val_dist_relevant_mae: 1.2968 - val_dist_relevant_mse: 4.9834 - val_dist_dist_iou_metric: 0.6779 - lr: 0.0010
# Epoch 42/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3671 - prob_loss: 0.1945 - dist_loss: 0.8630 - prob_kld: 0.0407 - dist_relevant_mae: 0.8627 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3670 - prob_loss: 0.1946 - dist_loss: 0.8617 - prob_kld: 0.0406 - dist_relevant_mae: 0.8614 - dist_relevant_mse: 2.0929 - dist_dist_iou_metric: 0.7572 - val_loss: 0.4827 - val_prob_loss: 0.2273 - val_dist_loss: 1.2771 - val_prob_kld: 0.0732 - val_dist_relevant_mae: 1.2769 - val_dist_relevant_mse: 4.9517 - val_dist_dist_iou_metric: 0.6648 - lr: 0.0010
# Epoch 43/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3626 - prob_loss: 0.1936 - dist_loss: 0.8449 - prob_kld: 0.0397 - dist_relevant_mae: 0.8447 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3635 - prob_loss: 0.1943 - dist_loss: 0.8458 - prob_kld: 0.0398 - dist_relevant_mae: 0.8455 - dist_relevant_mse: 2.0311 - dist_dist_iou_metric: 0.7602 - val_loss: 0.4853 - val_prob_loss: 0.2293 - val_dist_loss: 1.2802 - val_prob_kld: 0.0751 - val_dist_relevant_mae: 1.2799 - val_dist_relevant_mse: 5.0152 - val_dist_dist_iou_metric: 0.6765 - lr: 0.0010
# Epoch 44/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3673 - prob_loss: 0.1929 - dist_loss: 0.8720 - prob_kld: 0.0400 - dist_relevant_mae: 0.8717 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3670 - prob_loss: 0.1930 - dist_loss: 0.8702 - prob_kld: 0.0399 - dist_relevant_mae: 0.8700 - dist_relevant_mse: 2.1207 - dist_dist_iou_metric: 0.7572 - val_loss: 0.4852 - val_prob_loss: 0.2262 - val_dist_loss: 1.2949 - val_prob_kld: 0.0721 - val_dist_relevant_mae: 1.2947 - val_dist_relevant_mse: 4.9627 - val_dist_dist_iou_metric: 0.6630 - lr: 0.0010
# Epoch 45/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3658 - prob_loss: 0.1951 - dist_loss: 0.8536 - prob_kld: 0.0399 - dist_relevant_mae: 0.8534 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3649 - prob_loss: 0.1945 - dist_loss: 0.8519 - prob_kld: 0.0398 - dist_relevant_mae: 0.8517 - dist_relevant_mse: 2.0836 - dist_dist_iou_metric: 0.7601 - val_loss: 0.4774 - val_prob_loss: 0.2256 - val_dist_loss: 1.2590 - val_prob_kld: 0.0715 - val_dist_relevant_mae: 1.2587 - val_dist_relevant_mse: 4.8403 - val_dist_dist_iou_metric: 0.6789 - lr: 0.0010
# Epoch 46/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3637 - prob_loss: 0.1909 - dist_loss: 0.8637 - prob_kld: 0.0419 - dist_relevant_mae: 0.8635 - dist_relev
# 100/100 [==============================] - 3s 35ms/step - loss: 0.3638 - prob_loss: 0.1909 - dist_loss: 0.8646 - prob_kld: 0.0420 - dist_relevant_mae: 0.8644 - dist_relevant_mse: 2.1142 - dist_dist_iou_metric: 0.7570 - val_loss: 0.4810 - val_prob_loss: 0.2271 - val_dist_loss: 1.2695 - val_prob_kld: 0.0730 - val_dist_relevant_mae: 1.2692 - val_dist_relevant_mse: 4.9470 - val_dist_dist_iou_metric: 0.6784 - lr: 0.0010
# Epoch 47/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3634 - prob_loss: 0.1940 - dist_loss: 0.8471 - prob_kld: 0.0392 - dist_relevant_mae: 0.8469 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3634 - prob_loss: 0.1939 - dist_loss: 0.8477 - prob_kld: 0.0392 - dist_relevant_mae: 0.8474 - dist_relevant_mse: 2.0570 - dist_dist_iou_metric: 0.7625 - val_loss: 0.4799 - val_prob_loss: 0.2270 - val_dist_loss: 1.2648 - val_prob_kld: 0.0728 - val_dist_relevant_mae: 1.2645 - val_dist_relevant_mse: 4.8224 - val_dist_dist_iou_metric: 0.6717 - lr: 0.0010
# Epoch 48/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3584 - prob_loss: 0.1908 - dist_loss: 0.8377 - prob_kld: 0.0384 - dist_relevant_mae: 0.8374 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.3584 - prob_loss: 0.1908 - dist_loss: 0.8377 - prob_kld: 0.0384 - dist_relevant_mae: 0.8374 - dist_relevant_mse: 1.9822 - dist_dist_iou_metric: 0.7635 - val_loss: 0.4815 - val_prob_loss: 0.2276 - val_dist_loss: 1.2697 - val_prob_kld: 0.0734 - val_dist_relevant_mae: 1.2695 - val_dist_relevant_mse: 4.9320 - val_dist_dist_iou_metric: 0.6750 - lr: 0.0010
# Epoch 49/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3649 - prob_loss: 0.1954 - dist_loss: 0.8475 - prob_kld: 0.0401 - dist_relevant_mae: 0.8473 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3647 - prob_loss: 0.1954 - dist_loss: 0.8464 - prob_kld: 0.0400 - dist_relevant_mae: 0.8461 - dist_relevant_mse: 2.0574 - dist_dist_iou_metric: 0.7621 - val_loss: 0.4967 - val_prob_loss: 0.2332 - val_dist_loss: 1.3174 - val_prob_kld: 0.0791 - val_dist_relevant_mae: 1.3171 - val_dist_relevant_mse: 5.2039 - val_dist_dist_iou_metric: 0.6533 - lr: 0.0010
# Epoch 50/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3604 - prob_loss: 0.1905 - dist_loss: 0.8495 - prob_kld: 0.0384 - dist_relevant_mae: 0.8492 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3610 - prob_loss: 0.1907 - dist_loss: 0.8512 - prob_kld: 0.0385 - dist_relevant_mae: 0.8509 - dist_relevant_mse: 2.0383 - dist_dist_iou_metric: 0.7613 - val_loss: 0.4809 - val_prob_loss: 0.2264 - val_dist_loss: 1.2723 - val_prob_kld: 0.0723 - val_dist_relevant_mae: 1.2720 - val_dist_relevant_mse: 4.9793 - val_dist_dist_iou_metric: 0.6758 - lr: 0.0010
# Epoch 51/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3579 - prob_loss: 0.1938 - dist_loss: 0.8206 - prob_kld: 0.0381 - dist_relevant_mae: 0.8204 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3583 - prob_loss: 0.1944 - dist_loss: 0.8196 - prob_kld: 0.0382 - dist_relevant_mae: 0.8193 - dist_relevant_mse: 1.9088 - dist_dist_iou_metric: 0.7678 - val_loss: 0.4855 - val_prob_loss: 0.2292 - val_dist_loss: 1.2817 - val_prob_kld: 0.0750 - val_dist_relevant_mae: 1.2815 - val_dist_relevant_mse: 5.0205 - val_dist_dist_iou_metric: 0.6725 - lr: 0.0010
# Epoch 52/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3539 - prob_loss: 0.1884 - dist_loss: 0.8276 - prob_kld: 0.0370 - dist_relevant_mae: 0.8273 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3537 - prob_loss: 0.1878 - dist_loss: 0.8299 - prob_kld: 0.0370 - dist_relevant_mae: 0.8297 - dist_relevant_mse: 1.9528 - dist_dist_iou_metric: 0.7650 - val_loss: 0.4918 - val_prob_loss: 0.2323 - val_dist_loss: 1.2976 - val_prob_kld: 0.0782 - val_dist_relevant_mae: 1.2973 - val_dist_relevant_mse: 5.0974 - val_dist_dist_iou_metric: 0.6635 - lr: 0.0010
# Epoch 53/400
#  99/100 [============================>.] - ETA: 0s - loss: 0.3570 - prob_loss: 0.1932 - dist_loss: 0.8186 - prob_kld: 0.0382 - dist_relevant_mae: 0.8183 - dist_relevant_mse: 1.9222 - dist_dist_iou_metric: 0.7673
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 [==============================] - 0s 3ms/step
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3562 - prob_loss: 0.1925 - dist_loss: 0.8183 - prob_kld: 0.0381 - dist_relevant_mae: 0.8181 - dist_relevant_mse: 1.9199 - dist_dist_iou_metric: 0.7672 - val_loss: 0.4785 - val_prob_loss: 0.2254 - val_dist_loss: 1.2658 - val_prob_kld: 0.0713 - val_dist_relevant_mae: 1.2655 - val_dist_relevant_mse: 4.9518 - val_dist_dist_iou_metric: 0.6772 - lr: 0.0010
# Epoch 54/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3475 - prob_loss: 0.1893 - dist_loss: 0.7910 - prob_kld: 0.0355 - dist_relevant_mae: 0.7908 - dist_relev
# 100/100 [==============================] - 3s 35ms/step - loss: 0.3472 - prob_loss: 0.1891 - dist_loss: 0.7904 - prob_kld: 0.0354 - dist_relevant_mae: 0.7901 - dist_relevant_mse: 1.8480 - dist_dist_iou_metric: 0.7776 - val_loss: 0.4817 - val_prob_loss: 0.2289 - val_dist_loss: 1.2637 - val_prob_kld: 0.0748 - val_dist_relevant_mae: 1.2635 - val_dist_relevant_mse: 4.9216 - val_dist_dist_iou_metric: 0.6748 - lr: 5.0000e-04
# Epoch 55/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3403 - prob_loss: 0.1876 - dist_loss: 0.7634 - prob_kld: 0.0345 - dist_relevant_mae: 0.7632 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3409 - prob_loss: 0.1878 - dist_loss: 0.7653 - prob_kld: 0.0346 - dist_relevant_mae: 0.7651 - dist_relevant_mse: 1.7345 - dist_dist_iou_metric: 0.7806 - val_loss: 0.4842 - val_prob_loss: 0.2299 - val_dist_loss: 1.2713 - val_prob_kld: 0.0758 - val_dist_relevant_mae: 1.2711 - val_dist_relevant_mse: 5.0090 - val_dist_dist_iou_metric: 0.6733 - lr: 5.0000e-04
# Epoch 56/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3396 - prob_loss: 0.1867 - dist_loss: 0.7647 - prob_kld: 0.0337 - dist_relevant_mae: 0.7645 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3387 - prob_loss: 0.1861 - dist_loss: 0.7630 - prob_kld: 0.0335 - dist_relevant_mae: 0.7627 - dist_relevant_mse: 1.7301 - dist_dist_iou_metric: 0.7827 - val_loss: 0.4883 - val_prob_loss: 0.2334 - val_dist_loss: 1.2745 - val_prob_kld: 0.0793 - val_dist_relevant_mae: 1.2742 - val_dist_relevant_mse: 5.0317 - val_dist_dist_iou_metric: 0.6737 - lr: 5.0000e-04
# Epoch 57/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3377 - prob_loss: 0.1865 - dist_loss: 0.7563 - prob_kld: 0.0333 - dist_relevant_mae: 0.7560 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3381 - prob_loss: 0.1869 - dist_loss: 0.7559 - prob_kld: 0.0334 - dist_relevant_mae: 0.7557 - dist_relevant_mse: 1.6848 - dist_dist_iou_metric: 0.7843 - val_loss: 0.4873 - val_prob_loss: 0.2319 - val_dist_loss: 1.2771 - val_prob_kld: 0.0777 - val_dist_relevant_mae: 1.2768 - val_dist_relevant_mse: 5.0537 - val_dist_dist_iou_metric: 0.6709 - lr: 5.0000e-04
# Epoch 58/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3342 - prob_loss: 0.1857 - dist_loss: 0.7424 - prob_kld: 0.0329 - dist_relevant_mae: 0.7422 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3345 - prob_loss: 0.1859 - dist_loss: 0.7429 - prob_kld: 0.0329 - dist_relevant_mae: 0.7427 - dist_relevant_mse: 1.6157 - dist_dist_iou_metric: 0.7862 - val_loss: 0.4865 - val_prob_loss: 0.2317 - val_dist_loss: 1.2737 - val_prob_kld: 0.0776 - val_dist_relevant_mae: 1.2735 - val_dist_relevant_mse: 5.0835 - val_dist_dist_iou_metric: 0.6761 - lr: 5.0000e-04
# Epoch 59/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3388 - prob_loss: 0.1888 - dist_loss: 0.7502 - prob_kld: 0.0331 - dist_relevant_mae: 0.7500 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3388 - prob_loss: 0.1888 - dist_loss: 0.7502 - prob_kld: 0.0331 - dist_relevant_mae: 0.7500 - dist_relevant_mse: 1.6922 - dist_dist_iou_metric: 0.7864 - val_loss: 0.4868 - val_prob_loss: 0.2320 - val_dist_loss: 1.2738 - val_prob_kld: 0.0779 - val_dist_relevant_mae: 1.2736 - val_dist_relevant_mse: 5.0183 - val_dist_dist_iou_metric: 0.6744 - lr: 5.0000e-04
# Epoch 60/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3314 - prob_loss: 0.1819 - dist_loss: 0.7474 - prob_kld: 0.0321 - dist_relevant_mae: 0.7471 - dist_relev
# 100/100 [==============================] - 4s 38ms/step - loss: 0.3313 - prob_loss: 0.1821 - dist_loss: 0.7460 - prob_kld: 0.0320 - dist_relevant_mae: 0.7458 - dist_relevant_mse: 1.6418 - dist_dist_iou_metric: 0.7862 - val_loss: 0.4923 - val_prob_loss: 0.2352 - val_dist_loss: 1.2855 - val_prob_kld: 0.0811 - val_dist_relevant_mae: 1.2852 - val_dist_relevant_mse: 5.1022 - val_dist_dist_iou_metric: 0.6689 - lr: 5.0000e-04
# Epoch 61/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3381 - prob_loss: 0.1883 - dist_loss: 0.7491 - prob_kld: 0.0332 - dist_relevant_mae: 0.7489 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3382 - prob_loss: 0.1885 - dist_loss: 0.7486 - prob_kld: 0.0333 - dist_relevant_mae: 0.7484 - dist_relevant_mse: 1.6556 - dist_dist_iou_metric: 0.7862 - val_loss: 0.4842 - val_prob_loss: 0.2296 - val_dist_loss: 1.2730 - val_prob_kld: 0.0755 - val_dist_relevant_mae: 1.2727 - val_dist_relevant_mse: 5.0232 - val_dist_dist_iou_metric: 0.6742 - lr: 5.0000e-04
# Epoch 62/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3347 - prob_loss: 0.1862 - dist_loss: 0.7425 - prob_kld: 0.0325 - dist_relevant_mae: 0.7422 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3347 - prob_loss: 0.1859 - dist_loss: 0.7437 - prob_kld: 0.0324 - dist_relevant_mae: 0.7435 - dist_relevant_mse: 1.6309 - dist_dist_iou_metric: 0.7868 - val_loss: 0.4856 - val_prob_loss: 0.2309 - val_dist_loss: 1.2733 - val_prob_kld: 0.0768 - val_dist_relevant_mae: 1.2730 - val_dist_relevant_mse: 5.0505 - val_dist_dist_iou_metric: 0.6757 - lr: 5.0000e-04
# Epoch 63/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3343 - prob_loss: 0.1872 - dist_loss: 0.7353 - prob_kld: 0.0327 - dist_relevant_mae: 0.7351 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3332 - prob_loss: 0.1862 - dist_loss: 0.7351 - prob_kld: 0.0325 - dist_relevant_mae: 0.7348 - dist_relevant_mse: 1.5864 - dist_dist_iou_metric: 0.7887 - val_loss: 0.4905 - val_prob_loss: 0.2339 - val_dist_loss: 1.2827 - val_prob_kld: 0.0798 - val_dist_relevant_mae: 1.2825 - val_dist_relevant_mse: 5.1820 - val_dist_dist_iou_metric: 0.6732 - lr: 5.0000e-04
# Epoch 64/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3321 - prob_loss: 0.1847 - dist_loss: 0.7372 - prob_kld: 0.0320 - dist_relevant_mae: 0.7370 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3321 - prob_loss: 0.1843 - dist_loss: 0.7391 - prob_kld: 0.0320 - dist_relevant_mae: 0.7389 - dist_relevant_mse: 1.6564 - dist_dist_iou_metric: 0.7874 - val_loss: 0.4896 - val_prob_loss: 0.2341 - val_dist_loss: 1.2777 - val_prob_kld: 0.0799 - val_dist_relevant_mae: 1.2775 - val_dist_relevant_mse: 5.0849 - val_dist_dist_iou_metric: 0.6748 - lr: 5.0000e-04
# Epoch 65/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3342 - prob_loss: 0.1869 - dist_loss: 0.7368 - prob_kld: 0.0316 - dist_relevant_mae: 0.7365 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3339 - prob_loss: 0.1862 - dist_loss: 0.7385 - prob_kld: 0.0316 - dist_relevant_mae: 0.7382 - dist_relevant_mse: 1.6252 - dist_dist_iou_metric: 0.7906 - val_loss: 0.4997 - val_prob_loss: 0.2393 - val_dist_loss: 1.3021 - val_prob_kld: 0.0851 - val_dist_relevant_mae: 1.3019 - val_dist_relevant_mse: 5.3053 - val_dist_dist_iou_metric: 0.6685 - lr: 5.0000e-04
# Epoch 66/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3317 - prob_loss: 0.1832 - dist_loss: 0.7424 - prob_kld: 0.0320 - dist_relevant_mae: 0.7422 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3313 - prob_loss: 0.1830 - dist_loss: 0.7410 - prob_kld: 0.0319 - dist_relevant_mae: 0.7408 - dist_relevant_mse: 1.6413 - dist_dist_iou_metric: 0.7879 - val_loss: 0.4902 - val_prob_loss: 0.2336 - val_dist_loss: 1.2830 - val_prob_kld: 0.0795 - val_dist_relevant_mae: 1.2827 - val_dist_relevant_mse: 5.1793 - val_dist_dist_iou_metric: 0.6752 - lr: 5.0000e-04
# Epoch 67/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3351 - prob_loss: 0.1881 - dist_loss: 0.7349 - prob_kld: 0.0320 - dist_relevant_mae: 0.7347 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3351 - prob_loss: 0.1881 - dist_loss: 0.7349 - prob_kld: 0.0320 - dist_relevant_mae: 0.7347 - dist_relevant_mse: 1.6071 - dist_dist_iou_metric: 0.7881 - val_loss: 0.4896 - val_prob_loss: 0.2337 - val_dist_loss: 1.2794 - val_prob_kld: 0.0796 - val_dist_relevant_mae: 1.2792 - val_dist_relevant_mse: 5.1044 - val_dist_dist_iou_metric: 0.6736 - lr: 5.0000e-04
# Epoch 68/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3362 - prob_loss: 0.1870 - dist_loss: 0.7459 - prob_kld: 0.0319 - dist_relevant_mae: 0.7457 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3363 - prob_loss: 0.1872 - dist_loss: 0.7455 - prob_kld: 0.0318 - dist_relevant_mae: 0.7453 - dist_relevant_mse: 1.6372 - dist_dist_iou_metric: 0.7883 - val_loss: 0.4941 - val_prob_loss: 0.2346 - val_dist_loss: 1.2979 - val_prob_kld: 0.0804 - val_dist_relevant_mae: 1.2977 - val_dist_relevant_mse: 5.1992 - val_dist_dist_iou_metric: 0.6694 - lr: 5.0000e-04
# Epoch 69/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3252 - prob_loss: 0.1789 - dist_loss: 0.7314 - prob_kld: 0.0306 - dist_relevant_mae: 0.7312 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.3257 - prob_loss: 0.1796 - dist_loss: 0.7307 - prob_kld: 0.0306 - dist_relevant_mae: 0.7304 - dist_relevant_mse: 1.5679 - dist_dist_iou_metric: 0.7885 - val_loss: 0.4926 - val_prob_loss: 0.2353 - val_dist_loss: 1.2865 - val_prob_kld: 0.0812 - val_dist_relevant_mae: 1.2862 - val_dist_relevant_mse: 5.1197 - val_dist_dist_iou_metric: 0.6706 - lr: 5.0000e-04
# Epoch 70/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3333 - prob_loss: 0.1860 - dist_loss: 0.7366 - prob_kld: 0.0321 - dist_relevant_mae: 0.7364 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3349 - prob_loss: 0.1877 - dist_loss: 0.7358 - prob_kld: 0.0321 - dist_relevant_mae: 0.7356 - dist_relevant_mse: 1.6163 - dist_dist_iou_metric: 0.7891 - val_loss: 0.4922 - val_prob_loss: 0.2352 - val_dist_loss: 1.2848 - val_prob_kld: 0.0811 - val_dist_relevant_mae: 1.2845 - val_dist_relevant_mse: 5.1681 - val_dist_dist_iou_metric: 0.6752 - lr: 5.0000e-04
# Epoch 71/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3297 - prob_loss: 0.1845 - dist_loss: 0.7260 - prob_kld: 0.0310 - dist_relevant_mae: 0.7258 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3300 - prob_loss: 0.1845 - dist_loss: 0.7279 - prob_kld: 0.0311 - dist_relevant_mae: 0.7276 - dist_relevant_mse: 1.5981 - dist_dist_iou_metric: 0.7903 - val_loss: 0.4878 - val_prob_loss: 0.2319 - val_dist_loss: 1.2796 - val_prob_kld: 0.0778 - val_dist_relevant_mae: 1.2793 - val_dist_relevant_mse: 5.1156 - val_dist_dist_iou_metric: 0.6756 - lr: 5.0000e-04
# Epoch 72/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3272 - prob_loss: 0.1839 - dist_loss: 0.7167 - prob_kld: 0.0305 - dist_relevant_mae: 0.7164 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3280 - prob_loss: 0.1849 - dist_loss: 0.7156 - prob_kld: 0.0306 - dist_relevant_mae: 0.7154 - dist_relevant_mse: 1.5120 - dist_dist_iou_metric: 0.7932 - val_loss: 0.4933 - val_prob_loss: 0.2354 - val_dist_loss: 1.2899 - val_prob_kld: 0.0812 - val_dist_relevant_mae: 1.2896 - val_dist_relevant_mse: 5.1806 - val_dist_dist_iou_metric: 0.6729 - lr: 5.0000e-04
# Epoch 73/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3302 - prob_loss: 0.1847 - dist_loss: 0.7276 - prob_kld: 0.0310 - dist_relevant_mae: 0.7274 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.3305 - prob_loss: 0.1851 - dist_loss: 0.7273 - prob_kld: 0.0311 - dist_relevant_mae: 0.7270 - dist_relevant_mse: 1.5758 - dist_dist_iou_metric: 0.7911 - val_loss: 0.4922 - val_prob_loss: 0.2353 - val_dist_loss: 1.2844 - val_prob_kld: 0.0812 - val_dist_relevant_mae: 1.2841 - val_dist_relevant_mse: 5.1325 - val_dist_dist_iou_metric: 0.6718 - lr: 5.0000e-04
# Epoch 74/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3269 - prob_loss: 0.1807 - dist_loss: 0.7307 - prob_kld: 0.0306 - dist_relevant_mae: 0.7304 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3277 - prob_loss: 0.1817 - dist_loss: 0.7301 - prob_kld: 0.0307 - dist_relevant_mae: 0.7299 - dist_relevant_mse: 1.5734 - dist_dist_iou_metric: 0.7904 - val_loss: 0.4925 - val_prob_loss: 0.2349 - val_dist_loss: 1.2877 - val_prob_kld: 0.0808 - val_dist_relevant_mae: 1.2875 - val_dist_relevant_mse: 5.1740 - val_dist_dist_iou_metric: 0.6746 - lr: 5.0000e-04
# Epoch 75/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3336 - prob_loss: 0.1852 - dist_loss: 0.7419 - prob_kld: 0.0311 - dist_relevant_mae: 0.7417 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3339 - prob_loss: 0.1855 - dist_loss: 0.7424 - prob_kld: 0.0311 - dist_relevant_mae: 0.7421 - dist_relevant_mse: 1.6456 - dist_dist_iou_metric: 0.7883 - val_loss: 0.4898 - val_prob_loss: 0.2340 - val_dist_loss: 1.2790 - val_prob_kld: 0.0799 - val_dist_relevant_mae: 1.2787 - val_dist_relevant_mse: 5.0832 - val_dist_dist_iou_metric: 0.6738 - lr: 5.0000e-04
# Epoch 76/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3277 - prob_loss: 0.1843 - dist_loss: 0.7170 - prob_kld: 0.0305 - dist_relevant_mae: 0.7168 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3276 - prob_loss: 0.1845 - dist_loss: 0.7157 - prob_kld: 0.0305 - dist_relevant_mae: 0.7155 - dist_relevant_mse: 1.5144 - dist_dist_iou_metric: 0.7934 - val_loss: 0.4882 - val_prob_loss: 0.2322 - val_dist_loss: 1.2797 - val_prob_kld: 0.0781 - val_dist_relevant_mae: 1.2794 - val_dist_relevant_mse: 5.1588 - val_dist_dist_iou_metric: 0.6776 - lr: 5.0000e-04
# Epoch 77/400
# ...
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2918 - prob_loss: 0.1726 - dist_loss: 0.5960 - prob_kld: 0.0186 - dist_relevant_mae: 0.5958 - dist_relevant_mse: 1.1915 - dist_dist_iou_metric: 0.8248 - val_loss: 0.5385 - val_prob_loss: 0.2710 - val_dist_loss: 1.3376 - val_prob_kld: 0.1148 - val_dist_relevant_mae: 1.3374 - val_dist_relevant_mse: 5.6419 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 377/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2920 - prob_loss: 0.1726 - dist_loss: 0.5971 - prob_kld: 0.0188 - dist_relevant_mae: 0.5969 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2915 - prob_loss: 0.1723 - dist_loss: 0.5959 - prob_kld: 0.0187 - dist_relevant_mae: 0.5957 - dist_relevant_mse: 1.1703 - dist_dist_iou_metric: 0.8239 - val_loss: 0.5384 - val_prob_loss: 0.2709 - val_dist_loss: 1.3374 - val_prob_kld: 0.1147 - val_dist_relevant_mae: 1.3372 - val_dist_relevant_mse: 5.6410 - val_dist_dist_iou_metric: 0.6648 - lr: 1.9531e-06
# Epoch 378/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2877 - prob_loss: 0.1713 - dist_loss: 0.5819 - prob_kld: 0.0181 - dist_relevant_mae: 0.5817 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2878 - prob_loss: 0.1713 - dist_loss: 0.5827 - prob_kld: 0.0182 - dist_relevant_mae: 0.5825 - dist_relevant_mse: 1.0918 - dist_dist_iou_metric: 0.8265 - val_loss: 0.5385 - val_prob_loss: 0.2710 - val_dist_loss: 1.3375 - val_prob_kld: 0.1148 - val_dist_relevant_mae: 1.3373 - val_dist_relevant_mse: 5.6419 - val_dist_dist_iou_metric: 0.6648 - lr: 1.9531e-06
# Epoch 379/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2897 - prob_loss: 0.1723 - dist_loss: 0.5870 - prob_kld: 0.0183 - dist_relevant_mae: 0.5868 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2900 - prob_loss: 0.1728 - dist_loss: 0.5859 - prob_kld: 0.0183 - dist_relevant_mae: 0.5857 - dist_relevant_mse: 1.1195 - dist_dist_iou_metric: 0.8259 - val_loss: 0.5385 - val_prob_loss: 0.2710 - val_dist_loss: 1.3376 - val_prob_kld: 0.1148 - val_dist_relevant_mae: 1.3374 - val_dist_relevant_mse: 5.6410 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 380/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2929 - prob_loss: 0.1716 - dist_loss: 0.6061 - prob_kld: 0.0189 - dist_relevant_mae: 0.6059 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2927 - prob_loss: 0.1718 - dist_loss: 0.6047 - prob_kld: 0.0188 - dist_relevant_mae: 0.6045 - dist_relevant_mse: 1.1927 - dist_dist_iou_metric: 0.8238 - val_loss: 0.5386 - val_prob_loss: 0.2710 - val_dist_loss: 1.3379 - val_prob_kld: 0.1148 - val_dist_relevant_mae: 1.3377 - val_dist_relevant_mse: 5.6465 - val_dist_dist_iou_metric: 0.6648 - lr: 1.9531e-06
# Epoch 381/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2868 - prob_loss: 0.1707 - dist_loss: 0.5805 - prob_kld: 0.0180 - dist_relevant_mae: 0.5804 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2871 - prob_loss: 0.1711 - dist_loss: 0.5802 - prob_kld: 0.0180 - dist_relevant_mae: 0.5800 - dist_relevant_mse: 1.0827 - dist_dist_iou_metric: 0.8261 - val_loss: 0.5388 - val_prob_loss: 0.2712 - val_dist_loss: 1.3379 - val_prob_kld: 0.1150 - val_dist_relevant_mae: 1.3377 - val_dist_relevant_mse: 5.6455 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 382/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2932 - prob_loss: 0.1747 - dist_loss: 0.5927 - prob_kld: 0.0185 - dist_relevant_mae: 0.5925 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.2932 - prob_loss: 0.1747 - dist_loss: 0.5927 - prob_kld: 0.0185 - dist_relevant_mae: 0.5925 - dist_relevant_mse: 1.1472 - dist_dist_iou_metric: 0.8253 - val_loss: 0.5386 - val_prob_loss: 0.2711 - val_dist_loss: 1.3376 - val_prob_kld: 0.1149 - val_dist_relevant_mae: 1.3374 - val_dist_relevant_mse: 5.6413 - val_dist_dist_iou_metric: 0.6646 - lr: 1.9531e-06
# Epoch 383/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2910 - prob_loss: 0.1708 - dist_loss: 0.6012 - prob_kld: 0.0187 - dist_relevant_mae: 0.6011 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2910 - prob_loss: 0.1708 - dist_loss: 0.6012 - prob_kld: 0.0187 - dist_relevant_mae: 0.6011 - dist_relevant_mse: 1.1773 - dist_dist_iou_metric: 0.8237 - val_loss: 0.5386 - val_prob_loss: 0.2710 - val_dist_loss: 1.3378 - val_prob_kld: 0.1148 - val_dist_relevant_mae: 1.3377 - val_dist_relevant_mse: 5.6450 - val_dist_dist_iou_metric: 0.6649 - lr: 1.9531e-06
# Epoch 384/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2895 - prob_loss: 0.1718 - dist_loss: 0.5886 - prob_kld: 0.0182 - dist_relevant_mae: 0.5884 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.2890 - prob_loss: 0.1714 - dist_loss: 0.5881 - prob_kld: 0.0182 - dist_relevant_mae: 0.5879 - dist_relevant_mse: 1.1409 - dist_dist_iou_metric: 0.8255 - val_loss: 0.5388 - val_prob_loss: 0.2712 - val_dist_loss: 1.3382 - val_prob_kld: 0.1150 - val_dist_relevant_mae: 1.3380 - val_dist_relevant_mse: 5.6469 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 385/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2913 - prob_loss: 0.1731 - dist_loss: 0.5909 - prob_kld: 0.0186 - dist_relevant_mae: 0.5907 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.2913 - prob_loss: 0.1731 - dist_loss: 0.5909 - prob_kld: 0.0186 - dist_relevant_mae: 0.5907 - dist_relevant_mse: 1.1322 - dist_dist_iou_metric: 0.8253 - val_loss: 0.5389 - val_prob_loss: 0.2713 - val_dist_loss: 1.3381 - val_prob_kld: 0.1151 - val_dist_relevant_mae: 1.3379 - val_dist_relevant_mse: 5.6467 - val_dist_dist_iou_metric: 0.6646 - lr: 1.9531e-06
# Epoch 386/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2908 - prob_loss: 0.1709 - dist_loss: 0.5997 - prob_kld: 0.0183 - dist_relevant_mae: 0.5995 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2908 - prob_loss: 0.1709 - dist_loss: 0.5997 - prob_kld: 0.0183 - dist_relevant_mae: 0.5995 - dist_relevant_mse: 1.1692 - dist_dist_iou_metric: 0.8235 - val_loss: 0.5389 - val_prob_loss: 0.2712 - val_dist_loss: 1.3383 - val_prob_kld: 0.1150 - val_dist_relevant_mae: 1.3381 - val_dist_relevant_mse: 5.6498 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 387/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2888 - prob_loss: 0.1691 - dist_loss: 0.5989 - prob_kld: 0.0185 - dist_relevant_mae: 0.5987 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.2883 - prob_loss: 0.1689 - dist_loss: 0.5970 - prob_kld: 0.0184 - dist_relevant_mae: 0.5968 - dist_relevant_mse: 1.1666 - dist_dist_iou_metric: 0.8238 - val_loss: 0.5387 - val_prob_loss: 0.2711 - val_dist_loss: 1.3379 - val_prob_kld: 0.1149 - val_dist_relevant_mae: 1.3377 - val_dist_relevant_mse: 5.6444 - val_dist_dist_iou_metric: 0.6648 - lr: 1.9531e-06
# Epoch 388/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2948 - prob_loss: 0.1751 - dist_loss: 0.5986 - prob_kld: 0.0187 - dist_relevant_mae: 0.5985 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2953 - prob_loss: 0.1754 - dist_loss: 0.5993 - prob_kld: 0.0189 - dist_relevant_mae: 0.5991 - dist_relevant_mse: 1.1723 - dist_dist_iou_metric: 0.8232 - val_loss: 0.5388 - val_prob_loss: 0.2712 - val_dist_loss: 1.3380 - val_prob_kld: 0.1150 - val_dist_relevant_mae: 1.3378 - val_dist_relevant_mse: 5.6474 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 389/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2909 - prob_loss: 0.1713 - dist_loss: 0.5980 - prob_kld: 0.0184 - dist_relevant_mae: 0.5978 - dist_relev
# 100/100 [==============================] - 4s 38ms/step - loss: 0.2909 - prob_loss: 0.1708 - dist_loss: 0.6007 - prob_kld: 0.0184 - dist_relevant_mae: 0.6006 - dist_relevant_mse: 1.1928 - dist_dist_iou_metric: 0.8243 - val_loss: 0.5382 - val_prob_loss: 0.2708 - val_dist_loss: 1.3373 - val_prob_kld: 0.1146 - val_dist_relevant_mae: 1.3371 - val_dist_relevant_mse: 5.6411 - val_dist_dist_iou_metric: 0.6648 - lr: 1.9531e-06
# Epoch 390/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2909 - prob_loss: 0.1750 - dist_loss: 0.5798 - prob_kld: 0.0179 - dist_relevant_mae: 0.5796 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2905 - prob_loss: 0.1744 - dist_loss: 0.5805 - prob_kld: 0.0179 - dist_relevant_mae: 0.5803 - dist_relevant_mse: 1.0928 - dist_dist_iou_metric: 0.8275 - val_loss: 0.5389 - val_prob_loss: 0.2713 - val_dist_loss: 1.3381 - val_prob_kld: 0.1151 - val_dist_relevant_mae: 1.3379 - val_dist_relevant_mse: 5.6482 - val_dist_dist_iou_metric: 0.6646 - lr: 1.9531e-06
# Epoch 391/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2919 - prob_loss: 0.1715 - dist_loss: 0.6019 - prob_kld: 0.0191 - dist_relevant_mae: 0.6017 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2920 - prob_loss: 0.1716 - dist_loss: 0.6019 - prob_kld: 0.0191 - dist_relevant_mae: 0.6018 - dist_relevant_mse: 1.1847 - dist_dist_iou_metric: 0.8237 - val_loss: 0.5386 - val_prob_loss: 0.2710 - val_dist_loss: 1.3380 - val_prob_kld: 0.1148 - val_dist_relevant_mae: 1.3378 - val_dist_relevant_mse: 5.6483 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 392/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2900 - prob_loss: 0.1738 - dist_loss: 0.5809 - prob_kld: 0.0181 - dist_relevant_mae: 0.5807 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2900 - prob_loss: 0.1738 - dist_loss: 0.5809 - prob_kld: 0.0181 - dist_relevant_mae: 0.5807 - dist_relevant_mse: 1.0993 - dist_dist_iou_metric: 0.8269 - val_loss: 0.5391 - val_prob_loss: 0.2714 - val_dist_loss: 1.3381 - val_prob_kld: 0.1152 - val_dist_relevant_mae: 1.3379 - val_dist_relevant_mse: 5.6470 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 393/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2866 - prob_loss: 0.1674 - dist_loss: 0.5958 - prob_kld: 0.0186 - dist_relevant_mae: 0.5957 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2866 - prob_loss: 0.1674 - dist_loss: 0.5958 - prob_kld: 0.0186 - dist_relevant_mae: 0.5957 - dist_relevant_mse: 1.1623 - dist_dist_iou_metric: 0.8249 - val_loss: 0.5387 - val_prob_loss: 0.2712 - val_dist_loss: 1.3379 - val_prob_kld: 0.1149 - val_dist_relevant_mae: 1.3377 - val_dist_relevant_mse: 5.6462 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 394/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2880 - prob_loss: 0.1707 - dist_loss: 0.5866 - prob_kld: 0.0183 - dist_relevant_mae: 0.5864 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2876 - prob_loss: 0.1703 - dist_loss: 0.5865 - prob_kld: 0.0182 - dist_relevant_mae: 0.5863 - dist_relevant_mse: 1.1391 - dist_dist_iou_metric: 0.8255 - val_loss: 0.5387 - val_prob_loss: 0.2712 - val_dist_loss: 1.3377 - val_prob_kld: 0.1149 - val_dist_relevant_mae: 1.3376 - val_dist_relevant_mse: 5.6435 - val_dist_dist_iou_metric: 0.6648 - lr: 1.9531e-06
# Epoch 395/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2918 - prob_loss: 0.1743 - dist_loss: 0.5870 - prob_kld: 0.0185 - dist_relevant_mae: 0.5869 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.2915 - prob_loss: 0.1739 - dist_loss: 0.5882 - prob_kld: 0.0185 - dist_relevant_mae: 0.5880 - dist_relevant_mse: 1.1369 - dist_dist_iou_metric: 0.8252 - val_loss: 0.5386 - val_prob_loss: 0.2711 - val_dist_loss: 1.3377 - val_prob_kld: 0.1149 - val_dist_relevant_mae: 1.3376 - val_dist_relevant_mse: 5.6444 - val_dist_dist_iou_metric: 0.6648 - lr: 1.9531e-06
# Epoch 396/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2926 - prob_loss: 0.1731 - dist_loss: 0.5975 - prob_kld: 0.0186 - dist_relevant_mae: 0.5974 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2924 - prob_loss: 0.1730 - dist_loss: 0.5970 - prob_kld: 0.0186 - dist_relevant_mae: 0.5969 - dist_relevant_mse: 1.1592 - dist_dist_iou_metric: 0.8254 - val_loss: 0.5388 - val_prob_loss: 0.2712 - val_dist_loss: 1.3380 - val_prob_kld: 0.1150 - val_dist_relevant_mae: 1.3378 - val_dist_relevant_mse: 5.6466 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 397/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2907 - prob_loss: 0.1717 - dist_loss: 0.5953 - prob_kld: 0.0185 - dist_relevant_mae: 0.5951 - dist_relev
# 100/100 [==============================] - 4s 37ms/step - loss: 0.2915 - prob_loss: 0.1725 - dist_loss: 0.5952 - prob_kld: 0.0186 - dist_relevant_mae: 0.5950 - dist_relevant_mse: 1.1573 - dist_dist_iou_metric: 0.8240 - val_loss: 0.5385 - val_prob_loss: 0.2710 - val_dist_loss: 1.3376 - val_prob_kld: 0.1148 - val_dist_relevant_mae: 1.3374 - val_dist_relevant_mse: 5.6434 - val_dist_dist_iou_metric: 0.6646 - lr: 1.9531e-06
# Epoch 398/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2898 - prob_loss: 0.1705 - dist_loss: 0.5965 - prob_kld: 0.0185 - dist_relevant_mae: 0.5963 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2900 - prob_loss: 0.1709 - dist_loss: 0.5958 - prob_kld: 0.0185 - dist_relevant_mae: 0.5956 - dist_relevant_mse: 1.1660 - dist_dist_iou_metric: 0.8239 - val_loss: 0.5385 - val_prob_loss: 0.2710 - val_dist_loss: 1.3374 - val_prob_kld: 0.1148 - val_dist_relevant_mae: 1.3373 - val_dist_relevant_mse: 5.6430 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 399/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2896 - prob_loss: 0.1719 - dist_loss: 0.5885 - prob_kld: 0.0181 - dist_relevant_mae: 0.5883 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.2897 - prob_loss: 0.1721 - dist_loss: 0.5882 - prob_kld: 0.0182 - dist_relevant_mae: 0.5881 - dist_relevant_mse: 1.1257 - dist_dist_iou_metric: 0.8253 - val_loss: 0.5391 - val_prob_loss: 0.2715 - val_dist_loss: 1.3380 - val_prob_kld: 0.1152 - val_dist_relevant_mae: 1.3378 - val_dist_relevant_mse: 5.6475 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
# Epoch 400/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2903 - prob_loss: 0.1723 - dist_loss: 0.5903 - prob_kld: 0.0184 - dist_relevant_mae: 0.5901 - dist_relev
# 100/100 [==============================] - 4s 38ms/step - loss: 0.2908 - prob_loss: 0.1723 - dist_loss: 0.5927 - prob_kld: 0.0185 - dist_relevant_mae: 0.5925 - dist_relevant_mse: 1.1533 - dist_dist_iou_metric: 0.8242 - val_loss: 0.5389 - val_prob_loss: 0.2713 - val_dist_loss: 1.3383 - val_prob_kld: 0.1151 - val_dist_relevant_mae: 1.3381 - val_dist_relevant_mse: 5.6490 - val_dist_dist_iou_metric: 0.6647 - lr: 1.9531e-06
#
# Loading network weights from 'weights_best.h5'.
# NMS threshold = 0.3:  75%|███████▌  | 15/20 [00:09<00:03,  1.58it/s, 0.621 -> 0.638]
# NMS threshold = 0.4:  75%|███████▌  | 15/20 [00:08<00:02,  1.81it/s, 0.632 -> 0.636]
# NMS threshold = 0.5:  75%|███████▌  | 15/20 [00:08<00:02,  1.77it/s, 0.641 -> 0.631]
# Using optimized values: prob_thresh=0.618122, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# WARNING:tensorflow:From C:\Users\Donald\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\tensorflow\python\summary\summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow | From C:\Users\Donald\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\tensorflow\python\summary\summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
pthHE= fr'\\10.99.68.178\andreex\data\Stardist\Testing\monkey\tiles'
pthmasks= fr'\\10.99.68.178\andreex\data\Stardist\Testing\monkey\qupath\ground_truth\masks'

HE_tiles_pths = sorted(glob(os.path.join(pthHE,'*.tif')))
mask_tiles_pths = sorted(glob(os.path.join(pthmasks,'*.tif')))

HE_tiles_val = list(map(imread,HE_tiles_pths))
mask_tiles_val = list(map(imread,mask_tiles_pths))

HE_tiles_val = [x/255 for x in HE_tiles_val]  # just divide by 255 to get into (0,1) range
mask_tiles_val = [fill_label_holes(y) for y in mask_tiles_val]  # fills holes in annotations if there are any

# %%
#Predict on validation images
mask_val_pred = [model.predict_instances(x, n_tiles=model._guess_n_tiles(x), show_tile_progress=False)[0]
              for x in tqdm(HE_tiles_val)]
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 19.33it/s]

# %%
X_val = HE_tiles_val
Y_val_pred = mask_val_pred
Y_val = mask_tiles_val

ind = 3

cropped_img = X_val[ind]
cropped_lbl = Y_val_pred[ind]
cropped_lbl_gt = Y_val[ind]

fig, ax = plt.subplots(1,3,figsize = (16, 8))
ax[0].imshow(cropped_img)
ax[0].axis('off')
ax[0].set_title('H&E')

ax[1].imshow(cropped_img)
ax[1].imshow(cropped_lbl_gt, cmap=lbl_cmap, alpha=0.5)
ax[1].axis('off')
ax[1].set_title('Ground Truth')

ax[2].imshow(cropped_img)
ax[2].imshow(cropped_lbl, cmap=lbl_cmap, alpha=0.5)
ax[2].axis('off')
ax[2].set_title('Predicted')
plt.show()
