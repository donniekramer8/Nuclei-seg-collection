# %%
# pip install gputools
# pip install scikit-tensor-py3

from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import numpy as np
import matplotlib
matplotlib.rcParams["image.interpolation"] = 'nearest'
import matplotlib.pyplot as plt
import os
from PIL import Image
import tensorflow as tf
from glob import glob
from tqdm import tqdm
from tifffile import imread
import struct
import cv2
import pandas as pd

from stardist import fill_label_holes, random_label_cmap, calculate_extents, gputools_available
from stardist.models import Config2D, StarDist2D, StarDistData2D

# %%
#Random color map labels
np.random.seed(42)
lbl_cmap = random_label_cmap()

# %%
pth=r'\\10.99.68.178\andreex\data\Stardist\qupath_training_annotations'
pthtraining= os.path.join(pth,'Training')
pthtesting= os.path.join(pth,'Testing')
pthmodels= os.path.join(pth,'models')
pthfiles= os.path.join(pth,'files')

pthHE= r'\\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles'
pthmasks= r'\\10.99.68.178\andreex\data\Stardist\Training\Mask_tiles'

# %%
pthmodels
# Out:
# '\\\\10.99.68.178\\andreex\\data\\Stardist\\qupath_training_annotations\\models'

# %%
training_HE_tiles_pths = sorted(glob(os.path.join(pthHE,'*.tif')))
training_mask_tiles_pths = sorted(glob(os.path.join(pthmasks,'*.tif')))

# %%
training_HE_tiles_pths
# Out:
# ['\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_117.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_157.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_217.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_271.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_331.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_377.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_439.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_479.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_523.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\fallopian_tubes_AJER376_565.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0105_ecm.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0271_eye.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0371_Lung.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0400_spinalcord.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0420_brain.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0431_GI.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0432_bone.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0450_heart.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0451_kidney.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0507_Thyroid.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0519_Ganglion.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0532_heart.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0612_brain.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0640_bone.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0642_bone2.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\Training\\H&E_tiles\\monkey_fetus_40_0730_kidney.tif']

# %%
HE_original_tiles = list(map(imread,training_HE_tiles_pths))
mask_original_tiles = list(map(imread,training_mask_tiles_pths))

# %%
def augment_images(HE_tiles, mask_tiles):
  """
  Augments a set of HE images and corresponding mask labels by rotating and flipping them.

  Args:
    HE_tiles: A list of NumPy arrays representing the HE images.
    mask_tiles: A list of NumPy arrays representing the mask labels for the HE images.

  Returns:
    HE_aug: A list of NumPy arrays representing the augmented HE images.
    mask_aug: A list of NumPy arrays representing the augmented mask labels.
  """

  HE_aug = [[] for _ in range(len(HE_tiles))]
  mask_aug = [[] for _ in range(len(mask_tiles))]

  for i in range(len(HE_tiles)):
    im = Image.fromarray(HE_tiles[i])
    lbl = Image.fromarray(mask_tiles[i])

    # Rotate the image and label 90 degrees three times.
    for _ in range(3):
      im = im.rotate(90)
      HE_aug[i].append(im)
      lbl = lbl.rotate(90)
      mask_aug[i].append(lbl)

    # Flip the image and label horizontally.
    im = Image.fromarray(HE_tiles[i])
    flipped_im = im.transpose(Image.FLIP_LEFT_RIGHT)

    lbl = Image.fromarray(mask_tiles[i])
    flipped_lbl = lbl.transpose(Image.FLIP_LEFT_RIGHT)

    HE_aug[i].append(flipped_im)
    mask_aug[i].append(flipped_lbl)

    # Rotate the flipped image and label 90 degrees three times.
    for _ in range(3):
      flipped_im = flipped_im.rotate(90)
      HE_aug[i].append(flipped_im)
      flipped_lbl = flipped_lbl.rotate(90)
      mask_aug[i].append(flipped_lbl)

  return HE_aug, mask_aug

# %%
HE_aug, mask_aug = augment_images(HE_original_tiles, mask_original_tiles)

# %%
def get_mean_and_std(x):
	x_mean, x_std = cv2.meanStdDev(x)
	x_mean = np.hstack(np.around(x_mean,2))
	x_std = np.hstack(np.around(x_std,2))
	return x_mean, x_std

pth_template = r'\\10.99.68.178\andreex\data\Stardist\Testing\monkey\tiles\monkey_fetus_40_0451_heart2.tif'

template_img = cv2.imread(pth_template)
template_img = cv2.cvtColor(template_img,cv2.COLOR_BGR2LAB)
template_mean, template_std = get_mean_and_std(template_img)


normalized = []

for img in training_HE_tiles_pths:
    print(img)
    input_img = imread(img)
    input_img = cv2.cvtColor(input_img,cv2.COLOR_BGR2LAB)


    img_mean, img_std = get_mean_and_std(input_img)


    height, width, channel = input_img.shape
    for i in range(0,height):
        for j in range(0,width):
            for k in range(0,channel):
            	x = input_img[i,j,k]
            	x = ((x-img_mean[k])*(template_std[k]/img_std[k]))+template_mean[k]
            	x = round(x)
            	# boundary check
            	x = 0 if x<0 else x
            	x = 255 if x>255 else x
            	input_img[i,j,k] = x

    input_img= cv2.cvtColor(input_img,cv2.COLOR_LAB2BGR)
    normalized.append(input_img)
    # cv2.imwrite(output_dir+"modified_"+img, input_img)
# Out:
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_117.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_157.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_217.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_271.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_331.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_377.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_439.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_479.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_523.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\fallopian_tubes_AJER376_565.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0105_ecm.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0271_eye.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0371_Lung.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0400_spinalcord.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0420_brain.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0431_GI.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0432_bone.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0450_heart.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0451_kidney.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0507_Thyroid.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0519_Ganglion.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0532_heart.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0612_brain.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0640_bone.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0642_bone2.tif
# \\10.99.68.178\andreex\data\Stardist\Training\H&E_tiles\monkey_fetus_40_0730_kidney.tif

# %%
#Normalize input images and fill holes in masks
# HE_original_tiles = [x/255 for x in HE_original_tiles]  # no norm, just divide by 255 to get into (0,1) range
HE_original_tiles = [x/255 for x in normalized]  # divide by 255 to get into (0,1) range
mask_original_tiles = [fill_label_holes(y) for y in mask_original_tiles]  # fills holes in annotations if there are any

# %%
normalized_aug = []

def rein_norm(img):
    input_img = cv2.cvtColor(img,cv2.COLOR_BGR2LAB)


    img_mean, img_std = get_mean_and_std(input_img)


    height, width, channel = input_img.shape
    for i in range(0,height):
        for j in range(0,width):
            for k in range(0,channel):
            	x = input_img[i,j,k]
            	x = ((x-img_mean[k])*(template_std[k]/img_std[k]))+template_mean[k]
            	x = round(x)
            	# boundary check
            	x = 0 if x<0 else x
            	x = 255 if x>255 else x
            	input_img[i,j,k] = x

    input_img= cv2.cvtColor(input_img,cv2.COLOR_LAB2BGR)
    return input_img

# %%
def normalize_images(images, masks):
  
  normalized_masks = [[] for i in range(len(masks))]
  normalized_images = [[] for i in range(len(images))]
  
  for i in range(len(masks)):
      masks_list = masks[i]
      images_list = images[i]
      
      for j in range(len(images_list)):
          im = images_list[j]
          im = np.asarray(im)
          im = rein_norm(im)
          im = im/255
          normalized_images[i].append(im)
      
      for j in range(len(masks_list)):
          im = masks_list[j]
          im = np.asarray(im)
          im = fill_label_holes(im)
          normalized_masks[i].append(im)
          
  return normalized_images, normalized_masks

# %%
HE_aug_norm, mask_aug_norm = normalize_images(HE_aug, mask_aug)

# %%
def split_augmented_data(HE_aug_norm_list, mask_aug_norm_list):
  """
  Splits augmented HE images and mask images into training and validation sets.

  Args:
    HE_aug_norm: A list of NumPy arrays representing the normalized augmented HE images.
    mask_aug_norm: A list of NumPy arrays representing the normalized augmented mask images.

  Returns:
    X_trn, Y_trn, X_val, Y_val: Training and validation sets of HE images and mask images.
  """

  # Create empty lists to store the training and validation sets.
  X_trn = []
  Y_trn = []
  X_val = []
  Y_val = []
  
  for i in range(len(HE_aug_norm_list)):
    HE_aug_norm = HE_aug_norm_list[i]
    mask_aug_norm = mask_aug_norm_list[i]

    # Assert that there is enough training data.
    assert len(HE_aug_norm) > 1, "not enough training data"

    # Create a random number generator with a fixed seed for reproducibility.
    rng = np.random.RandomState(42)

    # Permute the indices of the augmented data.
    ind = rng.permutation(len(HE_aug_norm))

    # Split the indices into training and validation indices.
    n_val = max(1, int(round(0.15 * len(ind))))
    ind_trn, ind_val = ind[:-n_val], ind[-n_val:]

    # Split the augmented data into training and validation sets.
    for kk in ind_trn:
      X_trn.append(HE_aug_norm[kk])
      Y_trn.append(mask_aug_norm[kk])

    for lol in ind_val:
      X_val.append(HE_aug_norm[lol])
      Y_val.append(mask_aug_norm[lol])
  
  print(f'number of images: {len(HE_aug_norm_list*len(HE_aug_norm_list[0]))}')
  print(f'- training: {len(X_trn)}')
  print(f'- validation: {len(X_val)}')
  
  X_trn = [np.array(x) for x in X_trn]
  Y_trn = [np.array(y) for y in Y_trn]
  
  X_val = [np.array(x) for x in X_val]
  Y_val = [np.array(y) for y in Y_val]
  
  # Return the training and validation sets.
  return X_trn, Y_trn, X_val, Y_val

# %%
HE_trn, mask_trn, HE_val, mask_val = split_augmented_data(HE_aug_norm, mask_aug_norm)
# Out:
# number of images: 182
# - training: 156
# - validation: 26

# %%
#PLot image and label for some images - sanity check
def show_tile_segmented(tile, segmented, **kwargs):
    """Plot large image at different resolutions."""
    fig, ax = plt.subplots(1, 2, figsize=(16/2, 8/2))

    # Plot the original image on the left
    ax[0].imshow(tile, **kwargs)

    # Plot the cropped image on the right
    ax[1].imshow(segmented, **kwargs)

    ax[0].axis('off')
    ax[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
i = 14

img, lbl = HE_val[i], mask_val[i]
assert img.ndim in (2,3)
img = img if (img.ndim==2 or img.shape[-1]==3) else img[...,0]
show_tile_segmented(img,lbl)

# %%
if tf.config.list_physical_devices('GPU'):
    print("GPU is available")
else:
    print("GPU is not available")
    
print(tf.__version__)

#Define the config by setting some parameter values
# 32 is a good default choice (see 1_data.ipynb)
n_rays = 32  #Number of radial directions for the star-convex polygon.

# Use OpenCL-based computations for data generator during training (requires 'gputools')
use_gpu = True and gputools_available()

# Predict on subsampled grid for increased efficiency and larger field of view
grid = (2,2)

n_channel = 1 if HE_trn[0].ndim == 2 else HE_trn[0].shape[-1]  #If no third dim. then number of channels = 1. Otherwise get the num channels from the last dim.


conf = Config2D (
    n_rays       = n_rays,
    grid         = grid,
    use_gpu      = use_gpu,
    n_channel_in = n_channel,
)
# print(conf)
vars(conf)
# Out:
# GPU is available
# 2.9.3
# Warning: Could not find scikit-tensor which is needed for separable approximations...
# If you want to compute separable approximations, please install it with
# pip install scikit-tensor-py3
# {'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 3,
#  'n_channel_out': 33,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'n_rays': 32,
#  'grid': (2, 2),
#  'backbone': 'unet',
#  'n_classes': None,
#  'unet_n_depth': 3,
#  'unet_kernel_size': (3, 3),
#  'unet_n_filter_base': 32,
#  'unet_n_conv_per_depth': 2,
#  'unet_pool': (2, 2),
#  'unet_activation': 'relu',
#  'unet_last_activation': 'relu',
#  'unet_batch_norm': False,
#  'unet_dropout': 0.0,
#  'unet_prefix': '',
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, 3),
#  'net_mask_shape': (None, None, 1),
#  'train_shape_completion': False,
#  'train_completion_crop': 32,
#  'train_patch_size': (256, 256),
#  'train_background_reg': 0.0001,
#  'train_foreground_only': 0.9,
#  'train_sample_cache': True,
#  'train_dist_loss': 'mae',
#  'train_loss_weights': (1, 0.2),
#  'train_class_weights': (1, 1),
#  'train_epochs': 400,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0003,
#  'train_batch_size': 4,
#  'train_n_val_patches': None,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 40, 'min_delta': 0},
#  'use_gpu': True}

# %%
#Start from 40x H&E pre-trained model to the specified directory
import copy
import json

def load_justin_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = load_model(r'\\10.99.68.178\andreex\students\Donald Monkey fetus\stardist\Model_00')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_published_he_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = StarDist2D.from_pretrained('2D_versatile_he')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_model(model_path: str) -> StarDist2D:
    # Load StarDist model weights, configurations, and thresholds
    with open(model_path + '\\config.json', 'r') as f:
        config = json.load(f)
    with open(model_path + '\\thresholds.json', 'r') as f:
        thresh = json.load(f)
    model = StarDist2D(config=Config2D(**config), basedir=model_path, name='offshoot_model')
    model.thresholds = thresh
    print('Overriding defaults:', model.thresholds, '\n')
    model.load_weights(model_path + '\\weights_best.h5')
    return model

def configure_model_for_training(model: StarDist2D,
                                 epochs: int = 25, learning_rate: float = 1e-6,
                                 batch_size: int = 4, patch_size: list[int,int] = [256, 256]) -> StarDist2D:
    model.config.train_epochs = epochs
    model.config.train_learning_rate = learning_rate
    model.config.train_batch_size = batch_size
    model.config.train_patch_size = patch_size
    return model

# %%
from tensorflow.python.summary.summary_iterator import summary_iterator

def get_loss_data(pth_training_log, pth_out) -> list:

    # event_file = r"\\10.99.68.178\andreex\data\Stardist\models\monkey_ft_11_02_2023_lr_1e-4_epochs_200_pt_10\logs\train\events.out.tfevents.1698964029.WPC-C13.20400.7.v2"

    loss_values = []

    for summary in summary_iterator(pth_training_log):
        for value in summary.summary.value:
            if value.tag == 'epoch_loss':
                loss = struct.unpack('f', value.tensor.tensor_content)[0]
                loss_values.append(loss)

    out_txt_name = f"{pth_out}\loss.txt"

    with open(out_txt_name, 'w') as f:
        f.write('\n'.join(map(str, loss_values)) + '\n')

    return loss_values

# %%
pthmodels + outnm
# Out:
# '\\\\10.99.68.178\\andreex\\data\\Stardist\\qupath_training_annotations\\modelsmonkey_ft_11_16_2023_lr_0.001_epochs_400_pt_40'

# %%
lr = 0.001
epochs = 400
patience = 40

nm='monkey_ft_'
dt='11_16_2023'
outnm = nm + dt + '_lr_' + str(lr) + '_epochs_' + str(epochs) + '_pt_' + str(patience)
print(outnm)


model = load_published_he_model(pthmodels, outnm)
model.config.train_learning_rate = lr
model.config.train_patch_size = (256,256)
model.config.train_reduce_lr={'factor': 0.5, 'patience': patience, 'min_delta': 0}
model.train(HE_trn, mask_trn, validation_data=(HE_val,mask_val), epochs=epochs, steps_per_epoch=100)
model.optimize_thresholds(HE_val, mask_val)

pth_log_train = fr"{pthmodels}\{outnm}\logs\train"

pth_log = glob(os.path.join(pth_log_train,'*.v2'))[0]
loss = get_loss_data(str(pth_log), pth_log_train)
# Out:
# monkey_ft_11_16_2023_lr_0.001_epochs_400_pt_40
# Found model '2D_versatile_he' for 'StarDist2D'.
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.692478, nms_thresh=0.3.
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# Epoch 1/400
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x00000240EAA01310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000240EAA01310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow | AutoGraph could not transform <function _gcd_import at 0x00000240EAA01310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000240EAA01310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x00000240EAA01310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000240EAA01310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5867 - prob_loss: 0.2480 - dist_loss: 1.6935 - prob_kld: 0.1023 - dist_relevant_mae: 1.6932 - dist_relev
# 100/100 [==============================] - 9s 65ms/step - loss: 0.5861 - prob_loss: 0.2476 - dist_loss: 1.6927 - prob_kld: 0.1022 - dist_relevant_mae: 1.6924 - dist_relevant_mse: 7.5741 - dist_dist_iou_metric: 0.5910 - val_loss: 0.5342 - val_prob_loss: 0.2317 - val_dist_loss: 1.5124 - val_prob_kld: 0.0835 - val_dist_relevant_mae: 1.5121 - val_dist_relevant_mse: 6.3371 - val_dist_dist_iou_metric: 0.6274 - lr: 0.0010
# Epoch 2/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5421 - prob_loss: 0.2294 - dist_loss: 1.5634 - prob_kld: 0.0834 - dist_relevant_mae: 1.5631 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.5427 - prob_loss: 0.2302 - dist_loss: 1.5628 - prob_kld: 0.0838 - dist_relevant_mae: 1.5625 - dist_relevant_mse: 6.4059 - dist_dist_iou_metric: 0.6154 - val_loss: 0.5236 - val_prob_loss: 0.2297 - val_dist_loss: 1.4696 - val_prob_kld: 0.0815 - val_dist_relevant_mae: 1.4693 - val_dist_relevant_mse: 5.6285 - val_dist_dist_iou_metric: 0.6233 - lr: 0.0010
# Epoch 3/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5029 - prob_loss: 0.2228 - dist_loss: 1.4006 - prob_kld: 0.0760 - dist_relevant_mae: 1.4003 - dist_relev
# 100/100 [==============================] - 4s 44ms/step - loss: 0.5031 - prob_loss: 0.2229 - dist_loss: 1.4009 - prob_kld: 0.0761 - dist_relevant_mae: 1.4006 - dist_relevant_mse: 5.2408 - dist_dist_iou_metric: 0.6465 - val_loss: 0.5020 - val_prob_loss: 0.2235 - val_dist_loss: 1.3925 - val_prob_kld: 0.0753 - val_dist_relevant_mae: 1.3922 - val_dist_relevant_mse: 5.2697 - val_dist_dist_iou_metric: 0.6515 - lr: 0.0010
# Epoch 4/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4924 - prob_loss: 0.2173 - dist_loss: 1.3755 - prob_kld: 0.0737 - dist_relevant_mae: 1.3752 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.4926 - prob_loss: 0.2169 - dist_loss: 1.3782 - prob_kld: 0.0736 - dist_relevant_mae: 1.3779 - dist_relevant_mse: 5.0401 - dist_dist_iou_metric: 0.6458 - val_loss: 0.4922 - val_prob_loss: 0.2205 - val_dist_loss: 1.3582 - val_prob_kld: 0.0723 - val_dist_relevant_mae: 1.3578 - val_dist_relevant_mse: 5.0459 - val_dist_dist_iou_metric: 0.6533 - lr: 0.0010
# Epoch 5/400
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4832 - prob_loss: 0.2200 - dist_loss: 1.3161 - prob_kld: 0.0720 - dist_relevant_mae: 1.3158 - dist_relev
# 100/100 [==============================] - 5s 48ms/step - loss: 0.4832 - prob_loss: 0.2200 - dist_loss: 1.3161 - prob_kld: 0.0720 - dist_relevant_mae: 1.3158 - dist_relevant_mse: 4.6164 - dist_dist_iou_metric: 0.6582 - val_loss: 0.4955 - val_prob_loss: 0.2222 - val_dist_loss: 1.3665 - val_prob_kld: 0.0740 - val_dist_relevant_mae: 1.3661 - val_dist_relevant_mse: 5.1144 - val_dist_dist_iou_metric: 0.6608 - lr: 0.0010
# Epoch 6/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4830 - prob_loss: 0.2168 - dist_loss: 1.3306 - prob_kld: 0.0711 - dist_relevant_mae: 1.3303 - dist_relev
# 100/100 [==============================] - 5s 46ms/step - loss: 0.4822 - prob_loss: 0.2165 - dist_loss: 1.3282 - prob_kld: 0.0710 - dist_relevant_mae: 1.3278 - dist_relevant_mse: 4.7137 - dist_dist_iou_metric: 0.6580 - val_loss: 0.4909 - val_prob_loss: 0.2223 - val_dist_loss: 1.3431 - val_prob_kld: 0.0741 - val_dist_relevant_mae: 1.3428 - val_dist_relevant_mse: 4.9443 - val_dist_dist_iou_metric: 0.6674 - lr: 0.0010
# Epoch 7/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4758 - prob_loss: 0.2172 - dist_loss: 1.2929 - prob_kld: 0.0691 - dist_relevant_mae: 1.2926 - dist_relev
# 100/100 [==============================] - 5s 47ms/step - loss: 0.4752 - prob_loss: 0.2166 - dist_loss: 1.2935 - prob_kld: 0.0690 - dist_relevant_mae: 1.2932 - dist_relevant_mse: 4.4918 - dist_dist_iou_metric: 0.6657 - val_loss: 0.4790 - val_prob_loss: 0.2183 - val_dist_loss: 1.3034 - val_prob_kld: 0.0702 - val_dist_relevant_mae: 1.3031 - val_dist_relevant_mse: 4.7502 - val_dist_dist_iou_metric: 0.6639 - lr: 0.0010
# Epoch 8/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4654 - prob_loss: 0.2148 - dist_loss: 1.2529 - prob_kld: 0.0673 - dist_relevant_mae: 1.2526 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.4651 - prob_loss: 0.2144 - dist_loss: 1.2535 - prob_kld: 0.0672 - dist_relevant_mae: 1.2532 - dist_relevant_mse: 4.2307 - dist_dist_iou_metric: 0.6716 - val_loss: 0.4807 - val_prob_loss: 0.2180 - val_dist_loss: 1.3135 - val_prob_kld: 0.0698 - val_dist_relevant_mae: 1.3132 - val_dist_relevant_mse: 4.8474 - val_dist_dist_iou_metric: 0.6635 - lr: 0.0010
# Epoch 9/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4500 - prob_loss: 0.2075 - dist_loss: 1.2127 - prob_kld: 0.0634 - dist_relevant_mae: 1.2124 - dist_relev
# 100/100 [==============================] - 5s 47ms/step - loss: 0.4503 - prob_loss: 0.2078 - dist_loss: 1.2126 - prob_kld: 0.0634 - dist_relevant_mae: 1.2123 - dist_relevant_mse: 3.9772 - dist_dist_iou_metric: 0.6824 - val_loss: 0.4721 - val_prob_loss: 0.2164 - val_dist_loss: 1.2786 - val_prob_kld: 0.0682 - val_dist_relevant_mae: 1.2783 - val_dist_relevant_mse: 4.6474 - val_dist_dist_iou_metric: 0.6746 - lr: 0.0010
# Epoch 10/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4460 - prob_loss: 0.2077 - dist_loss: 1.1919 - prob_kld: 0.0619 - dist_relevant_mae: 1.1916 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4467 - prob_loss: 0.2080 - dist_loss: 1.1935 - prob_kld: 0.0620 - dist_relevant_mae: 1.1932 - dist_relevant_mse: 3.8745 - dist_dist_iou_metric: 0.6838 - val_loss: 0.4754 - val_prob_loss: 0.2167 - val_dist_loss: 1.2934 - val_prob_kld: 0.0685 - val_dist_relevant_mae: 1.2932 - val_dist_relevant_mse: 4.8561 - val_dist_dist_iou_metric: 0.6690 - lr: 0.0010
# Epoch 11/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4450 - prob_loss: 0.2066 - dist_loss: 1.1921 - prob_kld: 0.0609 - dist_relevant_mae: 1.1918 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.4448 - prob_loss: 0.2063 - dist_loss: 1.1926 - prob_kld: 0.0609 - dist_relevant_mae: 1.1923 - dist_relevant_mse: 3.8534 - dist_dist_iou_metric: 0.6855 - val_loss: 0.4735 - val_prob_loss: 0.2161 - val_dist_loss: 1.2871 - val_prob_kld: 0.0679 - val_dist_relevant_mae: 1.2868 - val_dist_relevant_mse: 4.8549 - val_dist_dist_iou_metric: 0.6698 - lr: 0.0010
# Epoch 12/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4342 - prob_loss: 0.2032 - dist_loss: 1.1550 - prob_kld: 0.0586 - dist_relevant_mae: 1.1547 - dist_relev
# 100/100 [==============================] - 4s 45ms/step - loss: 0.4338 - prob_loss: 0.2029 - dist_loss: 1.1546 - prob_kld: 0.0586 - dist_relevant_mae: 1.1543 - dist_relevant_mse: 3.6564 - dist_dist_iou_metric: 0.6932 - val_loss: 0.4737 - val_prob_loss: 0.2170 - val_dist_loss: 1.2832 - val_prob_kld: 0.0688 - val_dist_relevant_mae: 1.2829 - val_dist_relevant_mse: 4.6785 - val_dist_dist_iou_metric: 0.6758 - lr: 0.0010
# Epoch 13/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4376 - prob_loss: 0.2067 - dist_loss: 1.1546 - prob_kld: 0.0593 - dist_relevant_mae: 1.1543 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.4363 - prob_loss: 0.2058 - dist_loss: 1.1523 - prob_kld: 0.0590 - dist_relevant_mae: 1.1520 - dist_relevant_mse: 3.6191 - dist_dist_iou_metric: 0.6944 - val_loss: 0.4845 - val_prob_loss: 0.2229 - val_dist_loss: 1.3078 - val_prob_kld: 0.0747 - val_dist_relevant_mae: 1.3075 - val_dist_relevant_mse: 5.0195 - val_dist_dist_iou_metric: 0.6597 - lr: 0.0010
# Epoch 14/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4357 - prob_loss: 0.2050 - dist_loss: 1.1537 - prob_kld: 0.0587 - dist_relevant_mae: 1.1534 - dist_relev
# 100/100 [==============================] - 4s 42ms/step - loss: 0.4366 - prob_loss: 0.2060 - dist_loss: 1.1532 - prob_kld: 0.0588 - dist_relevant_mae: 1.1529 - dist_relevant_mse: 3.6217 - dist_dist_iou_metric: 0.6948 - val_loss: 0.4768 - val_prob_loss: 0.2186 - val_dist_loss: 1.2911 - val_prob_kld: 0.0704 - val_dist_relevant_mae: 1.2908 - val_dist_relevant_mse: 4.8123 - val_dist_dist_iou_metric: 0.6650 - lr: 0.0010
# Epoch 15/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4288 - prob_loss: 0.2042 - dist_loss: 1.1227 - prob_kld: 0.0585 - dist_relevant_mae: 1.1224 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.4287 - prob_loss: 0.2036 - dist_loss: 1.1258 - prob_kld: 0.0583 - dist_relevant_mae: 1.1255 - dist_relevant_mse: 3.4443 - dist_dist_iou_metric: 0.6948 - val_loss: 0.4721 - val_prob_loss: 0.2150 - val_dist_loss: 1.2853 - val_prob_kld: 0.0669 - val_dist_relevant_mae: 1.2849 - val_dist_relevant_mse: 4.8467 - val_dist_dist_iou_metric: 0.6757 - lr: 0.0010
# Epoch 16/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4262 - prob_loss: 0.2012 - dist_loss: 1.1253 - prob_kld: 0.0553 - dist_relevant_mae: 1.1250 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.4265 - prob_loss: 0.2014 - dist_loss: 1.1257 - prob_kld: 0.0554 - dist_relevant_mae: 1.1254 - dist_relevant_mse: 3.3955 - dist_dist_iou_metric: 0.6983 - val_loss: 0.4799 - val_prob_loss: 0.2196 - val_dist_loss: 1.3015 - val_prob_kld: 0.0715 - val_dist_relevant_mae: 1.3012 - val_dist_relevant_mse: 4.8316 - val_dist_dist_iou_metric: 0.6550 - lr: 0.0010
# Epoch 17/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4261 - prob_loss: 0.2026 - dist_loss: 1.1172 - prob_kld: 0.0560 - dist_relevant_mae: 1.1169 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.4250 - prob_loss: 0.2017 - dist_loss: 1.1162 - prob_kld: 0.0558 - dist_relevant_mae: 1.1159 - dist_relevant_mse: 3.3793 - dist_dist_iou_metric: 0.7022 - val_loss: 0.4723 - val_prob_loss: 0.2183 - val_dist_loss: 1.2699 - val_prob_kld: 0.0702 - val_dist_relevant_mae: 1.2696 - val_dist_relevant_mse: 4.7221 - val_dist_dist_iou_metric: 0.6776 - lr: 0.0010
# Epoch 18/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4148 - prob_loss: 0.1991 - dist_loss: 1.0786 - prob_kld: 0.0536 - dist_relevant_mae: 1.0783 - dist_relev
# 100/100 [==============================] - 5s 55ms/step - loss: 0.4148 - prob_loss: 0.1991 - dist_loss: 1.0786 - prob_kld: 0.0536 - dist_relevant_mae: 1.0783 - dist_relevant_mse: 3.1996 - dist_dist_iou_metric: 0.7094 - val_loss: 0.4686 - val_prob_loss: 0.2152 - val_dist_loss: 1.2671 - val_prob_kld: 0.0670 - val_dist_relevant_mae: 1.2668 - val_dist_relevant_mse: 4.7534 - val_dist_dist_iou_metric: 0.6769 - lr: 0.0010
# Epoch 19/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4258 - prob_loss: 0.2037 - dist_loss: 1.1104 - prob_kld: 0.0560 - dist_relevant_mae: 1.1101 - dist_relev
# 100/100 [==============================] - 5s 48ms/step - loss: 0.4258 - prob_loss: 0.2037 - dist_loss: 1.1104 - prob_kld: 0.0560 - dist_relevant_mae: 1.1101 - dist_relevant_mse: 3.3407 - dist_dist_iou_metric: 0.7011 - val_loss: 0.4722 - val_prob_loss: 0.2165 - val_dist_loss: 1.2788 - val_prob_kld: 0.0683 - val_dist_relevant_mae: 1.2786 - val_dist_relevant_mse: 4.8820 - val_dist_dist_iou_metric: 0.6720 - lr: 0.0010
# Epoch 20/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4145 - prob_loss: 0.1974 - dist_loss: 1.0854 - prob_kld: 0.0532 - dist_relevant_mae: 1.0851 - dist_relev
# 100/100 [==============================] - 5s 46ms/step - loss: 0.4145 - prob_loss: 0.1977 - dist_loss: 1.0843 - prob_kld: 0.0532 - dist_relevant_mae: 1.0840 - dist_relevant_mse: 3.2081 - dist_dist_iou_metric: 0.7080 - val_loss: 0.4718 - val_prob_loss: 0.2170 - val_dist_loss: 1.2740 - val_prob_kld: 0.0689 - val_dist_relevant_mae: 1.2737 - val_dist_relevant_mse: 4.7882 - val_dist_dist_iou_metric: 0.6757 - lr: 0.0010
# Epoch 21/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4114 - prob_loss: 0.2002 - dist_loss: 1.0564 - prob_kld: 0.0523 - dist_relevant_mae: 1.0561 - dist_relev
# 100/100 [==============================] - 5s 47ms/step - loss: 0.4114 - prob_loss: 0.2002 - dist_loss: 1.0564 - prob_kld: 0.0523 - dist_relevant_mae: 1.0561 - dist_relevant_mse: 3.0480 - dist_dist_iou_metric: 0.7142 - val_loss: 0.4780 - val_prob_loss: 0.2210 - val_dist_loss: 1.2851 - val_prob_kld: 0.0728 - val_dist_relevant_mae: 1.2848 - val_dist_relevant_mse: 4.8657 - val_dist_dist_iou_metric: 0.6731 - lr: 0.0010
# Epoch 22/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4036 - prob_loss: 0.1970 - dist_loss: 1.0328 - prob_kld: 0.0510 - dist_relevant_mae: 1.0325 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.4034 - prob_loss: 0.1968 - dist_loss: 1.0330 - prob_kld: 0.0510 - dist_relevant_mae: 1.0327 - dist_relevant_mse: 2.9281 - dist_dist_iou_metric: 0.7175 - val_loss: 0.4889 - val_prob_loss: 0.2273 - val_dist_loss: 1.3079 - val_prob_kld: 0.0792 - val_dist_relevant_mae: 1.3076 - val_dist_relevant_mse: 5.1248 - val_dist_dist_iou_metric: 0.6658 - lr: 0.0010
# Epoch 23/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4025 - prob_loss: 0.1950 - dist_loss: 1.0378 - prob_kld: 0.0497 - dist_relevant_mae: 1.0375 - dist_relev
# 100/100 [==============================] - 4s 44ms/step - loss: 0.4020 - prob_loss: 0.1943 - dist_loss: 1.0387 - prob_kld: 0.0495 - dist_relevant_mae: 1.0384 - dist_relevant_mse: 2.9687 - dist_dist_iou_metric: 0.7192 - val_loss: 0.4734 - val_prob_loss: 0.2183 - val_dist_loss: 1.2756 - val_prob_kld: 0.0701 - val_dist_relevant_mae: 1.2754 - val_dist_relevant_mse: 4.7957 - val_dist_dist_iou_metric: 0.6724 - lr: 0.0010
# Epoch 24/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3998 - prob_loss: 0.1960 - dist_loss: 1.0194 - prob_kld: 0.0494 - dist_relevant_mae: 1.0191 - dist_relev
# 100/100 [==============================] - 5s 50ms/step - loss: 0.4003 - prob_loss: 0.1965 - dist_loss: 1.0189 - prob_kld: 0.0495 - dist_relevant_mae: 1.0186 - dist_relevant_mse: 2.8361 - dist_dist_iou_metric: 0.7213 - val_loss: 0.4751 - val_prob_loss: 0.2185 - val_dist_loss: 1.2832 - val_prob_kld: 0.0703 - val_dist_relevant_mae: 1.2830 - val_dist_relevant_mse: 4.9318 - val_dist_dist_iou_metric: 0.6751 - lr: 0.0010
# Epoch 25/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3929 - prob_loss: 0.1917 - dist_loss: 1.0060 - prob_kld: 0.0477 - dist_relevant_mae: 1.0057 - dist_relev
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3925 - prob_loss: 0.1909 - dist_loss: 1.0080 - prob_kld: 0.0476 - dist_relevant_mae: 1.0077 - dist_relevant_mse: 2.7903 - dist_dist_iou_metric: 0.7257 - val_loss: 0.4774 - val_prob_loss: 0.2206 - val_dist_loss: 1.2839 - val_prob_kld: 0.0724 - val_dist_relevant_mae: 1.2836 - val_dist_relevant_mse: 4.9096 - val_dist_dist_iou_metric: 0.6764 - lr: 0.0010
# Epoch 26/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3936 - prob_loss: 0.1931 - dist_loss: 1.0026 - prob_kld: 0.0474 - dist_relevant_mae: 1.0023 - dist_relev
# 100/100 [==============================] - 5s 49ms/step - loss: 0.3941 - prob_loss: 0.1932 - dist_loss: 1.0046 - prob_kld: 0.0474 - dist_relevant_mae: 1.0043 - dist_relevant_mse: 2.7929 - dist_dist_iou_metric: 0.7258 - val_loss: 0.4708 - val_prob_loss: 0.2175 - val_dist_loss: 1.2666 - val_prob_kld: 0.0693 - val_dist_relevant_mae: 1.2663 - val_dist_relevant_mse: 4.7616 - val_dist_dist_iou_metric: 0.6744 - lr: 0.0010
# Epoch 27/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3902 - prob_loss: 0.1942 - dist_loss: 0.9799 - prob_kld: 0.0467 - dist_relevant_mae: 0.9797 - dist_relev
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3896 - prob_loss: 0.1937 - dist_loss: 0.9794 - prob_kld: 0.0466 - dist_relevant_mae: 0.9792 - dist_relevant_mse: 2.6432 - dist_dist_iou_metric: 0.7313 - val_loss: 0.4738 - val_prob_loss: 0.2184 - val_dist_loss: 1.2770 - val_prob_kld: 0.0702 - val_dist_relevant_mae: 1.2767 - val_dist_relevant_mse: 4.8812 - val_dist_dist_iou_metric: 0.6816 - lr: 0.0010
# Epoch 28/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3883 - prob_loss: 0.1935 - dist_loss: 0.9737 - prob_kld: 0.0458 - dist_relevant_mae: 0.9734 - dist_relev
# 100/100 [==============================] - 5s 46ms/step - loss: 0.3881 - prob_loss: 0.1930 - dist_loss: 0.9755 - prob_kld: 0.0457 - dist_relevant_mae: 0.9752 - dist_relevant_mse: 2.6105 - dist_dist_iou_metric: 0.7316 - val_loss: 0.4810 - val_prob_loss: 0.2189 - val_dist_loss: 1.3104 - val_prob_kld: 0.0707 - val_dist_relevant_mae: 1.3101 - val_dist_relevant_mse: 4.9284 - val_dist_dist_iou_metric: 0.6746 - lr: 0.0010
# Epoch 29/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3999 - prob_loss: 0.1948 - dist_loss: 1.0257 - prob_kld: 0.0482 - dist_relevant_mae: 1.0254 - dist_relev
# 100/100 [==============================] - 5s 48ms/step - loss: 0.4000 - prob_loss: 0.1949 - dist_loss: 1.0256 - prob_kld: 0.0484 - dist_relevant_mae: 1.0253 - dist_relevant_mse: 2.8086 - dist_dist_iou_metric: 0.7199 - val_loss: 0.4892 - val_prob_loss: 0.2197 - val_dist_loss: 1.3475 - val_prob_kld: 0.0715 - val_dist_relevant_mae: 1.3473 - val_dist_relevant_mse: 5.1119 - val_dist_dist_iou_metric: 0.6435 - lr: 0.0010
# Epoch 30/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3890 - prob_loss: 0.1916 - dist_loss: 0.9868 - prob_kld: 0.0467 - dist_relevant_mae: 0.9865 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3881 - prob_loss: 0.1908 - dist_loss: 0.9863 - prob_kld: 0.0466 - dist_relevant_mae: 0.9860 - dist_relevant_mse: 2.6965 - dist_dist_iou_metric: 0.7289 - val_loss: 0.4813 - val_prob_loss: 0.2208 - val_dist_loss: 1.3023 - val_prob_kld: 0.0727 - val_dist_relevant_mae: 1.3020 - val_dist_relevant_mse: 4.9695 - val_dist_dist_iou_metric: 0.6669 - lr: 0.0010
# Epoch 31/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3808 - prob_loss: 0.1910 - dist_loss: 0.9487 - prob_kld: 0.0447 - dist_relevant_mae: 0.9484 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3811 - prob_loss: 0.1909 - dist_loss: 0.9510 - prob_kld: 0.0447 - dist_relevant_mae: 0.9508 - dist_relevant_mse: 2.5110 - dist_dist_iou_metric: 0.7380 - val_loss: 0.4775 - val_prob_loss: 0.2220 - val_dist_loss: 1.2774 - val_prob_kld: 0.0736 - val_dist_relevant_mae: 1.2771 - val_dist_relevant_mse: 4.9241 - val_dist_dist_iou_metric: 0.6751 - lr: 0.0010
# Epoch 32/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3786 - prob_loss: 0.1913 - dist_loss: 0.9365 - prob_kld: 0.0447 - dist_relevant_mae: 0.9362 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3783 - prob_loss: 0.1909 - dist_loss: 0.9372 - prob_kld: 0.0445 - dist_relevant_mae: 0.9369 - dist_relevant_mse: 2.4279 - dist_dist_iou_metric: 0.7408 - val_loss: 0.4745 - val_prob_loss: 0.2197 - val_dist_loss: 1.2742 - val_prob_kld: 0.0715 - val_dist_relevant_mae: 1.2739 - val_dist_relevant_mse: 4.9275 - val_dist_dist_iou_metric: 0.6756 - lr: 0.0010
# Epoch 33/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3760 - prob_loss: 0.1862 - dist_loss: 0.9489 - prob_kld: 0.0438 - dist_relevant_mae: 0.9486 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3760 - prob_loss: 0.1862 - dist_loss: 0.9489 - prob_kld: 0.0438 - dist_relevant_mae: 0.9486 - dist_relevant_mse: 2.4863 - dist_dist_iou_metric: 0.7376 - val_loss: 0.4704 - val_prob_loss: 0.2172 - val_dist_loss: 1.2664 - val_prob_kld: 0.0690 - val_dist_relevant_mae: 1.2661 - val_dist_relevant_mse: 4.8317 - val_dist_dist_iou_metric: 0.6821 - lr: 0.0010
# Epoch 34/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3744 - prob_loss: 0.1893 - dist_loss: 0.9256 - prob_kld: 0.0425 - dist_relevant_mae: 0.9253 - dist_relev
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3746 - prob_loss: 0.1896 - dist_loss: 0.9255 - prob_kld: 0.0426 - dist_relevant_mae: 0.9252 - dist_relevant_mse: 2.4068 - dist_dist_iou_metric: 0.7446 - val_loss: 0.4776 - val_prob_loss: 0.2211 - val_dist_loss: 1.2824 - val_prob_kld: 0.0729 - val_dist_relevant_mae: 1.2822 - val_dist_relevant_mse: 5.0084 - val_dist_dist_iou_metric: 0.6758 - lr: 0.0010
# Epoch 35/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3771 - prob_loss: 0.1870 - dist_loss: 0.9504 - prob_kld: 0.0428 - dist_relevant_mae: 0.9502 - dist_relev
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3778 - prob_loss: 0.1877 - dist_loss: 0.9506 - prob_kld: 0.0430 - dist_relevant_mae: 0.9503 - dist_relevant_mse: 2.4955 - dist_dist_iou_metric: 0.7403 - val_loss: 0.4752 - val_prob_loss: 0.2185 - val_dist_loss: 1.2838 - val_prob_kld: 0.0703 - val_dist_relevant_mae: 1.2835 - val_dist_relevant_mse: 4.9666 - val_dist_dist_iou_metric: 0.6796 - lr: 0.0010
# Epoch 36/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3683 - prob_loss: 0.1867 - dist_loss: 0.9080 - prob_kld: 0.0423 - dist_relevant_mae: 0.9077 - dist_relev
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3683 - prob_loss: 0.1867 - dist_loss: 0.9080 - prob_kld: 0.0423 - dist_relevant_mae: 0.9077 - dist_relevant_mse: 2.2963 - dist_dist_iou_metric: 0.7477 - val_loss: 0.4953 - val_prob_loss: 0.2331 - val_dist_loss: 1.3109 - val_prob_kld: 0.0848 - val_dist_relevant_mae: 1.3107 - val_dist_relevant_mse: 5.3511 - val_dist_dist_iou_metric: 0.6716 - lr: 0.0010
# Epoch 37/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3772 - prob_loss: 0.1904 - dist_loss: 0.9344 - prob_kld: 0.0439 - dist_relevant_mae: 0.9341 - dist_relev
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3772 - prob_loss: 0.1900 - dist_loss: 0.9364 - prob_kld: 0.0438 - dist_relevant_mae: 0.9362 - dist_relevant_mse: 2.4210 - dist_dist_iou_metric: 0.7391 - val_loss: 0.4770 - val_prob_loss: 0.2195 - val_dist_loss: 1.2877 - val_prob_kld: 0.0713 - val_dist_relevant_mae: 1.2874 - val_dist_relevant_mse: 5.0084 - val_dist_dist_iou_metric: 0.6695 - lr: 0.0010
# Epoch 38/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3703 - prob_loss: 0.1863 - dist_loss: 0.9199 - prob_kld: 0.0416 - dist_relevant_mae: 0.9197 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3709 - prob_loss: 0.1869 - dist_loss: 0.9201 - prob_kld: 0.0419 - dist_relevant_mae: 0.9198 - dist_relevant_mse: 2.3713 - dist_dist_iou_metric: 0.7462 - val_loss: 0.4865 - val_prob_loss: 0.2271 - val_dist_loss: 1.2969 - val_prob_kld: 0.0789 - val_dist_relevant_mae: 1.2966 - val_dist_relevant_mse: 5.0009 - val_dist_dist_iou_metric: 0.6704 - lr: 0.0010
# Epoch 39/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3752 - prob_loss: 0.1918 - dist_loss: 0.9174 - prob_kld: 0.0432 - dist_relevant_mae: 0.9171 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3745 - prob_loss: 0.1916 - dist_loss: 0.9147 - prob_kld: 0.0431 - dist_relevant_mae: 0.9145 - dist_relevant_mse: 2.3256 - dist_dist_iou_metric: 0.7466 - val_loss: 0.4836 - val_prob_loss: 0.2234 - val_dist_loss: 1.3009 - val_prob_kld: 0.0752 - val_dist_relevant_mae: 1.3006 - val_dist_relevant_mse: 5.0731 - val_dist_dist_iou_metric: 0.6650 - lr: 0.0010
# Epoch 40/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3701 - prob_loss: 0.1893 - dist_loss: 0.9042 - prob_kld: 0.0424 - dist_relevant_mae: 0.9040 - dist_relev
# 100/100 [==============================] - 6s 57ms/step - loss: 0.3705 - prob_loss: 0.1896 - dist_loss: 0.9047 - prob_kld: 0.0425 - dist_relevant_mae: 0.9045 - dist_relevant_mse: 2.3089 - dist_dist_iou_metric: 0.7477 - val_loss: 0.4845 - val_prob_loss: 0.2214 - val_dist_loss: 1.3154 - val_prob_kld: 0.0732 - val_dist_relevant_mae: 1.3151 - val_dist_relevant_mse: 5.0920 - val_dist_dist_iou_metric: 0.6767 - lr: 0.0010
# Epoch 41/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3645 - prob_loss: 0.1857 - dist_loss: 0.8939 - prob_kld: 0.0406 - dist_relevant_mae: 0.8937 - dist_relev
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3650 - prob_loss: 0.1861 - dist_loss: 0.8943 - prob_kld: 0.0406 - dist_relevant_mae: 0.8941 - dist_relevant_mse: 2.2606 - dist_dist_iou_metric: 0.7517 - val_loss: 0.4833 - val_prob_loss: 0.2247 - val_dist_loss: 1.2929 - val_prob_kld: 0.0765 - val_dist_relevant_mae: 1.2926 - val_dist_relevant_mse: 4.9843 - val_dist_dist_iou_metric: 0.6679 - lr: 0.0010
# Epoch 42/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3612 - prob_loss: 0.1834 - dist_loss: 0.8891 - prob_kld: 0.0400 - dist_relevant_mae: 0.8888 - dist_relev
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3606 - prob_loss: 0.1832 - dist_loss: 0.8875 - prob_kld: 0.0400 - dist_relevant_mae: 0.8872 - dist_relevant_mse: 2.2455 - dist_dist_iou_metric: 0.7534 - val_loss: 0.4798 - val_prob_loss: 0.2215 - val_dist_loss: 1.2913 - val_prob_kld: 0.0734 - val_dist_relevant_mae: 1.2911 - val_dist_relevant_mse: 5.0382 - val_dist_dist_iou_metric: 0.6715 - lr: 0.0010
# Epoch 43/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3648 - prob_loss: 0.1891 - dist_loss: 0.8786 - prob_kld: 0.0401 - dist_relevant_mae: 0.8783 - dist_relev
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3648 - prob_loss: 0.1891 - dist_loss: 0.8786 - prob_kld: 0.0401 - dist_relevant_mae: 0.8783 - dist_relevant_mse: 2.1845 - dist_dist_iou_metric: 0.7554 - val_loss: 0.4857 - val_prob_loss: 0.2250 - val_dist_loss: 1.3033 - val_prob_kld: 0.0768 - val_dist_relevant_mae: 1.3031 - val_dist_relevant_mse: 5.1326 - val_dist_dist_iou_metric: 0.6744 - lr: 0.0010
# Epoch 44/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3619 - prob_loss: 0.1831 - dist_loss: 0.8940 - prob_kld: 0.0401 - dist_relevant_mae: 0.8938 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3620 - prob_loss: 0.1831 - dist_loss: 0.8945 - prob_kld: 0.0400 - dist_relevant_mae: 0.8943 - dist_relevant_mse: 2.2560 - dist_dist_iou_metric: 0.7534 - val_loss: 0.4837 - val_prob_loss: 0.2234 - val_dist_loss: 1.3013 - val_prob_kld: 0.0752 - val_dist_relevant_mae: 1.3010 - val_dist_relevant_mse: 5.2124 - val_dist_dist_iou_metric: 0.6707 - lr: 0.0010
# Epoch 45/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3619 - prob_loss: 0.1851 - dist_loss: 0.8842 - prob_kld: 0.0404 - dist_relevant_mae: 0.8840 - dist_relev
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3620 - prob_loss: 0.1854 - dist_loss: 0.8829 - prob_kld: 0.0404 - dist_relevant_mae: 0.8827 - dist_relevant_mse: 2.1870 - dist_dist_iou_metric: 0.7537 - val_loss: 0.4760 - val_prob_loss: 0.2214 - val_dist_loss: 1.2733 - val_prob_kld: 0.0732 - val_dist_relevant_mae: 1.2731 - val_dist_relevant_mse: 4.9578 - val_dist_dist_iou_metric: 0.6780 - lr: 0.0010
# Epoch 46/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3560 - prob_loss: 0.1853 - dist_loss: 0.8534 - prob_kld: 0.0394 - dist_relevant_mae: 0.8532 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3560 - prob_loss: 0.1853 - dist_loss: 0.8534 - prob_kld: 0.0394 - dist_relevant_mae: 0.8532 - dist_relevant_mse: 2.0623 - dist_dist_iou_metric: 0.7604 - val_loss: 0.4847 - val_prob_loss: 0.2260 - val_dist_loss: 1.2933 - val_prob_kld: 0.0779 - val_dist_relevant_mae: 1.2931 - val_dist_relevant_mse: 5.0963 - val_dist_dist_iou_metric: 0.6744 - lr: 0.0010
# Epoch 47/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3626 - prob_loss: 0.1843 - dist_loss: 0.8916 - prob_kld: 0.0396 - dist_relevant_mae: 0.8913 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3628 - prob_loss: 0.1849 - dist_loss: 0.8899 - prob_kld: 0.0397 - dist_relevant_mae: 0.8896 - dist_relevant_mse: 2.2519 - dist_dist_iou_metric: 0.7547 - val_loss: 0.4804 - val_prob_loss: 0.2208 - val_dist_loss: 1.2977 - val_prob_kld: 0.0727 - val_dist_relevant_mae: 1.2974 - val_dist_relevant_mse: 5.0882 - val_dist_dist_iou_metric: 0.6762 - lr: 0.0010
# Epoch 48/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3578 - prob_loss: 0.1844 - dist_loss: 0.8673 - prob_kld: 0.0385 - dist_relevant_mae: 0.8671 - dist_relev
# 100/100 [==============================] - 5s 47ms/step - loss: 0.3575 - prob_loss: 0.1840 - dist_loss: 0.8676 - prob_kld: 0.0385 - dist_relevant_mae: 0.8674 - dist_relevant_mse: 2.1284 - dist_dist_iou_metric: 0.7569 - val_loss: 0.4999 - val_prob_loss: 0.2370 - val_dist_loss: 1.3144 - val_prob_kld: 0.0888 - val_dist_relevant_mae: 1.3142 - val_dist_relevant_mse: 5.2697 - val_dist_dist_iou_metric: 0.6650 - lr: 0.0010
# Epoch 49/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3552 - prob_loss: 0.1848 - dist_loss: 0.8519 - prob_kld: 0.0387 - dist_relevant_mae: 0.8517 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3550 - prob_loss: 0.1847 - dist_loss: 0.8519 - prob_kld: 0.0385 - dist_relevant_mae: 0.8517 - dist_relevant_mse: 2.0605 - dist_dist_iou_metric: 0.7622 - val_loss: 0.4773 - val_prob_loss: 0.2212 - val_dist_loss: 1.2801 - val_prob_kld: 0.0730 - val_dist_relevant_mae: 1.2799 - val_dist_relevant_mse: 4.9599 - val_dist_dist_iou_metric: 0.6711 - lr: 0.0010
# Epoch 50/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3536 - prob_loss: 0.1827 - dist_loss: 0.8548 - prob_kld: 0.0382 - dist_relevant_mae: 0.8546 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3543 - prob_loss: 0.1833 - dist_loss: 0.8552 - prob_kld: 0.0384 - dist_relevant_mae: 0.8550 - dist_relevant_mse: 2.0829 - dist_dist_iou_metric: 0.7606 - val_loss: 0.4800 - val_prob_loss: 0.2206 - val_dist_loss: 1.2972 - val_prob_kld: 0.0724 - val_dist_relevant_mae: 1.2970 - val_dist_relevant_mse: 5.1009 - val_dist_dist_iou_metric: 0.6774 - lr: 0.0010
# Epoch 51/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3521 - prob_loss: 0.1834 - dist_loss: 0.8436 - prob_kld: 0.0369 - dist_relevant_mae: 0.8434 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3529 - prob_loss: 0.1837 - dist_loss: 0.8457 - prob_kld: 0.0369 - dist_relevant_mae: 0.8455 - dist_relevant_mse: 2.0310 - dist_dist_iou_metric: 0.7639 - val_loss: 0.4807 - val_prob_loss: 0.2232 - val_dist_loss: 1.2880 - val_prob_kld: 0.0750 - val_dist_relevant_mae: 1.2878 - val_dist_relevant_mse: 5.0403 - val_dist_dist_iou_metric: 0.6726 - lr: 0.0010
# Epoch 52/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3554 - prob_loss: 0.1814 - dist_loss: 0.8702 - prob_kld: 0.0383 - dist_relevant_mae: 0.8700 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3556 - prob_loss: 0.1820 - dist_loss: 0.8680 - prob_kld: 0.0383 - dist_relevant_mae: 0.8678 - dist_relevant_mse: 2.1093 - dist_dist_iou_metric: 0.7579 - val_loss: 0.4904 - val_prob_loss: 0.2304 - val_dist_loss: 1.3002 - val_prob_kld: 0.0821 - val_dist_relevant_mae: 1.3000 - val_dist_relevant_mse: 5.2635 - val_dist_dist_iou_metric: 0.6739 - lr: 0.0010
# Epoch 53/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3627 - prob_loss: 0.1878 - dist_loss: 0.8741 - prob_kld: 0.0399 - dist_relevant_mae: 0.8739 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3632 - prob_loss: 0.1880 - dist_loss: 0.8760 - prob_kld: 0.0400 - dist_relevant_mae: 0.8758 - dist_relevant_mse: 2.2007 - dist_dist_iou_metric: 0.7546 - val_loss: 0.4785 - val_prob_loss: 0.2228 - val_dist_loss: 1.2785 - val_prob_kld: 0.0746 - val_dist_relevant_mae: 1.2783 - val_dist_relevant_mse: 4.9624 - val_dist_dist_iou_metric: 0.6768 - lr: 0.0010
# Epoch 54/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3483 - prob_loss: 0.1815 - dist_loss: 0.8339 - prob_kld: 0.0370 - dist_relevant_mae: 0.8337 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3475 - prob_loss: 0.1809 - dist_loss: 0.8329 - prob_kld: 0.0368 - dist_relevant_mae: 0.8327 - dist_relevant_mse: 2.0013 - dist_dist_iou_metric: 0.7677 - val_loss: 0.4760 - val_prob_loss: 0.2209 - val_dist_loss: 1.2756 - val_prob_kld: 0.0727 - val_dist_relevant_mae: 1.2754 - val_dist_relevant_mse: 5.0149 - val_dist_dist_iou_metric: 0.6797 - lr: 0.0010
# Epoch 55/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3540 - prob_loss: 0.1848 - dist_loss: 0.8460 - prob_kld: 0.0377 - dist_relevant_mae: 0.8458 - dist_relev
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3534 - prob_loss: 0.1843 - dist_loss: 0.8455 - prob_kld: 0.0377 - dist_relevant_mae: 0.8453 - dist_relevant_mse: 2.0485 - dist_dist_iou_metric: 0.7626 - val_loss: 0.4827 - val_prob_loss: 0.2266 - val_dist_loss: 1.2803 - val_prob_kld: 0.0784 - val_dist_relevant_mae: 1.2801 - val_dist_relevant_mse: 5.1107 - val_dist_dist_iou_metric: 0.6777 - lr: 0.0010
# Epoch 56/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3495 - prob_loss: 0.1835 - dist_loss: 0.8296 - prob_kld: 0.0362 - dist_relevant_mae: 0.8294 - dist_relev
# 100/100 [==============================] - 5s 48ms/step - loss: 0.3495 - prob_loss: 0.1835 - dist_loss: 0.8296 - prob_kld: 0.0362 - dist_relevant_mae: 0.8294 - dist_relevant_mse: 1.9882 - dist_dist_iou_metric: 0.7677 - val_loss: 0.4848 - val_prob_loss: 0.2243 - val_dist_loss: 1.3025 - val_prob_kld: 0.0761 - val_dist_relevant_mae: 1.3022 - val_dist_relevant_mse: 5.2345 - val_dist_dist_iou_metric: 0.6781 - lr: 0.0010
# Epoch 57/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3455 - prob_loss: 0.1813 - dist_loss: 0.8209 - prob_kld: 0.0364 - dist_relevant_mae: 0.8207 - dist_relev
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3457 - prob_loss: 0.1814 - dist_loss: 0.8213 - prob_kld: 0.0365 - dist_relevant_mae: 0.8211 - dist_relevant_mse: 1.9294 - dist_dist_iou_metric: 0.7683 - val_loss: 0.4768 - val_prob_loss: 0.2226 - val_dist_loss: 1.2711 - val_prob_kld: 0.0744 - val_dist_relevant_mae: 1.2709 - val_dist_relevant_mse: 5.0058 - val_dist_dist_iou_metric: 0.6790 - lr: 0.0010
# Epoch 58/400
#  99/100 [============================>.] - ETA: 0s - loss: 0.3402 - prob_loss: 0.1791 - dist_loss: 0.8057 - prob_kld: 0.0351 - dist_relevant_mae: 0.8055 - dist_relevant_mse: 1.8793 - dist_dist_iou_metric: 0.7726
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 [==============================] - 0s 2ms/step
# 100/100 [==============================] - 5s 46ms/step - loss: 0.3395 - prob_loss: 0.1784 - dist_loss: 0.8053 - prob_kld: 0.0350 - dist_relevant_mae: 0.8051 - dist_relevant_mse: 1.8766 - dist_dist_iou_metric: 0.7729 - val_loss: 0.4900 - val_prob_loss: 0.2297 - val_dist_loss: 1.3017 - val_prob_kld: 0.0815 - val_dist_relevant_mae: 1.3015 - val_dist_relevant_mse: 5.2442 - val_dist_dist_iou_metric: 0.6743 - lr: 0.0010
# Epoch 59/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3392 - prob_loss: 0.1801 - dist_loss: 0.7957 - prob_kld: 0.0344 - dist_relevant_mae: 0.7955 - dist_relev
# 100/100 [==============================] - 5s 46ms/step - loss: 0.3387 - prob_loss: 0.1797 - dist_loss: 0.7950 - prob_kld: 0.0343 - dist_relevant_mae: 0.7948 - dist_relevant_mse: 1.8560 - dist_dist_iou_metric: 0.7771 - val_loss: 0.4782 - val_prob_loss: 0.2244 - val_dist_loss: 1.2692 - val_prob_kld: 0.0762 - val_dist_relevant_mae: 1.2690 - val_dist_relevant_mse: 4.9907 - val_dist_dist_iou_metric: 0.6803 - lr: 5.0000e-04
# Epoch 60/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3348 - prob_loss: 0.1801 - dist_loss: 0.7733 - prob_kld: 0.0332 - dist_relevant_mae: 0.7731 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3346 - prob_loss: 0.1795 - dist_loss: 0.7756 - prob_kld: 0.0331 - dist_relevant_mae: 0.7754 - dist_relevant_mse: 1.7622 - dist_dist_iou_metric: 0.7811 - val_loss: 0.4794 - val_prob_loss: 0.2247 - val_dist_loss: 1.2734 - val_prob_kld: 0.0765 - val_dist_relevant_mae: 1.2732 - val_dist_relevant_mse: 5.0406 - val_dist_dist_iou_metric: 0.6795 - lr: 5.0000e-04
# Epoch 61/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3362 - prob_loss: 0.1825 - dist_loss: 0.7684 - prob_kld: 0.0330 - dist_relevant_mae: 0.7682 - dist_relev
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3357 - prob_loss: 0.1822 - dist_loss: 0.7676 - prob_kld: 0.0329 - dist_relevant_mae: 0.7674 - dist_relevant_mse: 1.7453 - dist_dist_iou_metric: 0.7818 - val_loss: 0.4796 - val_prob_loss: 0.2240 - val_dist_loss: 1.2783 - val_prob_kld: 0.0758 - val_dist_relevant_mae: 1.2781 - val_dist_relevant_mse: 5.0555 - val_dist_dist_iou_metric: 0.6796 - lr: 5.0000e-04
# Epoch 62/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3313 - prob_loss: 0.1768 - dist_loss: 0.7725 - prob_kld: 0.0327 - dist_relevant_mae: 0.7723 - dist_relev
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3319 - prob_loss: 0.1768 - dist_loss: 0.7756 - prob_kld: 0.0328 - dist_relevant_mae: 0.7754 - dist_relevant_mse: 1.8016 - dist_dist_iou_metric: 0.7803 - val_loss: 0.4827 - val_prob_loss: 0.2269 - val_dist_loss: 1.2789 - val_prob_kld: 0.0788 - val_dist_relevant_mae: 1.2787 - val_dist_relevant_mse: 5.0756 - val_dist_dist_iou_metric: 0.6767 - lr: 5.0000e-04
# Epoch 63/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3269 - prob_loss: 0.1764 - dist_loss: 0.7525 - prob_kld: 0.0319 - dist_relevant_mae: 0.7523 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3280 - prob_loss: 0.1773 - dist_loss: 0.7532 - prob_kld: 0.0320 - dist_relevant_mae: 0.7531 - dist_relevant_mse: 1.6773 - dist_dist_iou_metric: 0.7854 - val_loss: 0.4812 - val_prob_loss: 0.2253 - val_dist_loss: 1.2798 - val_prob_kld: 0.0771 - val_dist_relevant_mae: 1.2796 - val_dist_relevant_mse: 5.0708 - val_dist_dist_iou_metric: 0.6781 - lr: 5.0000e-04
# Epoch 64/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3316 - prob_loss: 0.1769 - dist_loss: 0.7735 - prob_kld: 0.0321 - dist_relevant_mae: 0.7733 - dist_relev
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3315 - prob_loss: 0.1764 - dist_loss: 0.7754 - prob_kld: 0.0321 - dist_relevant_mae: 0.7752 - dist_relevant_mse: 1.7791 - dist_dist_iou_metric: 0.7827 - val_loss: 0.4850 - val_prob_loss: 0.2298 - val_dist_loss: 1.2761 - val_prob_kld: 0.0816 - val_dist_relevant_mae: 1.2759 - val_dist_relevant_mse: 5.0159 - val_dist_dist_iou_metric: 0.6767 - lr: 5.0000e-04
# Epoch 65/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3305 - prob_loss: 0.1792 - dist_loss: 0.7561 - prob_kld: 0.0324 - dist_relevant_mae: 0.7559 - dist_relev
# 100/100 [==============================] - 5s 48ms/step - loss: 0.3299 - prob_loss: 0.1788 - dist_loss: 0.7551 - prob_kld: 0.0323 - dist_relevant_mae: 0.7549 - dist_relevant_mse: 1.6788 - dist_dist_iou_metric: 0.7854 - val_loss: 0.4846 - val_prob_loss: 0.2272 - val_dist_loss: 1.2871 - val_prob_kld: 0.0790 - val_dist_relevant_mae: 1.2869 - val_dist_relevant_mse: 5.1227 - val_dist_dist_iou_metric: 0.6755 - lr: 5.0000e-04
# Epoch 66/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3279 - prob_loss: 0.1766 - dist_loss: 0.7564 - prob_kld: 0.0321 - dist_relevant_mae: 0.7562 - dist_relev
# 100/100 [==============================] - 5s 47ms/step - loss: 0.3278 - prob_loss: 0.1765 - dist_loss: 0.7563 - prob_kld: 0.0322 - dist_relevant_mae: 0.7562 - dist_relevant_mse: 1.7049 - dist_dist_iou_metric: 0.7831 - val_loss: 0.4862 - val_prob_loss: 0.2284 - val_dist_loss: 1.2891 - val_prob_kld: 0.0802 - val_dist_relevant_mae: 1.2889 - val_dist_relevant_mse: 5.1270 - val_dist_dist_iou_metric: 0.6772 - lr: 5.0000e-04
# Epoch 67/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3275 - prob_loss: 0.1762 - dist_loss: 0.7565 - prob_kld: 0.0314 - dist_relevant_mae: 0.7563 - dist_relev
# 100/100 [==============================] - 6s 57ms/step - loss: 0.3279 - prob_loss: 0.1768 - dist_loss: 0.7555 - prob_kld: 0.0314 - dist_relevant_mae: 0.7553 - dist_relevant_mse: 1.7214 - dist_dist_iou_metric: 0.7854 - val_loss: 0.4919 - val_prob_loss: 0.2323 - val_dist_loss: 1.2977 - val_prob_kld: 0.0841 - val_dist_relevant_mae: 1.2975 - val_dist_relevant_mse: 5.2074 - val_dist_dist_iou_metric: 0.6739 - lr: 5.0000e-04
# Epoch 68/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3234 - prob_loss: 0.1737 - dist_loss: 0.7483 - prob_kld: 0.0308 - dist_relevant_mae: 0.7481 - dist_relev
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3234 - prob_loss: 0.1737 - dist_loss: 0.7483 - prob_kld: 0.0308 - dist_relevant_mae: 0.7481 - dist_relevant_mse: 1.6654 - dist_dist_iou_metric: 0.7861 - val_loss: 0.4914 - val_prob_loss: 0.2300 - val_dist_loss: 1.3070 - val_prob_kld: 0.0818 - val_dist_relevant_mae: 1.3068 - val_dist_relevant_mse: 5.2436 - val_dist_dist_iou_metric: 0.6671 - lr: 5.0000e-04
# Epoch 69/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3300 - prob_loss: 0.1792 - dist_loss: 0.7544 - prob_kld: 0.0318 - dist_relevant_mae: 0.7542 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3305 - prob_loss: 0.1797 - dist_loss: 0.7541 - prob_kld: 0.0318 - dist_relevant_mae: 0.7540 - dist_relevant_mse: 1.6994 - dist_dist_iou_metric: 0.7858 - val_loss: 0.4834 - val_prob_loss: 0.2269 - val_dist_loss: 1.2826 - val_prob_kld: 0.0787 - val_dist_relevant_mae: 1.2824 - val_dist_relevant_mse: 5.1030 - val_dist_dist_iou_metric: 0.6770 - lr: 5.0000e-04
# Epoch 70/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3277 - prob_loss: 0.1772 - dist_loss: 0.7525 - prob_kld: 0.0309 - dist_relevant_mae: 0.7523 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3280 - prob_loss: 0.1774 - dist_loss: 0.7529 - prob_kld: 0.0310 - dist_relevant_mae: 0.7527 - dist_relevant_mse: 1.6953 - dist_dist_iou_metric: 0.7867 - val_loss: 0.4827 - val_prob_loss: 0.2272 - val_dist_loss: 1.2776 - val_prob_kld: 0.0790 - val_dist_relevant_mae: 1.2774 - val_dist_relevant_mse: 5.0088 - val_dist_dist_iou_metric: 0.6735 - lr: 5.0000e-04
# Epoch 71/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3261 - prob_loss: 0.1774 - dist_loss: 0.7434 - prob_kld: 0.0312 - dist_relevant_mae: 0.7432 - dist_relev
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3259 - prob_loss: 0.1769 - dist_loss: 0.7453 - prob_kld: 0.0312 - dist_relevant_mae: 0.7451 - dist_relevant_mse: 1.6424 - dist_dist_iou_metric: 0.7874 - val_loss: 0.4790 - val_prob_loss: 0.2230 - val_dist_loss: 1.2802 - val_prob_kld: 0.0748 - val_dist_relevant_mae: 1.2800 - val_dist_relevant_mse: 5.1035 - val_dist_dist_iou_metric: 0.6792 - lr: 5.0000e-04
# Epoch 72/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3269 - prob_loss: 0.1792 - dist_loss: 0.7382 - prob_kld: 0.0307 - dist_relevant_mae: 0.7380 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3264 - prob_loss: 0.1785 - dist_loss: 0.7399 - prob_kld: 0.0306 - dist_relevant_mae: 0.7397 - dist_relevant_mse: 1.6293 - dist_dist_iou_metric: 0.7893 - val_loss: 0.4920 - val_prob_loss: 0.2330 - val_dist_loss: 1.2953 - val_prob_kld: 0.0848 - val_dist_relevant_mae: 1.2951 - val_dist_relevant_mse: 5.2322 - val_dist_dist_iou_metric: 0.6736 - lr: 5.0000e-04
# Epoch 73/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3237 - prob_loss: 0.1742 - dist_loss: 0.7472 - prob_kld: 0.0304 - dist_relevant_mae: 0.7470 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3237 - prob_loss: 0.1742 - dist_loss: 0.7472 - prob_kld: 0.0304 - dist_relevant_mae: 0.7470 - dist_relevant_mse: 1.6698 - dist_dist_iou_metric: 0.7884 - val_loss: 0.4917 - val_prob_loss: 0.2312 - val_dist_loss: 1.3027 - val_prob_kld: 0.0830 - val_dist_relevant_mae: 1.3025 - val_dist_relevant_mse: 5.3072 - val_dist_dist_iou_metric: 0.6745 - lr: 5.0000e-04
# Epoch 74/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3227 - prob_loss: 0.1752 - dist_loss: 0.7372 - prob_kld: 0.0302 - dist_relevant_mae: 0.7370 - dist_relev
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3229 - prob_loss: 0.1754 - dist_loss: 0.7376 - prob_kld: 0.0304 - dist_relevant_mae: 0.7374 - dist_relevant_mse: 1.6103 - dist_dist_iou_metric: 0.7891 - val_loss: 0.4932 - val_prob_loss: 0.2315 - val_dist_loss: 1.3087 - val_prob_kld: 0.0833 - val_dist_relevant_mae: 1.3085 - val_dist_relevant_mse: 5.2719 - val_dist_dist_iou_metric: 0.6734 - lr: 5.0000e-04
# Epoch 75/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3288 - prob_loss: 0.1782 - dist_loss: 0.7531 - prob_kld: 0.0311 - dist_relevant_mae: 0.7529 - dist_relev
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3286 - prob_loss: 0.1779 - dist_loss: 0.7536 - prob_kld: 0.0311 - dist_relevant_mae: 0.7534 - dist_relevant_mse: 1.7061 - dist_dist_iou_metric: 0.7872 - val_loss: 0.4856 - val_prob_loss: 0.2285 - val_dist_loss: 1.2852 - val_prob_kld: 0.0804 - val_dist_relevant_mae: 1.2850 - val_dist_relevant_mse: 5.1486 - val_dist_dist_iou_metric: 0.6773 - lr: 5.0000e-04
# Epoch 76/400
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3218 - prob_loss: 0.1778 - dist_loss: 0.7197 - prob_kld: 0.0299 - dist_relevant_mae: 0.7195 - dist_relev
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3212 - prob_loss: 0.1770 - dist_loss: 0.7209 - prob_kld: 0.0298 - dist_relevant_mae: 0.7208 - dist_relevant_mse: 1.5528 - dist_dist_iou_metric: 0.7927 - val_loss: 0.4855 - val_prob_loss: 0.2278 - val_dist_loss: 1.2885 - val_prob_kld: 0.0796 - val_dist_relevant_mae: 1.2883 - val_dist_relevant_mse: 5.2225 - val_dist_dist_iou_metric: 0.6781 - lr: 5.0000e-04
# Epoch 77/400
# ...
# Epoch 377/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2848 - prob_loss: 0.1644 - dist_loss: 0.6019 - prob_kld: 0.0187 - dist_relevant_mae: 0.6018 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2852 - prob_loss: 0.1647 - dist_loss: 0.6022 - prob_kld: 0.0188 - dist_relevant_mae: 0.6021 - dist_relevant_mse: 1.1953 - dist_dist_iou_metric: 0.8233 - val_loss: 0.5268 - val_prob_loss: 0.2622 - val_dist_loss: 1.3227 - val_prob_kld: 0.1114 - val_dist_relevant_mae: 1.3225 - val_dist_relevant_mse: 5.4901 - val_dist_dist_iou_metric: 0.6704 - lr: 3.9063e-06
# Epoch 378/400
#  99/100 [============================>.] - ETA: 0s - loss: 0.2938 - prob_loss: 0.1696 - dist_loss: 0.6209 - prob_kld: 0.0199 - dist_relevant_mae: 0.6208 - dist_relevant_mse: 1.2533 - dist_dist_iou_metric: 0.8199
# Epoch 378: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3/3 [==============================] - 0s 9ms/step
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2935 - prob_loss: 0.1694 - dist_loss: 0.6206 - prob_kld: 0.0199 - dist_relevant_mae: 0.6204 - dist_relevant_mse: 1.2514 - dist_dist_iou_metric: 0.8200 - val_loss: 0.5263 - val_prob_loss: 0.2618 - val_dist_loss: 1.3221 - val_prob_kld: 0.1110 - val_dist_relevant_mae: 1.3219 - val_dist_relevant_mse: 5.4845 - val_dist_dist_iou_metric: 0.6702 - lr: 3.9063e-06
# Epoch 379/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2824 - prob_loss: 0.1629 - dist_loss: 0.5979 - prob_kld: 0.0183 - dist_relevant_mae: 0.5977 - dist_relev
# 100/100 [==============================] - 5s 53ms/step - loss: 0.2829 - prob_loss: 0.1631 - dist_loss: 0.5989 - prob_kld: 0.0185 - dist_relevant_mae: 0.5988 - dist_relevant_mse: 1.1682 - dist_dist_iou_metric: 0.8239 - val_loss: 0.5270 - val_prob_loss: 0.2624 - val_dist_loss: 1.3229 - val_prob_kld: 0.1115 - val_dist_relevant_mae: 1.3227 - val_dist_relevant_mse: 5.4930 - val_dist_dist_iou_metric: 0.6701 - lr: 1.9531e-06
# Epoch 380/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2842 - prob_loss: 0.1610 - dist_loss: 0.6161 - prob_kld: 0.0192 - dist_relevant_mae: 0.6159 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2842 - prob_loss: 0.1610 - dist_loss: 0.6161 - prob_kld: 0.0192 - dist_relevant_mae: 0.6159 - dist_relevant_mse: 1.2390 - dist_dist_iou_metric: 0.8196 - val_loss: 0.5267 - val_prob_loss: 0.2621 - val_dist_loss: 1.3228 - val_prob_kld: 0.1113 - val_dist_relevant_mae: 1.3226 - val_dist_relevant_mse: 5.4935 - val_dist_dist_iou_metric: 0.6702 - lr: 1.9531e-06
# Epoch 381/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2881 - prob_loss: 0.1662 - dist_loss: 0.6096 - prob_kld: 0.0190 - dist_relevant_mae: 0.6094 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2881 - prob_loss: 0.1662 - dist_loss: 0.6096 - prob_kld: 0.0190 - dist_relevant_mae: 0.6094 - dist_relevant_mse: 1.2179 - dist_dist_iou_metric: 0.8227 - val_loss: 0.5263 - val_prob_loss: 0.2618 - val_dist_loss: 1.3224 - val_prob_kld: 0.1111 - val_dist_relevant_mae: 1.3222 - val_dist_relevant_mse: 5.4886 - val_dist_dist_iou_metric: 0.6702 - lr: 1.9531e-06
# Epoch 382/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2914 - prob_loss: 0.1684 - dist_loss: 0.6147 - prob_kld: 0.0192 - dist_relevant_mae: 0.6146 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2910 - prob_loss: 0.1684 - dist_loss: 0.6132 - prob_kld: 0.0192 - dist_relevant_mae: 0.6130 - dist_relevant_mse: 1.2213 - dist_dist_iou_metric: 0.8226 - val_loss: 0.5267 - val_prob_loss: 0.2622 - val_dist_loss: 1.3227 - val_prob_kld: 0.1114 - val_dist_relevant_mae: 1.3225 - val_dist_relevant_mse: 5.4903 - val_dist_dist_iou_metric: 0.6699 - lr: 1.9531e-06
# Epoch 383/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2847 - prob_loss: 0.1637 - dist_loss: 0.6051 - prob_kld: 0.0189 - dist_relevant_mae: 0.6050 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2845 - prob_loss: 0.1636 - dist_loss: 0.6045 - prob_kld: 0.0188 - dist_relevant_mae: 0.6043 - dist_relevant_mse: 1.1940 - dist_dist_iou_metric: 0.8224 - val_loss: 0.5269 - val_prob_loss: 0.2623 - val_dist_loss: 1.3229 - val_prob_kld: 0.1115 - val_dist_relevant_mae: 1.3227 - val_dist_relevant_mse: 5.4921 - val_dist_dist_iou_metric: 0.6700 - lr: 1.9531e-06
# Epoch 384/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2886 - prob_loss: 0.1656 - dist_loss: 0.6151 - prob_kld: 0.0190 - dist_relevant_mae: 0.6149 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2886 - prob_loss: 0.1656 - dist_loss: 0.6151 - prob_kld: 0.0190 - dist_relevant_mae: 0.6149 - dist_relevant_mse: 1.2394 - dist_dist_iou_metric: 0.8200 - val_loss: 0.5267 - val_prob_loss: 0.2621 - val_dist_loss: 1.3227 - val_prob_kld: 0.1113 - val_dist_relevant_mae: 1.3225 - val_dist_relevant_mse: 5.4925 - val_dist_dist_iou_metric: 0.6700 - lr: 1.9531e-06
# Epoch 385/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2854 - prob_loss: 0.1630 - dist_loss: 0.6119 - prob_kld: 0.0188 - dist_relevant_mae: 0.6117 - dist_relev
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2861 - prob_loss: 0.1634 - dist_loss: 0.6136 - prob_kld: 0.0189 - dist_relevant_mae: 0.6134 - dist_relevant_mse: 1.2314 - dist_dist_iou_metric: 0.8209 - val_loss: 0.5269 - val_prob_loss: 0.2623 - val_dist_loss: 1.3229 - val_prob_kld: 0.1114 - val_dist_relevant_mae: 1.3227 - val_dist_relevant_mse: 5.4923 - val_dist_dist_iou_metric: 0.6700 - lr: 1.9531e-06
# Epoch 386/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2854 - prob_loss: 0.1657 - dist_loss: 0.5985 - prob_kld: 0.0191 - dist_relevant_mae: 0.5983 - dist_relev
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2864 - prob_loss: 0.1664 - dist_loss: 0.5996 - prob_kld: 0.0192 - dist_relevant_mae: 0.5995 - dist_relevant_mse: 1.1641 - dist_dist_iou_metric: 0.8231 - val_loss: 0.5264 - val_prob_loss: 0.2619 - val_dist_loss: 1.3225 - val_prob_kld: 0.1111 - val_dist_relevant_mae: 1.3224 - val_dist_relevant_mse: 5.4904 - val_dist_dist_iou_metric: 0.6701 - lr: 1.9531e-06
# Epoch 387/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2845 - prob_loss: 0.1636 - dist_loss: 0.6045 - prob_kld: 0.0186 - dist_relevant_mae: 0.6044 - dist_relev
# 100/100 [==============================] - 5s 49ms/step - loss: 0.2847 - prob_loss: 0.1633 - dist_loss: 0.6070 - prob_kld: 0.0187 - dist_relevant_mae: 0.6068 - dist_relevant_mse: 1.2011 - dist_dist_iou_metric: 0.8217 - val_loss: 0.5268 - val_prob_loss: 0.2623 - val_dist_loss: 1.3228 - val_prob_kld: 0.1114 - val_dist_relevant_mae: 1.3226 - val_dist_relevant_mse: 5.4918 - val_dist_dist_iou_metric: 0.6700 - lr: 1.9531e-06
# Epoch 388/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2890 - prob_loss: 0.1665 - dist_loss: 0.6129 - prob_kld: 0.0195 - dist_relevant_mae: 0.6127 - dist_relev
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2890 - prob_loss: 0.1665 - dist_loss: 0.6129 - prob_kld: 0.0195 - dist_relevant_mae: 0.6127 - dist_relevant_mse: 1.2286 - dist_dist_iou_metric: 0.8226 - val_loss: 0.5267 - val_prob_loss: 0.2621 - val_dist_loss: 1.3228 - val_prob_kld: 0.1113 - val_dist_relevant_mae: 1.3227 - val_dist_relevant_mse: 5.4931 - val_dist_dist_iou_metric: 0.6701 - lr: 1.9531e-06
# Epoch 389/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2820 - prob_loss: 0.1616 - dist_loss: 0.6023 - prob_kld: 0.0183 - dist_relevant_mae: 0.6022 - dist_relev
# 100/100 [==============================] - 5s 47ms/step - loss: 0.2818 - prob_loss: 0.1612 - dist_loss: 0.6029 - prob_kld: 0.0182 - dist_relevant_mae: 0.6027 - dist_relevant_mse: 1.1770 - dist_dist_iou_metric: 0.8218 - val_loss: 0.5272 - val_prob_loss: 0.2625 - val_dist_loss: 1.3234 - val_prob_kld: 0.1117 - val_dist_relevant_mae: 1.3232 - val_dist_relevant_mse: 5.4964 - val_dist_dist_iou_metric: 0.6699 - lr: 1.9531e-06
# Epoch 390/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2866 - prob_loss: 0.1656 - dist_loss: 0.6053 - prob_kld: 0.0190 - dist_relevant_mae: 0.6052 - dist_relev
# 100/100 [==============================] - 4s 45ms/step - loss: 0.2866 - prob_loss: 0.1656 - dist_loss: 0.6053 - prob_kld: 0.0190 - dist_relevant_mae: 0.6052 - dist_relevant_mse: 1.1877 - dist_dist_iou_metric: 0.8228 - val_loss: 0.5271 - val_prob_loss: 0.2625 - val_dist_loss: 1.3231 - val_prob_kld: 0.1116 - val_dist_relevant_mae: 1.3229 - val_dist_relevant_mse: 5.4930 - val_dist_dist_iou_metric: 0.6700 - lr: 1.9531e-06
# Epoch 391/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2847 - prob_loss: 0.1637 - dist_loss: 0.6053 - prob_kld: 0.0186 - dist_relevant_mae: 0.6051 - dist_relev
# 100/100 [==============================] - 5s 48ms/step - loss: 0.2843 - prob_loss: 0.1634 - dist_loss: 0.6046 - prob_kld: 0.0185 - dist_relevant_mae: 0.6045 - dist_relevant_mse: 1.1965 - dist_dist_iou_metric: 0.8227 - val_loss: 0.5273 - val_prob_loss: 0.2626 - val_dist_loss: 1.3234 - val_prob_kld: 0.1117 - val_dist_relevant_mae: 1.3232 - val_dist_relevant_mse: 5.4947 - val_dist_dist_iou_metric: 0.6698 - lr: 1.9531e-06
# Epoch 392/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2902 - prob_loss: 0.1672 - dist_loss: 0.6149 - prob_kld: 0.0195 - dist_relevant_mae: 0.6148 - dist_relev
# 100/100 [==============================] - 4s 45ms/step - loss: 0.2903 - prob_loss: 0.1668 - dist_loss: 0.6173 - prob_kld: 0.0197 - dist_relevant_mae: 0.6172 - dist_relevant_mse: 1.2547 - dist_dist_iou_metric: 0.8201 - val_loss: 0.5272 - val_prob_loss: 0.2626 - val_dist_loss: 1.3231 - val_prob_kld: 0.1117 - val_dist_relevant_mae: 1.3229 - val_dist_relevant_mse: 5.4942 - val_dist_dist_iou_metric: 0.6700 - lr: 1.9531e-06
# Epoch 393/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2849 - prob_loss: 0.1640 - dist_loss: 0.6045 - prob_kld: 0.0185 - dist_relevant_mae: 0.6044 - dist_relev
# 100/100 [==============================] - 5s 55ms/step - loss: 0.2850 - prob_loss: 0.1638 - dist_loss: 0.6056 - prob_kld: 0.0185 - dist_relevant_mae: 0.6055 - dist_relevant_mse: 1.2195 - dist_dist_iou_metric: 0.8233 - val_loss: 0.5267 - val_prob_loss: 0.2621 - val_dist_loss: 1.3227 - val_prob_kld: 0.1113 - val_dist_relevant_mae: 1.3226 - val_dist_relevant_mse: 5.4903 - val_dist_dist_iou_metric: 0.6702 - lr: 1.9531e-06
# Epoch 394/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2874 - prob_loss: 0.1646 - dist_loss: 0.6139 - prob_kld: 0.0192 - dist_relevant_mae: 0.6138 - dist_relev
# 100/100 [==============================] - 7s 67ms/step - loss: 0.2872 - prob_loss: 0.1644 - dist_loss: 0.6140 - prob_kld: 0.0192 - dist_relevant_mae: 0.6138 - dist_relevant_mse: 1.2310 - dist_dist_iou_metric: 0.8207 - val_loss: 0.5267 - val_prob_loss: 0.2621 - val_dist_loss: 1.3229 - val_prob_kld: 0.1113 - val_dist_relevant_mae: 1.3227 - val_dist_relevant_mse: 5.4933 - val_dist_dist_iou_metric: 0.6701 - lr: 1.9531e-06
# Epoch 395/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2894 - prob_loss: 0.1678 - dist_loss: 0.6084 - prob_kld: 0.0191 - dist_relevant_mae: 0.6082 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2894 - prob_loss: 0.1678 - dist_loss: 0.6084 - prob_kld: 0.0191 - dist_relevant_mae: 0.6082 - dist_relevant_mse: 1.2091 - dist_dist_iou_metric: 0.8224 - val_loss: 0.5272 - val_prob_loss: 0.2626 - val_dist_loss: 1.3233 - val_prob_kld: 0.1117 - val_dist_relevant_mae: 1.3232 - val_dist_relevant_mse: 5.4964 - val_dist_dist_iou_metric: 0.6700 - lr: 1.9531e-06
# Epoch 396/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2856 - prob_loss: 0.1639 - dist_loss: 0.6083 - prob_kld: 0.0188 - dist_relevant_mae: 0.6081 - dist_relev
# 100/100 [==============================] - 5s 46ms/step - loss: 0.2856 - prob_loss: 0.1639 - dist_loss: 0.6083 - prob_kld: 0.0188 - dist_relevant_mae: 0.6081 - dist_relevant_mse: 1.2038 - dist_dist_iou_metric: 0.8224 - val_loss: 0.5270 - val_prob_loss: 0.2623 - val_dist_loss: 1.3232 - val_prob_kld: 0.1115 - val_dist_relevant_mae: 1.3230 - val_dist_relevant_mse: 5.4946 - val_dist_dist_iou_metric: 0.6700 - lr: 1.9531e-06
# Epoch 397/400
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2898 - prob_loss: 0.1677 - dist_loss: 0.6106 - prob_kld: 0.0194 - dist_relevant_mae: 0.6104 - dist_relev
# 100/100 [==============================] - 5s 51ms/step - loss: 0.2895 - prob_loss: 0.1676 - dist_loss: 0.6095 - prob_kld: 0.0193 - dist_relevant_mae: 0.6093 - dist_relevant_mse: 1.2116 - dist_dist_iou_metric: 0.8224 - val_loss: 0.5267 - val_prob_loss: 0.2622 - val_dist_loss: 1.3225 - val_prob_kld: 0.1114 - val_dist_relevant_mae: 1.3224 - val_dist_relevant_mse: 5.4898 - val_dist_dist_iou_metric: 0.6702 - lr: 1.9531e-06
# Epoch 398/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2838 - prob_loss: 0.1607 - dist_loss: 0.6157 - prob_kld: 0.0183 - dist_relevant_mae: 0.6156 - dist_relev
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2837 - prob_loss: 0.1604 - dist_loss: 0.6168 - prob_kld: 0.0183 - dist_relevant_mae: 0.6166 - dist_relevant_mse: 1.2721 - dist_dist_iou_metric: 0.8214 - val_loss: 0.5269 - val_prob_loss: 0.2623 - val_dist_loss: 1.3227 - val_prob_kld: 0.1115 - val_dist_relevant_mae: 1.3226 - val_dist_relevant_mse: 5.4925 - val_dist_dist_iou_metric: 0.6702 - lr: 1.9531e-06
# Epoch 399/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2894 - prob_loss: 0.1670 - dist_loss: 0.6123 - prob_kld: 0.0195 - dist_relevant_mae: 0.6121 - dist_relev
# 100/100 [==============================] - 5s 53ms/step - loss: 0.2894 - prob_loss: 0.1670 - dist_loss: 0.6123 - prob_kld: 0.0195 - dist_relevant_mae: 0.6121 - dist_relevant_mse: 1.2241 - dist_dist_iou_metric: 0.8222 - val_loss: 0.5268 - val_prob_loss: 0.2622 - val_dist_loss: 1.3228 - val_prob_kld: 0.1114 - val_dist_relevant_mae: 1.3226 - val_dist_relevant_mse: 5.4905 - val_dist_dist_iou_metric: 0.6700 - lr: 1.9531e-06
# Epoch 400/400
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2915 - prob_loss: 0.1683 - dist_loss: 0.6161 - prob_kld: 0.0199 - dist_relevant_mae: 0.6160 - dist_relev
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2917 - prob_loss: 0.1686 - dist_loss: 0.6154 - prob_kld: 0.0199 - dist_relevant_mae: 0.6153 - dist_relevant_mse: 1.2535 - dist_dist_iou_metric: 0.8211 - val_loss: 0.5262 - val_prob_loss: 0.2617 - val_dist_loss: 1.3225 - val_prob_kld: 0.1109 - val_dist_relevant_mae: 1.3223 - val_dist_relevant_mse: 5.4898 - val_dist_dist_iou_metric: 0.6703 - lr: 1.9531e-06
#
# Loading network weights from 'weights_best.h5'.
# NMS threshold = 0.3:  75%|███████▌  | 15/20 [00:09<00:03,  1.63it/s, 0.652 -> 0.632]
# NMS threshold = 0.4:  75%|███████▌  | 15/20 [00:08<00:02,  1.84it/s, 0.643 -> 0.631]
# NMS threshold = 0.5:  75%|███████▌  | 15/20 [00:07<00:02,  1.97it/s, 0.714 -> 0.627]
# Using optimized values: prob_thresh=0.649478, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# WARNING:tensorflow:From C:\Users\Donald\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\tensorflow\python\summary\summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow | From C:\Users\Donald\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\tensorflow\python\summary\summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
#Predict on validation images
mask_val_pred = [model.predict_instances(x, n_tiles=model._guess_n_tiles(x), show_tile_progress=False)[0]
              for x in tqdm(HE_val)]
# Out:
# 100%|██████████| 26/26 [00:01<00:00, 14.91it/s]

# %%
X_val = HE_val
Y_val_pred = mask_val_pred
Y_val = mask_val

ind = 3

cropped_img = X_val[ind]
cropped_lbl = Y_val_pred[ind]
cropped_lbl_gt = Y_val[ind]

fig, ax = plt.subplots(1,3,figsize = (16, 8))
ax[0].imshow(cropped_img)
ax[0].axis('off')
ax[0].set_title('H&E')

ax[1].imshow(cropped_img)
ax[1].imshow(cropped_lbl_gt, cmap=lbl_cmap, alpha=0.5)
ax[1].axis('off')
ax[1].set_title('Ground Truth')

ax[2].imshow(cropped_img)
ax[2].imshow(cropped_lbl, cmap=lbl_cmap, alpha=0.5)
ax[2].axis('off')
ax[2].set_title('Predicted')
plt.show()
