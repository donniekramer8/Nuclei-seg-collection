# %%
import os
import pandas as pd
import numpy as np
import cv2

# %%
# def json2df():
def cntarea(cnt):
    cnt = np.array(cnt)
    area = cv2.contourArea(cnt)
    return area

def cntperi(cnt):
    cnt = np.array(cnt)
    perimeter = cv2.arcLength(cnt,True)
    return perimeter

def cntMA(cnt):
    cnt = np.array(cnt)
    #Orientation, Aspect_ratio
    (x,y),(MA,ma),orientation = cv2.fitEllipse(cnt)
    return np.max((MA,ma)),np.min((MA,ma)),orientation

# %%
#input folder
jsonsrc = r'\\10.99.68.178\andreex\data\monkey fetus\gestational 40\hovernet_out\json'
#output folder creation
dst = os.path.join(os.path.dirname(jsonsrc), 'df')
if not os.path.exists(dst): os.mkdir(dst)

# %%
jsonnms = [i for i in os.listdir(jsonsrc) if i.endswith('json')]
for jsonnm in jsonnms:
    jsonpth = os.path.join(jsonsrc,jsonnm)
    imID,ext = os.path.splitext(os.path.basename(jsonpth))
    dstfn = os.path.join(dst, '{}.pkl'.format(imID))
    if os.path.exists(dstfn):
        print("pkl already exists, skipping the file ID {}".format(imID))
    try:
        json = pd.read_json(jsonpth, orient='index')
    except:
        print('cannot open json')
    print("Saving: {}".format(imID))
    json = pd.DataFrame(json[0].loc['nuc']).T.drop(columns=['type_prob'])
    json = json[json['contour'].map(len) > 5].reset_index(drop=True)
    json['Area'] = json['contour'].apply(lambda row: cntarea(row))
    json['Perimeter'] = json['contour'].apply(lambda row: cntperi(row))
    json['Circularity'] = 4 * np.pi * json['Area'] / json['Perimeter'] ** 2
    json['MA'] = json['contour'].apply(lambda row: cntMA(row))
    json[['MA', 'ma', 'orientation']] = pd.DataFrame(json.MA.tolist())
    json['AspectRatio'] = json['MA'] / json['ma']
    json['imID'] = imID
    json.to_pickle(dstfn)
# Out:
# pkl already exists, skipping the file ID monkey_fetus_40_0001
# Saving: monkey_fetus_40_0001
# pkl already exists, skipping the file ID monkey_fetus_40_0002
# Saving: monkey_fetus_40_0002
# pkl already exists, skipping the file ID monkey_fetus_40_0003
# Saving: monkey_fetus_40_0003
# pkl already exists, skipping the file ID monkey_fetus_40_0004
# Saving: monkey_fetus_40_0004
# pkl already exists, skipping the file ID monkey_fetus_40_0005
# Saving: monkey_fetus_40_0005
# pkl already exists, skipping the file ID monkey_fetus_40_0006
# Saving: monkey_fetus_40_0006
# pkl already exists, skipping the file ID monkey_fetus_40_0007
# Saving: monkey_fetus_40_0007
# pkl already exists, skipping the file ID monkey_fetus_40_0008
# Saving: monkey_fetus_40_0008
# pkl already exists, skipping the file ID monkey_fetus_40_0009
# Saving: monkey_fetus_40_0009
# pkl already exists, skipping the file ID monkey_fetus_40_0010
# Saving: monkey_fetus_40_0010
# pkl already exists, skipping the file ID monkey_fetus_40_0011
# Saving: monkey_fetus_40_0011
# pkl already exists, skipping the file ID monkey_fetus_40_0012
# Saving: monkey_fetus_40_0012
# pkl already exists, skipping the file ID monkey_fetus_40_0013
# Saving: monkey_fetus_40_0013
# pkl already exists, skipping the file ID monkey_fetus_40_0014
# Saving: monkey_fetus_40_0014
# pkl already exists, skipping the file ID monkey_fetus_40_0015
# Saving: monkey_fetus_40_0015
# pkl already exists, skipping the file ID monkey_fetus_40_0016
# Saving: monkey_fetus_40_0016
# pkl already exists, skipping the file ID monkey_fetus_40_0017
# Saving: monkey_fetus_40_0017
# pkl already exists, skipping the file ID monkey_fetus_40_0018
# Saving: monkey_fetus_40_0018
# pkl already exists, skipping the file ID monkey_fetus_40_0019
# Saving: monkey_fetus_40_0019
# pkl already exists, skipping the file ID monkey_fetus_40_0020
# Saving: monkey_fetus_40_0020
# pkl already exists, skipping the file ID monkey_fetus_40_0021
# Saving: monkey_fetus_40_0021
# pkl already exists, skipping the file ID monkey_fetus_40_0022
# Saving: monkey_fetus_40_0022
# pkl already exists, skipping the file ID monkey_fetus_40_0023
# Saving: monkey_fetus_40_0023
# pkl already exists, skipping the file ID monkey_fetus_40_0024
# Saving: monkey_fetus_40_0024
# pkl already exists, skipping the file ID monkey_fetus_40_0025
# Saving: monkey_fetus_40_0025
# pkl already exists, skipping the file ID monkey_fetus_40_0026
# Saving: monkey_fetus_40_0026
# pkl already exists, skipping the file ID monkey_fetus_40_0028
# Saving: monkey_fetus_40_0028
# pkl already exists, skipping the file ID monkey_fetus_40_0029
# Saving: monkey_fetus_40_0029
# pkl already exists, skipping the file ID monkey_fetus_40_0030
# Saving: monkey_fetus_40_0030
# pkl already exists, skipping the file ID monkey_fetus_40_0031
# Saving: monkey_fetus_40_0031
# pkl already exists, skipping the file ID monkey_fetus_40_0032
# Saving: monkey_fetus_40_0032
# pkl already exists, skipping the file ID monkey_fetus_40_0033
# Saving: monkey_fetus_40_0033
# pkl already exists, skipping the file ID monkey_fetus_40_0036
# Saving: monkey_fetus_40_0036
# pkl already exists, skipping the file ID monkey_fetus_40_0037
# Saving: monkey_fetus_40_0037
# pkl already exists, skipping the file ID monkey_fetus_40_0038
# Saving: monkey_fetus_40_0038
# pkl already exists, skipping the file ID monkey_fetus_40_0039
# Saving: monkey_fetus_40_0039
# pkl already exists, skipping the file ID monkey_fetus_40_0040
# Saving: monkey_fetus_40_0040
# pkl already exists, skipping the file ID monkey_fetus_40_0041
# Saving: monkey_fetus_40_0041
# pkl already exists, skipping the file ID monkey_fetus_40_0068
# Saving: monkey_fetus_40_0068
# pkl already exists, skipping the file ID monkey_fetus_40_0069
# Saving: monkey_fetus_40_0069
# pkl already exists, skipping the file ID monkey_fetus_40_0074
# Saving: monkey_fetus_40_0074
# pkl already exists, skipping the file ID monkey_fetus_40_0075
# Saving: monkey_fetus_40_0075
# pkl already exists, skipping the file ID monkey_fetus_40_0076
# Saving: monkey_fetus_40_0076
# pkl already exists, skipping the file ID monkey_fetus_40_0077
# Saving: monkey_fetus_40_0077
# pkl already exists, skipping the file ID monkey_fetus_40_0101
# Saving: monkey_fetus_40_0101
# pkl already exists, skipping the file ID monkey_fetus_40_0102
# Saving: monkey_fetus_40_0102
# pkl already exists, skipping the file ID monkey_fetus_40_0103
# Saving: monkey_fetus_40_0103
# pkl already exists, skipping the file ID monkey_fetus_40_0104
# Saving: monkey_fetus_40_0104
# pkl already exists, skipping the file ID monkey_fetus_40_0105
# Saving: monkey_fetus_40_0105
# pkl already exists, skipping the file ID monkey_fetus_40_0106
# Saving: monkey_fetus_40_0106
# pkl already exists, skipping the file ID monkey_fetus_40_0107
# Saving: monkey_fetus_40_0107
# pkl already exists, skipping the file ID monkey_fetus_40_0108
# Saving: monkey_fetus_40_0108
# pkl already exists, skipping the file ID monkey_fetus_40_0109
# Saving: monkey_fetus_40_0109
# pkl already exists, skipping the file ID monkey_fetus_40_0110
# Saving: monkey_fetus_40_0110
# pkl already exists, skipping the file ID monkey_fetus_40_0111
# Saving: monkey_fetus_40_0111
# pkl already exists, skipping the file ID monkey_fetus_40_0112
# Saving: monkey_fetus_40_0112
# pkl already exists, skipping the file ID monkey_fetus_40_0113
# Saving: monkey_fetus_40_0113
# pkl already exists, skipping the file ID monkey_fetus_40_0114
# Saving: monkey_fetus_40_0114
# pkl already exists, skipping the file ID monkey_fetus_40_0115
# Saving: monkey_fetus_40_0115
# pkl already exists, skipping the file ID monkey_fetus_40_0116
# Saving: monkey_fetus_40_0116
# pkl already exists, skipping the file ID monkey_fetus_40_0117
# Saving: monkey_fetus_40_0117
# pkl already exists, skipping the file ID monkey_fetus_40_0118
# Saving: monkey_fetus_40_0118
# pkl already exists, skipping the file ID monkey_fetus_40_0119
# Saving: monkey_fetus_40_0119
# pkl already exists, skipping the file ID monkey_fetus_40_0120
# Saving: monkey_fetus_40_0120
# pkl already exists, skipping the file ID monkey_fetus_40_0121
# Saving: monkey_fetus_40_0121
# pkl already exists, skipping the file ID monkey_fetus_40_0122
# Saving: monkey_fetus_40_0122
# pkl already exists, skipping the file ID monkey_fetus_40_0123
# Saving: monkey_fetus_40_0123
# pkl already exists, skipping the file ID monkey_fetus_40_0124
# Saving: monkey_fetus_40_0124
# pkl already exists, skipping the file ID monkey_fetus_40_0125
# Saving: monkey_fetus_40_0125
# pkl already exists, skipping the file ID monkey_fetus_40_0126
# Saving: monkey_fetus_40_0126
# pkl already exists, skipping the file ID monkey_fetus_40_0127
# Saving: monkey_fetus_40_0127
# pkl already exists, skipping the file ID monkey_fetus_40_0128
# Saving: monkey_fetus_40_0128
# pkl already exists, skipping the file ID monkey_fetus_40_0129
# Saving: monkey_fetus_40_0129
# pkl already exists, skipping the file ID monkey_fetus_40_0130
# Saving: monkey_fetus_40_0130
# pkl already exists, skipping the file ID monkey_fetus_40_0131
# Saving: monkey_fetus_40_0131
# pkl already exists, skipping the file ID monkey_fetus_40_0132
# Saving: monkey_fetus_40_0132
# pkl already exists, skipping the file ID monkey_fetus_40_0133
# Saving: monkey_fetus_40_0133
# pkl already exists, skipping the file ID monkey_fetus_40_0134
# Saving: monkey_fetus_40_0134
# pkl already exists, skipping the file ID monkey_fetus_40_0135
# Saving: monkey_fetus_40_0135
# pkl already exists, skipping the file ID monkey_fetus_40_0136
# Saving: monkey_fetus_40_0136
# pkl already exists, skipping the file ID monkey_fetus_40_0137
# Saving: monkey_fetus_40_0137
# pkl already exists, skipping the file ID monkey_fetus_40_0138
# Saving: monkey_fetus_40_0138
# pkl already exists, skipping the file ID monkey_fetus_40_0139
# Saving: monkey_fetus_40_0139
# pkl already exists, skipping the file ID monkey_fetus_40_0140
# Saving: monkey_fetus_40_0140
# pkl already exists, skipping the file ID monkey_fetus_40_0141
# Saving: monkey_fetus_40_0141
# pkl already exists, skipping the file ID monkey_fetus_40_0142
# Saving: monkey_fetus_40_0142
# pkl already exists, skipping the file ID monkey_fetus_40_0143
# Saving: monkey_fetus_40_0143
# pkl already exists, skipping the file ID monkey_fetus_40_0144
# Saving: monkey_fetus_40_0144
# pkl already exists, skipping the file ID monkey_fetus_40_0145
# Saving: monkey_fetus_40_0145
# pkl already exists, skipping the file ID monkey_fetus_40_0146
# Saving: monkey_fetus_40_0146
# pkl already exists, skipping the file ID monkey_fetus_40_0147
# Saving: monkey_fetus_40_0147
# pkl already exists, skipping the file ID monkey_fetus_40_0148
# Saving: monkey_fetus_40_0148
# pkl already exists, skipping the file ID monkey_fetus_40_0149
# Saving: monkey_fetus_40_0149
# pkl already exists, skipping the file ID monkey_fetus_40_0150
# Saving: monkey_fetus_40_0150
# pkl already exists, skipping the file ID monkey_fetus_40_0151
# Saving: monkey_fetus_40_0151
# pkl already exists, skipping the file ID monkey_fetus_40_0152
# Saving: monkey_fetus_40_0152
# pkl already exists, skipping the file ID monkey_fetus_40_0153
# Saving: monkey_fetus_40_0153
# pkl already exists, skipping the file ID monkey_fetus_40_0154
# Saving: monkey_fetus_40_0154
# pkl already exists, skipping the file ID monkey_fetus_40_0155
# Saving: monkey_fetus_40_0155
# pkl already exists, skipping the file ID monkey_fetus_40_0156
# Saving: monkey_fetus_40_0156
# pkl already exists, skipping the file ID monkey_fetus_40_0157
# Saving: monkey_fetus_40_0157
# pkl already exists, skipping the file ID monkey_fetus_40_0158
# Saving: monkey_fetus_40_0158
# pkl already exists, skipping the file ID monkey_fetus_40_0159
# Saving: monkey_fetus_40_0159
# pkl already exists, skipping the file ID monkey_fetus_40_0160
# Saving: monkey_fetus_40_0160
# pkl already exists, skipping the file ID monkey_fetus_40_0161
# Saving: monkey_fetus_40_0161
# pkl already exists, skipping the file ID monkey_fetus_40_0162
# Saving: monkey_fetus_40_0162
# pkl already exists, skipping the file ID monkey_fetus_40_0163
# Saving: monkey_fetus_40_0163
# pkl already exists, skipping the file ID monkey_fetus_40_0164
# Saving: monkey_fetus_40_0164
# pkl already exists, skipping the file ID monkey_fetus_40_0165
# Saving: monkey_fetus_40_0165
# pkl already exists, skipping the file ID monkey_fetus_40_0166
# Saving: monkey_fetus_40_0166
# pkl already exists, skipping the file ID monkey_fetus_40_0167
# Saving: monkey_fetus_40_0167
# pkl already exists, skipping the file ID monkey_fetus_40_0168
# Saving: monkey_fetus_40_0168
# pkl already exists, skipping the file ID monkey_fetus_40_0169
# Saving: monkey_fetus_40_0169
# pkl already exists, skipping the file ID monkey_fetus_40_0170
# Saving: monkey_fetus_40_0170
# pkl already exists, skipping the file ID monkey_fetus_40_0171
# Saving: monkey_fetus_40_0171
# pkl already exists, skipping the file ID monkey_fetus_40_0172
# Saving: monkey_fetus_40_0172
# pkl already exists, skipping the file ID monkey_fetus_40_0173
# Saving: monkey_fetus_40_0173
# pkl already exists, skipping the file ID monkey_fetus_40_0174
# Saving: monkey_fetus_40_0174
# pkl already exists, skipping the file ID monkey_fetus_40_0175
# Saving: monkey_fetus_40_0175
# pkl already exists, skipping the file ID monkey_fetus_40_0176
# Saving: monkey_fetus_40_0176
# pkl already exists, skipping the file ID monkey_fetus_40_0177
# Saving: monkey_fetus_40_0177
# pkl already exists, skipping the file ID monkey_fetus_40_0178
# Saving: monkey_fetus_40_0178
# pkl already exists, skipping the file ID monkey_fetus_40_0179
# Saving: monkey_fetus_40_0179
# pkl already exists, skipping the file ID monkey_fetus_40_0180
# Saving: monkey_fetus_40_0180
# pkl already exists, skipping the file ID monkey_fetus_40_0181
# Saving: monkey_fetus_40_0181
# pkl already exists, skipping the file ID monkey_fetus_40_0182
# Saving: monkey_fetus_40_0182
# pkl already exists, skipping the file ID monkey_fetus_40_0183
# Saving: monkey_fetus_40_0183
# pkl already exists, skipping the file ID monkey_fetus_40_0184
# Saving: monkey_fetus_40_0184
# pkl already exists, skipping the file ID monkey_fetus_40_0185
# Saving: monkey_fetus_40_0185
# pkl already exists, skipping the file ID monkey_fetus_40_0186
# Saving: monkey_fetus_40_0186
# pkl already exists, skipping the file ID monkey_fetus_40_0187
# Saving: monkey_fetus_40_0187
# pkl already exists, skipping the file ID monkey_fetus_40_0188
# Saving: monkey_fetus_40_0188
# pkl already exists, skipping the file ID monkey_fetus_40_0189
# Saving: monkey_fetus_40_0189
# pkl already exists, skipping the file ID monkey_fetus_40_0190
# Saving: monkey_fetus_40_0190
# pkl already exists, skipping the file ID monkey_fetus_40_0191
# Saving: monkey_fetus_40_0191
# pkl already exists, skipping the file ID monkey_fetus_40_0192
# Saving: monkey_fetus_40_0192
# pkl already exists, skipping the file ID monkey_fetus_40_0193
# Saving: monkey_fetus_40_0193
# pkl already exists, skipping the file ID monkey_fetus_40_0194
# Saving: monkey_fetus_40_0194
# pkl already exists, skipping the file ID monkey_fetus_40_0195
# Saving: monkey_fetus_40_0195
# pkl already exists, skipping the file ID monkey_fetus_40_0196
# Saving: monkey_fetus_40_0196
# pkl already exists, skipping the file ID monkey_fetus_40_0197
# Saving: monkey_fetus_40_0197
# pkl already exists, skipping the file ID monkey_fetus_40_0198
# Saving: monkey_fetus_40_0198
# pkl already exists, skipping the file ID monkey_fetus_40_0199
# Saving: monkey_fetus_40_0199
# pkl already exists, skipping the file ID monkey_fetus_40_0200
# Saving: monkey_fetus_40_0200
# pkl already exists, skipping the file ID monkey_fetus_40_0201
# Saving: monkey_fetus_40_0201
# pkl already exists, skipping the file ID monkey_fetus_40_0202
# Saving: monkey_fetus_40_0202
# pkl already exists, skipping the file ID monkey_fetus_40_0203
# Saving: monkey_fetus_40_0203
# pkl already exists, skipping the file ID monkey_fetus_40_0204
# Saving: monkey_fetus_40_0204
# pkl already exists, skipping the file ID monkey_fetus_40_0205
# Saving: monkey_fetus_40_0205
# pkl already exists, skipping the file ID monkey_fetus_40_0206
# Saving: monkey_fetus_40_0206
# pkl already exists, skipping the file ID monkey_fetus_40_0207
# Saving: monkey_fetus_40_0207
# pkl already exists, skipping the file ID monkey_fetus_40_0208
# Saving: monkey_fetus_40_0208
# pkl already exists, skipping the file ID monkey_fetus_40_0211
# Saving: monkey_fetus_40_0211
# pkl already exists, skipping the file ID monkey_fetus_40_0212
# Saving: monkey_fetus_40_0212
# pkl already exists, skipping the file ID monkey_fetus_40_0213
# Saving: monkey_fetus_40_0213
# pkl already exists, skipping the file ID monkey_fetus_40_0214
# Saving: monkey_fetus_40_0214
# pkl already exists, skipping the file ID monkey_fetus_40_0215
# Saving: monkey_fetus_40_0215
# pkl already exists, skipping the file ID monkey_fetus_40_0216
# Saving: monkey_fetus_40_0216
# pkl already exists, skipping the file ID monkey_fetus_40_0217
# Saving: monkey_fetus_40_0217
# pkl already exists, skipping the file ID monkey_fetus_40_0218
# Saving: monkey_fetus_40_0218
# pkl already exists, skipping the file ID monkey_fetus_40_0219
# Saving: monkey_fetus_40_0219
# pkl already exists, skipping the file ID monkey_fetus_40_0220
# Saving: monkey_fetus_40_0220
# pkl already exists, skipping the file ID monkey_fetus_40_0221
# Saving: monkey_fetus_40_0221
# pkl already exists, skipping the file ID monkey_fetus_40_0222
# Saving: monkey_fetus_40_0222
# pkl already exists, skipping the file ID monkey_fetus_40_0223
# Saving: monkey_fetus_40_0223
# pkl already exists, skipping the file ID monkey_fetus_40_0224
# Saving: monkey_fetus_40_0224
# pkl already exists, skipping the file ID monkey_fetus_40_0225
# Saving: monkey_fetus_40_0225
# pkl already exists, skipping the file ID monkey_fetus_40_0226
# Saving: monkey_fetus_40_0226
# pkl already exists, skipping the file ID monkey_fetus_40_0227
# Saving: monkey_fetus_40_0227
# pkl already exists, skipping the file ID monkey_fetus_40_0228
# Saving: monkey_fetus_40_0228
# pkl already exists, skipping the file ID monkey_fetus_40_0229
# Saving: monkey_fetus_40_0229
# pkl already exists, skipping the file ID monkey_fetus_40_0230
# Saving: monkey_fetus_40_0230
# pkl already exists, skipping the file ID monkey_fetus_40_0231
# Saving: monkey_fetus_40_0231
# pkl already exists, skipping the file ID monkey_fetus_40_0232
# Saving: monkey_fetus_40_0232
# pkl already exists, skipping the file ID monkey_fetus_40_0233
# Saving: monkey_fetus_40_0233
# pkl already exists, skipping the file ID monkey_fetus_40_0234
# Saving: monkey_fetus_40_0234
# pkl already exists, skipping the file ID monkey_fetus_40_0235
# Saving: monkey_fetus_40_0235
# pkl already exists, skipping the file ID monkey_fetus_40_0236
# Saving: monkey_fetus_40_0236
# pkl already exists, skipping the file ID monkey_fetus_40_0237
# Saving: monkey_fetus_40_0237
# pkl already exists, skipping the file ID monkey_fetus_40_0238
# Saving: monkey_fetus_40_0238
# pkl already exists, skipping the file ID monkey_fetus_40_0239
# Saving: monkey_fetus_40_0239
# pkl already exists, skipping the file ID monkey_fetus_40_0240
# Saving: monkey_fetus_40_0240
# pkl already exists, skipping the file ID monkey_fetus_40_0241
# Saving: monkey_fetus_40_0241
# pkl already exists, skipping the file ID monkey_fetus_40_0242
# Saving: monkey_fetus_40_0242
# pkl already exists, skipping the file ID monkey_fetus_40_0243
# Saving: monkey_fetus_40_0243
# pkl already exists, skipping the file ID monkey_fetus_40_0244
# Saving: monkey_fetus_40_0244
# pkl already exists, skipping the file ID monkey_fetus_40_0245
# Saving: monkey_fetus_40_0245
# pkl already exists, skipping the file ID monkey_fetus_40_0246
# Saving: monkey_fetus_40_0246
# pkl already exists, skipping the file ID monkey_fetus_40_0247
# Saving: monkey_fetus_40_0247
# pkl already exists, skipping the file ID monkey_fetus_40_0248
# Saving: monkey_fetus_40_0248
# pkl already exists, skipping the file ID monkey_fetus_40_0249
# Saving: monkey_fetus_40_0249
# pkl already exists, skipping the file ID monkey_fetus_40_0250
# Saving: monkey_fetus_40_0250
# pkl already exists, skipping the file ID monkey_fetus_40_0251
# Saving: monkey_fetus_40_0251
# pkl already exists, skipping the file ID monkey_fetus_40_0252
# Saving: monkey_fetus_40_0252
# pkl already exists, skipping the file ID monkey_fetus_40_0253
# Saving: monkey_fetus_40_0253
# pkl already exists, skipping the file ID monkey_fetus_40_0254
# Saving: monkey_fetus_40_0254
# pkl already exists, skipping the file ID monkey_fetus_40_0255
# Saving: monkey_fetus_40_0255
# pkl already exists, skipping the file ID monkey_fetus_40_0256
# Saving: monkey_fetus_40_0256
# pkl already exists, skipping the file ID monkey_fetus_40_0257
# Saving: monkey_fetus_40_0257
# pkl already exists, skipping the file ID monkey_fetus_40_0258
# Saving: monkey_fetus_40_0258
# pkl already exists, skipping the file ID monkey_fetus_40_0259
# Saving: monkey_fetus_40_0259
# pkl already exists, skipping the file ID monkey_fetus_40_0260
# Saving: monkey_fetus_40_0260
# pkl already exists, skipping the file ID monkey_fetus_40_0261
# Saving: monkey_fetus_40_0261
# pkl already exists, skipping the file ID monkey_fetus_40_0262
# Saving: monkey_fetus_40_0262
# pkl already exists, skipping the file ID monkey_fetus_40_0263
# Saving: monkey_fetus_40_0263
# pkl already exists, skipping the file ID monkey_fetus_40_0264
# Saving: monkey_fetus_40_0264
# pkl already exists, skipping the file ID monkey_fetus_40_0265
# Saving: monkey_fetus_40_0265
# pkl already exists, skipping the file ID monkey_fetus_40_0266
# Saving: monkey_fetus_40_0266
# pkl already exists, skipping the file ID monkey_fetus_40_0267
# Saving: monkey_fetus_40_0267
# pkl already exists, skipping the file ID monkey_fetus_40_0268
# Saving: monkey_fetus_40_0268
# pkl already exists, skipping the file ID monkey_fetus_40_0269
# Saving: monkey_fetus_40_0269
# pkl already exists, skipping the file ID monkey_fetus_40_0270
# Saving: monkey_fetus_40_0270
# pkl already exists, skipping the file ID monkey_fetus_40_0271
# Saving: monkey_fetus_40_0271
# pkl already exists, skipping the file ID monkey_fetus_40_0272
# Saving: monkey_fetus_40_0272
# pkl already exists, skipping the file ID monkey_fetus_40_0273
# Saving: monkey_fetus_40_0273
# pkl already exists, skipping the file ID monkey_fetus_40_0274
# Saving: monkey_fetus_40_0274
# pkl already exists, skipping the file ID monkey_fetus_40_0275
# Saving: monkey_fetus_40_0275
# pkl already exists, skipping the file ID monkey_fetus_40_0276
# Saving: monkey_fetus_40_0276
# pkl already exists, skipping the file ID monkey_fetus_40_0277
# Saving: monkey_fetus_40_0277
# pkl already exists, skipping the file ID monkey_fetus_40_0278
# Saving: monkey_fetus_40_0278
# pkl already exists, skipping the file ID monkey_fetus_40_0301
# Saving: monkey_fetus_40_0301
# pkl already exists, skipping the file ID monkey_fetus_40_0302
# Saving: monkey_fetus_40_0302
# pkl already exists, skipping the file ID monkey_fetus_40_0303
# Saving: monkey_fetus_40_0303
# pkl already exists, skipping the file ID monkey_fetus_40_0304
# Saving: monkey_fetus_40_0304
# pkl already exists, skipping the file ID monkey_fetus_40_0305
# Saving: monkey_fetus_40_0305
# pkl already exists, skipping the file ID monkey_fetus_40_0306
# Saving: monkey_fetus_40_0306
# pkl already exists, skipping the file ID monkey_fetus_40_0307
# Saving: monkey_fetus_40_0307
# pkl already exists, skipping the file ID monkey_fetus_40_0308
# Saving: monkey_fetus_40_0308
# pkl already exists, skipping the file ID monkey_fetus_40_0309
# Saving: monkey_fetus_40_0309
# pkl already exists, skipping the file ID monkey_fetus_40_0310
# Saving: monkey_fetus_40_0310
# pkl already exists, skipping the file ID monkey_fetus_40_0311
# Saving: monkey_fetus_40_0311
# pkl already exists, skipping the file ID monkey_fetus_40_0312
# Saving: monkey_fetus_40_0312
# pkl already exists, skipping the file ID monkey_fetus_40_0313
# Saving: monkey_fetus_40_0313
# pkl already exists, skipping the file ID monkey_fetus_40_0314
# Saving: monkey_fetus_40_0314
# pkl already exists, skipping the file ID monkey_fetus_40_0315
# Saving: monkey_fetus_40_0315
# pkl already exists, skipping the file ID monkey_fetus_40_0316
# Saving: monkey_fetus_40_0316
# pkl already exists, skipping the file ID monkey_fetus_40_0317
# Saving: monkey_fetus_40_0317
# pkl already exists, skipping the file ID monkey_fetus_40_0318
# Saving: monkey_fetus_40_0318
# pkl already exists, skipping the file ID monkey_fetus_40_0319
# Saving: monkey_fetus_40_0319
# pkl already exists, skipping the file ID monkey_fetus_40_0320
# Saving: monkey_fetus_40_0320
# pkl already exists, skipping the file ID monkey_fetus_40_0321
# Saving: monkey_fetus_40_0321
# pkl already exists, skipping the file ID monkey_fetus_40_0322
# Saving: monkey_fetus_40_0322
# pkl already exists, skipping the file ID monkey_fetus_40_0323
# Saving: monkey_fetus_40_0323
# pkl already exists, skipping the file ID monkey_fetus_40_0324
# Saving: monkey_fetus_40_0324
# pkl already exists, skipping the file ID monkey_fetus_40_0325
# Saving: monkey_fetus_40_0325
# pkl already exists, skipping the file ID monkey_fetus_40_0326
# Saving: monkey_fetus_40_0326
# pkl already exists, skipping the file ID monkey_fetus_40_0327
# Saving: monkey_fetus_40_0327
# pkl already exists, skipping the file ID monkey_fetus_40_0328
# Saving: monkey_fetus_40_0328
# pkl already exists, skipping the file ID monkey_fetus_40_0329
# Saving: monkey_fetus_40_0329
# pkl already exists, skipping the file ID monkey_fetus_40_0330
# Saving: monkey_fetus_40_0330
# pkl already exists, skipping the file ID monkey_fetus_40_0331
# Saving: monkey_fetus_40_0331
# pkl already exists, skipping the file ID monkey_fetus_40_0332
# Saving: monkey_fetus_40_0332
# pkl already exists, skipping the file ID monkey_fetus_40_0333
# Saving: monkey_fetus_40_0333
# pkl already exists, skipping the file ID monkey_fetus_40_0334
# Saving: monkey_fetus_40_0334
# pkl already exists, skipping the file ID monkey_fetus_40_0335
# Saving: monkey_fetus_40_0335
# pkl already exists, skipping the file ID monkey_fetus_40_0336
# Saving: monkey_fetus_40_0336
# pkl already exists, skipping the file ID monkey_fetus_40_0337
# Saving: monkey_fetus_40_0337
# pkl already exists, skipping the file ID monkey_fetus_40_0338
# Saving: monkey_fetus_40_0338
# pkl already exists, skipping the file ID monkey_fetus_40_0339
# Saving: monkey_fetus_40_0339
# pkl already exists, skipping the file ID monkey_fetus_40_0340
# Saving: monkey_fetus_40_0340
# pkl already exists, skipping the file ID monkey_fetus_40_0341
# Saving: monkey_fetus_40_0341
# pkl already exists, skipping the file ID monkey_fetus_40_0342
# Saving: monkey_fetus_40_0342
# pkl already exists, skipping the file ID monkey_fetus_40_0343
# Saving: monkey_fetus_40_0343
# pkl already exists, skipping the file ID monkey_fetus_40_0344
# Saving: monkey_fetus_40_0344
# pkl already exists, skipping the file ID monkey_fetus_40_0345
# Saving: monkey_fetus_40_0345
# pkl already exists, skipping the file ID monkey_fetus_40_0346
# Saving: monkey_fetus_40_0346
# pkl already exists, skipping the file ID monkey_fetus_40_0347
# Saving: monkey_fetus_40_0347
# pkl already exists, skipping the file ID monkey_fetus_40_0348
# Saving: monkey_fetus_40_0348
# pkl already exists, skipping the file ID monkey_fetus_40_0349
# Saving: monkey_fetus_40_0349
# pkl already exists, skipping the file ID monkey_fetus_40_0350
# Saving: monkey_fetus_40_0350
# pkl already exists, skipping the file ID monkey_fetus_40_0351
# Saving: monkey_fetus_40_0351
# pkl already exists, skipping the file ID monkey_fetus_40_0352
# Saving: monkey_fetus_40_0352
# pkl already exists, skipping the file ID monkey_fetus_40_0353
# Saving: monkey_fetus_40_0353
# pkl already exists, skipping the file ID monkey_fetus_40_0354
# Saving: monkey_fetus_40_0354
# pkl already exists, skipping the file ID monkey_fetus_40_0355
# Saving: monkey_fetus_40_0355
# pkl already exists, skipping the file ID monkey_fetus_40_0356
# Saving: monkey_fetus_40_0356
# pkl already exists, skipping the file ID monkey_fetus_40_0357
# Saving: monkey_fetus_40_0357
# pkl already exists, skipping the file ID monkey_fetus_40_0358
# Saving: monkey_fetus_40_0358
# pkl already exists, skipping the file ID monkey_fetus_40_0359
# Saving: monkey_fetus_40_0359
# pkl already exists, skipping the file ID monkey_fetus_40_0360
# Saving: monkey_fetus_40_0360
# pkl already exists, skipping the file ID monkey_fetus_40_0361
# Saving: monkey_fetus_40_0361
# pkl already exists, skipping the file ID monkey_fetus_40_0362
# Saving: monkey_fetus_40_0362
# pkl already exists, skipping the file ID monkey_fetus_40_0363
# Saving: monkey_fetus_40_0363
# pkl already exists, skipping the file ID monkey_fetus_40_0364
# Saving: monkey_fetus_40_0364
# pkl already exists, skipping the file ID monkey_fetus_40_0365
# Saving: monkey_fetus_40_0365
# pkl already exists, skipping the file ID monkey_fetus_40_0405
# Saving: monkey_fetus_40_0405
# pkl already exists, skipping the file ID monkey_fetus_40_0027
# Saving: monkey_fetus_40_0027
# pkl already exists, skipping the file ID monkey_fetus_40_0035
# Saving: monkey_fetus_40_0035
# pkl already exists, skipping the file ID monkey_fetus_40_0042
# Saving: monkey_fetus_40_0042
# pkl already exists, skipping the file ID monkey_fetus_40_0043
# Saving: monkey_fetus_40_0043
# pkl already exists, skipping the file ID monkey_fetus_40_0044
# Saving: monkey_fetus_40_0044
# pkl already exists, skipping the file ID monkey_fetus_40_0045
# Saving: monkey_fetus_40_0045
# pkl already exists, skipping the file ID monkey_fetus_40_0046
# Saving: monkey_fetus_40_0046
# pkl already exists, skipping the file ID monkey_fetus_40_0047
# Saving: monkey_fetus_40_0047
# pkl already exists, skipping the file ID monkey_fetus_40_0048
# Saving: monkey_fetus_40_0048
# pkl already exists, skipping the file ID monkey_fetus_40_0049
# Saving: monkey_fetus_40_0049
# pkl already exists, skipping the file ID monkey_fetus_40_0051
# Saving: monkey_fetus_40_0051
# pkl already exists, skipping the file ID monkey_fetus_40_0052
# Saving: monkey_fetus_40_0052
# pkl already exists, skipping the file ID monkey_fetus_40_0053
# Saving: monkey_fetus_40_0053
# pkl already exists, skipping the file ID monkey_fetus_40_0279
# Saving: monkey_fetus_40_0279
# pkl already exists, skipping the file ID monkey_fetus_40_0280
# Saving: monkey_fetus_40_0280
# pkl already exists, skipping the file ID monkey_fetus_40_0281
# Saving: monkey_fetus_40_0281
# pkl already exists, skipping the file ID monkey_fetus_40_0282
# Saving: monkey_fetus_40_0282
# pkl already exists, skipping the file ID monkey_fetus_40_0283
# Saving: monkey_fetus_40_0283
# pkl already exists, skipping the file ID monkey_fetus_40_0284
# Saving: monkey_fetus_40_0284
# pkl already exists, skipping the file ID monkey_fetus_40_0285
# Saving: monkey_fetus_40_0285
# pkl already exists, skipping the file ID monkey_fetus_40_0286
# Saving: monkey_fetus_40_0286
# pkl already exists, skipping the file ID monkey_fetus_40_0366
# Saving: monkey_fetus_40_0366
# pkl already exists, skipping the file ID monkey_fetus_40_0367
# Saving: monkey_fetus_40_0367
# pkl already exists, skipping the file ID monkey_fetus_40_0368
# Saving: monkey_fetus_40_0368
# pkl already exists, skipping the file ID monkey_fetus_40_0369
# Saving: monkey_fetus_40_0369
# pkl already exists, skipping the file ID monkey_fetus_40_0370
# Saving: monkey_fetus_40_0370
# pkl already exists, skipping the file ID monkey_fetus_40_0371
# Saving: monkey_fetus_40_0371
# pkl already exists, skipping the file ID monkey_fetus_40_0372
# Saving: monkey_fetus_40_0372
# pkl already exists, skipping the file ID monkey_fetus_40_0373
# Saving: monkey_fetus_40_0373
# pkl already exists, skipping the file ID monkey_fetus_40_0401
# Saving: monkey_fetus_40_0401
# pkl already exists, skipping the file ID monkey_fetus_40_0402
# Saving: monkey_fetus_40_0402
# pkl already exists, skipping the file ID monkey_fetus_40_0403
# Saving: monkey_fetus_40_0403
# pkl already exists, skipping the file ID monkey_fetus_40_0404
# Saving: monkey_fetus_40_0404
# Saving: monkey_fetus_40_0745
# Saving: monkey_fetus_40_0034
# Saving: monkey_fetus_40_0050
# Saving: monkey_fetus_40_0054
# Saving: monkey_fetus_40_0055
# Saving: monkey_fetus_40_0056
# Saving: monkey_fetus_40_0057
# Saving: monkey_fetus_40_0058
# Saving: monkey_fetus_40_0059
# Saving: monkey_fetus_40_0060
# Saving: monkey_fetus_40_0066
# Saving: monkey_fetus_40_0081
# Saving: monkey_fetus_40_0082
# Saving: monkey_fetus_40_0083
# Saving: monkey_fetus_40_0084
# Saving: monkey_fetus_40_0085
# Saving: monkey_fetus_40_0087
# Saving: monkey_fetus_40_0088
# Saving: monkey_fetus_40_0089
# Saving: monkey_fetus_40_0090
# Saving: monkey_fetus_40_0093
# Saving: monkey_fetus_40_0097
# Saving: monkey_fetus_40_0098
# Saving: monkey_fetus_40_0287
# Saving: monkey_fetus_40_0288
# Saving: monkey_fetus_40_0289
# Saving: monkey_fetus_40_0290
# Saving: monkey_fetus_40_0291
# Saving: monkey_fetus_40_0292
# Saving: monkey_fetus_40_0293
# Saving: monkey_fetus_40_0294
# Saving: monkey_fetus_40_0295
# Saving: monkey_fetus_40_0296
# Saving: monkey_fetus_40_0297
# Saving: monkey_fetus_40_0298
# Saving: monkey_fetus_40_0299
# Saving: monkey_fetus_40_0300
# Saving: monkey_fetus_40_0374
# Saving: monkey_fetus_40_0375
# Saving: monkey_fetus_40_0376
# Saving: monkey_fetus_40_0377
# Saving: monkey_fetus_40_0378
# Saving: monkey_fetus_40_0379
# Saving: monkey_fetus_40_0380
# Saving: monkey_fetus_40_0381
# Saving: monkey_fetus_40_0382
# Saving: monkey_fetus_40_0383
# Saving: monkey_fetus_40_0384
# Saving: monkey_fetus_40_0385
# Saving: monkey_fetus_40_0386
# Saving: monkey_fetus_40_0387
# Saving: monkey_fetus_40_0388
# Saving: monkey_fetus_40_0389
# Saving: monkey_fetus_40_0390
# Saving: monkey_fetus_40_0391
# Saving: monkey_fetus_40_0392
# Saving: monkey_fetus_40_0393
# Saving: monkey_fetus_40_0394
# Saving: monkey_fetus_40_0395
# Saving: monkey_fetus_40_0396
# Saving: monkey_fetus_40_0397
# Saving: monkey_fetus_40_0398
# Saving: monkey_fetus_40_0399
# Saving: monkey_fetus_40_0400
# Saving: monkey_fetus_40_0406
# Saving: monkey_fetus_40_0407
# Saving: monkey_fetus_40_0408
# Saving: monkey_fetus_40_0409
# Saving: monkey_fetus_40_0410
# Saving: monkey_fetus_40_0411
# Saving: monkey_fetus_40_0412
# Saving: monkey_fetus_40_0413
# Saving: monkey_fetus_40_0414
# Saving: monkey_fetus_40_0415
# Saving: monkey_fetus_40_0416
# Saving: monkey_fetus_40_0417
# Saving: monkey_fetus_40_0418
# Saving: monkey_fetus_40_0419
# Saving: monkey_fetus_40_0420
# Saving: monkey_fetus_40_0421
# Saving: monkey_fetus_40_0422
# Saving: monkey_fetus_40_0423
# Saving: monkey_fetus_40_0424
# Saving: monkey_fetus_40_0425
# Saving: monkey_fetus_40_0426
# Saving: monkey_fetus_40_0427
# Saving: monkey_fetus_40_0428
# Saving: monkey_fetus_40_0429
# Saving: monkey_fetus_40_0430
# Saving: monkey_fetus_40_0431
# Saving: monkey_fetus_40_0432
# Saving: monkey_fetus_40_0433
# Saving: monkey_fetus_40_0434
# Saving: monkey_fetus_40_0435
# Saving: monkey_fetus_40_0436
# Saving: monkey_fetus_40_0437
# Saving: monkey_fetus_40_0438
# Saving: monkey_fetus_40_0439
# Saving: monkey_fetus_40_0440
# Saving: monkey_fetus_40_0441
# Saving: monkey_fetus_40_0442
# Saving: monkey_fetus_40_0443
# Saving: monkey_fetus_40_0444
# Saving: monkey_fetus_40_0445
# Saving: monkey_fetus_40_0446
# Saving: monkey_fetus_40_0447
# Saving: monkey_fetus_40_0448
# Saving: monkey_fetus_40_0449
# Saving: monkey_fetus_40_0450
# Saving: monkey_fetus_40_0451
# Saving: monkey_fetus_40_0452
# Saving: monkey_fetus_40_0453
# Saving: monkey_fetus_40_0454
# Saving: monkey_fetus_40_0455
# Saving: monkey_fetus_40_0456
# Saving: monkey_fetus_40_0457
# Saving: monkey_fetus_40_0458
# Saving: monkey_fetus_40_0459
# Saving: monkey_fetus_40_0460
# Saving: monkey_fetus_40_0461
# Saving: monkey_fetus_40_0462
# Saving: monkey_fetus_40_0463
# Saving: monkey_fetus_40_0464
# Saving: monkey_fetus_40_0465
# Saving: monkey_fetus_40_0466
# Saving: monkey_fetus_40_0467
# Saving: monkey_fetus_40_0468
# Saving: monkey_fetus_40_0469
# Saving: monkey_fetus_40_0470
# Saving: monkey_fetus_40_0471
# Saving: monkey_fetus_40_0472
# Saving: monkey_fetus_40_0473
# Saving: monkey_fetus_40_0474
# Saving: monkey_fetus_40_0475
# Saving: monkey_fetus_40_0476
# Saving: monkey_fetus_40_0477
# Saving: monkey_fetus_40_0478
# Saving: monkey_fetus_40_0479
# Saving: monkey_fetus_40_0480
# Saving: monkey_fetus_40_0481
# Saving: monkey_fetus_40_0482
# Saving: monkey_fetus_40_0483
# Saving: monkey_fetus_40_0484
# Saving: monkey_fetus_40_0485
# Saving: monkey_fetus_40_0486
# Saving: monkey_fetus_40_0487
# Saving: monkey_fetus_40_0488
# Saving: monkey_fetus_40_0489
# Saving: monkey_fetus_40_0490
# Saving: monkey_fetus_40_0491
# Saving: monkey_fetus_40_0492
# Saving: monkey_fetus_40_0493
# Saving: monkey_fetus_40_0494
# Saving: monkey_fetus_40_0495
# Saving: monkey_fetus_40_0496
# Saving: monkey_fetus_40_0497
# Saving: monkey_fetus_40_0498
# Saving: monkey_fetus_40_0499
# Saving: monkey_fetus_40_0500
# Saving: monkey_fetus_40_0501
# Saving: monkey_fetus_40_0502
# Saving: monkey_fetus_40_0503
# Saving: monkey_fetus_40_0504
# Saving: monkey_fetus_40_0505
# Saving: monkey_fetus_40_0506
# Saving: monkey_fetus_40_0507
# Saving: monkey_fetus_40_0508
# Saving: monkey_fetus_40_0509
# Saving: monkey_fetus_40_0510
# Saving: monkey_fetus_40_0511
# Saving: monkey_fetus_40_0512
# Saving: monkey_fetus_40_0513
# Saving: monkey_fetus_40_0514
# Saving: monkey_fetus_40_0515
# Saving: monkey_fetus_40_0516
# Saving: monkey_fetus_40_0517
# Saving: monkey_fetus_40_0518
# Saving: monkey_fetus_40_0519
# Saving: monkey_fetus_40_0520
# Saving: monkey_fetus_40_0521
# Saving: monkey_fetus_40_0601
# Saving: monkey_fetus_40_0602
# Saving: monkey_fetus_40_0603
# Saving: monkey_fetus_40_0604
# Saving: monkey_fetus_40_0605
# Saving: monkey_fetus_40_0606
# Saving: monkey_fetus_40_0607
# Saving: monkey_fetus_40_0608
# Saving: monkey_fetus_40_0609
# Saving: monkey_fetus_40_0610
# Saving: monkey_fetus_40_0612
# Saving: monkey_fetus_40_0613
# Saving: monkey_fetus_40_0614
# Saving: monkey_fetus_40_0615
# Saving: monkey_fetus_40_0616
# Saving: monkey_fetus_40_0617
# Saving: monkey_fetus_40_0618
# Saving: monkey_fetus_40_0619
# Saving: monkey_fetus_40_0620
# Saving: monkey_fetus_40_0622
# Saving: monkey_fetus_40_0623
# Saving: monkey_fetus_40_0624
# Saving: monkey_fetus_40_0625
# Saving: monkey_fetus_40_0626
# Saving: monkey_fetus_40_0627
# Saving: monkey_fetus_40_0628
# Saving: monkey_fetus_40_0712
# Saving: monkey_fetus_40_0713
# Saving: monkey_fetus_40_0714
# Saving: monkey_fetus_40_0715
# Saving: monkey_fetus_40_0716
# Saving: monkey_fetus_40_0717
# Saving: monkey_fetus_40_0718
# Saving: monkey_fetus_40_0719
# Saving: monkey_fetus_40_0720
# Saving: monkey_fetus_40_0722
# Saving: monkey_fetus_40_0723
# Saving: monkey_fetus_40_0724
# Saving: monkey_fetus_40_0725
# Saving: monkey_fetus_40_0726
# Saving: monkey_fetus_40_0727
# Saving: monkey_fetus_40_0728
# Saving: monkey_fetus_40_0729
# Saving: monkey_fetus_40_0730
# Saving: monkey_fetus_40_0732
# Saving: monkey_fetus_40_0733
# Saving: monkey_fetus_40_0734
# Saving: monkey_fetus_40_0735
# Saving: monkey_fetus_40_0736
# Saving: monkey_fetus_40_0737
# Saving: monkey_fetus_40_0738
# Saving: monkey_fetus_40_0739
# Saving: monkey_fetus_40_0740
# Saving: monkey_fetus_40_0742
# Saving: monkey_fetus_40_0743
# Saving: monkey_fetus_40_0744
# Saving: monkey_fetus_40_1044
# Saving: monkey_fetus_40_0061
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 13
#      11     print('cannot open json')
#      12 print("Saving: {}".format(imID))
# ---> 13 json = pd.DataFrame(json[0].loc['nuc']).T.drop(columns=['type_prob'])
#      14 json = json[json['contour'].map(len) > 5].reset_index(drop=True)
#      15 json['Area'] = json['contour'].apply(lambda row: cntarea(row))
#
# File ~\anaconda3\envs\Process_hovernet_data\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File ~\anaconda3\envs\Process_hovernet_data\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~\anaconda3\envs\Process_hovernet_data\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~\anaconda3\envs\Process_hovernet_data\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['type_prob'] not found in axis"
