# %%
from scipy.io import loadmat
import h5py
import os
import json
import numpy as np
from tifffile import imread

# %%
pth_crop_info_dir = r'\\10.99.68.178\andreex\data\monkey fetus\gestational 40\2_5x\cropped_images\bounding_boxes'
crop_mat_list = sorted(os.listdir(pth_crop_info_dir))
crop_mat_list = [file for file in crop_mat_list if 'monkey' in file]

# %%
crop_mat_list
# Out:
# ['monkey_fetus_40_0001.mat',
#  'monkey_fetus_40_0002.mat',
#  'monkey_fetus_40_0003.mat',
#  'monkey_fetus_40_0004.mat',
#  'monkey_fetus_40_0005.mat',
#  'monkey_fetus_40_0006.mat',
#  'monkey_fetus_40_0007.mat',
#  'monkey_fetus_40_0008.mat',
#  'monkey_fetus_40_0009.mat',
#  'monkey_fetus_40_0010.mat',
#  'monkey_fetus_40_0011.mat',
#  'monkey_fetus_40_0012.mat',
#  'monkey_fetus_40_0013.mat',
#  'monkey_fetus_40_0014.mat',
#  'monkey_fetus_40_0015.mat',
#  'monkey_fetus_40_0016.mat',
#  'monkey_fetus_40_0017.mat',
#  'monkey_fetus_40_0018.mat',
#  'monkey_fetus_40_0019.mat',
#  'monkey_fetus_40_0020.mat',
#  'monkey_fetus_40_0021.mat',
#  'monkey_fetus_40_0023.mat',
#  'monkey_fetus_40_0024.mat',
#  'monkey_fetus_40_0025.mat',
#  'monkey_fetus_40_0026.mat',
#  'monkey_fetus_40_0027.mat',
#  'monkey_fetus_40_0028.mat',
#  'monkey_fetus_40_0029.mat',
#  'monkey_fetus_40_0030.mat',
#  'monkey_fetus_40_0031.mat',
#  'monkey_fetus_40_0032.mat',
#  'monkey_fetus_40_0033.mat',
#  'monkey_fetus_40_0034.mat',
#  'monkey_fetus_40_0035.mat',
#  'monkey_fetus_40_0036.mat',
#  'monkey_fetus_40_0037.mat',
#  'monkey_fetus_40_0038.mat',
#  'monkey_fetus_40_0039.mat',
#  'monkey_fetus_40_0040.mat',
#  'monkey_fetus_40_0041.mat',
#  'monkey_fetus_40_0042.mat',
#  'monkey_fetus_40_0043.mat',
#  'monkey_fetus_40_0044.mat',
#  'monkey_fetus_40_0045.mat',
#  'monkey_fetus_40_0046.mat',
#  'monkey_fetus_40_0047.mat',
#  'monkey_fetus_40_0048.mat',
#  'monkey_fetus_40_0049.mat',
#  'monkey_fetus_40_0050.mat',
#  'monkey_fetus_40_0051.mat',
#  'monkey_fetus_40_0052.mat',
#  'monkey_fetus_40_0053.mat',
#  'monkey_fetus_40_0054.mat',
#  'monkey_fetus_40_0055.mat',
#  'monkey_fetus_40_0056.mat',
#  'monkey_fetus_40_0057.mat',
#  'monkey_fetus_40_0058.mat',
#  'monkey_fetus_40_0059.mat',
#  'monkey_fetus_40_0060.mat',
#  'monkey_fetus_40_0061.mat',
#  'monkey_fetus_40_0062.mat',
#  'monkey_fetus_40_0063.mat',
#  'monkey_fetus_40_0064.mat',
#  'monkey_fetus_40_0065.mat',
#  'monkey_fetus_40_0066.mat',
#  'monkey_fetus_40_0067.mat',
#  'monkey_fetus_40_0068.mat',
#  'monkey_fetus_40_0069.mat',
#  'monkey_fetus_40_0070.mat',
#  'monkey_fetus_40_0071.mat',
#  'monkey_fetus_40_0072.mat',
#  'monkey_fetus_40_0073.mat',
#  'monkey_fetus_40_0074.mat',
#  'monkey_fetus_40_0075.mat',
#  'monkey_fetus_40_0076.mat',
#  'monkey_fetus_40_0077.mat',
#  'monkey_fetus_40_0078.mat',
#  'monkey_fetus_40_0079.mat',
#  'monkey_fetus_40_0080.mat',
#  'monkey_fetus_40_0081.mat',
#  'monkey_fetus_40_0082.mat',
#  'monkey_fetus_40_0083.mat',
#  'monkey_fetus_40_0084.mat',
#  'monkey_fetus_40_0085.mat',
#  'monkey_fetus_40_0086.mat',
#  'monkey_fetus_40_0087.mat',
#  'monkey_fetus_40_0088.mat',
#  'monkey_fetus_40_0089.mat',
#  'monkey_fetus_40_0090.mat',
#  'monkey_fetus_40_0091.mat',
#  'monkey_fetus_40_0092.mat',
#  'monkey_fetus_40_0093.mat',
#  'monkey_fetus_40_0094.mat',
#  'monkey_fetus_40_0095.mat',
#  'monkey_fetus_40_0096.mat',
#  'monkey_fetus_40_0097.mat',
#  'monkey_fetus_40_0098.mat',
#  'monkey_fetus_40_0099.mat',
#  'monkey_fetus_40_0100.mat',
#  'monkey_fetus_40_0101.mat',
#  'monkey_fetus_40_0102.mat',
#  'monkey_fetus_40_0103.mat',
#  'monkey_fetus_40_0104.mat',
#  'monkey_fetus_40_0105.mat',
#  'monkey_fetus_40_0106.mat',
#  'monkey_fetus_40_0107.mat',
#  'monkey_fetus_40_0108.mat',
#  'monkey_fetus_40_0109.mat',
#  'monkey_fetus_40_0110.mat',
#  'monkey_fetus_40_0111.mat',
#  'monkey_fetus_40_0112.mat',
#  'monkey_fetus_40_0113.mat',
#  'monkey_fetus_40_0114.mat',
#  'monkey_fetus_40_0115.mat',
#  'monkey_fetus_40_0116.mat',
#  'monkey_fetus_40_0117.mat',
#  'monkey_fetus_40_0118.mat',
#  'monkey_fetus_40_0119.mat',
#  'monkey_fetus_40_0120.mat',
#  'monkey_fetus_40_0121.mat',
#  'monkey_fetus_40_0122.mat',
#  'monkey_fetus_40_0123.mat',
#  'monkey_fetus_40_0124.mat',
#  'monkey_fetus_40_0125.mat',
#  'monkey_fetus_40_0126.mat',
#  'monkey_fetus_40_0127.mat',
#  'monkey_fetus_40_0128.mat',
#  'monkey_fetus_40_0129.mat',
#  'monkey_fetus_40_0130.mat',
#  'monkey_fetus_40_0131.mat',
#  'monkey_fetus_40_0132.mat',
#  'monkey_fetus_40_0133.mat',
#  'monkey_fetus_40_0134.mat',
#  'monkey_fetus_40_0135.mat',
#  'monkey_fetus_40_0136.mat',
#  'monkey_fetus_40_0137.mat',
#  'monkey_fetus_40_0138.mat',
#  'monkey_fetus_40_0139.mat',
#  'monkey_fetus_40_0140.mat',
#  'monkey_fetus_40_0141.mat',
#  'monkey_fetus_40_0142.mat',
#  'monkey_fetus_40_0143.mat',
#  'monkey_fetus_40_0144.mat',
#  'monkey_fetus_40_0145.mat',
#  'monkey_fetus_40_0146.mat',
#  'monkey_fetus_40_0147.mat',
#  'monkey_fetus_40_0148.mat',
#  'monkey_fetus_40_0149.mat',
#  'monkey_fetus_40_0150.mat',
#  'monkey_fetus_40_0151.mat',
#  'monkey_fetus_40_0152.mat',
#  'monkey_fetus_40_0153.mat',
#  'monkey_fetus_40_0154.mat',
#  'monkey_fetus_40_0155.mat',
#  'monkey_fetus_40_0156.mat',
#  'monkey_fetus_40_0157.mat',
#  'monkey_fetus_40_0158.mat',
#  'monkey_fetus_40_0159.mat',
#  'monkey_fetus_40_0160.mat',
#  'monkey_fetus_40_0161.mat',
#  'monkey_fetus_40_0162.mat',
#  'monkey_fetus_40_0163.mat',
#  'monkey_fetus_40_0164.mat',
#  'monkey_fetus_40_0165.mat',
#  'monkey_fetus_40_0166.mat',
#  'monkey_fetus_40_0167.mat',
#  'monkey_fetus_40_0168.mat',
#  'monkey_fetus_40_0169.mat',
#  'monkey_fetus_40_0170.mat',
#  'monkey_fetus_40_0171.mat',
#  'monkey_fetus_40_0172.mat',
#  'monkey_fetus_40_0173.mat',
#  'monkey_fetus_40_0174.mat',
#  'monkey_fetus_40_0175.mat',
#  'monkey_fetus_40_0176.mat',
#  'monkey_fetus_40_0177.mat',
#  'monkey_fetus_40_0178.mat',
#  'monkey_fetus_40_0179.mat',
#  'monkey_fetus_40_0180.mat',
#  'monkey_fetus_40_0181.mat',
#  'monkey_fetus_40_0182.mat',
#  'monkey_fetus_40_0183.mat',
#  'monkey_fetus_40_0184.mat',
#  'monkey_fetus_40_0185.mat',
#  'monkey_fetus_40_0186.mat',
#  'monkey_fetus_40_0187.mat',
#  'monkey_fetus_40_0188.mat',
#  'monkey_fetus_40_0189.mat',
#  'monkey_fetus_40_0190.mat',
#  'monkey_fetus_40_0191.mat',
#  'monkey_fetus_40_0192.mat',
#  'monkey_fetus_40_0193.mat',
#  'monkey_fetus_40_0194.mat',
#  'monkey_fetus_40_0195.mat',
#  'monkey_fetus_40_0196.mat',
#  'monkey_fetus_40_0197.mat',
#  'monkey_fetus_40_0198.mat',
#  'monkey_fetus_40_0199.mat',
#  'monkey_fetus_40_0200.mat',
#  'monkey_fetus_40_0201.mat',
#  'monkey_fetus_40_0202.mat',
#  'monkey_fetus_40_0203.mat',
#  'monkey_fetus_40_0204.mat',
#  'monkey_fetus_40_0205.mat',
#  'monkey_fetus_40_0206.mat',
#  'monkey_fetus_40_0207.mat',
#  'monkey_fetus_40_0208.mat',
#  'monkey_fetus_40_0209.mat',
#  'monkey_fetus_40_0210.mat',
#  'monkey_fetus_40_0211.mat',
#  'monkey_fetus_40_0212.mat',
#  'monkey_fetus_40_0213.mat',
#  'monkey_fetus_40_0214.mat',
#  'monkey_fetus_40_0215.mat',
#  'monkey_fetus_40_0216.mat',
#  'monkey_fetus_40_0217.mat',
#  'monkey_fetus_40_0218.mat',
#  'monkey_fetus_40_0219.mat',
#  'monkey_fetus_40_0220.mat',
#  'monkey_fetus_40_0221.mat',
#  'monkey_fetus_40_0222.mat',
#  'monkey_fetus_40_0223.mat',
#  'monkey_fetus_40_0224.mat',
#  'monkey_fetus_40_0225.mat',
#  'monkey_fetus_40_0226.mat',
#  'monkey_fetus_40_0227.mat',
#  'monkey_fetus_40_0228.mat',
#  'monkey_fetus_40_0229.mat',
#  'monkey_fetus_40_0230.mat',
#  'monkey_fetus_40_0231.mat',
#  'monkey_fetus_40_0232.mat',
#  'monkey_fetus_40_0233.mat',
#  'monkey_fetus_40_0234.mat',
#  'monkey_fetus_40_0235.mat',
#  'monkey_fetus_40_0236.mat',
#  'monkey_fetus_40_0237.mat',
#  'monkey_fetus_40_0238.mat',
#  'monkey_fetus_40_0239.mat',
#  'monkey_fetus_40_0240.mat',
#  'monkey_fetus_40_0241.mat',
#  'monkey_fetus_40_0242.mat',
#  'monkey_fetus_40_0243.mat',
#  'monkey_fetus_40_0244.mat',
#  'monkey_fetus_40_0245.mat',
#  'monkey_fetus_40_0246.mat',
#  'monkey_fetus_40_0247.mat',
#  'monkey_fetus_40_0248.mat',
#  'monkey_fetus_40_0249.mat',
#  'monkey_fetus_40_0250.mat',
#  'monkey_fetus_40_0251.mat',
#  'monkey_fetus_40_0252.mat',
#  'monkey_fetus_40_0253.mat',
#  'monkey_fetus_40_0254.mat',
#  'monkey_fetus_40_0255.mat',
#  'monkey_fetus_40_0256.mat',
#  'monkey_fetus_40_0257.mat',
#  'monkey_fetus_40_0258.mat',
#  'monkey_fetus_40_0259.mat',
#  'monkey_fetus_40_0260.mat',
#  'monkey_fetus_40_0261.mat',
#  'monkey_fetus_40_0262.mat',
#  'monkey_fetus_40_0263.mat',
#  'monkey_fetus_40_0264.mat',
#  'monkey_fetus_40_0265.mat',
#  'monkey_fetus_40_0266.mat',
#  'monkey_fetus_40_0267.mat',
#  'monkey_fetus_40_0268.mat',
#  'monkey_fetus_40_0269.mat',
#  'monkey_fetus_40_0270.mat',
#  'monkey_fetus_40_0271.mat',
#  'monkey_fetus_40_0272.mat',
#  'monkey_fetus_40_0273.mat',
#  'monkey_fetus_40_0274.mat',
#  'monkey_fetus_40_0275.mat',
#  'monkey_fetus_40_0276.mat',
#  'monkey_fetus_40_0277.mat',
#  'monkey_fetus_40_0278.mat',
#  'monkey_fetus_40_0279.mat',
#  'monkey_fetus_40_0280.mat',
#  'monkey_fetus_40_0281.mat',
#  'monkey_fetus_40_0282.mat',
#  'monkey_fetus_40_0283.mat',
#  'monkey_fetus_40_0284.mat',
#  'monkey_fetus_40_0285.mat',
#  'monkey_fetus_40_0286.mat',
#  'monkey_fetus_40_0287.mat',
#  'monkey_fetus_40_0288.mat',
#  'monkey_fetus_40_0289.mat',
#  'monkey_fetus_40_0290.mat',
#  'monkey_fetus_40_0291.mat',
#  'monkey_fetus_40_0292.mat',
#  'monkey_fetus_40_0293.mat',
#  'monkey_fetus_40_0294.mat',
#  'monkey_fetus_40_0295.mat',
#  'monkey_fetus_40_0296.mat',
#  'monkey_fetus_40_0297.mat',
#  'monkey_fetus_40_0298.mat',
#  'monkey_fetus_40_0299.mat',
#  'monkey_fetus_40_0300.mat',
#  'monkey_fetus_40_0301.mat',
#  'monkey_fetus_40_0302.mat',
#  'monkey_fetus_40_0303.mat',
#  'monkey_fetus_40_0304.mat',
#  'monkey_fetus_40_0305.mat',
#  'monkey_fetus_40_0306.mat',
#  'monkey_fetus_40_0307.mat',
#  'monkey_fetus_40_0308.mat',
#  'monkey_fetus_40_0309.mat',
#  'monkey_fetus_40_0310.mat',
#  'monkey_fetus_40_0311.mat',
#  'monkey_fetus_40_0312.mat',
#  'monkey_fetus_40_0313.mat',
#  'monkey_fetus_40_0314.mat',
#  'monkey_fetus_40_0315.mat',
#  'monkey_fetus_40_0316.mat',
#  'monkey_fetus_40_0317.mat',
#  'monkey_fetus_40_0318.mat',
#  'monkey_fetus_40_0319.mat',
#  'monkey_fetus_40_0320.mat',
#  'monkey_fetus_40_0321.mat',
#  'monkey_fetus_40_0322.mat',
#  'monkey_fetus_40_0323.mat',
#  'monkey_fetus_40_0324.mat',
#  'monkey_fetus_40_0325.mat',
#  'monkey_fetus_40_0326.mat',
#  'monkey_fetus_40_0327.mat',
#  'monkey_fetus_40_0328.mat',
#  'monkey_fetus_40_0329.mat',
#  'monkey_fetus_40_0330.mat',
#  'monkey_fetus_40_0331.mat',
#  'monkey_fetus_40_0332.mat',
#  'monkey_fetus_40_0333.mat',
#  'monkey_fetus_40_0334.mat',
#  'monkey_fetus_40_0335.mat',
#  'monkey_fetus_40_0336.mat',
#  'monkey_fetus_40_0337.mat',
#  'monkey_fetus_40_0338.mat',
#  'monkey_fetus_40_0339.mat',
#  'monkey_fetus_40_0340.mat',
#  'monkey_fetus_40_0341.mat',
#  'monkey_fetus_40_0342.mat',
#  'monkey_fetus_40_0343.mat',
#  'monkey_fetus_40_0344.mat',
#  'monkey_fetus_40_0345.mat',
#  'monkey_fetus_40_0346.mat',
#  'monkey_fetus_40_0347.mat',
#  'monkey_fetus_40_0348.mat',
#  'monkey_fetus_40_0349.mat',
#  'monkey_fetus_40_0350.mat',
#  'monkey_fetus_40_0351.mat',
#  'monkey_fetus_40_0352.mat',
#  'monkey_fetus_40_0353.mat',
#  'monkey_fetus_40_0354.mat',
#  'monkey_fetus_40_0355.mat',
#  'monkey_fetus_40_0356.mat',
#  'monkey_fetus_40_0357.mat',
#  'monkey_fetus_40_0358.mat',
#  'monkey_fetus_40_0359.mat',
#  'monkey_fetus_40_0360.mat',
#  'monkey_fetus_40_0361.mat',
#  'monkey_fetus_40_0362.mat',
#  'monkey_fetus_40_0363.mat',
#  'monkey_fetus_40_0364.mat',
#  'monkey_fetus_40_0365.mat',
#  'monkey_fetus_40_0366.mat',
#  'monkey_fetus_40_0367.mat',
#  'monkey_fetus_40_0368.mat',
#  'monkey_fetus_40_0369.mat',
#  'monkey_fetus_40_0370.mat',
#  'monkey_fetus_40_0371.mat',
#  'monkey_fetus_40_0372.mat',
#  'monkey_fetus_40_0373.mat',
#  'monkey_fetus_40_0374.mat',
#  'monkey_fetus_40_0375.mat',
#  'monkey_fetus_40_0376.mat',
#  'monkey_fetus_40_0377.mat',
#  'monkey_fetus_40_0378.mat',
#  'monkey_fetus_40_0379.mat',
#  'monkey_fetus_40_0380.mat',
#  'monkey_fetus_40_0381.mat',
#  'monkey_fetus_40_0382.mat',
#  'monkey_fetus_40_0383.mat',
#  'monkey_fetus_40_0384.mat',
#  'monkey_fetus_40_0385.mat',
#  'monkey_fetus_40_0386.mat',
#  'monkey_fetus_40_0387.mat',
#  'monkey_fetus_40_0388.mat',
#  'monkey_fetus_40_0389.mat',
#  'monkey_fetus_40_0390.mat',
#  'monkey_fetus_40_0391.mat',
#  'monkey_fetus_40_0392.mat',
#  'monkey_fetus_40_0393.mat',
#  'monkey_fetus_40_0394.mat',
#  'monkey_fetus_40_0395.mat',
#  'monkey_fetus_40_0396.mat',
#  'monkey_fetus_40_0397.mat',
#  'monkey_fetus_40_0398.mat',
#  'monkey_fetus_40_0399.mat',
#  'monkey_fetus_40_0400.mat',
#  'monkey_fetus_40_0401.mat',
#  'monkey_fetus_40_0402.mat',
#  'monkey_fetus_40_0403.mat',
#  'monkey_fetus_40_0404.mat',
#  'monkey_fetus_40_0405.mat',
#  'monkey_fetus_40_0406.mat',
#  'monkey_fetus_40_0407.mat',
#  'monkey_fetus_40_0408.mat',
#  'monkey_fetus_40_0409.mat',
#  'monkey_fetus_40_0410.mat',
#  'monkey_fetus_40_0411.mat',
#  'monkey_fetus_40_0412.mat',
#  'monkey_fetus_40_0413.mat',
#  'monkey_fetus_40_0414.mat',
#  'monkey_fetus_40_0415.mat',
#  'monkey_fetus_40_0416.mat',
#  'monkey_fetus_40_0417.mat',
#  'monkey_fetus_40_0418.mat',
#  'monkey_fetus_40_0419.mat',
#  'monkey_fetus_40_0420.mat',
#  'monkey_fetus_40_0421.mat',
#  'monkey_fetus_40_0422.mat',
#  'monkey_fetus_40_0423.mat',
#  'monkey_fetus_40_0424.mat',
#  'monkey_fetus_40_0425.mat',
#  'monkey_fetus_40_0426.mat',
#  'monkey_fetus_40_0427.mat',
#  'monkey_fetus_40_0428.mat',
#  'monkey_fetus_40_0429.mat',
#  'monkey_fetus_40_0430.mat',
#  'monkey_fetus_40_0431.mat',
#  'monkey_fetus_40_0432.mat',
#  'monkey_fetus_40_0433.mat',
#  'monkey_fetus_40_0434.mat',
#  'monkey_fetus_40_0435.mat',
#  'monkey_fetus_40_0436.mat',
#  'monkey_fetus_40_0437.mat',
#  'monkey_fetus_40_0438.mat',
#  'monkey_fetus_40_0439.mat',
#  'monkey_fetus_40_0440.mat',
#  'monkey_fetus_40_0441.mat',
#  'monkey_fetus_40_0442.mat',
#  'monkey_fetus_40_0443.mat',
#  'monkey_fetus_40_0444.mat',
#  'monkey_fetus_40_0445.mat',
#  'monkey_fetus_40_0446.mat',
#  'monkey_fetus_40_0447.mat',
#  'monkey_fetus_40_0448.mat',
#  'monkey_fetus_40_0449.mat',
#  'monkey_fetus_40_0450.mat',
#  'monkey_fetus_40_0451.mat',
#  'monkey_fetus_40_0452.mat',
#  'monkey_fetus_40_0453.mat',
#  'monkey_fetus_40_0454.mat',
#  'monkey_fetus_40_0455.mat',
#  'monkey_fetus_40_0456.mat',
#  'monkey_fetus_40_0457.mat',
#  'monkey_fetus_40_0458.mat',
#  'monkey_fetus_40_0459.mat',
#  'monkey_fetus_40_0460.mat',
#  'monkey_fetus_40_0461.mat',
#  'monkey_fetus_40_0462.mat',
#  'monkey_fetus_40_0463.mat',
#  'monkey_fetus_40_0464.mat',
#  'monkey_fetus_40_0465.mat',
#  'monkey_fetus_40_0466.mat',
#  'monkey_fetus_40_0467.mat',
#  'monkey_fetus_40_0468.mat',
#  'monkey_fetus_40_0469.mat',
#  'monkey_fetus_40_0470.mat',
#  'monkey_fetus_40_0471.mat',
#  'monkey_fetus_40_0472.mat',
#  'monkey_fetus_40_0473.mat',
#  'monkey_fetus_40_0474.mat',
#  'monkey_fetus_40_0475.mat',
#  'monkey_fetus_40_0476.mat',
#  'monkey_fetus_40_0477.mat',
#  'monkey_fetus_40_0478.mat',
#  'monkey_fetus_40_0479.mat',
#  'monkey_fetus_40_0480.mat',
#  'monkey_fetus_40_0481.mat',
#  'monkey_fetus_40_0482.mat',
#  'monkey_fetus_40_0483.mat',
#  'monkey_fetus_40_0484.mat',
#  'monkey_fetus_40_0485.mat',
#  'monkey_fetus_40_0486.mat',
#  'monkey_fetus_40_0487.mat',
#  'monkey_fetus_40_0488.mat',
#  'monkey_fetus_40_0489.mat',
#  'monkey_fetus_40_0490.mat',
#  'monkey_fetus_40_0491.mat',
#  'monkey_fetus_40_0492.mat',
#  'monkey_fetus_40_0493.mat',
#  'monkey_fetus_40_0494.mat',
#  'monkey_fetus_40_0495.mat',
#  'monkey_fetus_40_0496.mat',
#  'monkey_fetus_40_0497.mat',
#  'monkey_fetus_40_0498.mat',
#  'monkey_fetus_40_0499.mat',
#  'monkey_fetus_40_0500.mat',
#  'monkey_fetus_40_0501.mat',
#  'monkey_fetus_40_0502.mat',
#  'monkey_fetus_40_0503.mat',
#  'monkey_fetus_40_0504.mat',
#  'monkey_fetus_40_0505.mat',
#  'monkey_fetus_40_0506.mat',
#  'monkey_fetus_40_0507.mat',
#  'monkey_fetus_40_0508.mat',
#  'monkey_fetus_40_0509.mat',
#  'monkey_fetus_40_0510.mat',
#  'monkey_fetus_40_0511.mat',
#  'monkey_fetus_40_0512.mat',
#  'monkey_fetus_40_0513.mat',
#  'monkey_fetus_40_0514.mat',
#  'monkey_fetus_40_0515.mat',
#  'monkey_fetus_40_0516.mat',
#  'monkey_fetus_40_0517.mat',
#  'monkey_fetus_40_0518.mat',
#  'monkey_fetus_40_0519.mat',
#  'monkey_fetus_40_0520.mat',
#  'monkey_fetus_40_0521.mat',
#  'monkey_fetus_40_0522.mat',
#  'monkey_fetus_40_0523.mat',
#  'monkey_fetus_40_0524.mat',
#  'monkey_fetus_40_0525.mat',
#  'monkey_fetus_40_0526.mat',
#  'monkey_fetus_40_0527.mat',
#  'monkey_fetus_40_0528.mat',
#  'monkey_fetus_40_0529.mat',
#  'monkey_fetus_40_0530.mat',
#  'monkey_fetus_40_0531.mat',
#  'monkey_fetus_40_0532.mat',
#  'monkey_fetus_40_0533.mat',
#  'monkey_fetus_40_0534.mat',
#  'monkey_fetus_40_0535.mat',
#  'monkey_fetus_40_0536.mat',
#  'monkey_fetus_40_0537.mat',
#  'monkey_fetus_40_0538.mat',
#  'monkey_fetus_40_0539.mat',
#  'monkey_fetus_40_0540.mat',
#  'monkey_fetus_40_0541.mat',
#  'monkey_fetus_40_0542.mat',
#  'monkey_fetus_40_0543.mat',
#  'monkey_fetus_40_0544.mat',
#  'monkey_fetus_40_0545.mat',
#  'monkey_fetus_40_0546.mat',
#  'monkey_fetus_40_0547.mat',
#  'monkey_fetus_40_0548.mat',
#  'monkey_fetus_40_0549.mat',
#  'monkey_fetus_40_0550.mat',
#  'monkey_fetus_40_0551.mat',
#  'monkey_fetus_40_0552.mat',
#  'monkey_fetus_40_0553.mat',
#  'monkey_fetus_40_0554.mat',
#  'monkey_fetus_40_0555.mat',
#  'monkey_fetus_40_0556.mat',
#  'monkey_fetus_40_0557.mat',
#  'monkey_fetus_40_0558.mat',
#  'monkey_fetus_40_0559.mat',
#  'monkey_fetus_40_0560.mat',
#  'monkey_fetus_40_0561.mat',
#  'monkey_fetus_40_0562.mat',
#  'monkey_fetus_40_0563.mat',
#  'monkey_fetus_40_0564.mat',
#  'monkey_fetus_40_0565.mat',
#  'monkey_fetus_40_0566.mat',
#  'monkey_fetus_40_0567.mat',
#  'monkey_fetus_40_0568.mat',
#  'monkey_fetus_40_0569.mat',
#  'monkey_fetus_40_0570.mat',
#  'monkey_fetus_40_0571.mat',
#  'monkey_fetus_40_0572.mat',
#  'monkey_fetus_40_0573.mat',
#  'monkey_fetus_40_0574.mat',
#  'monkey_fetus_40_0575.mat',
#  'monkey_fetus_40_0576.mat',
#  'monkey_fetus_40_0577.mat',
#  'monkey_fetus_40_0578.mat',
#  'monkey_fetus_40_0579.mat',
#  'monkey_fetus_40_0580.mat',
#  'monkey_fetus_40_0581.mat',
#  'monkey_fetus_40_0582.mat',
#  'monkey_fetus_40_0583.mat',
#  'monkey_fetus_40_0584.mat',
#  'monkey_fetus_40_0585.mat',
#  'monkey_fetus_40_0586.mat',
#  'monkey_fetus_40_0587.mat',
#  'monkey_fetus_40_0588.mat',
#  'monkey_fetus_40_0589.mat',
#  'monkey_fetus_40_0590.mat',
#  'monkey_fetus_40_0591.mat',
#  'monkey_fetus_40_0592.mat',
#  'monkey_fetus_40_0593.mat',
#  'monkey_fetus_40_0594.mat',
#  'monkey_fetus_40_0595.mat',
#  'monkey_fetus_40_0596.mat',
#  'monkey_fetus_40_0597.mat',
#  'monkey_fetus_40_0598.mat',
#  'monkey_fetus_40_0599.mat',
#  'monkey_fetus_40_0600.mat',
#  'monkey_fetus_40_0601.mat',
#  'monkey_fetus_40_0602.mat',
#  'monkey_fetus_40_0603.mat',
#  'monkey_fetus_40_0604.mat',
#  'monkey_fetus_40_0605.mat',
#  'monkey_fetus_40_0606.mat',
#  'monkey_fetus_40_0607.mat',
#  'monkey_fetus_40_0608.mat',
#  'monkey_fetus_40_0609.mat',
#  'monkey_fetus_40_0610.mat',
#  'monkey_fetus_40_0612.mat',
#  'monkey_fetus_40_0613.mat',
#  'monkey_fetus_40_0614.mat',
#  'monkey_fetus_40_0615.mat',
#  'monkey_fetus_40_0616.mat',
#  'monkey_fetus_40_0617.mat',
#  'monkey_fetus_40_0618.mat',
#  'monkey_fetus_40_0619.mat',
#  'monkey_fetus_40_0620.mat',
#  'monkey_fetus_40_0622.mat',
#  'monkey_fetus_40_0623.mat',
#  'monkey_fetus_40_0624.mat',
#  'monkey_fetus_40_0625.mat',
#  'monkey_fetus_40_0626.mat',
#  'monkey_fetus_40_0627.mat',
#  'monkey_fetus_40_0628.mat',
#  'monkey_fetus_40_0629.mat',
#  'monkey_fetus_40_0630.mat',
#  'monkey_fetus_40_0632.mat',
#  'monkey_fetus_40_0633.mat',
#  'monkey_fetus_40_0634.mat',
#  'monkey_fetus_40_0635.mat',
#  'monkey_fetus_40_0636.mat',
#  'monkey_fetus_40_0637.mat',
#  'monkey_fetus_40_0638.mat',
#  'monkey_fetus_40_0639.mat',
#  'monkey_fetus_40_0640.mat',
#  'monkey_fetus_40_0642.mat',
#  'monkey_fetus_40_0643.mat',
#  'monkey_fetus_40_0644.mat',
#  'monkey_fetus_40_0645.mat',
#  'monkey_fetus_40_0646.mat',
#  'monkey_fetus_40_0647.mat',
#  'monkey_fetus_40_0648.mat',
#  'monkey_fetus_40_0649.mat',
#  'monkey_fetus_40_0650.mat',
#  'monkey_fetus_40_0652.mat',
#  'monkey_fetus_40_0653.mat',
#  'monkey_fetus_40_0654.mat',
#  'monkey_fetus_40_0655.mat',
#  'monkey_fetus_40_0656.mat',
#  'monkey_fetus_40_0657.mat',
#  'monkey_fetus_40_0658.mat',
#  'monkey_fetus_40_0659.mat',
#  'monkey_fetus_40_0660.mat',
#  'monkey_fetus_40_0662.mat',
#  'monkey_fetus_40_0663.mat',
#  'monkey_fetus_40_0664.mat',
#  'monkey_fetus_40_0665.mat',
#  'monkey_fetus_40_0666.mat',
#  'monkey_fetus_40_0667.mat',
#  'monkey_fetus_40_0668.mat',
#  'monkey_fetus_40_0669.mat',
#  'monkey_fetus_40_0670.mat',
#  'monkey_fetus_40_0672.mat',
#  'monkey_fetus_40_0673.mat',
#  'monkey_fetus_40_0674.mat',
#  'monkey_fetus_40_0675.mat',
#  'monkey_fetus_40_0676.mat',
#  'monkey_fetus_40_0677.mat',
#  'monkey_fetus_40_0678.mat',
#  'monkey_fetus_40_0679.mat',
#  'monkey_fetus_40_0680.mat',
#  'monkey_fetus_40_0682.mat',
#  'monkey_fetus_40_0683.mat',
#  'monkey_fetus_40_0684.mat',
#  'monkey_fetus_40_0685.mat',
#  'monkey_fetus_40_0686.mat',
#  'monkey_fetus_40_0687.mat',
#  'monkey_fetus_40_0688.mat',
#  'monkey_fetus_40_0689.mat',
#  'monkey_fetus_40_0690.mat',
#  'monkey_fetus_40_0692.mat',
#  'monkey_fetus_40_0693.mat',
#  'monkey_fetus_40_0694.mat',
#  'monkey_fetus_40_0695.mat',
#  'monkey_fetus_40_0696.mat',
#  'monkey_fetus_40_0697.mat',
#  'monkey_fetus_40_0698.mat',
#  'monkey_fetus_40_0699.mat',
#  'monkey_fetus_40_0700.mat',
#  'monkey_fetus_40_0702.mat',
#  'monkey_fetus_40_0703.mat',
#  'monkey_fetus_40_0704.mat',
#  'monkey_fetus_40_0705.mat',
#  'monkey_fetus_40_0706.mat',
#  'monkey_fetus_40_0707.mat',
#  'monkey_fetus_40_0708.mat',
#  'monkey_fetus_40_0709.mat',
#  'monkey_fetus_40_0710.mat',
#  'monkey_fetus_40_0712.mat',
#  'monkey_fetus_40_0713.mat',
#  'monkey_fetus_40_0714.mat',
#  'monkey_fetus_40_0715.mat',
#  'monkey_fetus_40_0716.mat',
#  'monkey_fetus_40_0717.mat',
#  'monkey_fetus_40_0718.mat',
#  'monkey_fetus_40_0719.mat',
#  'monkey_fetus_40_0720.mat',
#  'monkey_fetus_40_0722.mat',
#  'monkey_fetus_40_0723.mat',
#  'monkey_fetus_40_0724.mat',
#  'monkey_fetus_40_0725.mat',
#  'monkey_fetus_40_0726.mat',
#  'monkey_fetus_40_0727.mat',
#  'monkey_fetus_40_0728.mat',
#  'monkey_fetus_40_0729.mat',
#  'monkey_fetus_40_0730.mat',
#  'monkey_fetus_40_0732.mat',
#  'monkey_fetus_40_0733.mat',
#  'monkey_fetus_40_0734.mat',
#  'monkey_fetus_40_0735.mat',
#  'monkey_fetus_40_0736.mat',
#  'monkey_fetus_40_0737.mat',
#  'monkey_fetus_40_0738.mat',
#  'monkey_fetus_40_0739.mat',
#  'monkey_fetus_40_0740.mat',
#  'monkey_fetus_40_0742.mat',
#  'monkey_fetus_40_0743.mat',
#  'monkey_fetus_40_0744.mat',
#  'monkey_fetus_40_0745.mat',
#  'monkey_fetus_40_0746.mat',
#  'monkey_fetus_40_0747.mat',
#  'monkey_fetus_40_0748.mat',
#  'monkey_fetus_40_0749.mat',
#  'monkey_fetus_40_0750.mat',
#  'monkey_fetus_40_0752.mat',
#  'monkey_fetus_40_0753.mat',
#  'monkey_fetus_40_0754.mat',
#  'monkey_fetus_40_0755.mat',
#  'monkey_fetus_40_0756.mat',
#  'monkey_fetus_40_0757.mat',
#  'monkey_fetus_40_0758.mat',
#  'monkey_fetus_40_0759.mat',
#  'monkey_fetus_40_0760.mat',
#  'monkey_fetus_40_0762.mat',
#  'monkey_fetus_40_0763.mat',
#  'monkey_fetus_40_0764.mat',
#  'monkey_fetus_40_0765.mat',
#  'monkey_fetus_40_0766.mat',
#  'monkey_fetus_40_0767.mat',
#  'monkey_fetus_40_0768.mat',
#  'monkey_fetus_40_0769.mat',
#  'monkey_fetus_40_0770.mat',
#  'monkey_fetus_40_0772.mat',
#  'monkey_fetus_40_0773.mat',
#  'monkey_fetus_40_0774.mat',
#  'monkey_fetus_40_0775.mat',
#  'monkey_fetus_40_0776.mat',
#  'monkey_fetus_40_0777.mat',
#  'monkey_fetus_40_0778.mat',
#  'monkey_fetus_40_0779.mat',
#  'monkey_fetus_40_0780.mat',
#  'monkey_fetus_40_0782.mat',
#  'monkey_fetus_40_0783.mat',
#  'monkey_fetus_40_0784.mat',
#  'monkey_fetus_40_0785.mat',
#  'monkey_fetus_40_0786.mat',
#  'monkey_fetus_40_0787.mat',
#  'monkey_fetus_40_0788.mat',
#  'monkey_fetus_40_0789.mat',
#  'monkey_fetus_40_0790.mat',
#  'monkey_fetus_40_0792.mat',
#  'monkey_fetus_40_0793.mat',
#  'monkey_fetus_40_0794.mat',
#  'monkey_fetus_40_0795.mat',
#  'monkey_fetus_40_0796.mat',
#  'monkey_fetus_40_0797.mat',
#  'monkey_fetus_40_0798.mat',
#  'monkey_fetus_40_0799.mat',
#  'monkey_fetus_40_0800.mat',
#  'monkey_fetus_40_0802.mat',
#  'monkey_fetus_40_0803.mat',
#  'monkey_fetus_40_0804.mat',
#  'monkey_fetus_40_0805.mat',
#  'monkey_fetus_40_0806.mat',
#  'monkey_fetus_40_0807.mat',
#  'monkey_fetus_40_0808.mat',
#  'monkey_fetus_40_0809.mat',
#  'monkey_fetus_40_0810.mat',
#  'monkey_fetus_40_0812.mat',
#  'monkey_fetus_40_0813.mat',
#  'monkey_fetus_40_0814.mat',
#  'monkey_fetus_40_0815.mat',
#  'monkey_fetus_40_0816.mat',
#  'monkey_fetus_40_0817.mat',
#  'monkey_fetus_40_0818.mat',
#  'monkey_fetus_40_0819.mat',
#  'monkey_fetus_40_0820.mat',
#  'monkey_fetus_40_0822.mat',
#  'monkey_fetus_40_0823.mat',
#  'monkey_fetus_40_0824.mat',
#  'monkey_fetus_40_0825.mat',
#  'monkey_fetus_40_0826.mat',
#  'monkey_fetus_40_0827.mat',
#  'monkey_fetus_40_0828.mat',
#  'monkey_fetus_40_0829.mat',
#  'monkey_fetus_40_0830.mat',
#  'monkey_fetus_40_0832.mat',
#  'monkey_fetus_40_0833.mat',
#  'monkey_fetus_40_0834.mat',
#  'monkey_fetus_40_0835.mat',
#  'monkey_fetus_40_0836.mat',
#  'monkey_fetus_40_0837.mat',
#  'monkey_fetus_40_0838.mat',
#  'monkey_fetus_40_0839.mat',
#  'monkey_fetus_40_0840.mat',
#  'monkey_fetus_40_0842.mat',
#  'monkey_fetus_40_0843.mat',
#  'monkey_fetus_40_0844.mat',
#  'monkey_fetus_40_0845.mat',
#  'monkey_fetus_40_0846.mat',
#  'monkey_fetus_40_0847.mat',
#  'monkey_fetus_40_0848.mat',
#  'monkey_fetus_40_0849.mat',
#  'monkey_fetus_40_0850.mat',
#  'monkey_fetus_40_0852.mat',
#  'monkey_fetus_40_0853.mat',
#  'monkey_fetus_40_0854.mat',
#  'monkey_fetus_40_0855.mat',
#  'monkey_fetus_40_0856.mat',
#  'monkey_fetus_40_0857.mat',
#  'monkey_fetus_40_0858.mat',
#  'monkey_fetus_40_0859.mat',
#  'monkey_fetus_40_0860.mat',
#  'monkey_fetus_40_0862.mat',
#  'monkey_fetus_40_0863.mat',
#  'monkey_fetus_40_0864.mat',
#  'monkey_fetus_40_0865.mat',
#  'monkey_fetus_40_0866.mat',
#  'monkey_fetus_40_0867.mat',
#  'monkey_fetus_40_0868.mat',
#  'monkey_fetus_40_0869.mat',
#  'monkey_fetus_40_0870.mat',
#  'monkey_fetus_40_0872.mat',
#  'monkey_fetus_40_0873.mat',
#  'monkey_fetus_40_0874.mat',
#  'monkey_fetus_40_0875.mat',
#  'monkey_fetus_40_0876.mat',
#  'monkey_fetus_40_0877.mat',
#  'monkey_fetus_40_0878.mat',
#  'monkey_fetus_40_0879.mat',
#  'monkey_fetus_40_0880.mat',
#  'monkey_fetus_40_0882.mat',
#  'monkey_fetus_40_0883.mat',
#  'monkey_fetus_40_0884.mat',
#  'monkey_fetus_40_0885.mat',
#  'monkey_fetus_40_0886.mat',
#  'monkey_fetus_40_0887.mat',
#  'monkey_fetus_40_0888.mat',
#  'monkey_fetus_40_0889.mat',
#  'monkey_fetus_40_0890.mat',
#  'monkey_fetus_40_0892.mat',
#  'monkey_fetus_40_0893.mat',
#  'monkey_fetus_40_0894.mat',
#  'monkey_fetus_40_0895.mat',
#  'monkey_fetus_40_0896.mat',
#  'monkey_fetus_40_0897.mat',
#  'monkey_fetus_40_0898.mat',
#  'monkey_fetus_40_0899.mat',
#  'monkey_fetus_40_0900.mat',
#  'monkey_fetus_40_0902.mat',
#  'monkey_fetus_40_0903.mat',
#  'monkey_fetus_40_0904.mat',
#  'monkey_fetus_40_0905.mat',
#  'monkey_fetus_40_0906.mat',
#  'monkey_fetus_40_0907.mat',
#  'monkey_fetus_40_0908.mat',
#  'monkey_fetus_40_0909.mat',
#  'monkey_fetus_40_0910.mat',
#  'monkey_fetus_40_0912.mat',
#  'monkey_fetus_40_0913.mat',
#  'monkey_fetus_40_0914.mat',
#  'monkey_fetus_40_0915.mat',
#  'monkey_fetus_40_0916.mat',
#  'monkey_fetus_40_0917.mat',
#  'monkey_fetus_40_0918.mat',
#  'monkey_fetus_40_0919.mat',
#  'monkey_fetus_40_0920.mat',
#  'monkey_fetus_40_0922.mat',
#  'monkey_fetus_40_0923.mat',
#  'monkey_fetus_40_0924.mat',
#  'monkey_fetus_40_0925.mat',
#  'monkey_fetus_40_0926.mat',
#  'monkey_fetus_40_0927.mat',
#  'monkey_fetus_40_0928.mat',
#  'monkey_fetus_40_0929.mat',
#  'monkey_fetus_40_0930.mat',
#  'monkey_fetus_40_0932.mat',
#  'monkey_fetus_40_0933.mat',
#  'monkey_fetus_40_0934.mat',
#  'monkey_fetus_40_0935.mat',
#  'monkey_fetus_40_0936.mat',
#  'monkey_fetus_40_0937.mat',
#  'monkey_fetus_40_0938.mat',
#  'monkey_fetus_40_0939.mat',
#  'monkey_fetus_40_0940.mat',
#  'monkey_fetus_40_0942.mat',
#  'monkey_fetus_40_0943.mat',
#  'monkey_fetus_40_0944.mat',
#  'monkey_fetus_40_0945.mat',
#  'monkey_fetus_40_0946.mat',
#  'monkey_fetus_40_0947.mat',
#  'monkey_fetus_40_0948.mat',
#  'monkey_fetus_40_0949.mat',
#  'monkey_fetus_40_0950.mat',
#  'monkey_fetus_40_0952.mat',
#  'monkey_fetus_40_0953.mat',
#  'monkey_fetus_40_0954.mat',
#  'monkey_fetus_40_0955.mat',
#  'monkey_fetus_40_0956.mat',
#  'monkey_fetus_40_0957.mat',
#  'monkey_fetus_40_0958.mat',
#  'monkey_fetus_40_0959.mat',
#  'monkey_fetus_40_0960.mat',
#  'monkey_fetus_40_0962.mat',
#  'monkey_fetus_40_0963.mat',
#  'monkey_fetus_40_0964.mat',
#  'monkey_fetus_40_0965.mat',
#  'monkey_fetus_40_0966.mat',
#  'monkey_fetus_40_0967.mat',
#  'monkey_fetus_40_0968.mat',
#  'monkey_fetus_40_0969.mat',
#  'monkey_fetus_40_0970.mat',
#  'monkey_fetus_40_0972.mat',
#  'monkey_fetus_40_0973.mat',
#  'monkey_fetus_40_0974.mat',
#  'monkey_fetus_40_0975.mat',
#  'monkey_fetus_40_0976.mat',
#  'monkey_fetus_40_0977.mat',
#  'monkey_fetus_40_0978.mat',
#  'monkey_fetus_40_0979.mat',
#  'monkey_fetus_40_0980.mat',
#  'monkey_fetus_40_0982.mat',
#  'monkey_fetus_40_0983.mat',
#  'monkey_fetus_40_0984.mat',
#  'monkey_fetus_40_0985.mat',
#  'monkey_fetus_40_0986.mat',
#  'monkey_fetus_40_0987.mat',
#  'monkey_fetus_40_0988.mat',
#  'monkey_fetus_40_0989.mat',
#  'monkey_fetus_40_0990.mat',
#  'monkey_fetus_40_0992.mat',
#  'monkey_fetus_40_0993.mat',
#  'monkey_fetus_40_0994.mat',
#  'monkey_fetus_40_0995.mat',
#  'monkey_fetus_40_0996.mat',
#  'monkey_fetus_40_0997.mat',
#  'monkey_fetus_40_0998.mat',
#  'monkey_fetus_40_0999.mat',
#  'monkey_fetus_40_1000.mat',
#  'monkey_fetus_40_1002.mat',
#  'monkey_fetus_40_1003.mat',
#  'monkey_fetus_40_1004.mat',
#  'monkey_fetus_40_1005.mat',
#  'monkey_fetus_40_1006.mat',
#  'monkey_fetus_40_1007.mat',
#  'monkey_fetus_40_1008.mat',
#  'monkey_fetus_40_1009.mat',
#  'monkey_fetus_40_1010.mat',
#  'monkey_fetus_40_1012.mat',
#  'monkey_fetus_40_1013.mat',
#  'monkey_fetus_40_1014.mat',
#  'monkey_fetus_40_1015.mat',
#  'monkey_fetus_40_1016.mat',
#  'monkey_fetus_40_1017.mat',
#  'monkey_fetus_40_1018.mat',
#  'monkey_fetus_40_1019.mat',
#  'monkey_fetus_40_1020.mat',
#  'monkey_fetus_40_1022.mat',
#  'monkey_fetus_40_1023.mat',
#  'monkey_fetus_40_1024.mat',
#  'monkey_fetus_40_1025.mat',
#  'monkey_fetus_40_1026.mat',
#  'monkey_fetus_40_1027.mat',
#  'monkey_fetus_40_1028.mat',
#  'monkey_fetus_40_1029.mat',
#  'monkey_fetus_40_1030.mat',
#  'monkey_fetus_40_1032.mat',
#  'monkey_fetus_40_1033.mat',
#  'monkey_fetus_40_1034.mat',
#  'monkey_fetus_40_1035.mat',
#  'monkey_fetus_40_1036.mat',
#  'monkey_fetus_40_1037.mat',
#  'monkey_fetus_40_1038.mat',
#  'monkey_fetus_40_1039.mat',
#  'monkey_fetus_40_1040.mat',
#  'monkey_fetus_40_1042.mat',
#  'monkey_fetus_40_1043.mat',
#  'monkey_fetus_40_1044.mat',
#  'monkey_fetus_40_1045.mat',
#  ...]

# %%
len(crop_mat_list)
# Out:
# 1154

# %%
# sometimes loading .mat file works with loadmat function from scipi.io, sometimes it doesn't and needs h5py module, so both cases are accounted for here

crop_data = []

for i, file in enumerate(sorted(crop_mat_list)):
    mat_file_name = os.path.join(pth_crop_info_dir, file)
    try:
        data = loadmat(mat_file_name)

        #print('scipy.io loadmat')
        bb = [int(x) for x in data['bb']]
        crop_data.append(bb)
        #print(bb)

    except:
        data = h5py.File(mat_file_name, 'r')

        #print('h5py')
        bb = [int(x) for x in data['bb'][()]]
        crop_data.append(bb)
        #print(bb)

# %%
pth_json_folder = r'\\10.99.68.178\andreex\data\monkey fetus\gestational 40\StarDist_11_21_23\json'
jsons = sorted(os.listdir(pth_json_folder))
jsons = [f for f in jsons if f.endswith('.json')]

# %%
print(f'length crop data: {len(crop_data)}')
print(f'length jsons: {len(jsons)}')
# Out:
# length crop data: 1154
# length jsons: 1154

# %%
# ensure everything matches up between json names and crop_mat names

for i, file_name in enumerate(crop_mat_list):
    if file_name[:-4] != jsons[i][:-5]:
        print(f'crop_mat_list: {file_name[:-4]}, json: {jsons[i][:-5]}')

# %%
model1_pth = r'\\10.99.68.178\andreex\data\monkey fetus\gestational 40\5x\cropped_images\classification_MODEL1_6_21_2023_all_annotations'
model1 = sorted(os.listdir(model1_pth))
model1 = [im for im in model1 if im.endswith('.tif')]

# model2_prefix = r'\\10.99.68.178\andreex\data\monkey fetus\gestational 40\10x\cropped_images'

# %%
# pixel res:
pth_pixel_res = r'\\10.99.68.178\andreex\data\monkey fetus\gestational 40\segmentation_analysis\pix_res_info'
pixel_res_info = sorted(os.listdir(pth_pixel_res))
pixel_res_files = [file for file in pixel_res_info if file.endswith('.mat')]

pixel_res_info = []

for i, file in enumerate(pixel_res_files):
    mat_file_name = os.path.join(pth_pixel_res, file)
    try:
        data = loadmat(mat_file_name)

        #print('scipy.io loadmat')
        x = float(data['pix_res']['x'][0][0][0])
        y = float(data['pix_res']['x'][0][0][0])
        pixel_res_info.append([x, y])

    except:
        data = h5py.File(mat_file_name, 'r')

        #print('h5py')
        x = float(data['pix_res'][()]['x'][0][0][0])
        y = float(data['pix_res'][()]['x'][0][0][0])
        pixel_res_info.append([x, y])

# %%
all_cells = []

for i, file in enumerate(jsons):

    # while debugging, just do once in loop
    i = 20
    file = jsons[i]

    print(file)

    pix_res = pixel_res_info[i][0]  # this is assuming x and y pix size are equal
    downsize10x = 1/pix_res
    downsize5x = 2/pix_res
    print(downsize5x)
    downsize2_5x = 4/pix_res

    m1_im_pth = os.path.join(model1_pth, model1[i])
    print(model1[i])
    m1_im = imread(m1_im_pth)
    print(m1_im.shape)

    crop_file_data = [num*downsize2_5x for num in crop_data[i]]  # multiple bounding box data by 2_5x crop ratio to get offsets for 20x points
    print(crop_file_data)
    #print(crop_file_data)

    x_offset = crop_file_data[0] - 1  # 0 to 1 indexing fix, probably right idk
    y_offset = crop_file_data[2] - 1

    print(f'x_offset: {x_offset}')
    print(f'y_offset: {y_offset}')

    fname = os.path.join(pth_json_folder, file)
    with open(fname, 'r') as file_n:
        data = json.load(file_n)

    centroids = []
    contours = []


    print([0, (crop_file_data[1] - 1)])
    print([0, (crop_file_data[3] - 1)])

    print([0, (crop_file_data[1] - x_offset)/downsize5x])
    print([0, (crop_file_data[3] - y_offset)/downsize5x])

    for entry in data:
        cent = entry['centroid'][0]
        cent = [cent[0] - y_offset, cent[1] - x_offset]  # coord might be backwards, idk
        cent = [num/downsize5x for num in cent]

        x_end = (crop_file_data[1] - x_offset)/downsize5x
        y_end = (crop_file_data[3] - y_offset)/downsize5x

        if (0 <= cent[0] < y_end) and (0 <= cent[1] < x_end) and (m1_im[round(cent[0]), round(cent[1])] == 18):
            centroids.append(cent)
            c = entry['contour'][0]
            contour = []
            for j in range(len(c[0])):
                point = [c[0][j] - y_offset, c[1][j] - x_offset]
                point = [num/downsize5x for num in point]
                contour.append(point)
            contours.append(contour)

    centroids = np.array(centroids)
    contours = np.array(contours)

    all_cells.append([centroids, contours])

    break

    #print(len(centroids))
    #print(len(contours))
    #print(len(contours[0]))
# Out:
# monkey_fetus_40_0021.json
# 4.5292
# monkey_fetus_40_0021.tif
# (5873, 8053)
# [4991.178400000001, 41460.296800000004, 5534.682400000001, 32130.144800000002]
# x_offset: 4990.178400000001
# y_offset: 5533.682400000001
# [0, 41459.296800000004]
# [0, 32129.144800000002]
# [0, 8052.2207895434085]
# [0, 5872.220789543407]

# %%
print(len(all_cells))
print(len(all_cells[0]))
# Out:
# 1
# 2

# %%
num = 0

slide_name = jsons[20]
slide = all_cells[num]
slide_centroids = slide[0]
slide_contours = slide[1]

print(len(slide_centroids))
print(len(slide_contours))
# Out:
# 19706
# 19706

# %%
m1_im.shape
# Out:
# (5873, 8053)

# %%
import matplotlib.pyplot as plt
# Extract x and y coordinates

x = slide_centroids[:, 1]
y = slide_centroids[:, 0]

# Create scatter plot|
plt.scatter(x, y, marker='o', color='blue', s=.01)

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title(slide_name)

plt.xlim(0, m1_im.shape[1])
plt.ylim(0, m1_im.shape[0])

plt.gca().invert_yaxis()

# Show the plot
plt.show()

# %%
max(x)
# Out:
# 8029.193146692571

# %%
max(y)
# Out:
# 5865.12355382849

# %%
# TEST pickle file, see if right coordinates...

# %%
import pandas as pd

# %%
pth = r'\\10.99.68.178\andreex\data\monkey fetus\gestational 40\segmentation_analysis\test_new_features\monkey_fetus_40_0895_new.pickle'
loaded_df = pd.read_pickle(pth) ## change back to (not2)

# %%
classification = 18

# %%
loaded_df.head()
loaded_df2 = loaded_df[loaded_df['Class'] == classification]
loaded_df2.head()
# Out:
#       Centroid_x   Centroid_y  Class      Area  Perimeter  Circularity  \
# 492   857.092113  1523.876534     18  7.502273  10.616238     0.836491
# 5288  704.305749  4727.091230     18  3.169358   6.870699     0.843683
# 5466  700.773117  4723.558598     18  6.160650   9.160175     0.922633
# 5534  705.630487  4736.364391     18  2.924501   6.595929     0.844714
# 5611  710.046277  4731.507021     18  6.870954   9.658339     0.925597
#
#       Aspect Ratio  compactness  eccentricity  euler_number    extent  \
# 492       1.955567    15.022715      0.859366      0.043940  0.769288
# 5288      1.420667    14.894657      0.710304      0.495426  0.771226
# 5466      1.426231    13.620124      0.713015      0.491466  0.775298
# 5534      1.230088    14.876479      0.582334      0.621721  0.770575
# 5611      1.373306    13.576501      0.685397      0.528508  0.770977
#
#       form_factor  maximum_radius  mean_radius  median_radius  \
# 492      1.195470        2.872617     1.464317       1.288130
# 5288     1.185279        1.245068     0.998329       1.014369
# 5466     1.083855        2.002535     1.380868       1.334047
# 5534     1.183833        1.240882     0.960649       0.909809
# 5611     1.080384        1.881483     1.471617       1.472046
#
#       minor_axis_length  orientation_degrees  Image ID
# 492            2.233138          6634.301530       895
# 5288           1.700782          6433.460747       895
# 5466           2.360390          3306.999028       895
# 5534           1.756508          2983.264453       895
# 5611           2.547441          4003.400088       895

# %%
cols = loaded_df2.columns
cols = [col for col in cols if col not in ['Centroid_x', 'Centroid_y', 'Class', 'Image ID']]
print(cols)
# Out:
# ['Area', 'Perimeter', 'Circularity', 'Aspect Ratio', 'compactness', 'eccentricity', 'euler_number', 'extent', 'form_factor', 'maximum_radius', 'mean_radius', 'median_radius', 'minor_axis_length', 'orientation_degrees']

# %%
classification = 18

y = np.where(loaded_df['Class'] == classification, loaded_df['Centroid_x'], np.nan)
x = np.where(loaded_df['Class'] == classification, loaded_df['Centroid_y'], np.nan)
#y = loaded_df['Centroid_x']
#x = loaded_df['Centroid_y']

# Create scatter plot|
plt.scatter(x, y, marker='o', color='blue', s=.01)

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('monkey_fetus_40_0895')

#plt.xlim(0, max(x))
#plt.ylim(0, max(y))

plt.gca().invert_yaxis()

# Show the plot
plt.show()

# %%
features_df = loaded_df2[cols]
features_df.head()
# Out:
#           Area  Perimeter  Circularity  Aspect Ratio  compactness  \
# 492   7.502273  10.616238     0.836491      1.955567    15.022715
# 5288  3.169358   6.870699     0.843683      1.420667    14.894657
# 5466  6.160650   9.160175     0.922633      1.426231    13.620124
# 5534  2.924501   6.595929     0.844714      1.230088    14.876479
# 5611  6.870954   9.658339     0.925597      1.373306    13.576501
#
#       eccentricity  euler_number    extent  form_factor  maximum_radius  \
# 492       0.859366      0.043940  0.769288     1.195470        2.872617
# 5288      0.710304      0.495426  0.771226     1.185279        1.245068
# 5466      0.713015      0.491466  0.775298     1.083855        2.002535
# 5534      0.582334      0.621721  0.770575     1.183833        1.240882
# 5611      0.685397      0.528508  0.770977     1.080384        1.881483
#
#       mean_radius  median_radius  minor_axis_length  orientation_degrees
# 492      1.464317       1.288130           2.233138          6634.301530
# 5288     0.998329       1.014369           1.700782          6433.460747
# 5466     1.380868       1.334047           2.360390          3306.999028
# 5534     0.960649       0.909809           1.756508          2983.264453
# 5611     1.471617       1.472046           2.547441          4003.400088

# %%
classes = np.array(loaded_df2['Class'])
classes
# Out:
# array([18, 18, 18, ..., 18, 18, 18], dtype=uint8)

# %%
print(len(classes))
# Out:
# 9844

# %%
print(features_df.shape)
# Out:
# (9844, 14)

# %%
max(classes)
# Out:
# 18

# %%
import numpy as np
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap

pca = PCA(n_components=2)
transformed_features = pca.fit_transform(features_df)

class_colors = ListedColormap(['red', 'green', 'blue', 'purple', 'orange', 'cyan', 'magenta', 'yellow', 'black', 'gray',
                               'pink', 'brown', 'olive', 'teal', 'coral', 'navy', 'lime', 'indigo', 'tan', 'salmon'])


# Plot the transformed features
scatter = plt.scatter(transformed_features[:, 0], transformed_features[:, 1], s=.1) # c=classes, cmap=class_colors, s=.1)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Plot')

cbar = plt.colorbar(scatter, ticks=np.arange(max(classes)+1))
cbar.set_label('Class')

plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# Assuming features_df is your DataFrame containing the features

# Perform PCA
pca = PCA(n_components=2)
transformed_features = pca.fit_transform(features_df)

# Perform K-means clustering
kmeans = KMeans(n_clusters=2)  # You can choose the number of clusters
cluster_labels = kmeans.fit_predict(transformed_features)

# Define a colormap for clusters
cluster_colors = ListedColormap(['red', 'blue'])

# Plot the transformed features with cluster colors
scatter = plt.scatter(transformed_features[:, 0], transformed_features[:, 1], c=cluster_labels, cmap=cluster_colors, s=0.01)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Plot with Clustering')

cbar = plt.colorbar(scatter, ticks=np.arange(max(cluster_labels) + 1))
cbar.set_label('Cluster')

plt.show()
# Out:
# C:\Users\Donald\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
cluster_labels
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %%
len(cluster_labels)
# Out:
# 9844

# %%
df3 = features_df
df3['Centroid_x'] = loaded_df2['Centroid_x']
df3['Centroid_y'] = loaded_df2['Centroid_y']
df3['Cluster'] = cluster_labels
df3.head()
# Out:
# C:\Users\Donald\AppData\Local\Temp\ipykernel_39540\2301453176.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Centroid_x'] = loaded_df2['Centroid_x']
# C:\Users\Donald\AppData\Local\Temp\ipykernel_39540\2301453176.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Centroid_y'] = loaded_df2['Centroid_y']
# C:\Users\Donald\AppData\Local\Temp\ipykernel_39540\2301453176.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Cluster'] = cluster_labels
#           Area  Perimeter  Circularity  Aspect Ratio  compactness  \
# 492   7.502273  10.616238     0.836491      1.955567    15.022715
# 5288  3.169358   6.870699     0.843683      1.420667    14.894657
# 5466  6.160650   9.160175     0.922633      1.426231    13.620124
# 5534  2.924501   6.595929     0.844714      1.230088    14.876479
# 5611  6.870954   9.658339     0.925597      1.373306    13.576501
#
#       eccentricity  euler_number    extent  form_factor  maximum_radius  \
# 492       0.859366      0.043940  0.769288     1.195470        2.872617
# 5288      0.710304      0.495426  0.771226     1.185279        1.245068
# 5466      0.713015      0.491466  0.775298     1.083855        2.002535
# 5534      0.582334      0.621721  0.770575     1.183833        1.240882
# 5611      0.685397      0.528508  0.770977     1.080384        1.881483
#
#       mean_radius  median_radius  minor_axis_length  orientation_degrees  \
# 492      1.464317       1.288130           2.233138          6634.301530
# 5288     0.998329       1.014369           1.700782          6433.460747
# 5466     1.380868       1.334047           2.360390          3306.999028
# 5534     0.960649       0.909809           1.756508          2983.264453
# 5611     1.471617       1.472046           2.547441          4003.400088
#
#       Centroid_x   Centroid_y  Cluster
# 492   857.092113  1523.876534        0
# 5288  704.305749  4727.091230        0
# 5466  700.773117  4723.558598        1
# 5534  705.630487  4736.364391        1
# 5611  710.046277  4731.507021        1

# %%
df3
# Out:
#             Area  Perimeter  Circularity  Aspect Ratio  compactness  \
# 492     7.502273  10.616238     0.836491      1.955567    15.022715
# 5288    3.169358   6.870699     0.843683      1.420667    14.894657
# 5466    6.160650   9.160175     0.922633      1.426231    13.620124
# 5534    2.924501   6.595929     0.844714      1.230088    14.876479
# 5611    6.870954   9.658339     0.925597      1.373306    13.576501
# ...          ...        ...          ...           ...          ...
# 409901  3.301319   7.315033     0.775291      2.002033    16.208585
# 409902  2.174376   7.754083     0.454447      4.991010    27.651981
# 409908  1.764734   6.778479     0.482641      3.893001    26.036666
# 409910  2.079381   6.954939     0.540203      3.990875    23.262296
# 409916  1.498321   5.673239     0.584996      3.170689    21.481137
#
#         eccentricity  euler_number    extent  form_factor  maximum_radius  \
# 492         0.859366      0.043940  0.769288     1.195470        2.872617
# 5288        0.710304      0.495426  0.771226     1.185279        1.245068
# 5466        0.713015      0.491466  0.775298     1.083855        2.002535
# 5534        0.582334      0.621721  0.770575     1.183833        1.240882
# 5611        0.685397      0.528508  0.770977     1.080384        1.881483
# ...              ...           ...       ...          ...             ...
# 409901      0.866318     -0.002034  0.757911     1.289838        2.018121
# 409902      0.979722     -5.227545  0.719547     2.200475        2.018154
# 409908      0.966446     -2.788865  0.731356     2.071932        1.539873
# 409910      0.968098     -2.981770  0.694009     1.851155        1.694848
# 409916      0.948963     -1.513317  0.740461     1.709415        1.410051
#
#         mean_radius  median_radius  minor_axis_length  orientation_degrees  \
# 492        1.464317       1.288130           2.233138          6634.301530
# 5288       0.998329       1.014369           1.700782          6433.460747
# 5466       1.380868       1.334047           2.360390          3306.999028
# 5534       0.960649       0.909809           1.756508          2983.264453
# 5611       1.471617       1.472046           2.547441          4003.400088
# ...             ...            ...                ...                  ...
# 409901     0.935709       0.736520           1.475024           465.869663
# 409902     0.701328       0.548320           0.778115          5062.142357
# 409908     0.670764       0.536835           0.787287          7559.044885
# 409910     0.716091       0.555827           0.866464          5208.081533
# 409916     0.634311       0.503709           0.798867          3089.532799
#
#          Centroid_x   Centroid_y  Cluster
# 492      857.092113  1523.876534        0
# 5288     704.305749  4727.091230        0
# 5466     700.773117  4723.558598        1
# 5534     705.630487  4736.364391        1
# 5611     710.046277  4731.507021        1
# ...             ...          ...      ...
# 409901  4170.701581  5019.416586        1
# 409902  4197.637905  5010.585004        1
# 409908  4152.596838  5046.352910        0
# 409910  4197.196326  5013.234478        1
# 409916  4161.428420  4945.231299        1
#
# [9844 rows x 17 columns]

# %%
df3.columns
# Out:
# Index(['Area', 'Perimeter', 'Circularity', 'Aspect Ratio', 'compactness',
#        'eccentricity', 'euler_number', 'extent', 'form_factor',
#        'maximum_radius', 'mean_radius', 'median_radius', 'minor_axis_length',
#        'orientation_degrees', 'Centroid_x', 'Centroid_y', 'Cluster'],
#       dtype='object')

# %%
coords = loaded_df2[['Centroid_x', 'Centroid_y']]
coords
# Out:
#          Centroid_x   Centroid_y
# 492      857.092113  1523.876534
# 5288     704.305749  4727.091230
# 5466     700.773117  4723.558598
# 5534     705.630487  4736.364391
# 5611     710.046277  4731.507021
# ...             ...          ...
# 409901  4170.701581  5019.416586
# 409902  4197.637905  5010.585004
# 409908  4152.596838  5046.352910
# 409910  4197.196326  5013.234478
# 409916  4161.428420  4945.231299
#
# [9844 rows x 2 columns]

# %%
print((cluster_labels == 0).sum())
print((cluster_labels == 1).sum())
# Out:
# 4777
# 5067

# %%
cluster_labels
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %%
y = loaded_df2['Centroid_x']
x = loaded_df2['Centroid_y']

# Create scatter plot|
plt.scatter(x, y, marker='o', c = cluster_labels, cmap = cluster_colors, s=.1)
# , c=cluster_labels, cmap=cluster_colors, s=0.01
# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('monkey_fetus_40_0895')

#plt.xlim(1100, 2250)
#plt.ylim(2250, 3750)

plt.gca().invert_yaxis()

# Show the plot
plt.show()

# %%
# Filter the DataFrame for Cluster 0
cluster_0_df = df3[df3['Cluster'] == 0]
cluster_0_df.head()

# Extract x and y coordinates for Cluster 0
y_cluster_0 = cluster_0_df['Centroid_x']
x_cluster_0 = cluster_0_df['Centroid_y']

# Create scatter plot|
plt.scatter(x_cluster_0, y_cluster_0, marker='o', c='red', s=0.1)
# , c=cluster_labels, cmap=cluster_colors, s=0.01
# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('monkey_fetus_40_0895')

#plt.xlim(1100, 2250)
#plt.ylim(2250, 3750)

plt.gca().invert_yaxis()

# Show the plot
plt.show()

# %%
# Filter the DataFrame for Cluster 0
cluster_1_df = df3[df3['Cluster'] == 1]
cluster_1_df.head()

# Extract x and y coordinates for Cluster 0
y_cluster_1 = cluster_1_df['Centroid_x']
x_cluster_1 = cluster_1_df['Centroid_y']

# Create scatter plot|
plt.scatter(x_cluster_1, y_cluster_1, marker='o', c='blue', s=0.1)
# , c=cluster_labels, cmap=cluster_colors, s=0.01
# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('monkey_fetus_40_0895')

#plt.xlim(1100, 2250)
#plt.ylim(2250, 3750)

plt.gca().invert_yaxis()

# Show the plot
plt.show()

# %%
y = loaded_df2['Centroid_x']
x = loaded_df2['Centroid_y']

# Create scatter plot|
plt.scatter(x, y, marker='o', color='blue', s=.01)
# , c=cluster_labels, cmap=cluster_colors, s=0.01
# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('monkey_fetus_40_0895')

#plt.xlim(1100, 2250)
#plt.ylim(2250, 3750)

plt.gca().invert_yaxis()

# Show the plot
plt.show()
