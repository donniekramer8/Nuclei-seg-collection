# %%
# pip install gputools
# pip install scikit-tensor-py3

from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import numpy as np
import matplotlib
matplotlib.rcParams["image.interpolation"] = 'nearest'
import matplotlib.pyplot as plt
import os
from PIL import Image
import tensorflow as tf
from glob import glob
from tqdm import tqdm
from tifffile import imread
import struct
import cv2
import pandas as pd

from stardist import fill_label_holes, random_label_cmap, calculate_extents, gputools_available
from stardist.models import Config2D, StarDist2D, StarDistData2D

# %%
#Random color map labels
np.random.seed(42)
lbl_cmap = random_label_cmap()

# %%
pthHE = r'\\10.99.68.178\andreex\data\Stardist\PDAC model\maybe_all_tiles_donald\HE'
pthmasks = r'\\10.99.68.178\andreex\data\Stardist\PDAC model\maybe_all_tiles_donald\mask'

# %%
training_HE_tiles_pths = sorted(glob(os.path.join(pthHE,'*.tif')))
training_mask_tiles_pths = sorted(glob(os.path.join(pthmasks,'*.tif')))

# %%
training_HE_tiles_pths
# Out:
# ['\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\H15_0091.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\H15_0151.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\H15_0277.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\H15_0277_1.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\H15_0421_1.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\H15_0421_2.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\PD.2 5N-T LCM.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\PD_15 3Q LCM1.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\PD_17 4M LCM.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\PD_17 4M LCM1.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\PD_18 2H LCM.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\PD_19 5M LCM.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\HE\\PD_25 3GG LCM1.tif']

# %%
print(len(training_HE_tiles_pths))
print(len(training_mask_tiles_pths))
# Out:
# 13
# 13

# %%
HE_original_tiles = list(map(imread,training_HE_tiles_pths))
mask_original_tiles = list(map(imread,training_mask_tiles_pths))

# %%
import random

size_total = len(training_HE_tiles_pths)
print(f'Size total: {size_total}')

val_ratio = 0.3
num_indices = int(size_total * val_ratio)

print(f'Size Training: {size_total - num_indices}')
print(f'Size Validation: {num_indices}')
# Out:
# Size total: 13
# Size Training: 10
# Size Validation: 3

# %%
val_indices = sorted(random.sample(range(size_total), num_indices))
train_indices = sorted(list(set(range(size_total)) - set(val_indices)))

print(val_indices)
print(train_indices)
# Out:
# [8, 10, 12]
# [0, 1, 2, 3, 4, 5, 6, 7, 9, 11]

# %%
training_tiles = [HE_original_tiles[i] for i in train_indices]
training_masks = [mask_original_tiles[i] for i in train_indices]
training_masks = [fill_label_holes(y) for y in training_masks]  # fills holes in annotations if there are any

val_tiles = [HE_original_tiles[i] for i in val_indices]
val_masks = [mask_original_tiles[i] for i in val_indices]
val_masks = [fill_label_holes(y) for y in val_masks]  # fills holes in annotations if there are any

print(len(training_tiles))
print(len(training_masks))

print(len(val_tiles))
print(len(val_masks))
# Out:
# 10
# 10
# 3
# 3

# %%
def augment_images(HE_tiles, mask_tiles):
  """
  Augments a set of HE images and corresponding mask labels by rotating and flipping them.

  Args:
    HE_tiles: A list of NumPy arrays representing the HE images.
    mask_tiles: A list of NumPy arrays representing the mask labels for the HE images.

  Returns:
    HE_aug: A list of NumPy arrays representing the augmented HE images.
    mask_aug: A list of NumPy arrays representing the augmented mask labels.
  """

  HE_aug = [[] for _ in range(len(HE_tiles))]
  mask_aug = [[] for _ in range(len(mask_tiles))]

  for i in range(len(HE_tiles)):
    im = Image.fromarray(HE_tiles[i])
    lbl = Image.fromarray(mask_tiles[i])

    # Rotate the image and label 90 degrees three times.
    for _ in range(3):
      im = im.rotate(90)
      HE_aug[i].append(im)
      lbl = lbl.rotate(90)
      mask_aug[i].append(lbl)

    # Flip the image and label horizontally.
    im = Image.fromarray(HE_tiles[i])
    flipped_im = im.transpose(Image.FLIP_LEFT_RIGHT)

    lbl = Image.fromarray(mask_tiles[i])
    flipped_lbl = lbl.transpose(Image.FLIP_LEFT_RIGHT)

    HE_aug[i].append(flipped_im)
    mask_aug[i].append(flipped_lbl)

    # Rotate the flipped image and label 90 degrees three times.
    for _ in range(3):
      flipped_im = flipped_im.rotate(90)
      HE_aug[i].append(flipped_im)
      flipped_lbl = flipped_lbl.rotate(90)
      mask_aug[i].append(flipped_lbl)

  return HE_aug, mask_aug

# %%
HE_aug, mask_aug = augment_images(training_tiles, training_masks)

# %%
print(len(training_tiles))
# Out:
# 10

# %%
print(len(HE_aug)*(len(HE_aug[0])))
print(len(mask_aug)*(len(mask_aug[0])))
# Out:
# 70
# 70

# %%
def normalize_images(images, masks):
  
  normalized_masks = [[] for i in range(len(masks))]
  normalized_images = [[] for i in range(len(images))]
  
  for i in range(len(masks)):
      masks_list = masks[i]
      images_list = images[i]
      
      for j in range(len(images_list)):
          im = images_list[j]
          im = np.asarray(im)
          im = im/255
          normalized_images[i].append(im)
      
      for j in range(len(masks_list)):
          im = masks_list[j]
          im = np.asarray(im)
          im = fill_label_holes(im)
          normalized_masks[i].append(im)
          
  return normalized_images, normalized_masks

# %%
print(len(HE_aug))
print(len(HE_aug[0]))
# Out:
# 10
# 7

# %%
HE_trn = [im for im in training_tiles]
for im_list in HE_aug:
    for im in im_list:
        HE_trn.append(np.array(im))

mask_trn = [im for im in training_masks]
for im_list in mask_aug:
    for im in im_list:
        mask_trn.append(np.array(im))

HE_trn = [im/255 for im in HE_trn]

print(len(HE_trn))
print(len(mask_trn))
# Out:
# 80
# 80

# %%
# divide val tiles by 255 also
val_tiles = [im/255 for im in val_tiles]

# %%
print(f'training images: {len(HE_trn)}')
print(f'training masks: {len(mask_trn)}')

print(f'validation masks: {len(val_tiles)}')
print(f'validation masks: {len(val_masks)}')
# Out:
# training images: 80
# training masks: 80
# validation masks: 3
# validation masks: 3

# %%
#PLot image and label for some images - sanity check
def show_tile_segmented(tile, segmented, **kwargs):
    """Plot large image at different resolutions."""
    fig, ax = plt.subplots(1, 2, figsize=(16/2, 8/2))

    # Plot the original image on the left
    ax[0].imshow(tile, **kwargs)

    # Plot the cropped image on the right
    ax[1].imshow(segmented, **kwargs)

    ax[0].axis('off')
    ax[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
i = 0

# %%
i += 1

img, lbl = HE_trn[i], mask_trn[i]
assert img.ndim in (2,3)
img = img if (img.ndim==2 or img.shape[-1]==3) else img[...,0]
show_tile_segmented(img,lbl)

# %%
if tf.config.list_physical_devices('GPU'):
    print("GPU is available")
else:
    print("GPU is not available")
    
print(tf.__version__)

#Define the config by setting some parameter values
# 32 is a good default choice (see 1_data.ipynb)
n_rays = 32  #Number of radial directions for the star-convex polygon.

# Use OpenCL-based computations for data generator during training (requires 'gputools')
use_gpu = True and gputools_available()

# Predict on subsampled grid for increased efficiency and larger field of view
grid = (2,2)

n_channel = 1 if HE_trn[0].ndim == 2 else HE_trn[0].shape[-1]  #If no third dim. then number of channels = 1. Otherwise get the num channels from the last dim.


conf = Config2D (
    n_rays       = n_rays,
    grid         = grid,
    use_gpu      = use_gpu,
    n_channel_in = n_channel,
)
# print(conf)
vars(conf)
# Out:
# GPU is available
# 2.9.3
# Warning: Could not find scikit-tensor which is needed for separable approximations...
# If you want to compute separable approximations, please install it with
# pip install scikit-tensor-py3
# {'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 3,
#  'n_channel_out': 33,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'n_rays': 32,
#  'grid': (2, 2),
#  'backbone': 'unet',
#  'n_classes': None,
#  'unet_n_depth': 3,
#  'unet_kernel_size': (3, 3),
#  'unet_n_filter_base': 32,
#  'unet_n_conv_per_depth': 2,
#  'unet_pool': (2, 2),
#  'unet_activation': 'relu',
#  'unet_last_activation': 'relu',
#  'unet_batch_norm': False,
#  'unet_dropout': 0.0,
#  'unet_prefix': '',
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, 3),
#  'net_mask_shape': (None, None, 1),
#  'train_shape_completion': False,
#  'train_completion_crop': 32,
#  'train_patch_size': (256, 256),
#  'train_background_reg': 0.0001,
#  'train_foreground_only': 0.9,
#  'train_sample_cache': True,
#  'train_dist_loss': 'mae',
#  'train_loss_weights': (1, 0.2),
#  'train_class_weights': (1, 1),
#  'train_epochs': 400,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0003,
#  'train_batch_size': 4,
#  'train_n_val_patches': None,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 40, 'min_delta': 0},
#  'use_gpu': True}

# %%
#Start from 40x H&E pre-trained model to the specified directory
import copy
import json

def load_justin_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = load_model(r'\\10.99.68.178\andreex\students\Donald Monkey fetus\stardist\Model_00')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_published_he_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = StarDist2D.from_pretrained('2D_versatile_he')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_model(model_path: str) -> StarDist2D:
    # Load StarDist model weights, configurations, and thresholds
    with open(model_path + '\\config.json', 'r') as f:
        config = json.load(f)
    with open(model_path + '\\thresholds.json', 'r') as f:
        thresh = json.load(f)
    model = StarDist2D(config=Config2D(**config), basedir=model_path, name='offshoot_model')
    model.thresholds = thresh
    print('Overriding defaults:', model.thresholds, '\n')
    model.load_weights(model_path + '\\weights_best.h5')
    return model

def configure_model_for_training(model: StarDist2D,
                                 epochs: int = 25, learning_rate: float = 1e-6,
                                 batch_size: int = 4, patch_size: list[int,int] = [256, 256]) -> StarDist2D:
    model.config.train_epochs = epochs
    model.config.train_learning_rate = learning_rate
    model.config.train_batch_size = batch_size
    model.config.train_patch_size = patch_size
    return model

# %%
from tensorflow.python.summary.summary_iterator import summary_iterator

def get_loss_data(pth_training_log, pth_out) -> list:

    # event_file = r"\\10.99.68.178\andreex\data\Stardist\models\monkey_ft_11_02_2023_lr_1e-4_epochs_200_pt_10\logs\train\events.out.tfevents.1698964029.WPC-C13.20400.7.v2"

    loss_values = []

    for summary in summary_iterator(pth_training_log):
        for value in summary.summary.value:
            if value.tag == 'epoch_loss':
                loss = struct.unpack('f', value.tensor.tensor_content)[0]
                loss_values.append(loss)

    out_txt_name = f"{pth_out}\loss.txt"

    with open(out_txt_name, 'w') as f:
        f.write('\n'.join(map(str, loss_values)) + '\n')

    return loss_values

# %%
# lr = 0.001
lr = 0.0001
# epochs = 400
epochs = 150
# patience = 40
patience = 15
nm='PDAC'
dt='02_9_24'
# outnm = nm + dt + '_lr_' + str(lr) + '_epochs_' + str(epochs) + '_pt_' + str(patience)
outnm=f'{nm}_{dt}_lr_{lr}_epochs_{epochs}_pt_{patience}_gaus_ratio_0'
print(outnm)
# Out:
# PDAC_02_9_24_lr_0.0001_epochs_150_pt_15_gaus_ratio_0

# %%
pthmodels = r'\\10.99.68.178\andreex\data\Stardist\PDAC model\maybe_all_tiles_donald\models\Fallopian_monkey_test_tiles_12_7_23_lr_0.001_epochs_400_pt_40'

# %%
model = load_model(os.path.join(pthmodels))
model.config.train_learning_rate = lr
model.config.train_patch_size = (256,256)
model.config.train_reduce_lr={'factor': 0.5, 'patience': patience, 'min_delta': 0}
# Out:
# base_model.py (149): output path for model already exists, files may be overwritten: \\10.99.68.178\andreex\data\Stardist\PDAC model\maybe_all_tiles_donald\models\Fallopian_monkey_test_tiles_12_7_23_lr_0.001_epochs_400_pt_40\offshoot_model
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# Overriding defaults: Thresholds(prob=0.6590521771973135, nms=0.3)

# %%
model.train(HE_trn, mask_trn, validation_data=(val_tiles,val_masks), epochs=epochs, steps_per_epoch=100)
model.optimize_thresholds(val_tiles, val_masks)

pth_log_train = fr"{pthmodels}\{outnm}\logs\train"
if not os.path.exists(pth_log_train): os.mkdir(pth_log_train)

pth_log = glob(os.path.join(pth_log_train,'*.v2'))[0]
loss = get_loss_data(str(pth_log), pth_log_train)
# Out:
# Epoch 1/150
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x0000021A45361310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x0000021A45361310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow | AutoGraph could not transform <function _gcd_import at 0x0000021A45361310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x0000021A45361310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x0000021A45361310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x0000021A45361310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4040 - prob_loss: 0.1477 - dist_loss: 1.2814 - prob_kld: 0.0604 - dist_relevant_mae: 1.2811 - dist_relev
# 100/100 [==============================] - 10s 51ms/step - loss: 0.4040 - prob_loss: 0.1477 - dist_loss: 1.2814 - prob_kld: 0.0604 - dist_relevant_mae: 1.2811 - dist_relevant_mse: 4.9763 - dist_dist_iou_metric: 0.6743 - val_loss: 0.4012 - val_prob_loss: 0.1630 - val_dist_loss: 1.1908 - val_prob_kld: 0.0594 - val_dist_relevant_mae: 1.1904 - val_dist_relevant_mse: 3.4942 - val_dist_dist_iou_metric: 0.6925 - lr: 1.0000e-04
# Epoch 2/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3863 - prob_loss: 0.1414 - dist_loss: 1.2244 - prob_kld: 0.0540 - dist_relevant_mae: 1.2240 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3863 - prob_loss: 0.1414 - dist_loss: 1.2244 - prob_kld: 0.0540 - dist_relevant_mae: 1.2240 - dist_relevant_mse: 4.4698 - dist_dist_iou_metric: 0.6862 - val_loss: 0.3923 - val_prob_loss: 0.1619 - val_dist_loss: 1.1521 - val_prob_kld: 0.0582 - val_dist_relevant_mae: 1.1517 - val_dist_relevant_mse: 3.3497 - val_dist_dist_iou_metric: 0.7035 - lr: 1.0000e-04
# Epoch 3/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3805 - prob_loss: 0.1403 - dist_loss: 1.2009 - prob_kld: 0.0531 - dist_relevant_mae: 1.2005 - dist_relev
# 100/100 [==============================] - 3s 33ms/step - loss: 0.3805 - prob_loss: 0.1403 - dist_loss: 1.2009 - prob_kld: 0.0531 - dist_relevant_mae: 1.2005 - dist_relevant_mse: 4.2718 - dist_dist_iou_metric: 0.6888 - val_loss: 0.3863 - val_prob_loss: 0.1607 - val_dist_loss: 1.1281 - val_prob_kld: 0.0570 - val_dist_relevant_mae: 1.1277 - val_dist_relevant_mse: 3.3009 - val_dist_dist_iou_metric: 0.7069 - lr: 1.0000e-04
# Epoch 4/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3715 - prob_loss: 0.1365 - dist_loss: 1.1749 - prob_kld: 0.0507 - dist_relevant_mae: 1.1745 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3715 - prob_loss: 0.1365 - dist_loss: 1.1749 - prob_kld: 0.0507 - dist_relevant_mae: 1.1745 - dist_relevant_mse: 4.0646 - dist_dist_iou_metric: 0.6940 - val_loss: 0.3945 - val_prob_loss: 0.1614 - val_dist_loss: 1.1656 - val_prob_kld: 0.0577 - val_dist_relevant_mae: 1.1652 - val_dist_relevant_mse: 3.3425 - val_dist_dist_iou_metric: 0.6975 - lr: 1.0000e-04
# Epoch 5/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3671 - prob_loss: 0.1366 - dist_loss: 1.1524 - prob_kld: 0.0502 - dist_relevant_mae: 1.1520 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3671 - prob_loss: 0.1366 - dist_loss: 1.1524 - prob_kld: 0.0502 - dist_relevant_mae: 1.1520 - dist_relevant_mse: 3.8785 - dist_dist_iou_metric: 0.6973 - val_loss: 0.3813 - val_prob_loss: 0.1596 - val_dist_loss: 1.1083 - val_prob_kld: 0.0559 - val_dist_relevant_mae: 1.1079 - val_dist_relevant_mse: 3.2194 - val_dist_dist_iou_metric: 0.7133 - lr: 1.0000e-04
# Epoch 6/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3691 - prob_loss: 0.1361 - dist_loss: 1.1654 - prob_kld: 0.0496 - dist_relevant_mae: 1.1650 - dist_relev
# 100/100 [==============================] - 4s 38ms/step - loss: 0.3691 - prob_loss: 0.1361 - dist_loss: 1.1654 - prob_kld: 0.0496 - dist_relevant_mae: 1.1650 - dist_relevant_mse: 4.0095 - dist_dist_iou_metric: 0.6965 - val_loss: 0.3884 - val_prob_loss: 0.1603 - val_dist_loss: 1.1405 - val_prob_kld: 0.0566 - val_dist_relevant_mae: 1.1401 - val_dist_relevant_mse: 3.2692 - val_dist_dist_iou_metric: 0.7052 - lr: 1.0000e-04
# Epoch 7/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3635 - prob_loss: 0.1350 - dist_loss: 1.1427 - prob_kld: 0.0488 - dist_relevant_mae: 1.1423 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3643 - prob_loss: 0.1352 - dist_loss: 1.1456 - prob_kld: 0.0489 - dist_relevant_mae: 1.1451 - dist_relevant_mse: 3.8871 - dist_dist_iou_metric: 0.6988 - val_loss: 0.3819 - val_prob_loss: 0.1610 - val_dist_loss: 1.1048 - val_prob_kld: 0.0573 - val_dist_relevant_mae: 1.1043 - val_dist_relevant_mse: 3.1908 - val_dist_dist_iou_metric: 0.7165 - lr: 1.0000e-04
# Epoch 8/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3622 - prob_loss: 0.1343 - dist_loss: 1.1394 - prob_kld: 0.0485 - dist_relevant_mae: 1.1390 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3622 - prob_loss: 0.1343 - dist_loss: 1.1394 - prob_kld: 0.0485 - dist_relevant_mae: 1.1390 - dist_relevant_mse: 3.7862 - dist_dist_iou_metric: 0.7007 - val_loss: 0.3928 - val_prob_loss: 0.1624 - val_dist_loss: 1.1522 - val_prob_kld: 0.0587 - val_dist_relevant_mae: 1.1518 - val_dist_relevant_mse: 3.2798 - val_dist_dist_iou_metric: 0.7010 - lr: 1.0000e-04
# Epoch 9/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3590 - prob_loss: 0.1345 - dist_loss: 1.1225 - prob_kld: 0.0478 - dist_relevant_mae: 1.1221 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3594 - prob_loss: 0.1348 - dist_loss: 1.1230 - prob_kld: 0.0479 - dist_relevant_mae: 1.1226 - dist_relevant_mse: 3.6500 - dist_dist_iou_metric: 0.7029 - val_loss: 0.3929 - val_prob_loss: 0.1616 - val_dist_loss: 1.1564 - val_prob_kld: 0.0579 - val_dist_relevant_mae: 1.1560 - val_dist_relevant_mse: 3.3417 - val_dist_dist_iou_metric: 0.7024 - lr: 1.0000e-04
# Epoch 10/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3585 - prob_loss: 0.1364 - dist_loss: 1.1102 - prob_kld: 0.0480 - dist_relevant_mae: 1.1098 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3581 - prob_loss: 0.1360 - dist_loss: 1.1103 - prob_kld: 0.0479 - dist_relevant_mae: 1.1099 - dist_relevant_mse: 3.5784 - dist_dist_iou_metric: 0.7064 - val_loss: 0.3882 - val_prob_loss: 0.1601 - val_dist_loss: 1.1404 - val_prob_kld: 0.0564 - val_dist_relevant_mae: 1.1400 - val_dist_relevant_mse: 3.3409 - val_dist_dist_iou_metric: 0.7065 - lr: 1.0000e-04
# Epoch 11/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3557 - prob_loss: 0.1325 - dist_loss: 1.1157 - prob_kld: 0.0464 - dist_relevant_mae: 1.1153 - dist_relev
# 100/100 [==============================] - 3s 33ms/step - loss: 0.3561 - prob_loss: 0.1328 - dist_loss: 1.1162 - prob_kld: 0.0466 - dist_relevant_mae: 1.1158 - dist_relevant_mse: 3.6430 - dist_dist_iou_metric: 0.7059 - val_loss: 0.3832 - val_prob_loss: 0.1599 - val_dist_loss: 1.1162 - val_prob_kld: 0.0562 - val_dist_relevant_mae: 1.1158 - val_dist_relevant_mse: 3.2728 - val_dist_dist_iou_metric: 0.7117 - lr: 1.0000e-04
# Epoch 12/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3554 - prob_loss: 0.1349 - dist_loss: 1.1021 - prob_kld: 0.0473 - dist_relevant_mae: 1.1017 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3554 - prob_loss: 0.1349 - dist_loss: 1.1021 - prob_kld: 0.0473 - dist_relevant_mae: 1.1017 - dist_relevant_mse: 3.4783 - dist_dist_iou_metric: 0.7077 - val_loss: 0.3985 - val_prob_loss: 0.1641 - val_dist_loss: 1.1717 - val_prob_kld: 0.0604 - val_dist_relevant_mae: 1.1713 - val_dist_relevant_mse: 3.4183 - val_dist_dist_iou_metric: 0.6974 - lr: 1.0000e-04
# Epoch 13/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3531 - prob_loss: 0.1310 - dist_loss: 1.1107 - prob_kld: 0.0458 - dist_relevant_mae: 1.1103 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3531 - prob_loss: 0.1310 - dist_loss: 1.1109 - prob_kld: 0.0458 - dist_relevant_mae: 1.1105 - dist_relevant_mse: 3.5443 - dist_dist_iou_metric: 0.7060 - val_loss: 0.3898 - val_prob_loss: 0.1623 - val_dist_loss: 1.1378 - val_prob_kld: 0.0586 - val_dist_relevant_mae: 1.1374 - val_dist_relevant_mse: 3.2924 - val_dist_dist_iou_metric: 0.7060 - lr: 1.0000e-04
# Epoch 14/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3512 - prob_loss: 0.1321 - dist_loss: 1.0955 - prob_kld: 0.0458 - dist_relevant_mae: 1.0951 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3512 - prob_loss: 0.1321 - dist_loss: 1.0955 - prob_kld: 0.0458 - dist_relevant_mae: 1.0951 - dist_relevant_mse: 3.4536 - dist_dist_iou_metric: 0.7083 - val_loss: 0.3892 - val_prob_loss: 0.1626 - val_dist_loss: 1.1331 - val_prob_kld: 0.0589 - val_dist_relevant_mae: 1.1327 - val_dist_relevant_mse: 3.3098 - val_dist_dist_iou_metric: 0.7100 - lr: 1.0000e-04
# Epoch 15/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3490 - prob_loss: 0.1318 - dist_loss: 1.0860 - prob_kld: 0.0453 - dist_relevant_mae: 1.0856 - dist_relev
# 100/100 [==============================] - 3s 34ms/step - loss: 0.3490 - prob_loss: 0.1318 - dist_loss: 1.0860 - prob_kld: 0.0453 - dist_relevant_mae: 1.0856 - dist_relevant_mse: 3.3756 - dist_dist_iou_metric: 0.7113 - val_loss: 0.3864 - val_prob_loss: 0.1627 - val_dist_loss: 1.1184 - val_prob_kld: 0.0591 - val_dist_relevant_mae: 1.1180 - val_dist_relevant_mse: 3.2080 - val_dist_dist_iou_metric: 0.7090 - lr: 1.0000e-04
# Epoch 16/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3497 - prob_loss: 0.1319 - dist_loss: 1.0889 - prob_kld: 0.0452 - dist_relevant_mae: 1.0885 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3497 - prob_loss: 0.1319 - dist_loss: 1.0889 - prob_kld: 0.0452 - dist_relevant_mae: 1.0885 - dist_relevant_mse: 3.3918 - dist_dist_iou_metric: 0.7116 - val_loss: 0.3936 - val_prob_loss: 0.1630 - val_dist_loss: 1.1530 - val_prob_kld: 0.0593 - val_dist_relevant_mae: 1.1526 - val_dist_relevant_mse: 3.3289 - val_dist_dist_iou_metric: 0.7009 - lr: 1.0000e-04
# Epoch 17/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3454 - prob_loss: 0.1330 - dist_loss: 1.0621 - prob_kld: 0.0452 - dist_relevant_mae: 1.0617 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3454 - prob_loss: 0.1330 - dist_loss: 1.0621 - prob_kld: 0.0452 - dist_relevant_mae: 1.0617 - dist_relevant_mse: 3.1773 - dist_dist_iou_metric: 0.7159 - val_loss: 0.3913 - val_prob_loss: 0.1625 - val_dist_loss: 1.1442 - val_prob_kld: 0.0588 - val_dist_relevant_mae: 1.1438 - val_dist_relevant_mse: 3.3708 - val_dist_dist_iou_metric: 0.7022 - lr: 1.0000e-04
# Epoch 18/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3463 - prob_loss: 0.1329 - dist_loss: 1.0674 - prob_kld: 0.0452 - dist_relevant_mae: 1.0670 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3465 - prob_loss: 0.1330 - dist_loss: 1.0678 - prob_kld: 0.0452 - dist_relevant_mae: 1.0674 - dist_relevant_mse: 3.2375 - dist_dist_iou_metric: 0.7140 - val_loss: 0.3888 - val_prob_loss: 0.1614 - val_dist_loss: 1.1370 - val_prob_kld: 0.0578 - val_dist_relevant_mae: 1.1366 - val_dist_relevant_mse: 3.3209 - val_dist_dist_iou_metric: 0.7062 - lr: 1.0000e-04
# Epoch 19/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3463 - prob_loss: 0.1315 - dist_loss: 1.0741 - prob_kld: 0.0448 - dist_relevant_mae: 1.0737 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3463 - prob_loss: 0.1315 - dist_loss: 1.0741 - prob_kld: 0.0448 - dist_relevant_mae: 1.0737 - dist_relevant_mse: 3.2871 - dist_dist_iou_metric: 0.7124 - val_loss: 0.3859 - val_prob_loss: 0.1626 - val_dist_loss: 1.1164 - val_prob_kld: 0.0589 - val_dist_relevant_mae: 1.1160 - val_dist_relevant_mse: 3.2864 - val_dist_dist_iou_metric: 0.7113 - lr: 1.0000e-04
# Epoch 20/150
#  99/100 [============================>.] - ETA: 0s - loss: 0.3432 - prob_loss: 0.1311 - dist_loss: 1.0606 - prob_kld: 0.0443 - dist_relevant_mae: 1.0602 - dist_relevant_mse: 3.1737 - dist_dist_iou_metric: 0.7156
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 3/3 [==============================] - 0s 2ms/step
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3432 - prob_loss: 0.1309 - dist_loss: 1.0615 - prob_kld: 0.0443 - dist_relevant_mae: 1.0611 - dist_relevant_mse: 3.1805 - dist_dist_iou_metric: 0.7154 - val_loss: 0.3891 - val_prob_loss: 0.1624 - val_dist_loss: 1.1334 - val_prob_kld: 0.0587 - val_dist_relevant_mae: 1.1331 - val_dist_relevant_mse: 3.3841 - val_dist_dist_iou_metric: 0.7064 - lr: 1.0000e-04
# Epoch 21/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3419 - prob_loss: 0.1299 - dist_loss: 1.0597 - prob_kld: 0.0438 - dist_relevant_mae: 1.0594 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3419 - prob_loss: 0.1299 - dist_loss: 1.0597 - prob_kld: 0.0438 - dist_relevant_mae: 1.0594 - dist_relevant_mse: 3.1639 - dist_dist_iou_metric: 0.7150 - val_loss: 0.3872 - val_prob_loss: 0.1624 - val_dist_loss: 1.1239 - val_prob_kld: 0.0587 - val_dist_relevant_mae: 1.1235 - val_dist_relevant_mse: 3.3133 - val_dist_dist_iou_metric: 0.7100 - lr: 5.0000e-05
# Epoch 22/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3399 - prob_loss: 0.1286 - dist_loss: 1.0569 - prob_kld: 0.0434 - dist_relevant_mae: 1.0565 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3399 - prob_loss: 0.1286 - dist_loss: 1.0569 - prob_kld: 0.0434 - dist_relevant_mae: 1.0565 - dist_relevant_mse: 3.1879 - dist_dist_iou_metric: 0.7157 - val_loss: 0.3834 - val_prob_loss: 0.1627 - val_dist_loss: 1.1036 - val_prob_kld: 0.0590 - val_dist_relevant_mae: 1.1033 - val_dist_relevant_mse: 3.2633 - val_dist_dist_iou_metric: 0.7143 - lr: 5.0000e-05
# Epoch 23/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3416 - prob_loss: 0.1313 - dist_loss: 1.0510 - prob_kld: 0.0440 - dist_relevant_mae: 1.0507 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3419 - prob_loss: 0.1315 - dist_loss: 1.0520 - prob_kld: 0.0441 - dist_relevant_mae: 1.0517 - dist_relevant_mse: 3.1001 - dist_dist_iou_metric: 0.7169 - val_loss: 0.3889 - val_prob_loss: 0.1631 - val_dist_loss: 1.1293 - val_prob_kld: 0.0594 - val_dist_relevant_mae: 1.1289 - val_dist_relevant_mse: 3.3716 - val_dist_dist_iou_metric: 0.7081 - lr: 5.0000e-05
# Epoch 24/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3401 - prob_loss: 0.1290 - dist_loss: 1.0557 - prob_kld: 0.0432 - dist_relevant_mae: 1.0553 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3399 - prob_loss: 0.1288 - dist_loss: 1.0551 - prob_kld: 0.0432 - dist_relevant_mae: 1.0548 - dist_relevant_mse: 3.1751 - dist_dist_iou_metric: 0.7170 - val_loss: 0.3912 - val_prob_loss: 0.1634 - val_dist_loss: 1.1387 - val_prob_kld: 0.0598 - val_dist_relevant_mae: 1.1383 - val_dist_relevant_mse: 3.3985 - val_dist_dist_iou_metric: 0.7055 - lr: 5.0000e-05
# Epoch 25/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3406 - prob_loss: 0.1303 - dist_loss: 1.0514 - prob_kld: 0.0438 - dist_relevant_mae: 1.0511 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3402 - prob_loss: 0.1304 - dist_loss: 1.0493 - prob_kld: 0.0437 - dist_relevant_mae: 1.0490 - dist_relevant_mse: 3.0983 - dist_dist_iou_metric: 0.7172 - val_loss: 0.3904 - val_prob_loss: 0.1625 - val_dist_loss: 1.1395 - val_prob_kld: 0.0588 - val_dist_relevant_mae: 1.1392 - val_dist_relevant_mse: 3.3259 - val_dist_dist_iou_metric: 0.7061 - lr: 5.0000e-05
# Epoch 26/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3414 - prob_loss: 0.1326 - dist_loss: 1.0441 - prob_kld: 0.0441 - dist_relevant_mae: 1.0438 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3414 - prob_loss: 0.1326 - dist_loss: 1.0441 - prob_kld: 0.0441 - dist_relevant_mae: 1.0438 - dist_relevant_mse: 3.0620 - dist_dist_iou_metric: 0.7187 - val_loss: 0.3932 - val_prob_loss: 0.1652 - val_dist_loss: 1.1399 - val_prob_kld: 0.0615 - val_dist_relevant_mae: 1.1396 - val_dist_relevant_mse: 3.4332 - val_dist_dist_iou_metric: 0.7049 - lr: 5.0000e-05
# Epoch 27/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3389 - prob_loss: 0.1301 - dist_loss: 1.0437 - prob_kld: 0.0437 - dist_relevant_mae: 1.0434 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3392 - prob_loss: 0.1302 - dist_loss: 1.0451 - prob_kld: 0.0437 - dist_relevant_mae: 1.0447 - dist_relevant_mse: 3.0750 - dist_dist_iou_metric: 0.7177 - val_loss: 0.3893 - val_prob_loss: 0.1633 - val_dist_loss: 1.1303 - val_prob_kld: 0.0596 - val_dist_relevant_mae: 1.1300 - val_dist_relevant_mse: 3.2844 - val_dist_dist_iou_metric: 0.7067 - lr: 5.0000e-05
# Epoch 28/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3374 - prob_loss: 0.1282 - dist_loss: 1.0463 - prob_kld: 0.0426 - dist_relevant_mae: 1.0459 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3374 - prob_loss: 0.1282 - dist_loss: 1.0463 - prob_kld: 0.0426 - dist_relevant_mae: 1.0459 - dist_relevant_mse: 3.0664 - dist_dist_iou_metric: 0.7190 - val_loss: 0.3903 - val_prob_loss: 0.1642 - val_dist_loss: 1.1305 - val_prob_kld: 0.0605 - val_dist_relevant_mae: 1.1302 - val_dist_relevant_mse: 3.3567 - val_dist_dist_iou_metric: 0.7070 - lr: 5.0000e-05
# Epoch 29/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3382 - prob_loss: 0.1293 - dist_loss: 1.0443 - prob_kld: 0.0431 - dist_relevant_mae: 1.0439 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3382 - prob_loss: 0.1293 - dist_loss: 1.0443 - prob_kld: 0.0431 - dist_relevant_mae: 1.0439 - dist_relevant_mse: 3.0365 - dist_dist_iou_metric: 0.7190 - val_loss: 0.3864 - val_prob_loss: 0.1629 - val_dist_loss: 1.1177 - val_prob_kld: 0.0592 - val_dist_relevant_mae: 1.1173 - val_dist_relevant_mse: 3.2904 - val_dist_dist_iou_metric: 0.7113 - lr: 5.0000e-05
# Epoch 30/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3363 - prob_loss: 0.1297 - dist_loss: 1.0328 - prob_kld: 0.0427 - dist_relevant_mae: 1.0325 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3360 - prob_loss: 0.1295 - dist_loss: 1.0326 - prob_kld: 0.0426 - dist_relevant_mae: 1.0323 - dist_relevant_mse: 2.9943 - dist_dist_iou_metric: 0.7204 - val_loss: 0.3869 - val_prob_loss: 0.1621 - val_dist_loss: 1.1240 - val_prob_kld: 0.0584 - val_dist_relevant_mae: 1.1237 - val_dist_relevant_mse: 3.3181 - val_dist_dist_iou_metric: 0.7085 - lr: 5.0000e-05
# Epoch 31/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3389 - prob_loss: 0.1295 - dist_loss: 1.0473 - prob_kld: 0.0429 - dist_relevant_mae: 1.0469 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3389 - prob_loss: 0.1295 - dist_loss: 1.0473 - prob_kld: 0.0429 - dist_relevant_mae: 1.0469 - dist_relevant_mse: 3.1030 - dist_dist_iou_metric: 0.7202 - val_loss: 0.3920 - val_prob_loss: 0.1629 - val_dist_loss: 1.1455 - val_prob_kld: 0.0592 - val_dist_relevant_mae: 1.1452 - val_dist_relevant_mse: 3.3763 - val_dist_dist_iou_metric: 0.7052 - lr: 5.0000e-05
# Epoch 32/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3355 - prob_loss: 0.1281 - dist_loss: 1.0371 - prob_kld: 0.0423 - dist_relevant_mae: 1.0368 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3358 - prob_loss: 0.1280 - dist_loss: 1.0388 - prob_kld: 0.0424 - dist_relevant_mae: 1.0384 - dist_relevant_mse: 3.0222 - dist_dist_iou_metric: 0.7195 - val_loss: 0.3916 - val_prob_loss: 0.1655 - val_dist_loss: 1.1306 - val_prob_kld: 0.0618 - val_dist_relevant_mae: 1.1303 - val_dist_relevant_mse: 3.3927 - val_dist_dist_iou_metric: 0.7075 - lr: 5.0000e-05
# Epoch 33/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3369 - prob_loss: 0.1301 - dist_loss: 1.0339 - prob_kld: 0.0428 - dist_relevant_mae: 1.0335 - dist_relev
# 100/100 [==============================] - 3s 33ms/step - loss: 0.3369 - prob_loss: 0.1301 - dist_loss: 1.0339 - prob_kld: 0.0428 - dist_relevant_mae: 1.0335 - dist_relevant_mse: 2.9676 - dist_dist_iou_metric: 0.7213 - val_loss: 0.3886 - val_prob_loss: 0.1633 - val_dist_loss: 1.1265 - val_prob_kld: 0.0596 - val_dist_relevant_mae: 1.1262 - val_dist_relevant_mse: 3.3739 - val_dist_dist_iou_metric: 0.7088 - lr: 5.0000e-05
# Epoch 34/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3352 - prob_loss: 0.1278 - dist_loss: 1.0371 - prob_kld: 0.0420 - dist_relevant_mae: 1.0367 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3352 - prob_loss: 0.1277 - dist_loss: 1.0378 - prob_kld: 0.0420 - dist_relevant_mae: 1.0374 - dist_relevant_mse: 3.0135 - dist_dist_iou_metric: 0.7206 - val_loss: 0.3874 - val_prob_loss: 0.1633 - val_dist_loss: 1.1205 - val_prob_kld: 0.0596 - val_dist_relevant_mae: 1.1202 - val_dist_relevant_mse: 3.2913 - val_dist_dist_iou_metric: 0.7088 - lr: 5.0000e-05
# Epoch 35/150
# 100/100 [==============================] - ETA: 0s - loss: 0.3331 - prob_loss: 0.1296 - dist_loss: 1.0177 - prob_kld: 0.0425 - dist_relevant_mae: 1.0174 - dist_relevant_mse: 2.8548 - dist_dist_iou_metric: 0.7243
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 3/3 [==============================] - 0s 2ms/step
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3331 - prob_loss: 0.1296 - dist_loss: 1.0177 - prob_kld: 0.0425 - dist_relevant_mae: 1.0174 - dist_relevant_mse: 2.8548 - dist_dist_iou_metric: 0.7243 - val_loss: 0.3900 - val_prob_loss: 0.1642 - val_dist_loss: 1.1292 - val_prob_kld: 0.0605 - val_dist_relevant_mae: 1.1289 - val_dist_relevant_mse: 3.3770 - val_dist_dist_iou_metric: 0.7098 - lr: 5.0000e-05
# Epoch 36/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3333 - prob_loss: 0.1271 - dist_loss: 1.0309 - prob_kld: 0.0419 - dist_relevant_mae: 1.0306 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3333 - prob_loss: 0.1271 - dist_loss: 1.0309 - prob_kld: 0.0419 - dist_relevant_mae: 1.0306 - dist_relevant_mse: 3.0076 - dist_dist_iou_metric: 0.7205 - val_loss: 0.3837 - val_prob_loss: 0.1622 - val_dist_loss: 1.1075 - val_prob_kld: 0.0585 - val_dist_relevant_mae: 1.1071 - val_dist_relevant_mse: 3.2799 - val_dist_dist_iou_metric: 0.7135 - lr: 2.5000e-05
# Epoch 37/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3344 - prob_loss: 0.1287 - dist_loss: 1.0281 - prob_kld: 0.0421 - dist_relevant_mae: 1.0278 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3344 - prob_loss: 0.1287 - dist_loss: 1.0281 - prob_kld: 0.0421 - dist_relevant_mae: 1.0278 - dist_relevant_mse: 2.9614 - dist_dist_iou_metric: 0.7222 - val_loss: 0.3891 - val_prob_loss: 0.1638 - val_dist_loss: 1.1265 - val_prob_kld: 0.0601 - val_dist_relevant_mae: 1.1262 - val_dist_relevant_mse: 3.3812 - val_dist_dist_iou_metric: 0.7098 - lr: 2.5000e-05
# Epoch 38/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3337 - prob_loss: 0.1278 - dist_loss: 1.0294 - prob_kld: 0.0418 - dist_relevant_mae: 1.0291 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3333 - prob_loss: 0.1275 - dist_loss: 1.0293 - prob_kld: 0.0417 - dist_relevant_mae: 1.0290 - dist_relevant_mse: 2.9697 - dist_dist_iou_metric: 0.7227 - val_loss: 0.3911 - val_prob_loss: 0.1649 - val_dist_loss: 1.1311 - val_prob_kld: 0.0612 - val_dist_relevant_mae: 1.1308 - val_dist_relevant_mse: 3.3704 - val_dist_dist_iou_metric: 0.7076 - lr: 2.5000e-05
# Epoch 39/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3365 - prob_loss: 0.1306 - dist_loss: 1.0292 - prob_kld: 0.0429 - dist_relevant_mae: 1.0288 - dist_relev
# 100/100 [==============================] - 3s 34ms/step - loss: 0.3365 - prob_loss: 0.1306 - dist_loss: 1.0292 - prob_kld: 0.0429 - dist_relevant_mae: 1.0288 - dist_relevant_mse: 2.9618 - dist_dist_iou_metric: 0.7225 - val_loss: 0.3925 - val_prob_loss: 0.1651 - val_dist_loss: 1.1370 - val_prob_kld: 0.0615 - val_dist_relevant_mae: 1.1366 - val_dist_relevant_mse: 3.4436 - val_dist_dist_iou_metric: 0.7067 - lr: 2.5000e-05
# Epoch 40/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3344 - prob_loss: 0.1276 - dist_loss: 1.0342 - prob_kld: 0.0417 - dist_relevant_mae: 1.0339 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3343 - prob_loss: 0.1276 - dist_loss: 1.0333 - prob_kld: 0.0417 - dist_relevant_mae: 1.0330 - dist_relevant_mse: 2.9908 - dist_dist_iou_metric: 0.7226 - val_loss: 0.3899 - val_prob_loss: 0.1646 - val_dist_loss: 1.1265 - val_prob_kld: 0.0609 - val_dist_relevant_mae: 1.1261 - val_dist_relevant_mse: 3.3567 - val_dist_dist_iou_metric: 0.7106 - lr: 2.5000e-05
# Epoch 41/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3339 - prob_loss: 0.1279 - dist_loss: 1.0299 - prob_kld: 0.0418 - dist_relevant_mae: 1.0296 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3339 - prob_loss: 0.1279 - dist_loss: 1.0299 - prob_kld: 0.0418 - dist_relevant_mae: 1.0296 - dist_relevant_mse: 2.9755 - dist_dist_iou_metric: 0.7231 - val_loss: 0.3888 - val_prob_loss: 0.1635 - val_dist_loss: 1.1268 - val_prob_kld: 0.0598 - val_dist_relevant_mae: 1.1265 - val_dist_relevant_mse: 3.3879 - val_dist_dist_iou_metric: 0.7108 - lr: 2.5000e-05
# Epoch 42/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3334 - prob_loss: 0.1288 - dist_loss: 1.0229 - prob_kld: 0.0422 - dist_relevant_mae: 1.0225 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3335 - prob_loss: 0.1288 - dist_loss: 1.0234 - prob_kld: 0.0422 - dist_relevant_mae: 1.0230 - dist_relevant_mse: 2.9112 - dist_dist_iou_metric: 0.7232 - val_loss: 0.3927 - val_prob_loss: 0.1648 - val_dist_loss: 1.1392 - val_prob_kld: 0.0611 - val_dist_relevant_mae: 1.1388 - val_dist_relevant_mse: 3.4244 - val_dist_dist_iou_metric: 0.7068 - lr: 2.5000e-05
# Epoch 43/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3311 - prob_loss: 0.1279 - dist_loss: 1.0161 - prob_kld: 0.0418 - dist_relevant_mae: 1.0158 - dist_relev
# 100/100 [==============================] - 3s 30ms/step - loss: 0.3311 - prob_loss: 0.1279 - dist_loss: 1.0161 - prob_kld: 0.0418 - dist_relevant_mae: 1.0158 - dist_relevant_mse: 2.8967 - dist_dist_iou_metric: 0.7235 - val_loss: 0.3928 - val_prob_loss: 0.1641 - val_dist_loss: 1.1435 - val_prob_kld: 0.0604 - val_dist_relevant_mae: 1.1432 - val_dist_relevant_mse: 3.4220 - val_dist_dist_iou_metric: 0.7061 - lr: 2.5000e-05
# Epoch 44/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3325 - prob_loss: 0.1289 - dist_loss: 1.0180 - prob_kld: 0.0414 - dist_relevant_mae: 1.0176 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3325 - prob_loss: 0.1289 - dist_loss: 1.0180 - prob_kld: 0.0414 - dist_relevant_mae: 1.0176 - dist_relevant_mse: 2.8927 - dist_dist_iou_metric: 0.7256 - val_loss: 0.3882 - val_prob_loss: 0.1641 - val_dist_loss: 1.1204 - val_prob_kld: 0.0605 - val_dist_relevant_mae: 1.1200 - val_dist_relevant_mse: 3.3502 - val_dist_dist_iou_metric: 0.7106 - lr: 2.5000e-05
# Epoch 45/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3309 - prob_loss: 0.1270 - dist_loss: 1.0199 - prob_kld: 0.0413 - dist_relevant_mae: 1.0196 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3310 - prob_loss: 0.1270 - dist_loss: 1.0199 - prob_kld: 0.0413 - dist_relevant_mae: 1.0195 - dist_relevant_mse: 2.9022 - dist_dist_iou_metric: 0.7233 - val_loss: 0.3911 - val_prob_loss: 0.1647 - val_dist_loss: 1.1321 - val_prob_kld: 0.0610 - val_dist_relevant_mae: 1.1318 - val_dist_relevant_mse: 3.4050 - val_dist_dist_iou_metric: 0.7083 - lr: 2.5000e-05
# Epoch 46/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3324 - prob_loss: 0.1288 - dist_loss: 1.0184 - prob_kld: 0.0419 - dist_relevant_mae: 1.0181 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3323 - prob_loss: 0.1285 - dist_loss: 1.0190 - prob_kld: 0.0418 - dist_relevant_mae: 1.0186 - dist_relevant_mse: 2.9074 - dist_dist_iou_metric: 0.7239 - val_loss: 0.3907 - val_prob_loss: 0.1645 - val_dist_loss: 1.1308 - val_prob_kld: 0.0608 - val_dist_relevant_mae: 1.1304 - val_dist_relevant_mse: 3.3704 - val_dist_dist_iou_metric: 0.7080 - lr: 2.5000e-05
# Epoch 47/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3342 - prob_loss: 0.1299 - dist_loss: 1.0216 - prob_kld: 0.0424 - dist_relevant_mae: 1.0212 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3342 - prob_loss: 0.1299 - dist_loss: 1.0216 - prob_kld: 0.0424 - dist_relevant_mae: 1.0212 - dist_relevant_mse: 2.9131 - dist_dist_iou_metric: 0.7249 - val_loss: 0.3913 - val_prob_loss: 0.1645 - val_dist_loss: 1.1340 - val_prob_kld: 0.0608 - val_dist_relevant_mae: 1.1336 - val_dist_relevant_mse: 3.3899 - val_dist_dist_iou_metric: 0.7077 - lr: 2.5000e-05
# Epoch 48/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3327 - prob_loss: 0.1289 - dist_loss: 1.0190 - prob_kld: 0.0418 - dist_relevant_mae: 1.0186 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3327 - prob_loss: 0.1289 - dist_loss: 1.0190 - prob_kld: 0.0418 - dist_relevant_mae: 1.0186 - dist_relevant_mse: 2.8869 - dist_dist_iou_metric: 0.7241 - val_loss: 0.3917 - val_prob_loss: 0.1654 - val_dist_loss: 1.1317 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1313 - val_dist_relevant_mse: 3.4091 - val_dist_dist_iou_metric: 0.7078 - lr: 2.5000e-05
# Epoch 49/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3343 - prob_loss: 0.1292 - dist_loss: 1.0256 - prob_kld: 0.0421 - dist_relevant_mae: 1.0252 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3343 - prob_loss: 0.1292 - dist_loss: 1.0256 - prob_kld: 0.0421 - dist_relevant_mae: 1.0252 - dist_relevant_mse: 2.9301 - dist_dist_iou_metric: 0.7234 - val_loss: 0.3906 - val_prob_loss: 0.1650 - val_dist_loss: 1.1278 - val_prob_kld: 0.0613 - val_dist_relevant_mae: 1.1275 - val_dist_relevant_mse: 3.3925 - val_dist_dist_iou_metric: 0.7078 - lr: 2.5000e-05
# Epoch 50/150
# 100/100 [==============================] - ETA: 0s - loss: 0.3309 - prob_loss: 0.1298 - dist_loss: 1.0058 - prob_kld: 0.0418 - dist_relevant_mae: 1.0054 - dist_relevant_mse: 2.8117 - dist_dist_iou_metric: 0.7264
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 3/3 [==============================] - 0s 3ms/step
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3309 - prob_loss: 0.1298 - dist_loss: 1.0058 - prob_kld: 0.0418 - dist_relevant_mae: 1.0054 - dist_relevant_mse: 2.8117 - dist_dist_iou_metric: 0.7264 - val_loss: 0.3874 - val_prob_loss: 0.1641 - val_dist_loss: 1.1165 - val_prob_kld: 0.0604 - val_dist_relevant_mae: 1.1162 - val_dist_relevant_mse: 3.3544 - val_dist_dist_iou_metric: 0.7108 - lr: 2.5000e-05
# Epoch 51/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3322 - prob_loss: 0.1287 - dist_loss: 1.0176 - prob_kld: 0.0413 - dist_relevant_mae: 1.0173 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3323 - prob_loss: 0.1289 - dist_loss: 1.0173 - prob_kld: 0.0414 - dist_relevant_mae: 1.0170 - dist_relevant_mse: 2.8817 - dist_dist_iou_metric: 0.7257 - val_loss: 0.3895 - val_prob_loss: 0.1641 - val_dist_loss: 1.1270 - val_prob_kld: 0.0604 - val_dist_relevant_mae: 1.1267 - val_dist_relevant_mse: 3.3688 - val_dist_dist_iou_metric: 0.7092 - lr: 1.2500e-05
# Epoch 52/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3274 - prob_loss: 0.1266 - dist_loss: 1.0044 - prob_kld: 0.0412 - dist_relevant_mae: 1.0040 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3271 - prob_loss: 0.1265 - dist_loss: 1.0028 - prob_kld: 0.0411 - dist_relevant_mae: 1.0024 - dist_relevant_mse: 2.7909 - dist_dist_iou_metric: 0.7262 - val_loss: 0.3894 - val_prob_loss: 0.1642 - val_dist_loss: 1.1262 - val_prob_kld: 0.0605 - val_dist_relevant_mae: 1.1258 - val_dist_relevant_mse: 3.3763 - val_dist_dist_iou_metric: 0.7098 - lr: 1.2500e-05
# Epoch 53/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3320 - prob_loss: 0.1286 - dist_loss: 1.0173 - prob_kld: 0.0416 - dist_relevant_mae: 1.0170 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3320 - prob_loss: 0.1286 - dist_loss: 1.0173 - prob_kld: 0.0416 - dist_relevant_mae: 1.0170 - dist_relevant_mse: 2.8706 - dist_dist_iou_metric: 0.7261 - val_loss: 0.3888 - val_prob_loss: 0.1646 - val_dist_loss: 1.1212 - val_prob_kld: 0.0609 - val_dist_relevant_mae: 1.1209 - val_dist_relevant_mse: 3.3596 - val_dist_dist_iou_metric: 0.7100 - lr: 1.2500e-05
# Epoch 54/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3299 - prob_loss: 0.1270 - dist_loss: 1.0144 - prob_kld: 0.0413 - dist_relevant_mae: 1.0140 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3298 - prob_loss: 0.1273 - dist_loss: 1.0126 - prob_kld: 0.0414 - dist_relevant_mae: 1.0123 - dist_relevant_mse: 2.8414 - dist_dist_iou_metric: 0.7251 - val_loss: 0.3904 - val_prob_loss: 0.1646 - val_dist_loss: 1.1290 - val_prob_kld: 0.0609 - val_dist_relevant_mae: 1.1287 - val_dist_relevant_mse: 3.3747 - val_dist_dist_iou_metric: 0.7081 - lr: 1.2500e-05
# Epoch 55/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3311 - prob_loss: 0.1280 - dist_loss: 1.0156 - prob_kld: 0.0414 - dist_relevant_mae: 1.0153 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3311 - prob_loss: 0.1280 - dist_loss: 1.0156 - prob_kld: 0.0414 - dist_relevant_mae: 1.0153 - dist_relevant_mse: 2.8950 - dist_dist_iou_metric: 0.7257 - val_loss: 0.3919 - val_prob_loss: 0.1650 - val_dist_loss: 1.1341 - val_prob_kld: 0.0613 - val_dist_relevant_mae: 1.1338 - val_dist_relevant_mse: 3.4101 - val_dist_dist_iou_metric: 0.7078 - lr: 1.2500e-05
# Epoch 56/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3328 - prob_loss: 0.1294 - dist_loss: 1.0169 - prob_kld: 0.0416 - dist_relevant_mae: 1.0166 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3328 - prob_loss: 0.1294 - dist_loss: 1.0169 - prob_kld: 0.0416 - dist_relevant_mae: 1.0166 - dist_relevant_mse: 2.8976 - dist_dist_iou_metric: 0.7260 - val_loss: 0.3895 - val_prob_loss: 0.1638 - val_dist_loss: 1.1285 - val_prob_kld: 0.0601 - val_dist_relevant_mae: 1.1281 - val_dist_relevant_mse: 3.3798 - val_dist_dist_iou_metric: 0.7080 - lr: 1.2500e-05
# Epoch 57/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3331 - prob_loss: 0.1300 - dist_loss: 1.0154 - prob_kld: 0.0421 - dist_relevant_mae: 1.0151 - dist_relev
# 100/100 [==============================] - 3s 34ms/step - loss: 0.3330 - prob_loss: 0.1301 - dist_loss: 1.0141 - prob_kld: 0.0422 - dist_relevant_mae: 1.0138 - dist_relevant_mse: 2.8599 - dist_dist_iou_metric: 0.7252 - val_loss: 0.3916 - val_prob_loss: 0.1645 - val_dist_loss: 1.1351 - val_prob_kld: 0.0609 - val_dist_relevant_mae: 1.1347 - val_dist_relevant_mse: 3.4196 - val_dist_dist_iou_metric: 0.7069 - lr: 1.2500e-05
# Epoch 58/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3303 - prob_loss: 0.1275 - dist_loss: 1.0141 - prob_kld: 0.0413 - dist_relevant_mae: 1.0138 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3303 - prob_loss: 0.1275 - dist_loss: 1.0141 - prob_kld: 0.0413 - dist_relevant_mae: 1.0138 - dist_relevant_mse: 2.8588 - dist_dist_iou_metric: 0.7262 - val_loss: 0.3907 - val_prob_loss: 0.1645 - val_dist_loss: 1.1311 - val_prob_kld: 0.0608 - val_dist_relevant_mae: 1.1307 - val_dist_relevant_mse: 3.3891 - val_dist_dist_iou_metric: 0.7080 - lr: 1.2500e-05
# Epoch 59/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3321 - prob_loss: 0.1279 - dist_loss: 1.0207 - prob_kld: 0.0416 - dist_relevant_mae: 1.0204 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3321 - prob_loss: 0.1279 - dist_loss: 1.0207 - prob_kld: 0.0416 - dist_relevant_mae: 1.0204 - dist_relevant_mse: 2.9147 - dist_dist_iou_metric: 0.7250 - val_loss: 0.3904 - val_prob_loss: 0.1644 - val_dist_loss: 1.1300 - val_prob_kld: 0.0607 - val_dist_relevant_mae: 1.1297 - val_dist_relevant_mse: 3.3893 - val_dist_dist_iou_metric: 0.7081 - lr: 1.2500e-05
# Epoch 60/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3300 - prob_loss: 0.1275 - dist_loss: 1.0126 - prob_kld: 0.0413 - dist_relevant_mae: 1.0123 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3300 - prob_loss: 0.1275 - dist_loss: 1.0126 - prob_kld: 0.0413 - dist_relevant_mae: 1.0123 - dist_relevant_mse: 2.8556 - dist_dist_iou_metric: 0.7253 - val_loss: 0.3911 - val_prob_loss: 0.1643 - val_dist_loss: 1.1340 - val_prob_kld: 0.0607 - val_dist_relevant_mae: 1.1337 - val_dist_relevant_mse: 3.3862 - val_dist_dist_iou_metric: 0.7068 - lr: 1.2500e-05
# Epoch 61/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3314 - prob_loss: 0.1269 - dist_loss: 1.0223 - prob_kld: 0.0410 - dist_relevant_mae: 1.0220 - dist_relev
# 100/100 [==============================] - 3s 35ms/step - loss: 0.3314 - prob_loss: 0.1271 - dist_loss: 1.0219 - prob_kld: 0.0411 - dist_relevant_mae: 1.0216 - dist_relevant_mse: 2.9416 - dist_dist_iou_metric: 0.7233 - val_loss: 0.3918 - val_prob_loss: 0.1648 - val_dist_loss: 1.1349 - val_prob_kld: 0.0612 - val_dist_relevant_mae: 1.1346 - val_dist_relevant_mse: 3.4428 - val_dist_dist_iou_metric: 0.7081 - lr: 1.2500e-05
# Epoch 62/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3286 - prob_loss: 0.1281 - dist_loss: 1.0023 - prob_kld: 0.0411 - dist_relevant_mae: 1.0020 - dist_relev
# 100/100 [==============================] - 3s 34ms/step - loss: 0.3286 - prob_loss: 0.1281 - dist_loss: 1.0023 - prob_kld: 0.0411 - dist_relevant_mae: 1.0020 - dist_relevant_mse: 2.7797 - dist_dist_iou_metric: 0.7274 - val_loss: 0.3894 - val_prob_loss: 0.1649 - val_dist_loss: 1.1225 - val_prob_kld: 0.0612 - val_dist_relevant_mae: 1.1222 - val_dist_relevant_mse: 3.3673 - val_dist_dist_iou_metric: 0.7102 - lr: 1.2500e-05
# Epoch 63/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3285 - prob_loss: 0.1271 - dist_loss: 1.0072 - prob_kld: 0.0408 - dist_relevant_mae: 1.0068 - dist_relev
# 100/100 [==============================] - 3s 30ms/step - loss: 0.3284 - prob_loss: 0.1272 - dist_loss: 1.0061 - prob_kld: 0.0408 - dist_relevant_mae: 1.0057 - dist_relevant_mse: 2.7973 - dist_dist_iou_metric: 0.7281 - val_loss: 0.3903 - val_prob_loss: 0.1645 - val_dist_loss: 1.1291 - val_prob_kld: 0.0608 - val_dist_relevant_mae: 1.1287 - val_dist_relevant_mse: 3.3986 - val_dist_dist_iou_metric: 0.7094 - lr: 1.2500e-05
# Epoch 64/150
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3294 - prob_loss: 0.1271 - dist_loss: 1.0115 - prob_kld: 0.0411 - dist_relevant_mae: 1.0112 - dist_relev
# 100/100 [==============================] - 3s 30ms/step - loss: 0.3294 - prob_loss: 0.1273 - dist_loss: 1.0102 - prob_kld: 0.0412 - dist_relevant_mae: 1.0099 - dist_relevant_mse: 2.8242 - dist_dist_iou_metric: 0.7266 - val_loss: 0.3908 - val_prob_loss: 0.1652 - val_dist_loss: 1.1280 - val_prob_kld: 0.0615 - val_dist_relevant_mae: 1.1277 - val_dist_relevant_mse: 3.3828 - val_dist_dist_iou_metric: 0.7087 - lr: 1.2500e-05
# Epoch 65/150
#  99/100 [============================>.] - ETA: 0s - loss: 0.3293 - prob_loss: 0.1279 - dist_loss: 1.0071 - prob_kld: 0.0412 - dist_relevant_mae: 1.0068 - dist_relevant_mse: 2.8173 - dist_dist_iou_metric: 0.7265
# Epoch 65: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 3/3 [==============================] - 0s 2ms/step
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3293 - prob_loss: 0.1277 - dist_loss: 1.0080 - prob_kld: 0.0412 - dist_relevant_mae: 1.0077 - dist_relevant_mse: 2.8222 - dist_dist_iou_metric: 0.7263 - val_loss: 0.3909 - val_prob_loss: 0.1653 - val_dist_loss: 1.1284 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1280 - val_dist_relevant_mse: 3.4055 - val_dist_dist_iou_metric: 0.7090 - lr: 1.2500e-05
# Epoch 66/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3287 - prob_loss: 0.1262 - dist_loss: 1.0126 - prob_kld: 0.0407 - dist_relevant_mae: 1.0123 - dist_relev
# 100/100 [==============================] - 3s 34ms/step - loss: 0.3285 - prob_loss: 0.1264 - dist_loss: 1.0106 - prob_kld: 0.0407 - dist_relevant_mae: 1.0103 - dist_relevant_mse: 2.8431 - dist_dist_iou_metric: 0.7266 - val_loss: 0.3924 - val_prob_loss: 0.1654 - val_dist_loss: 1.1351 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1347 - val_dist_relevant_mse: 3.4270 - val_dist_dist_iou_metric: 0.7072 - lr: 6.2500e-06
# Epoch 67/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3295 - prob_loss: 0.1269 - dist_loss: 1.0128 - prob_kld: 0.0410 - dist_relevant_mae: 1.0124 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3295 - prob_loss: 0.1269 - dist_loss: 1.0128 - prob_kld: 0.0410 - dist_relevant_mae: 1.0124 - dist_relevant_mse: 2.8648 - dist_dist_iou_metric: 0.7259 - val_loss: 0.3920 - val_prob_loss: 0.1650 - val_dist_loss: 1.1348 - val_prob_kld: 0.0613 - val_dist_relevant_mae: 1.1344 - val_dist_relevant_mse: 3.4256 - val_dist_dist_iou_metric: 0.7076 - lr: 6.2500e-06
# Epoch 68/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3310 - prob_loss: 0.1278 - dist_loss: 1.0160 - prob_kld: 0.0415 - dist_relevant_mae: 1.0157 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3310 - prob_loss: 0.1278 - dist_loss: 1.0160 - prob_kld: 0.0415 - dist_relevant_mae: 1.0157 - dist_relevant_mse: 2.8719 - dist_dist_iou_metric: 0.7253 - val_loss: 0.3910 - val_prob_loss: 0.1648 - val_dist_loss: 1.1312 - val_prob_kld: 0.0611 - val_dist_relevant_mae: 1.1309 - val_dist_relevant_mse: 3.4122 - val_dist_dist_iou_metric: 0.7089 - lr: 6.2500e-06
# Epoch 69/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3302 - prob_loss: 0.1293 - dist_loss: 1.0042 - prob_kld: 0.0420 - dist_relevant_mae: 1.0038 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3300 - prob_loss: 0.1294 - dist_loss: 1.0027 - prob_kld: 0.0421 - dist_relevant_mae: 1.0024 - dist_relevant_mse: 2.7684 - dist_dist_iou_metric: 0.7277 - val_loss: 0.3901 - val_prob_loss: 0.1646 - val_dist_loss: 1.1278 - val_prob_kld: 0.0609 - val_dist_relevant_mae: 1.1275 - val_dist_relevant_mse: 3.3930 - val_dist_dist_iou_metric: 0.7083 - lr: 6.2500e-06
# Epoch 70/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3286 - prob_loss: 0.1263 - dist_loss: 1.0120 - prob_kld: 0.0410 - dist_relevant_mae: 1.0116 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3286 - prob_loss: 0.1263 - dist_loss: 1.0120 - prob_kld: 0.0410 - dist_relevant_mae: 1.0116 - dist_relevant_mse: 2.8665 - dist_dist_iou_metric: 0.7257 - val_loss: 0.3918 - val_prob_loss: 0.1651 - val_dist_loss: 1.1337 - val_prob_kld: 0.0614 - val_dist_relevant_mae: 1.1334 - val_dist_relevant_mse: 3.4170 - val_dist_dist_iou_metric: 0.7079 - lr: 6.2500e-06
# Epoch 71/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3317 - prob_loss: 0.1301 - dist_loss: 1.0080 - prob_kld: 0.0419 - dist_relevant_mae: 1.0077 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3317 - prob_loss: 0.1301 - dist_loss: 1.0080 - prob_kld: 0.0419 - dist_relevant_mae: 1.0077 - dist_relevant_mse: 2.8267 - dist_dist_iou_metric: 0.7264 - val_loss: 0.3916 - val_prob_loss: 0.1652 - val_dist_loss: 1.1321 - val_prob_kld: 0.0615 - val_dist_relevant_mae: 1.1317 - val_dist_relevant_mse: 3.4155 - val_dist_dist_iou_metric: 0.7076 - lr: 6.2500e-06
# Epoch 72/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3290 - prob_loss: 0.1289 - dist_loss: 1.0009 - prob_kld: 0.0417 - dist_relevant_mae: 1.0005 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3293 - prob_loss: 0.1291 - dist_loss: 1.0011 - prob_kld: 0.0418 - dist_relevant_mae: 1.0007 - dist_relevant_mse: 2.7761 - dist_dist_iou_metric: 0.7271 - val_loss: 0.3913 - val_prob_loss: 0.1648 - val_dist_loss: 1.1327 - val_prob_kld: 0.0611 - val_dist_relevant_mae: 1.1324 - val_dist_relevant_mse: 3.4254 - val_dist_dist_iou_metric: 0.7088 - lr: 6.2500e-06
# Epoch 73/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3272 - prob_loss: 0.1276 - dist_loss: 0.9980 - prob_kld: 0.0412 - dist_relevant_mae: 0.9977 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3272 - prob_loss: 0.1276 - dist_loss: 0.9980 - prob_kld: 0.0412 - dist_relevant_mae: 0.9977 - dist_relevant_mse: 2.7619 - dist_dist_iou_metric: 0.7270 - val_loss: 0.3908 - val_prob_loss: 0.1652 - val_dist_loss: 1.1283 - val_prob_kld: 0.0615 - val_dist_relevant_mae: 1.1280 - val_dist_relevant_mse: 3.4024 - val_dist_dist_iou_metric: 0.7086 - lr: 6.2500e-06
# Epoch 74/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3292 - prob_loss: 0.1283 - dist_loss: 1.0046 - prob_kld: 0.0413 - dist_relevant_mae: 1.0043 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3293 - prob_loss: 0.1283 - dist_loss: 1.0049 - prob_kld: 0.0413 - dist_relevant_mae: 1.0046 - dist_relevant_mse: 2.8189 - dist_dist_iou_metric: 0.7259 - val_loss: 0.3935 - val_prob_loss: 0.1657 - val_dist_loss: 1.1391 - val_prob_kld: 0.0620 - val_dist_relevant_mae: 1.1387 - val_dist_relevant_mse: 3.4425 - val_dist_dist_iou_metric: 0.7059 - lr: 6.2500e-06
# Epoch 75/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3295 - prob_loss: 0.1279 - dist_loss: 1.0081 - prob_kld: 0.0416 - dist_relevant_mae: 1.0077 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3297 - prob_loss: 0.1281 - dist_loss: 1.0077 - prob_kld: 0.0417 - dist_relevant_mae: 1.0074 - dist_relevant_mse: 2.8519 - dist_dist_iou_metric: 0.7250 - val_loss: 0.3920 - val_prob_loss: 0.1653 - val_dist_loss: 1.1338 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1335 - val_dist_relevant_mse: 3.4232 - val_dist_dist_iou_metric: 0.7078 - lr: 6.2500e-06
# Epoch 76/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3289 - prob_loss: 0.1286 - dist_loss: 1.0018 - prob_kld: 0.0412 - dist_relevant_mae: 1.0014 - dist_relev
# ...
# Epoch 127/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3259 - prob_loss: 0.1273 - dist_loss: 0.9926 - prob_kld: 0.0407 - dist_relevant_mae: 0.9923 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3259 - prob_loss: 0.1273 - dist_loss: 0.9926 - prob_kld: 0.0407 - dist_relevant_mae: 0.9923 - dist_relevant_mse: 2.7196 - dist_dist_iou_metric: 0.7297 - val_loss: 0.3914 - val_prob_loss: 0.1652 - val_dist_loss: 1.1311 - val_prob_kld: 0.0615 - val_dist_relevant_mae: 1.1307 - val_dist_relevant_mse: 3.4102 - val_dist_dist_iou_metric: 0.7083 - lr: 3.9062e-07
# Epoch 128/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3285 - prob_loss: 0.1296 - dist_loss: 0.9949 - prob_kld: 0.0414 - dist_relevant_mae: 0.9946 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3285 - prob_loss: 0.1296 - dist_loss: 0.9949 - prob_kld: 0.0414 - dist_relevant_mae: 0.9946 - dist_relevant_mse: 2.7486 - dist_dist_iou_metric: 0.7287 - val_loss: 0.3916 - val_prob_loss: 0.1653 - val_dist_loss: 1.1311 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1308 - val_dist_relevant_mse: 3.4107 - val_dist_dist_iou_metric: 0.7082 - lr: 3.9062e-07
# Epoch 129/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3297 - prob_loss: 0.1288 - dist_loss: 1.0041 - prob_kld: 0.0413 - dist_relevant_mae: 1.0037 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3295 - prob_loss: 0.1287 - dist_loss: 1.0041 - prob_kld: 0.0413 - dist_relevant_mae: 1.0038 - dist_relevant_mse: 2.8063 - dist_dist_iou_metric: 0.7283 - val_loss: 0.3915 - val_prob_loss: 0.1654 - val_dist_loss: 1.1307 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1304 - val_dist_relevant_mse: 3.4113 - val_dist_dist_iou_metric: 0.7083 - lr: 3.9062e-07
# Epoch 130/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3263 - prob_loss: 0.1273 - dist_loss: 0.9947 - prob_kld: 0.0407 - dist_relevant_mae: 0.9943 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3263 - prob_loss: 0.1273 - dist_loss: 0.9947 - prob_kld: 0.0407 - dist_relevant_mae: 0.9943 - dist_relevant_mse: 2.7409 - dist_dist_iou_metric: 0.7281 - val_loss: 0.3915 - val_prob_loss: 0.1654 - val_dist_loss: 1.1308 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1305 - val_dist_relevant_mse: 3.4107 - val_dist_dist_iou_metric: 0.7083 - lr: 3.9062e-07
# Epoch 131/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3274 - prob_loss: 0.1272 - dist_loss: 1.0008 - prob_kld: 0.0407 - dist_relevant_mae: 1.0005 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3274 - prob_loss: 0.1272 - dist_loss: 1.0008 - prob_kld: 0.0407 - dist_relevant_mae: 1.0005 - dist_relevant_mse: 2.7690 - dist_dist_iou_metric: 0.7277 - val_loss: 0.3916 - val_prob_loss: 0.1653 - val_dist_loss: 1.1315 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1312 - val_dist_relevant_mse: 3.4131 - val_dist_dist_iou_metric: 0.7082 - lr: 3.9062e-07
# Epoch 132/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3304 - prob_loss: 0.1289 - dist_loss: 1.0072 - prob_kld: 0.0415 - dist_relevant_mae: 1.0069 - dist_relev
# 100/100 [==============================] - 3s 30ms/step - loss: 0.3304 - prob_loss: 0.1289 - dist_loss: 1.0072 - prob_kld: 0.0415 - dist_relevant_mae: 1.0069 - dist_relevant_mse: 2.8352 - dist_dist_iou_metric: 0.7266 - val_loss: 0.3914 - val_prob_loss: 0.1652 - val_dist_loss: 1.1308 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1305 - val_dist_relevant_mse: 3.4092 - val_dist_dist_iou_metric: 0.7083 - lr: 3.9062e-07
# Epoch 133/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3288 - prob_loss: 0.1279 - dist_loss: 1.0044 - prob_kld: 0.0411 - dist_relevant_mae: 1.0040 - dist_relev
# 100/100 [==============================] - 3s 30ms/step - loss: 0.3288 - prob_loss: 0.1279 - dist_loss: 1.0044 - prob_kld: 0.0411 - dist_relevant_mae: 1.0040 - dist_relevant_mse: 2.7909 - dist_dist_iou_metric: 0.7274 - val_loss: 0.3916 - val_prob_loss: 0.1653 - val_dist_loss: 1.1314 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1311 - val_dist_relevant_mse: 3.4118 - val_dist_dist_iou_metric: 0.7083 - lr: 3.9062e-07
# Epoch 134/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3253 - prob_loss: 0.1258 - dist_loss: 0.9972 - prob_kld: 0.0406 - dist_relevant_mae: 0.9969 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3254 - prob_loss: 0.1261 - dist_loss: 0.9965 - prob_kld: 0.0406 - dist_relevant_mae: 0.9961 - dist_relevant_mse: 2.7406 - dist_dist_iou_metric: 0.7286 - val_loss: 0.3914 - val_prob_loss: 0.1652 - val_dist_loss: 1.1309 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1306 - val_dist_relevant_mse: 3.4088 - val_dist_dist_iou_metric: 0.7083 - lr: 3.9062e-07
# Epoch 135/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3266 - prob_loss: 0.1253 - dist_loss: 1.0065 - prob_kld: 0.0404 - dist_relevant_mae: 1.0062 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3266 - prob_loss: 0.1253 - dist_loss: 1.0065 - prob_kld: 0.0404 - dist_relevant_mae: 1.0062 - dist_relevant_mse: 2.8255 - dist_dist_iou_metric: 0.7260 - val_loss: 0.3917 - val_prob_loss: 0.1654 - val_dist_loss: 1.1317 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1314 - val_dist_relevant_mse: 3.4131 - val_dist_dist_iou_metric: 0.7082 - lr: 3.9062e-07
# Epoch 136/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3291 - prob_loss: 0.1281 - dist_loss: 1.0052 - prob_kld: 0.0409 - dist_relevant_mae: 1.0048 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3292 - prob_loss: 0.1279 - dist_loss: 1.0062 - prob_kld: 0.0409 - dist_relevant_mae: 1.0059 - dist_relevant_mse: 2.8254 - dist_dist_iou_metric: 0.7273 - val_loss: 0.3917 - val_prob_loss: 0.1654 - val_dist_loss: 1.1313 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1310 - val_dist_relevant_mse: 3.4110 - val_dist_dist_iou_metric: 0.7082 - lr: 3.9062e-07
# Epoch 137/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3280 - prob_loss: 0.1278 - dist_loss: 1.0007 - prob_kld: 0.0410 - dist_relevant_mae: 1.0003 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3282 - prob_loss: 0.1280 - dist_loss: 1.0012 - prob_kld: 0.0410 - dist_relevant_mae: 1.0008 - dist_relevant_mse: 2.7979 - dist_dist_iou_metric: 0.7271 - val_loss: 0.3915 - val_prob_loss: 0.1653 - val_dist_loss: 1.1307 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1304 - val_dist_relevant_mse: 3.4079 - val_dist_dist_iou_metric: 0.7083 - lr: 3.9062e-07
# Epoch 138/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3279 - prob_loss: 0.1280 - dist_loss: 0.9994 - prob_kld: 0.0408 - dist_relevant_mae: 0.9991 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3281 - prob_loss: 0.1282 - dist_loss: 0.9992 - prob_kld: 0.0409 - dist_relevant_mae: 0.9989 - dist_relevant_mse: 2.7621 - dist_dist_iou_metric: 0.7279 - val_loss: 0.3914 - val_prob_loss: 0.1653 - val_dist_loss: 1.1305 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1302 - val_dist_relevant_mse: 3.4066 - val_dist_dist_iou_metric: 0.7083 - lr: 3.9062e-07
# Epoch 139/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3281 - prob_loss: 0.1298 - dist_loss: 0.9916 - prob_kld: 0.0413 - dist_relevant_mae: 0.9913 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3280 - prob_loss: 0.1297 - dist_loss: 0.9916 - prob_kld: 0.0413 - dist_relevant_mae: 0.9913 - dist_relevant_mse: 2.7015 - dist_dist_iou_metric: 0.7291 - val_loss: 0.3916 - val_prob_loss: 0.1654 - val_dist_loss: 1.1314 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1311 - val_dist_relevant_mse: 3.4095 - val_dist_dist_iou_metric: 0.7080 - lr: 3.9062e-07
# Epoch 140/150
#  99/100 [============================>.] - ETA: 0s - loss: 0.3283 - prob_loss: 0.1269 - dist_loss: 1.0070 - prob_kld: 0.0404 - dist_relevant_mae: 1.0067 - dist_relevant_mse: 2.8176 - dist_dist_iou_metric: 0.7280
# Epoch 140: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 3/3 [==============================] - 0s 3ms/step
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3281 - prob_loss: 0.1271 - dist_loss: 1.0050 - prob_kld: 0.0405 - dist_relevant_mae: 1.0047 - dist_relevant_mse: 2.8063 - dist_dist_iou_metric: 0.7283 - val_loss: 0.3914 - val_prob_loss: 0.1653 - val_dist_loss: 1.1303 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1300 - val_dist_relevant_mse: 3.4053 - val_dist_dist_iou_metric: 0.7085 - lr: 3.9062e-07
# Epoch 141/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3262 - prob_loss: 0.1269 - dist_loss: 0.9964 - prob_kld: 0.0407 - dist_relevant_mae: 0.9961 - dist_relev
# 100/100 [==============================] - 3s 30ms/step - loss: 0.3260 - prob_loss: 0.1268 - dist_loss: 0.9958 - prob_kld: 0.0407 - dist_relevant_mae: 0.9955 - dist_relevant_mse: 2.7488 - dist_dist_iou_metric: 0.7280 - val_loss: 0.3914 - val_prob_loss: 0.1653 - val_dist_loss: 1.1304 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1301 - val_dist_relevant_mse: 3.4053 - val_dist_dist_iou_metric: 0.7084 - lr: 1.9531e-07
# Epoch 142/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3277 - prob_loss: 0.1271 - dist_loss: 1.0030 - prob_kld: 0.0410 - dist_relevant_mae: 1.0026 - dist_relev
# 100/100 [==============================] - 3s 30ms/step - loss: 0.3277 - prob_loss: 0.1271 - dist_loss: 1.0030 - prob_kld: 0.0410 - dist_relevant_mae: 1.0026 - dist_relevant_mse: 2.8186 - dist_dist_iou_metric: 0.7273 - val_loss: 0.3915 - val_prob_loss: 0.1653 - val_dist_loss: 1.1308 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1305 - val_dist_relevant_mse: 3.4069 - val_dist_dist_iou_metric: 0.7083 - lr: 1.9531e-07
# Epoch 143/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3286 - prob_loss: 0.1275 - dist_loss: 1.0055 - prob_kld: 0.0409 - dist_relevant_mae: 1.0052 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3286 - prob_loss: 0.1275 - dist_loss: 1.0055 - prob_kld: 0.0409 - dist_relevant_mae: 1.0052 - dist_relevant_mse: 2.8046 - dist_dist_iou_metric: 0.7271 - val_loss: 0.3915 - val_prob_loss: 0.1653 - val_dist_loss: 1.1310 - val_prob_kld: 0.0616 - val_dist_relevant_mae: 1.1307 - val_dist_relevant_mse: 3.4077 - val_dist_dist_iou_metric: 0.7082 - lr: 1.9531e-07
# Epoch 144/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3230 - prob_loss: 0.1242 - dist_loss: 0.9936 - prob_kld: 0.0402 - dist_relevant_mae: 0.9933 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3227 - prob_loss: 0.1241 - dist_loss: 0.9929 - prob_kld: 0.0401 - dist_relevant_mae: 0.9926 - dist_relevant_mse: 2.7256 - dist_dist_iou_metric: 0.7275 - val_loss: 0.3916 - val_prob_loss: 0.1654 - val_dist_loss: 1.1313 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1310 - val_dist_relevant_mse: 3.4102 - val_dist_dist_iou_metric: 0.7082 - lr: 1.9531e-07
# Epoch 145/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3281 - prob_loss: 0.1282 - dist_loss: 0.9998 - prob_kld: 0.0413 - dist_relevant_mae: 0.9995 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3281 - prob_loss: 0.1282 - dist_loss: 0.9998 - prob_kld: 0.0413 - dist_relevant_mae: 0.9995 - dist_relevant_mse: 2.7665 - dist_dist_iou_metric: 0.7274 - val_loss: 0.3916 - val_prob_loss: 0.1654 - val_dist_loss: 1.1313 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1310 - val_dist_relevant_mse: 3.4103 - val_dist_dist_iou_metric: 0.7082 - lr: 1.9531e-07
# Epoch 146/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3290 - prob_loss: 0.1282 - dist_loss: 1.0043 - prob_kld: 0.0409 - dist_relevant_mae: 1.0039 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3291 - prob_loss: 0.1284 - dist_loss: 1.0032 - prob_kld: 0.0409 - dist_relevant_mae: 1.0029 - dist_relevant_mse: 2.7785 - dist_dist_iou_metric: 0.7285 - val_loss: 0.3917 - val_prob_loss: 0.1654 - val_dist_loss: 1.1313 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1310 - val_dist_relevant_mse: 3.4104 - val_dist_dist_iou_metric: 0.7082 - lr: 1.9531e-07
# Epoch 147/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3274 - prob_loss: 0.1276 - dist_loss: 0.9990 - prob_kld: 0.0406 - dist_relevant_mae: 0.9987 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3274 - prob_loss: 0.1276 - dist_loss: 0.9990 - prob_kld: 0.0406 - dist_relevant_mae: 0.9987 - dist_relevant_mse: 2.7805 - dist_dist_iou_metric: 0.7279 - val_loss: 0.3915 - val_prob_loss: 0.1654 - val_dist_loss: 1.1308 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1304 - val_dist_relevant_mse: 3.4090 - val_dist_dist_iou_metric: 0.7084 - lr: 1.9531e-07
# Epoch 148/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3258 - prob_loss: 0.1263 - dist_loss: 0.9975 - prob_kld: 0.0404 - dist_relevant_mae: 0.9972 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3263 - prob_loss: 0.1266 - dist_loss: 0.9988 - prob_kld: 0.0405 - dist_relevant_mae: 0.9984 - dist_relevant_mse: 2.7511 - dist_dist_iou_metric: 0.7289 - val_loss: 0.3917 - val_prob_loss: 0.1655 - val_dist_loss: 1.1312 - val_prob_kld: 0.0618 - val_dist_relevant_mae: 1.1309 - val_dist_relevant_mse: 3.4115 - val_dist_dist_iou_metric: 0.7083 - lr: 1.9531e-07
# Epoch 149/150
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3262 - prob_loss: 0.1287 - dist_loss: 0.9871 - prob_kld: 0.0409 - dist_relevant_mae: 0.9868 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3263 - prob_loss: 0.1285 - dist_loss: 0.9887 - prob_kld: 0.0408 - dist_relevant_mae: 0.9883 - dist_relevant_mse: 2.7344 - dist_dist_iou_metric: 0.7300 - val_loss: 0.3917 - val_prob_loss: 0.1655 - val_dist_loss: 1.1313 - val_prob_kld: 0.0618 - val_dist_relevant_mae: 1.1309 - val_dist_relevant_mse: 3.4116 - val_dist_dist_iou_metric: 0.7083 - lr: 1.9531e-07
# Epoch 150/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3291 - prob_loss: 0.1277 - dist_loss: 1.0072 - prob_kld: 0.0412 - dist_relevant_mae: 1.0069 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3293 - prob_loss: 0.1278 - dist_loss: 1.0073 - prob_kld: 0.0412 - dist_relevant_mae: 1.0069 - dist_relevant_mse: 2.8487 - dist_dist_iou_metric: 0.7268 - val_loss: 0.3917 - val_prob_loss: 0.1654 - val_dist_loss: 1.1313 - val_prob_kld: 0.0617 - val_dist_relevant_mae: 1.1310 - val_dist_relevant_mse: 3.4107 - val_dist_dist_iou_metric: 0.7082 - lr: 1.9531e-07
#
# Loading network weights from 'weights_best.h5'.
# NMS threshold = 0.3:  80%|████████  | 16/20 [00:07<00:01,  2.08it/s, 0.486 -> 0.691]
# NMS threshold = 0.4:  80%|████████  | 16/20 [00:07<00:01,  2.11it/s, 0.508 -> 0.688]
# NMS threshold = 0.5:  80%|████████  | 16/20 [00:08<00:02,  1.90it/s, 0.509 -> 0.685]
# Using optimized values: prob_thresh=0.487239, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 5
#       2 model.optimize_thresholds(val_tiles, val_masks)
#       4 pth_log_train = fr"{pthmodels}\{outnm}\logs\train"
# ----> 5 if not os.path.exists(pth_log_train): os.mkdir(pth_log_train)
#       7 pth_log = glob(os.path.join(pth_log_train,'*.v2'))[0]
#       8 loss = get_loss_data(str(pth_log), pth_log_train)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\maybe_all_tiles_donald\\models\\Fallopian_monkey_test_tiles_12_7_23_lr_0.001_epochs_400_pt_40\\PDAC_02_9_24_lr_0.0001_epochs_150_pt_15_gaus_ratio_0\\logs\\train'

# %%
# pthHE= fr'\\10.99.68.178\andreex\data\Stardist\Testing\monkey\tiles'
# pthmasks= fr'\\10.99.68.178\andreex\data\Stardist\Testing\monkey\qupath\ground_truth\masks'

HE_tiles_pths = sorted(glob(os.path.join(pthHE_testing,'*.tif')))
mask_tiles_pths = sorted(glob(os.path.join(pthmasks_testing,'*.tif')))

HE_tiles_val = list(map(imread,HE_tiles_pths))
mask_tiles_val = list(map(imread,mask_tiles_pths))

HE_tiles_val = [x/255 for x in HE_tiles_val]  # just divide by 255 to get into (0,1) range
mask_tiles_val = [fill_label_holes(y) for y in mask_tiles_val]  # fills holes in annotations if there are any
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 4
#       1 # pthHE= fr'\\10.99.68.178\andreex\data\Stardist\Testing\monkey\tiles'
#       2 # pthmasks= fr'\\10.99.68.178\andreex\data\Stardist\Testing\monkey\qupath\ground_truth\masks'
# ----> 4 HE_tiles_pths = sorted(glob(os.path.join(pthHE_testing,'*.tif')))
#       5 mask_tiles_pths = sorted(glob(os.path.join(pthmasks_testing,'*.tif')))
#       7 HE_tiles_val = list(map(imread,HE_tiles_pths))
#
# NameError: name 'pthHE_testing' is not defined

# %%
#Predict on validation images
mask_val_pred = [model.predict_instances(x, n_tiles=model._guess_n_tiles(x), show_tile_progress=False)[0]
              for x in tqdm(HE_tiles_val)]
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]

# %%
X_val = HE_tiles_val
Y_val_pred = mask_val_pred
Y_val = mask_tiles_val

ind = 0

cropped_img = X_val[ind]
cropped_lbl = Y_val_pred[ind]
cropped_lbl_gt = Y_val[ind]

fig, ax = plt.subplots(1,3,figsize = (16, 8))
ax[0].imshow(cropped_img)
ax[0].axis('off')
ax[0].set_title('H&E')

ax[1].imshow(cropped_img)
ax[1].imshow(cropped_lbl_gt, cmap=lbl_cmap, alpha=0.5)
ax[1].axis('off')
ax[1].set_title('Ground Truth')

ax[2].imshow(cropped_img)
ax[2].imshow(cropped_lbl, cmap=lbl_cmap, alpha=0.5)
ax[2].axis('off')
ax[2].set_title('Predicted')
plt.show()
