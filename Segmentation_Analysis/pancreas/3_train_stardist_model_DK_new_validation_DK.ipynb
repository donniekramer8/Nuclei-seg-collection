# %%
# pip install gputools
# pip install scikit-tensor-py3

from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import numpy as np
import matplotlib
matplotlib.rcParams["image.interpolation"] = 'nearest'
import matplotlib.pyplot as plt
import os
from PIL import Image
import tensorflow as tf
from glob import glob
from tqdm import tqdm
from tifffile import imread
import struct
import cv2
import pandas as pd

from stardist import fill_label_holes, random_label_cmap, calculate_extents, gputools_available
from stardist.models import Config2D, StarDist2D, StarDistData2D

# %%
#Random color map labels
np.random.seed(42)
lbl_cmap = random_label_cmap()

# %%
pth=r'\\10.99.68.178\andreex\data\Stardist\PDAC model'
pthtraining= os.path.join(pth,'training')
pthtesting= os.path.join(pth,'testing')
pthmodels= os.path.join(pth,'models')
pthfiles= os.path.join(pth,'files')

pthHE = os.path.join(pthtraining,'20x_HE_tiles')
pthmasks = os.path.join(pthtraining,'masks')

pthHE_testing = os.path.join(pthtesting,'20x_HE_tiles')
pthmasks_testing = os.path.join(pthtesting,'masks')

# %%
pthmodels
# Out:
# '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\models'

# %%
training_HE_tiles_pths = sorted(glob(os.path.join(pthHE,'*.tif')))
training_mask_tiles_pths = sorted(glob(os.path.join(pthmasks,'*.tif')))

# %%
training_HE_tiles_pths
# Out:
# ['\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\training\\20x_HE_tiles\\H15_0091.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\training\\20x_HE_tiles\\H15_0151.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\training\\20x_HE_tiles\\H15_0277_1.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\training\\20x_HE_tiles\\PD.2 5N-T LCM.tif',
#  '\\\\10.99.68.178\\andreex\\data\\Stardist\\PDAC model\\training\\20x_HE_tiles\\PD_25 3GG LCM1.tif']

# %%
print(len(training_HE_tiles_pths))
print(len(training_mask_tiles_pths))
# Out:
# 5
# 5

# %%
HE_original_tiles = list(map(imread,training_HE_tiles_pths))
mask_original_tiles = list(map(imread,training_mask_tiles_pths))

# %%
import random

size_total = len(training_HE_tiles_pths)
print(f'Size total: {size_total}')

val_ratio = 0.4
num_indices = int(size_total * val_ratio)

print(f'Size Training: {size_total - num_indices}')
print(f'Size Validation: {num_indices}')
# Out:
# Size total: 5
# Size Training: 3
# Size Validation: 2

# %%
val_indices = sorted(random.sample(range(size_total), num_indices))
train_indices = sorted(list(set(range(size_total)) - set(val_indices)))

print(val_indices)
print(train_indices)
# Out:
# [0, 3]
# [1, 2, 4]

# %%
training_tiles = [HE_original_tiles[i] for i in train_indices]
training_masks = [mask_original_tiles[i] for i in train_indices]
training_masks = [fill_label_holes(y) for y in training_masks]  # fills holes in annotations if there are any

val_tiles = [HE_original_tiles[i] for i in val_indices]
val_masks = [mask_original_tiles[i] for i in val_indices]
val_masks = [fill_label_holes(y) for y in val_masks]  # fills holes in annotations if there are any

print(len(training_tiles))
print(len(training_masks))

print(len(val_tiles))
print(len(val_masks))
# Out:
# 3
# 3
# 2
# 2

# %%
def augment_images(HE_tiles, mask_tiles):
  """
  Augments a set of HE images and corresponding mask labels by rotating and flipping them.

  Args:
    HE_tiles: A list of NumPy arrays representing the HE images.
    mask_tiles: A list of NumPy arrays representing the mask labels for the HE images.

  Returns:
    HE_aug: A list of NumPy arrays representing the augmented HE images.
    mask_aug: A list of NumPy arrays representing the augmented mask labels.
  """

  HE_aug = [[] for _ in range(len(HE_tiles))]
  mask_aug = [[] for _ in range(len(mask_tiles))]

  for i in range(len(HE_tiles)):
    im = Image.fromarray(HE_tiles[i])
    lbl = Image.fromarray(mask_tiles[i])

    # Rotate the image and label 90 degrees three times.
    for _ in range(3):
      im = im.rotate(90)
      HE_aug[i].append(im)
      lbl = lbl.rotate(90)
      mask_aug[i].append(lbl)

    # Flip the image and label horizontally.
    im = Image.fromarray(HE_tiles[i])
    flipped_im = im.transpose(Image.FLIP_LEFT_RIGHT)

    lbl = Image.fromarray(mask_tiles[i])
    flipped_lbl = lbl.transpose(Image.FLIP_LEFT_RIGHT)

    HE_aug[i].append(flipped_im)
    mask_aug[i].append(flipped_lbl)

    # Rotate the flipped image and label 90 degrees three times.
    for _ in range(3):
      flipped_im = flipped_im.rotate(90)
      HE_aug[i].append(flipped_im)
      flipped_lbl = flipped_lbl.rotate(90)
      mask_aug[i].append(flipped_lbl)

  return HE_aug, mask_aug

# %%
HE_aug, mask_aug = augment_images(training_tiles, training_masks)

# %%
print(len(training_tiles))
# Out:
# 3

# %%
print(len(HE_aug)*(len(HE_aug[0])))
print(len(mask_aug)*(len(mask_aug[0])))
# Out:
# 21
# 21

# %%
def normalize_images(images, masks):
  
  normalized_masks = [[] for i in range(len(masks))]
  normalized_images = [[] for i in range(len(images))]
  
  for i in range(len(masks)):
      masks_list = masks[i]
      images_list = images[i]
      
      for j in range(len(images_list)):
          im = images_list[j]
          im = np.asarray(im)
          im = im/255
          normalized_images[i].append(im)
      
      for j in range(len(masks_list)):
          im = masks_list[j]
          im = np.asarray(im)
          im = fill_label_holes(im)
          normalized_masks[i].append(im)
          
  return normalized_images, normalized_masks

# %%
print(len(HE_aug))
print(len(HE_aug[0]))
# Out:
# 3
# 7

# %%
HE_trn = [im for im in training_tiles]
for im_list in HE_aug:
    for im in im_list:
        HE_trn.append(np.array(im))

mask_trn = [im for im in training_masks]
for im_list in mask_aug:
    for im in im_list:
        mask_trn.append(np.array(im))

HE_trn = [im/255 for im in HE_trn]

print(len(HE_trn))
print(len(mask_trn))
# Out:
# 24
# 24

# %%
# divide val tiles by 255 also
val_tiles = [im/255 for im in val_tiles]

# %%
print(f'training images: {len(HE_trn)}')
print(f'training masks: {len(mask_trn)}')

print(f'validation masks: {len(val_tiles)}')
print(f'validation masks: {len(val_masks)}')
# Out:
# training images: 24
# training masks: 24
# validation masks: 2
# validation masks: 2

# %%
#PLot image and label for some images - sanity check
def show_tile_segmented(tile, segmented, **kwargs):
    """Plot large image at different resolutions."""
    fig, ax = plt.subplots(1, 2, figsize=(16/2, 8/2))

    # Plot the original image on the left
    ax[0].imshow(tile, **kwargs)

    # Plot the cropped image on the right
    ax[1].imshow(segmented, **kwargs)

    ax[0].axis('off')
    ax[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
i = 0

# %%
i += 1

img, lbl = HE_trn[i], mask_trn[i]
assert img.ndim in (2,3)
img = img if (img.ndim==2 or img.shape[-1]==3) else img[...,0]
show_tile_segmented(img,lbl)

# %%
if tf.config.list_physical_devices('GPU'):
    print("GPU is available")
else:
    print("GPU is not available")
    
print(tf.__version__)

#Define the config by setting some parameter values
# 32 is a good default choice (see 1_data.ipynb)
n_rays = 32  #Number of radial directions for the star-convex polygon.

# Use OpenCL-based computations for data generator during training (requires 'gputools')
use_gpu = True and gputools_available()

# Predict on subsampled grid for increased efficiency and larger field of view
grid = (2,2)

n_channel = 1 if HE_trn[0].ndim == 2 else HE_trn[0].shape[-1]  #If no third dim. then number of channels = 1. Otherwise get the num channels from the last dim.


conf = Config2D (
    n_rays       = n_rays,
    grid         = grid,
    use_gpu      = use_gpu,
    n_channel_in = n_channel,
)
# print(conf)
vars(conf)
# Out:
# GPU is available
# 2.9.3
# Warning: Could not find scikit-tensor which is needed for separable approximations...
# If you want to compute separable approximations, please install it with
# pip install scikit-tensor-py3
# {'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 3,
#  'n_channel_out': 33,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'n_rays': 32,
#  'grid': (2, 2),
#  'backbone': 'unet',
#  'n_classes': None,
#  'unet_n_depth': 3,
#  'unet_kernel_size': (3, 3),
#  'unet_n_filter_base': 32,
#  'unet_n_conv_per_depth': 2,
#  'unet_pool': (2, 2),
#  'unet_activation': 'relu',
#  'unet_last_activation': 'relu',
#  'unet_batch_norm': False,
#  'unet_dropout': 0.0,
#  'unet_prefix': '',
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, 3),
#  'net_mask_shape': (None, None, 1),
#  'train_shape_completion': False,
#  'train_completion_crop': 32,
#  'train_patch_size': (256, 256),
#  'train_background_reg': 0.0001,
#  'train_foreground_only': 0.9,
#  'train_sample_cache': True,
#  'train_dist_loss': 'mae',
#  'train_loss_weights': (1, 0.2),
#  'train_class_weights': (1, 1),
#  'train_epochs': 400,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0003,
#  'train_batch_size': 4,
#  'train_n_val_patches': None,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 40, 'min_delta': 0},
#  'use_gpu': True}

# %%
#Start from 40x H&E pre-trained model to the specified directory
import copy
import json

def load_justin_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = load_model(r'\\10.99.68.178\andreex\students\Donald Monkey fetus\stardist\Model_00')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_published_he_model(folder_to_write_new_model_folder: str, name_for_new_model: str) -> StarDist2D:
    published_model = StarDist2D.from_pretrained('2D_versatile_he')
    original_thresholds = copy.copy({'prob': published_model.thresholds[0], 'nms': published_model.thresholds[1]})
    configuration = Config2D(n_channel_in=3, grid=(2,2), use_gpu=True, train_patch_size=[256, 256])
    model = StarDist2D(config=configuration, basedir=folder_to_write_new_model_folder, name=name_for_new_model)
    model.keras_model.set_weights(published_model.keras_model.get_weights())
    model.thresholds = original_thresholds
    return model

def load_model(model_path: str) -> StarDist2D:
    # Load StarDist model weights, configurations, and thresholds
    with open(model_path + '\\config.json', 'r') as f:
        config = json.load(f)
    with open(model_path + '\\thresholds.json', 'r') as f:
        thresh = json.load(f)
    model = StarDist2D(config=Config2D(**config), basedir=model_path, name='offshoot_model')
    model.thresholds = thresh
    print('Overriding defaults:', model.thresholds, '\n')
    model.load_weights(model_path + '\\weights_best.h5')
    return model

def configure_model_for_training(model: StarDist2D,
                                 epochs: int = 25, learning_rate: float = 1e-6,
                                 batch_size: int = 4, patch_size: list[int,int] = [256, 256]) -> StarDist2D:
    model.config.train_epochs = epochs
    model.config.train_learning_rate = learning_rate
    model.config.train_batch_size = batch_size
    model.config.train_patch_size = patch_size
    return model

# %%
from tensorflow.python.summary.summary_iterator import summary_iterator

def get_loss_data(pth_training_log, pth_out) -> list:

    # event_file = r"\\10.99.68.178\andreex\data\Stardist\models\monkey_ft_11_02_2023_lr_1e-4_epochs_200_pt_10\logs\train\events.out.tfevents.1698964029.WPC-C13.20400.7.v2"

    loss_values = []

    for summary in summary_iterator(pth_training_log):
        for value in summary.summary.value:
            if value.tag == 'epoch_loss':
                loss = struct.unpack('f', value.tensor.tensor_content)[0]
                loss_values.append(loss)

    out_txt_name = f"{pth_out}\loss.txt"

    with open(out_txt_name, 'w') as f:
        f.write('\n'.join(map(str, loss_values)) + '\n')

    return loss_values

# %%
# lr = 0.001
lr = 0.0001
# epochs = 400
epochs = 150
# patience = 40
patience = 15
nm='PDAC'
dt='01_18_24'
# outnm = nm + dt + '_lr_' + str(lr) + '_epochs_' + str(epochs) + '_pt_' + str(patience)
outnm=f'{nm}_{dt}_lr_{lr}_epochs_{epochs}_pt_{patience}_gaus_ratio_0'
print(outnm)
# Out:
# PDAC_01_18_24_lr_0.0001_epochs_150_pt_15_gaus_ratio_0

# %%
# lr = 0.001
lr = 0.0001
# epochs = 400
epochs = 150
# patience = 40
patience = 15
# nm='monkey_add_fallopian_test'
# dt='_12_7_23'
# outnm = nm + dt + '_lr_' + str(lr) + '_epochs_' + str(
# epochs) + '_pt_' + str(patience)
outnm=f'monkey_12_12_2023_lr_0.001_epochs_400_pt_10_gaus_ratio_0'
print(outnm)
# Out:
# monkey_12_12_2023_lr_0.001_epochs_400_pt_10_gaus_ratio_0

# %%
print(fr"{pthmodels}\{outnm}\logs\train")
# Out:
# \\10.99.68.178\andreex\data\Stardist\PDAC model\models\monkey_12_12_2023_lr_0.001_epochs_400_pt_10_gaus_ratio_0\logs\train

# %%
model = load_model(os.path.join(pthmodels, outnm))
model.config.train_learning_rate = lr
model.config.train_patch_size = (256,256)
model.config.train_reduce_lr={'factor': 0.5, 'patience': patience, 'min_delta': 0}
# Out:
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# Overriding defaults: Thresholds(prob=0.6883699162882626, nms=0.3)

# %%
model.train(HE_trn, mask_trn, validation_data=(val_tiles,val_masks), epochs=epochs, steps_per_epoch=100)
model.optimize_thresholds(val_tiles, val_masks)

pth_log_train = fr"{pthmodels}\{outnm}\logs\train"
if not os.path.exists(pth_log_train): os.mkdir(pth_log_train)

pth_log = glob(os.path.join(pth_log_train,'*.v2'))[0]
loss = get_loss_data(str(pth_log), pth_log_train)
# Out:
# Epoch 1/150
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x00000184F2BD1310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000184F2BD1310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow | AutoGraph could not transform <function _gcd_import at 0x00000184F2BD1310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000184F2BD1310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x00000184F2BD1310> and will run it as-is.
# Cause: Unable to locate the source code of <function _gcd_import at 0x00000184F2BD1310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5645 - prob_loss: 0.1951 - dist_loss: 1.8469 - prob_kld: 0.1278 - dist_relevant_mae: 1.8465 - dist_relev
# 100/100 [==============================] - 8s 37ms/step - loss: 0.5628 - prob_loss: 0.1944 - dist_loss: 1.8419 - prob_kld: 0.1272 - dist_relevant_mae: 1.8415 - dist_relevant_mse: 8.9452 - dist_dist_iou_metric: 0.5584 - val_loss: 0.4638 - val_prob_loss: 0.2159 - val_dist_loss: 1.2393 - val_prob_kld: 0.0966 - val_dist_relevant_mae: 1.2390 - val_dist_relevant_mse: 3.9354 - val_dist_dist_iou_metric: 0.6494 - lr: 1.0000e-04
# Epoch 2/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5115 - prob_loss: 0.1710 - dist_loss: 1.7024 - prob_kld: 0.1060 - dist_relevant_mae: 1.7020 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.5115 - prob_loss: 0.1710 - dist_loss: 1.7024 - prob_kld: 0.1060 - dist_relevant_mae: 1.7020 - dist_relevant_mse: 7.6926 - dist_dist_iou_metric: 0.5759 - val_loss: 0.4621 - val_prob_loss: 0.2102 - val_dist_loss: 1.2598 - val_prob_kld: 0.0909 - val_dist_relevant_mae: 1.2595 - val_dist_relevant_mse: 4.1439 - val_dist_dist_iou_metric: 0.6452 - lr: 1.0000e-04
# Epoch 3/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5051 - prob_loss: 0.1671 - dist_loss: 1.6902 - prob_kld: 0.1020 - dist_relevant_mae: 1.6898 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.5030 - prob_loss: 0.1664 - dist_loss: 1.6826 - prob_kld: 0.1014 - dist_relevant_mae: 1.6822 - dist_relevant_mse: 7.4833 - dist_dist_iou_metric: 0.5791 - val_loss: 0.4705 - val_prob_loss: 0.2098 - val_dist_loss: 1.3037 - val_prob_kld: 0.0905 - val_dist_relevant_mae: 1.3034 - val_dist_relevant_mse: 4.4302 - val_dist_dist_iou_metric: 0.6304 - lr: 1.0000e-04
# Epoch 4/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4961 - prob_loss: 0.1614 - dist_loss: 1.6736 - prob_kld: 0.0959 - dist_relevant_mae: 1.6733 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4943 - prob_loss: 0.1611 - dist_loss: 1.6658 - prob_kld: 0.0954 - dist_relevant_mae: 1.6655 - dist_relevant_mse: 7.2391 - dist_dist_iou_metric: 0.5831 - val_loss: 0.4732 - val_prob_loss: 0.2091 - val_dist_loss: 1.3204 - val_prob_kld: 0.0898 - val_dist_relevant_mae: 1.3201 - val_dist_relevant_mse: 4.6014 - val_dist_dist_iou_metric: 0.6280 - lr: 1.0000e-04
# Epoch 5/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4802 - prob_loss: 0.1555 - dist_loss: 1.6237 - prob_kld: 0.0907 - dist_relevant_mae: 1.6234 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4816 - prob_loss: 0.1557 - dist_loss: 1.6291 - prob_kld: 0.0910 - dist_relevant_mae: 1.6288 - dist_relevant_mse: 6.9945 - dist_dist_iou_metric: 0.5868 - val_loss: 0.4812 - val_prob_loss: 0.2152 - val_dist_loss: 1.3303 - val_prob_kld: 0.0959 - val_dist_relevant_mae: 1.3300 - val_dist_relevant_mse: 4.6226 - val_dist_dist_iou_metric: 0.6231 - lr: 1.0000e-04
# Epoch 6/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4696 - prob_loss: 0.1538 - dist_loss: 1.5792 - prob_kld: 0.0868 - dist_relevant_mae: 1.5788 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4705 - prob_loss: 0.1542 - dist_loss: 1.5817 - prob_kld: 0.0871 - dist_relevant_mae: 1.5814 - dist_relevant_mse: 6.6375 - dist_dist_iou_metric: 0.5958 - val_loss: 0.4827 - val_prob_loss: 0.2153 - val_dist_loss: 1.3367 - val_prob_kld: 0.0960 - val_dist_relevant_mae: 1.3364 - val_dist_relevant_mse: 4.6626 - val_dist_dist_iou_metric: 0.6221 - lr: 1.0000e-04
# Epoch 7/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4655 - prob_loss: 0.1482 - dist_loss: 1.5861 - prob_kld: 0.0833 - dist_relevant_mae: 1.5858 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4662 - prob_loss: 0.1484 - dist_loss: 1.5889 - prob_kld: 0.0836 - dist_relevant_mae: 1.5885 - dist_relevant_mse: 6.6232 - dist_dist_iou_metric: 0.5947 - val_loss: 0.4703 - val_prob_loss: 0.2104 - val_dist_loss: 1.2995 - val_prob_kld: 0.0911 - val_dist_relevant_mae: 1.2992 - val_dist_relevant_mse: 4.4266 - val_dist_dist_iou_metric: 0.6323 - lr: 1.0000e-04
# Epoch 8/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4515 - prob_loss: 0.1462 - dist_loss: 1.5265 - prob_kld: 0.0806 - dist_relevant_mae: 1.5262 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4515 - prob_loss: 0.1462 - dist_loss: 1.5265 - prob_kld: 0.0806 - dist_relevant_mae: 1.5262 - dist_relevant_mse: 6.1436 - dist_dist_iou_metric: 0.6056 - val_loss: 0.4917 - val_prob_loss: 0.2225 - val_dist_loss: 1.3457 - val_prob_kld: 0.1033 - val_dist_relevant_mae: 1.3455 - val_dist_relevant_mse: 4.6854 - val_dist_dist_iou_metric: 0.6169 - lr: 1.0000e-04
# Epoch 9/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4483 - prob_loss: 0.1458 - dist_loss: 1.5123 - prob_kld: 0.0792 - dist_relevant_mae: 1.5120 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4500 - prob_loss: 0.1462 - dist_loss: 1.5187 - prob_kld: 0.0796 - dist_relevant_mae: 1.5184 - dist_relevant_mse: 6.0407 - dist_dist_iou_metric: 0.6060 - val_loss: 0.4831 - val_prob_loss: 0.2197 - val_dist_loss: 1.3170 - val_prob_kld: 0.1004 - val_dist_relevant_mae: 1.3167 - val_dist_relevant_mse: 4.4661 - val_dist_dist_iou_metric: 0.6258 - lr: 1.0000e-04
# Epoch 10/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4427 - prob_loss: 0.1420 - dist_loss: 1.5036 - prob_kld: 0.0763 - dist_relevant_mae: 1.5033 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4427 - prob_loss: 0.1420 - dist_loss: 1.5036 - prob_kld: 0.0763 - dist_relevant_mae: 1.5033 - dist_relevant_mse: 5.8968 - dist_dist_iou_metric: 0.6082 - val_loss: 0.4969 - val_prob_loss: 0.2302 - val_dist_loss: 1.3338 - val_prob_kld: 0.1109 - val_dist_relevant_mae: 1.3335 - val_dist_relevant_mse: 4.5286 - val_dist_dist_iou_metric: 0.6241 - lr: 1.0000e-04
# Epoch 11/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4305 - prob_loss: 0.1386 - dist_loss: 1.4597 - prob_kld: 0.0734 - dist_relevant_mae: 1.4594 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4314 - prob_loss: 0.1389 - dist_loss: 1.4627 - prob_kld: 0.0736 - dist_relevant_mae: 1.4624 - dist_relevant_mse: 5.5980 - dist_dist_iou_metric: 0.6155 - val_loss: 0.4916 - val_prob_loss: 0.2251 - val_dist_loss: 1.3325 - val_prob_kld: 0.1059 - val_dist_relevant_mae: 1.3322 - val_dist_relevant_mse: 4.5816 - val_dist_dist_iou_metric: 0.6211 - lr: 1.0000e-04
# Epoch 12/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4219 - prob_loss: 0.1373 - dist_loss: 1.4231 - prob_kld: 0.0709 - dist_relevant_mae: 1.4228 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4236 - prob_loss: 0.1377 - dist_loss: 1.4299 - prob_kld: 0.0713 - dist_relevant_mae: 1.4296 - dist_relevant_mse: 5.3491 - dist_dist_iou_metric: 0.6218 - val_loss: 0.4970 - val_prob_loss: 0.2278 - val_dist_loss: 1.3461 - val_prob_kld: 0.1085 - val_dist_relevant_mae: 1.3458 - val_dist_relevant_mse: 4.6731 - val_dist_dist_iou_metric: 0.6209 - lr: 1.0000e-04
# Epoch 13/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4211 - prob_loss: 0.1362 - dist_loss: 1.4242 - prob_kld: 0.0706 - dist_relevant_mae: 1.4239 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4218 - prob_loss: 0.1364 - dist_loss: 1.4268 - prob_kld: 0.0708 - dist_relevant_mae: 1.4265 - dist_relevant_mse: 5.2844 - dist_dist_iou_metric: 0.6208 - val_loss: 0.5085 - val_prob_loss: 0.2327 - val_dist_loss: 1.3790 - val_prob_kld: 0.1134 - val_dist_relevant_mae: 1.3787 - val_dist_relevant_mse: 4.8448 - val_dist_dist_iou_metric: 0.6097 - lr: 1.0000e-04
# Epoch 14/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4143 - prob_loss: 0.1352 - dist_loss: 1.3951 - prob_kld: 0.0686 - dist_relevant_mae: 1.3948 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4143 - prob_loss: 0.1352 - dist_loss: 1.3951 - prob_kld: 0.0686 - dist_relevant_mae: 1.3948 - dist_relevant_mse: 5.0389 - dist_dist_iou_metric: 0.6275 - val_loss: 0.4985 - val_prob_loss: 0.2268 - val_dist_loss: 1.3583 - val_prob_kld: 0.1075 - val_dist_relevant_mae: 1.3580 - val_dist_relevant_mse: 4.7764 - val_dist_dist_iou_metric: 0.6164 - lr: 1.0000e-04
# Epoch 15/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4069 - prob_loss: 0.1323 - dist_loss: 1.3728 - prob_kld: 0.0667 - dist_relevant_mae: 1.3725 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4070 - prob_loss: 0.1323 - dist_loss: 1.3735 - prob_kld: 0.0668 - dist_relevant_mae: 1.3733 - dist_relevant_mse: 4.8687 - dist_dist_iou_metric: 0.6303 - val_loss: 0.4902 - val_prob_loss: 0.2187 - val_dist_loss: 1.3575 - val_prob_kld: 0.0994 - val_dist_relevant_mae: 1.3572 - val_dist_relevant_mse: 4.8641 - val_dist_dist_iou_metric: 0.6152 - lr: 1.0000e-04
# Epoch 16/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3988 - prob_loss: 0.1307 - dist_loss: 1.3408 - prob_kld: 0.0649 - dist_relevant_mae: 1.3406 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3988 - prob_loss: 0.1307 - dist_loss: 1.3408 - prob_kld: 0.0649 - dist_relevant_mae: 1.3406 - dist_relevant_mse: 4.6383 - dist_dist_iou_metric: 0.6347 - val_loss: 0.5091 - val_prob_loss: 0.2305 - val_dist_loss: 1.3930 - val_prob_kld: 0.1112 - val_dist_relevant_mae: 1.3927 - val_dist_relevant_mse: 4.9971 - val_dist_dist_iou_metric: 0.6075 - lr: 1.0000e-04
# Epoch 17/150
#  99/100 [============================>.] - ETA: 0s - loss: 0.3987 - prob_loss: 0.1303 - dist_loss: 1.3423 - prob_kld: 0.0643 - dist_relevant_mae: 1.3421 - dist_relevant_mse: 4.6640 - dist_dist_iou_metric: 0.6342
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2/2 [==============================] - 0s 4ms/step
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3976 - prob_loss: 0.1300 - dist_loss: 1.3384 - prob_kld: 0.0641 - dist_relevant_mae: 1.3381 - dist_relevant_mse: 4.6411 - dist_dist_iou_metric: 0.6350 - val_loss: 0.4976 - val_prob_loss: 0.2274 - val_dist_loss: 1.3510 - val_prob_kld: 0.1081 - val_dist_relevant_mae: 1.3507 - val_dist_relevant_mse: 4.7576 - val_dist_dist_iou_metric: 0.6198 - lr: 1.0000e-04
# Epoch 18/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3923 - prob_loss: 0.1285 - dist_loss: 1.3188 - prob_kld: 0.0625 - dist_relevant_mae: 1.3185 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3923 - prob_loss: 0.1285 - dist_loss: 1.3188 - prob_kld: 0.0625 - dist_relevant_mae: 1.3185 - dist_relevant_mse: 4.4912 - dist_dist_iou_metric: 0.6398 - val_loss: 0.5195 - val_prob_loss: 0.2362 - val_dist_loss: 1.4165 - val_prob_kld: 0.1169 - val_dist_relevant_mae: 1.4162 - val_dist_relevant_mse: 5.1436 - val_dist_dist_iou_metric: 0.6019 - lr: 5.0000e-05
# Epoch 19/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3874 - prob_loss: 0.1277 - dist_loss: 1.2987 - prob_kld: 0.0613 - dist_relevant_mae: 1.2984 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3876 - prob_loss: 0.1277 - dist_loss: 1.2996 - prob_kld: 0.0614 - dist_relevant_mae: 1.2993 - dist_relevant_mse: 4.3862 - dist_dist_iou_metric: 0.6435 - val_loss: 0.5082 - val_prob_loss: 0.2280 - val_dist_loss: 1.4008 - val_prob_kld: 0.1087 - val_dist_relevant_mae: 1.4006 - val_dist_relevant_mse: 5.0670 - val_dist_dist_iou_metric: 0.6041 - lr: 5.0000e-05
# Epoch 20/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3882 - prob_loss: 0.1272 - dist_loss: 1.3048 - prob_kld: 0.0615 - dist_relevant_mae: 1.3045 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3882 - prob_loss: 0.1272 - dist_loss: 1.3048 - prob_kld: 0.0615 - dist_relevant_mae: 1.3045 - dist_relevant_mse: 4.3877 - dist_dist_iou_metric: 0.6408 - val_loss: 0.5166 - val_prob_loss: 0.2338 - val_dist_loss: 1.4139 - val_prob_kld: 0.1145 - val_dist_relevant_mae: 1.4136 - val_dist_relevant_mse: 5.1676 - val_dist_dist_iou_metric: 0.6030 - lr: 5.0000e-05
# Epoch 21/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3807 - prob_loss: 0.1252 - dist_loss: 1.2773 - prob_kld: 0.0594 - dist_relevant_mae: 1.2770 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3810 - prob_loss: 0.1253 - dist_loss: 1.2783 - prob_kld: 0.0596 - dist_relevant_mae: 1.2780 - dist_relevant_mse: 4.2160 - dist_dist_iou_metric: 0.6469 - val_loss: 0.5162 - val_prob_loss: 0.2343 - val_dist_loss: 1.4096 - val_prob_kld: 0.1151 - val_dist_relevant_mae: 1.4093 - val_dist_relevant_mse: 5.1687 - val_dist_dist_iou_metric: 0.6049 - lr: 5.0000e-05
# Epoch 22/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3830 - prob_loss: 0.1251 - dist_loss: 1.2897 - prob_kld: 0.0599 - dist_relevant_mae: 1.2894 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3836 - prob_loss: 0.1252 - dist_loss: 1.2919 - prob_kld: 0.0600 - dist_relevant_mae: 1.2916 - dist_relevant_mse: 4.3375 - dist_dist_iou_metric: 0.6441 - val_loss: 0.5160 - val_prob_loss: 0.2334 - val_dist_loss: 1.4132 - val_prob_kld: 0.1141 - val_dist_relevant_mae: 1.4129 - val_dist_relevant_mse: 5.1588 - val_dist_dist_iou_metric: 0.6015 - lr: 5.0000e-05
# Epoch 23/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3792 - prob_loss: 0.1241 - dist_loss: 1.2753 - prob_kld: 0.0592 - dist_relevant_mae: 1.2750 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3788 - prob_loss: 0.1240 - dist_loss: 1.2744 - prob_kld: 0.0591 - dist_relevant_mae: 1.2741 - dist_relevant_mse: 4.1839 - dist_dist_iou_metric: 0.6473 - val_loss: 0.5277 - val_prob_loss: 0.2390 - val_dist_loss: 1.4435 - val_prob_kld: 0.1197 - val_dist_relevant_mae: 1.4432 - val_dist_relevant_mse: 5.3863 - val_dist_dist_iou_metric: 0.5955 - lr: 5.0000e-05
# Epoch 24/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3757 - prob_loss: 0.1246 - dist_loss: 1.2556 - prob_kld: 0.0585 - dist_relevant_mae: 1.2553 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3757 - prob_loss: 0.1246 - dist_loss: 1.2556 - prob_kld: 0.0585 - dist_relevant_mae: 1.2553 - dist_relevant_mse: 4.0739 - dist_dist_iou_metric: 0.6515 - val_loss: 0.5300 - val_prob_loss: 0.2442 - val_dist_loss: 1.4291 - val_prob_kld: 0.1250 - val_dist_relevant_mae: 1.4288 - val_dist_relevant_mse: 5.2293 - val_dist_dist_iou_metric: 0.5995 - lr: 5.0000e-05
# Epoch 25/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3771 - prob_loss: 0.1251 - dist_loss: 1.2598 - prob_kld: 0.0584 - dist_relevant_mae: 1.2595 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3762 - prob_loss: 0.1248 - dist_loss: 1.2569 - prob_kld: 0.0582 - dist_relevant_mae: 1.2566 - dist_relevant_mse: 4.0860 - dist_dist_iou_metric: 0.6522 - val_loss: 0.5207 - val_prob_loss: 0.2357 - val_dist_loss: 1.4251 - val_prob_kld: 0.1164 - val_dist_relevant_mae: 1.4248 - val_dist_relevant_mse: 5.3009 - val_dist_dist_iou_metric: 0.6005 - lr: 5.0000e-05
# Epoch 26/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3730 - prob_loss: 0.1221 - dist_loss: 1.2545 - prob_kld: 0.0575 - dist_relevant_mae: 1.2542 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3738 - prob_loss: 0.1223 - dist_loss: 1.2573 - prob_kld: 0.0577 - dist_relevant_mae: 1.2570 - dist_relevant_mse: 4.0763 - dist_dist_iou_metric: 0.6500 - val_loss: 0.5066 - val_prob_loss: 0.2281 - val_dist_loss: 1.3922 - val_prob_kld: 0.1088 - val_dist_relevant_mae: 1.3920 - val_dist_relevant_mse: 5.0646 - val_dist_dist_iou_metric: 0.6087 - lr: 5.0000e-05
# Epoch 27/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3664 - prob_loss: 0.1211 - dist_loss: 1.2263 - prob_kld: 0.0567 - dist_relevant_mae: 1.2261 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3664 - prob_loss: 0.1211 - dist_loss: 1.2263 - prob_kld: 0.0567 - dist_relevant_mae: 1.2261 - dist_relevant_mse: 3.8809 - dist_dist_iou_metric: 0.6547 - val_loss: 0.5219 - val_prob_loss: 0.2322 - val_dist_loss: 1.4484 - val_prob_kld: 0.1129 - val_dist_relevant_mae: 1.4481 - val_dist_relevant_mse: 5.4471 - val_dist_dist_iou_metric: 0.5923 - lr: 5.0000e-05
# Epoch 28/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3694 - prob_loss: 0.1232 - dist_loss: 1.2309 - prob_kld: 0.0565 - dist_relevant_mae: 1.2306 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3694 - prob_loss: 0.1232 - dist_loss: 1.2309 - prob_kld: 0.0565 - dist_relevant_mae: 1.2306 - dist_relevant_mse: 3.8851 - dist_dist_iou_metric: 0.6567 - val_loss: 0.5161 - val_prob_loss: 0.2309 - val_dist_loss: 1.4260 - val_prob_kld: 0.1116 - val_dist_relevant_mae: 1.4257 - val_dist_relevant_mse: 5.2982 - val_dist_dist_iou_metric: 0.5983 - lr: 5.0000e-05
# Epoch 29/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3712 - prob_loss: 0.1213 - dist_loss: 1.2495 - prob_kld: 0.0564 - dist_relevant_mae: 1.2492 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3707 - prob_loss: 0.1213 - dist_loss: 1.2470 - prob_kld: 0.0562 - dist_relevant_mae: 1.2467 - dist_relevant_mse: 4.0105 - dist_dist_iou_metric: 0.6534 - val_loss: 0.5071 - val_prob_loss: 0.2276 - val_dist_loss: 1.3974 - val_prob_kld: 0.1084 - val_dist_relevant_mae: 1.3972 - val_dist_relevant_mse: 5.0879 - val_dist_dist_iou_metric: 0.6060 - lr: 5.0000e-05
# Epoch 30/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3684 - prob_loss: 0.1221 - dist_loss: 1.2313 - prob_kld: 0.0559 - dist_relevant_mae: 1.2310 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3697 - prob_loss: 0.1226 - dist_loss: 1.2354 - prob_kld: 0.0561 - dist_relevant_mae: 1.2352 - dist_relevant_mse: 3.9211 - dist_dist_iou_metric: 0.6565 - val_loss: 0.5278 - val_prob_loss: 0.2374 - val_dist_loss: 1.4523 - val_prob_kld: 0.1181 - val_dist_relevant_mae: 1.4521 - val_dist_relevant_mse: 5.4765 - val_dist_dist_iou_metric: 0.5928 - lr: 5.0000e-05
# Epoch 31/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3680 - prob_loss: 0.1230 - dist_loss: 1.2248 - prob_kld: 0.0557 - dist_relevant_mae: 1.2246 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3673 - prob_loss: 0.1227 - dist_loss: 1.2234 - prob_kld: 0.0556 - dist_relevant_mae: 1.2231 - dist_relevant_mse: 3.8792 - dist_dist_iou_metric: 0.6604 - val_loss: 0.5218 - val_prob_loss: 0.2362 - val_dist_loss: 1.4281 - val_prob_kld: 0.1169 - val_dist_relevant_mae: 1.4278 - val_dist_relevant_mse: 5.2888 - val_dist_dist_iou_metric: 0.5988 - lr: 5.0000e-05
# Epoch 32/150
#  99/100 [============================>.] - ETA: 0s - loss: 0.3618 - prob_loss: 0.1193 - dist_loss: 1.2126 - prob_kld: 0.0545 - dist_relevant_mae: 1.2123 - dist_relevant_mse: 3.7801 - dist_dist_iou_metric: 0.6575
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2/2 [==============================] - 0s 4ms/step
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3623 - prob_loss: 0.1195 - dist_loss: 1.2138 - prob_kld: 0.0546 - dist_relevant_mae: 1.2135 - dist_relevant_mse: 3.7859 - dist_dist_iou_metric: 0.6572 - val_loss: 0.5172 - val_prob_loss: 0.2309 - val_dist_loss: 1.4314 - val_prob_kld: 0.1116 - val_dist_relevant_mae: 1.4311 - val_dist_relevant_mse: 5.3206 - val_dist_dist_iou_metric: 0.5957 - lr: 5.0000e-05
# Epoch 33/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3574 - prob_loss: 0.1179 - dist_loss: 1.1974 - prob_kld: 0.0539 - dist_relevant_mae: 1.1971 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3574 - prob_loss: 0.1179 - dist_loss: 1.1974 - prob_kld: 0.0539 - dist_relevant_mae: 1.1971 - dist_relevant_mse: 3.6968 - dist_dist_iou_metric: 0.6616 - val_loss: 0.5253 - val_prob_loss: 0.2367 - val_dist_loss: 1.4431 - val_prob_kld: 0.1174 - val_dist_relevant_mae: 1.4428 - val_dist_relevant_mse: 5.4257 - val_dist_dist_iou_metric: 0.5940 - lr: 2.5000e-05
# Epoch 34/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3635 - prob_loss: 0.1204 - dist_loss: 1.2155 - prob_kld: 0.0538 - dist_relevant_mae: 1.2153 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3635 - prob_loss: 0.1204 - dist_loss: 1.2155 - prob_kld: 0.0538 - dist_relevant_mae: 1.2153 - dist_relevant_mse: 3.7872 - dist_dist_iou_metric: 0.6620 - val_loss: 0.5188 - val_prob_loss: 0.2322 - val_dist_loss: 1.4330 - val_prob_kld: 0.1129 - val_dist_relevant_mae: 1.4328 - val_dist_relevant_mse: 5.3423 - val_dist_dist_iou_metric: 0.5966 - lr: 2.5000e-05
# Epoch 35/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3616 - prob_loss: 0.1193 - dist_loss: 1.2113 - prob_kld: 0.0538 - dist_relevant_mae: 1.2110 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3616 - prob_loss: 0.1195 - dist_loss: 1.2106 - prob_kld: 0.0538 - dist_relevant_mae: 1.2103 - dist_relevant_mse: 3.7832 - dist_dist_iou_metric: 0.6605 - val_loss: 0.5226 - val_prob_loss: 0.2331 - val_dist_loss: 1.4473 - val_prob_kld: 0.1139 - val_dist_relevant_mae: 1.4470 - val_dist_relevant_mse: 5.4565 - val_dist_dist_iou_metric: 0.5929 - lr: 2.5000e-05
# Epoch 36/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3644 - prob_loss: 0.1208 - dist_loss: 1.2179 - prob_kld: 0.0540 - dist_relevant_mae: 1.2176 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3644 - prob_loss: 0.1209 - dist_loss: 1.2175 - prob_kld: 0.0540 - dist_relevant_mae: 1.2173 - dist_relevant_mse: 3.8229 - dist_dist_iou_metric: 0.6609 - val_loss: 0.5314 - val_prob_loss: 0.2386 - val_dist_loss: 1.4637 - val_prob_kld: 0.1193 - val_dist_relevant_mae: 1.4635 - val_dist_relevant_mse: 5.5345 - val_dist_dist_iou_metric: 0.5888 - lr: 2.5000e-05
# Epoch 37/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3550 - prob_loss: 0.1173 - dist_loss: 1.1885 - prob_kld: 0.0529 - dist_relevant_mae: 1.1882 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3553 - prob_loss: 0.1174 - dist_loss: 1.1894 - prob_kld: 0.0530 - dist_relevant_mae: 1.1891 - dist_relevant_mse: 3.6403 - dist_dist_iou_metric: 0.6632 - val_loss: 0.5212 - val_prob_loss: 0.2332 - val_dist_loss: 1.4399 - val_prob_kld: 0.1139 - val_dist_relevant_mae: 1.4396 - val_dist_relevant_mse: 5.3849 - val_dist_dist_iou_metric: 0.5963 - lr: 2.5000e-05
# Epoch 38/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3589 - prob_loss: 0.1194 - dist_loss: 1.1974 - prob_kld: 0.0533 - dist_relevant_mae: 1.1972 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3589 - prob_loss: 0.1194 - dist_loss: 1.1974 - prob_kld: 0.0533 - dist_relevant_mae: 1.1972 - dist_relevant_mse: 3.7088 - dist_dist_iou_metric: 0.6633 - val_loss: 0.5253 - val_prob_loss: 0.2346 - val_dist_loss: 1.4531 - val_prob_kld: 0.1154 - val_dist_relevant_mae: 1.4528 - val_dist_relevant_mse: 5.4924 - val_dist_dist_iou_metric: 0.5917 - lr: 2.5000e-05
# Epoch 39/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3523 - prob_loss: 0.1160 - dist_loss: 1.1813 - prob_kld: 0.0525 - dist_relevant_mae: 1.1811 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3523 - prob_loss: 0.1160 - dist_loss: 1.1813 - prob_kld: 0.0525 - dist_relevant_mae: 1.1811 - dist_relevant_mse: 3.5852 - dist_dist_iou_metric: 0.6633 - val_loss: 0.5192 - val_prob_loss: 0.2304 - val_dist_loss: 1.4439 - val_prob_kld: 0.1111 - val_dist_relevant_mae: 1.4436 - val_dist_relevant_mse: 5.4346 - val_dist_dist_iou_metric: 0.5945 - lr: 2.5000e-05
# Epoch 40/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3554 - prob_loss: 0.1172 - dist_loss: 1.1909 - prob_kld: 0.0523 - dist_relevant_mae: 1.1906 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3554 - prob_loss: 0.1172 - dist_loss: 1.1909 - prob_kld: 0.0523 - dist_relevant_mae: 1.1906 - dist_relevant_mse: 3.6511 - dist_dist_iou_metric: 0.6646 - val_loss: 0.5276 - val_prob_loss: 0.2355 - val_dist_loss: 1.4607 - val_prob_kld: 0.1162 - val_dist_relevant_mae: 1.4604 - val_dist_relevant_mse: 5.5389 - val_dist_dist_iou_metric: 0.5889 - lr: 2.5000e-05
# Epoch 41/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3559 - prob_loss: 0.1181 - dist_loss: 1.1892 - prob_kld: 0.0531 - dist_relevant_mae: 1.1889 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3568 - prob_loss: 0.1184 - dist_loss: 1.1920 - prob_kld: 0.0533 - dist_relevant_mae: 1.1918 - dist_relevant_mse: 3.6584 - dist_dist_iou_metric: 0.6644 - val_loss: 0.5173 - val_prob_loss: 0.2310 - val_dist_loss: 1.4317 - val_prob_kld: 0.1117 - val_dist_relevant_mae: 1.4314 - val_dist_relevant_mse: 5.3373 - val_dist_dist_iou_metric: 0.5975 - lr: 2.5000e-05
# Epoch 42/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3546 - prob_loss: 0.1178 - dist_loss: 1.1838 - prob_kld: 0.0521 - dist_relevant_mae: 1.1835 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3548 - prob_loss: 0.1178 - dist_loss: 1.1850 - prob_kld: 0.0522 - dist_relevant_mae: 1.1847 - dist_relevant_mse: 3.6202 - dist_dist_iou_metric: 0.6665 - val_loss: 0.5178 - val_prob_loss: 0.2296 - val_dist_loss: 1.4409 - val_prob_kld: 0.1103 - val_dist_relevant_mae: 1.4406 - val_dist_relevant_mse: 5.3894 - val_dist_dist_iou_metric: 0.5954 - lr: 2.5000e-05
# Epoch 43/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3528 - prob_loss: 0.1178 - dist_loss: 1.1747 - prob_kld: 0.0516 - dist_relevant_mae: 1.1744 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3519 - prob_loss: 0.1176 - dist_loss: 1.1718 - prob_kld: 0.0515 - dist_relevant_mae: 1.1715 - dist_relevant_mse: 3.5179 - dist_dist_iou_metric: 0.6693 - val_loss: 0.5238 - val_prob_loss: 0.2326 - val_dist_loss: 1.4563 - val_prob_kld: 0.1133 - val_dist_relevant_mae: 1.4560 - val_dist_relevant_mse: 5.5121 - val_dist_dist_iou_metric: 0.5915 - lr: 2.5000e-05
# Epoch 44/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3545 - prob_loss: 0.1180 - dist_loss: 1.1827 - prob_kld: 0.0524 - dist_relevant_mae: 1.1825 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3555 - prob_loss: 0.1183 - dist_loss: 1.1862 - prob_kld: 0.0528 - dist_relevant_mae: 1.1859 - dist_relevant_mse: 3.5959 - dist_dist_iou_metric: 0.6640 - val_loss: 0.5265 - val_prob_loss: 0.2356 - val_dist_loss: 1.4545 - val_prob_kld: 0.1163 - val_dist_relevant_mae: 1.4542 - val_dist_relevant_mse: 5.5002 - val_dist_dist_iou_metric: 0.5915 - lr: 2.5000e-05
# Epoch 45/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3533 - prob_loss: 0.1184 - dist_loss: 1.1744 - prob_kld: 0.0522 - dist_relevant_mae: 1.1742 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3533 - prob_loss: 0.1184 - dist_loss: 1.1744 - prob_kld: 0.0522 - dist_relevant_mae: 1.1742 - dist_relevant_mse: 3.5536 - dist_dist_iou_metric: 0.6677 - val_loss: 0.5289 - val_prob_loss: 0.2355 - val_dist_loss: 1.4669 - val_prob_kld: 0.1162 - val_dist_relevant_mae: 1.4666 - val_dist_relevant_mse: 5.5517 - val_dist_dist_iou_metric: 0.5884 - lr: 2.5000e-05
# Epoch 46/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3532 - prob_loss: 0.1187 - dist_loss: 1.1722 - prob_kld: 0.0522 - dist_relevant_mae: 1.1720 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3534 - prob_loss: 0.1187 - dist_loss: 1.1734 - prob_kld: 0.0523 - dist_relevant_mae: 1.1732 - dist_relevant_mse: 3.5275 - dist_dist_iou_metric: 0.6674 - val_loss: 0.5174 - val_prob_loss: 0.2296 - val_dist_loss: 1.4393 - val_prob_kld: 0.1103 - val_dist_relevant_mae: 1.4391 - val_dist_relevant_mse: 5.3808 - val_dist_dist_iou_metric: 0.5951 - lr: 2.5000e-05
# Epoch 47/150
# 100/100 [==============================] - ETA: 0s - loss: 0.3526 - prob_loss: 0.1166 - dist_loss: 1.1804 - prob_kld: 0.0514 - dist_relevant_mae: 1.1801 - dist_relevant_mse: 3.6057 - dist_dist_iou_metric: 0.6676
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 2/2 [==============================] - 0s 4ms/step
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3526 - prob_loss: 0.1166 - dist_loss: 1.1804 - prob_kld: 0.0514 - dist_relevant_mae: 1.1801 - dist_relevant_mse: 3.6057 - dist_dist_iou_metric: 0.6676 - val_loss: 0.5286 - val_prob_loss: 0.2374 - val_dist_loss: 1.4561 - val_prob_kld: 0.1181 - val_dist_relevant_mae: 1.4559 - val_dist_relevant_mse: 5.4705 - val_dist_dist_iou_metric: 0.5917 - lr: 2.5000e-05
# Epoch 48/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3528 - prob_loss: 0.1179 - dist_loss: 1.1741 - prob_kld: 0.0519 - dist_relevant_mae: 1.1739 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3524 - prob_loss: 0.1179 - dist_loss: 1.1727 - prob_kld: 0.0518 - dist_relevant_mae: 1.1724 - dist_relevant_mse: 3.5229 - dist_dist_iou_metric: 0.6691 - val_loss: 0.5259 - val_prob_loss: 0.2332 - val_dist_loss: 1.4636 - val_prob_kld: 0.1139 - val_dist_relevant_mae: 1.4633 - val_dist_relevant_mse: 5.5427 - val_dist_dist_iou_metric: 0.5886 - lr: 1.2500e-05
# Epoch 49/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3555 - prob_loss: 0.1178 - dist_loss: 1.1890 - prob_kld: 0.0518 - dist_relevant_mae: 1.1887 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3560 - prob_loss: 0.1178 - dist_loss: 1.1911 - prob_kld: 0.0519 - dist_relevant_mae: 1.1908 - dist_relevant_mse: 3.6276 - dist_dist_iou_metric: 0.6659 - val_loss: 0.5274 - val_prob_loss: 0.2357 - val_dist_loss: 1.4585 - val_prob_kld: 0.1164 - val_dist_relevant_mae: 1.4583 - val_dist_relevant_mse: 5.5060 - val_dist_dist_iou_metric: 0.5906 - lr: 1.2500e-05
# Epoch 50/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3491 - prob_loss: 0.1159 - dist_loss: 1.1661 - prob_kld: 0.0508 - dist_relevant_mae: 1.1659 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3491 - prob_loss: 0.1159 - dist_loss: 1.1661 - prob_kld: 0.0508 - dist_relevant_mae: 1.1659 - dist_relevant_mse: 3.4970 - dist_dist_iou_metric: 0.6688 - val_loss: 0.5240 - val_prob_loss: 0.2339 - val_dist_loss: 1.4505 - val_prob_kld: 0.1146 - val_dist_relevant_mae: 1.4503 - val_dist_relevant_mse: 5.4531 - val_dist_dist_iou_metric: 0.5924 - lr: 1.2500e-05
# Epoch 51/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3513 - prob_loss: 0.1175 - dist_loss: 1.1688 - prob_kld: 0.0508 - dist_relevant_mae: 1.1685 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3518 - prob_loss: 0.1175 - dist_loss: 1.1715 - prob_kld: 0.0508 - dist_relevant_mae: 1.1712 - dist_relevant_mse: 3.5400 - dist_dist_iou_metric: 0.6710 - val_loss: 0.5298 - val_prob_loss: 0.2369 - val_dist_loss: 1.4648 - val_prob_kld: 0.1176 - val_dist_relevant_mae: 1.4645 - val_dist_relevant_mse: 5.5520 - val_dist_dist_iou_metric: 0.5886 - lr: 1.2500e-05
# Epoch 52/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3503 - prob_loss: 0.1173 - dist_loss: 1.1653 - prob_kld: 0.0512 - dist_relevant_mae: 1.1651 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3508 - prob_loss: 0.1173 - dist_loss: 1.1674 - prob_kld: 0.0513 - dist_relevant_mae: 1.1671 - dist_relevant_mse: 3.4745 - dist_dist_iou_metric: 0.6694 - val_loss: 0.5191 - val_prob_loss: 0.2317 - val_dist_loss: 1.4374 - val_prob_kld: 0.1124 - val_dist_relevant_mae: 1.4371 - val_dist_relevant_mse: 5.3706 - val_dist_dist_iou_metric: 0.5956 - lr: 1.2500e-05
# Epoch 53/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3496 - prob_loss: 0.1144 - dist_loss: 1.1760 - prob_kld: 0.0507 - dist_relevant_mae: 1.1757 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3489 - prob_loss: 0.1141 - dist_loss: 1.1738 - prob_kld: 0.0505 - dist_relevant_mae: 1.1735 - dist_relevant_mse: 3.5325 - dist_dist_iou_metric: 0.6677 - val_loss: 0.5238 - val_prob_loss: 0.2344 - val_dist_loss: 1.4469 - val_prob_kld: 0.1151 - val_dist_relevant_mae: 1.4466 - val_dist_relevant_mse: 5.4376 - val_dist_dist_iou_metric: 0.5937 - lr: 1.2500e-05
# Epoch 54/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3473 - prob_loss: 0.1144 - dist_loss: 1.1646 - prob_kld: 0.0504 - dist_relevant_mae: 1.1643 - dist_relev
# 100/100 [==============================] - 4s 45ms/step - loss: 0.3481 - prob_loss: 0.1146 - dist_loss: 1.1679 - prob_kld: 0.0506 - dist_relevant_mae: 1.1677 - dist_relevant_mse: 3.5084 - dist_dist_iou_metric: 0.6667 - val_loss: 0.5214 - val_prob_loss: 0.2316 - val_dist_loss: 1.4492 - val_prob_kld: 0.1123 - val_dist_relevant_mae: 1.4489 - val_dist_relevant_mse: 5.4320 - val_dist_dist_iou_metric: 0.5929 - lr: 1.2500e-05
# Epoch 55/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3505 - prob_loss: 0.1164 - dist_loss: 1.1706 - prob_kld: 0.0508 - dist_relevant_mae: 1.1703 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3512 - prob_loss: 0.1165 - dist_loss: 1.1734 - prob_kld: 0.0510 - dist_relevant_mae: 1.1731 - dist_relevant_mse: 3.5409 - dist_dist_iou_metric: 0.6679 - val_loss: 0.5234 - val_prob_loss: 0.2341 - val_dist_loss: 1.4465 - val_prob_kld: 0.1148 - val_dist_relevant_mae: 1.4462 - val_dist_relevant_mse: 5.4310 - val_dist_dist_iou_metric: 0.5938 - lr: 1.2500e-05
# Epoch 56/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3500 - prob_loss: 0.1163 - dist_loss: 1.1682 - prob_kld: 0.0505 - dist_relevant_mae: 1.1680 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3500 - prob_loss: 0.1163 - dist_loss: 1.1682 - prob_kld: 0.0505 - dist_relevant_mae: 1.1680 - dist_relevant_mse: 3.4838 - dist_dist_iou_metric: 0.6694 - val_loss: 0.5269 - val_prob_loss: 0.2354 - val_dist_loss: 1.4577 - val_prob_kld: 0.1161 - val_dist_relevant_mae: 1.4574 - val_dist_relevant_mse: 5.5007 - val_dist_dist_iou_metric: 0.5905 - lr: 1.2500e-05
# Epoch 57/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3487 - prob_loss: 0.1162 - dist_loss: 1.1625 - prob_kld: 0.0505 - dist_relevant_mae: 1.1622 - dist_relev
# 100/100 [==============================] - 3s 35ms/step - loss: 0.3487 - prob_loss: 0.1162 - dist_loss: 1.1625 - prob_kld: 0.0505 - dist_relevant_mae: 1.1622 - dist_relevant_mse: 3.4731 - dist_dist_iou_metric: 0.6714 - val_loss: 0.5227 - val_prob_loss: 0.2324 - val_dist_loss: 1.4514 - val_prob_kld: 0.1131 - val_dist_relevant_mae: 1.4511 - val_dist_relevant_mse: 5.4495 - val_dist_dist_iou_metric: 0.5925 - lr: 1.2500e-05
# Epoch 58/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3431 - prob_loss: 0.1151 - dist_loss: 1.1399 - prob_kld: 0.0501 - dist_relevant_mae: 1.1396 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3431 - prob_loss: 0.1151 - dist_loss: 1.1399 - prob_kld: 0.0501 - dist_relevant_mae: 1.1396 - dist_relevant_mse: 3.3541 - dist_dist_iou_metric: 0.6736 - val_loss: 0.5271 - val_prob_loss: 0.2353 - val_dist_loss: 1.4594 - val_prob_kld: 0.1160 - val_dist_relevant_mae: 1.4591 - val_dist_relevant_mse: 5.5200 - val_dist_dist_iou_metric: 0.5903 - lr: 1.2500e-05
# Epoch 59/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3500 - prob_loss: 0.1156 - dist_loss: 1.1719 - prob_kld: 0.0510 - dist_relevant_mae: 1.1716 - dist_relev
# 100/100 [==============================] - 4s 42ms/step - loss: 0.3500 - prob_loss: 0.1156 - dist_loss: 1.1719 - prob_kld: 0.0510 - dist_relevant_mae: 1.1716 - dist_relevant_mse: 3.5481 - dist_dist_iou_metric: 0.6670 - val_loss: 0.5329 - val_prob_loss: 0.2393 - val_dist_loss: 1.4683 - val_prob_kld: 0.1200 - val_dist_relevant_mae: 1.4681 - val_dist_relevant_mse: 5.5689 - val_dist_dist_iou_metric: 0.5884 - lr: 1.2500e-05
# Epoch 60/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3476 - prob_loss: 0.1166 - dist_loss: 1.1550 - prob_kld: 0.0507 - dist_relevant_mae: 1.1547 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3469 - prob_loss: 0.1164 - dist_loss: 1.1525 - prob_kld: 0.0506 - dist_relevant_mae: 1.1522 - dist_relevant_mse: 3.3973 - dist_dist_iou_metric: 0.6720 - val_loss: 0.5252 - val_prob_loss: 0.2335 - val_dist_loss: 1.4586 - val_prob_kld: 0.1142 - val_dist_relevant_mae: 1.4583 - val_dist_relevant_mse: 5.4981 - val_dist_dist_iou_metric: 0.5906 - lr: 1.2500e-05
# Epoch 61/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3472 - prob_loss: 0.1158 - dist_loss: 1.1568 - prob_kld: 0.0502 - dist_relevant_mae: 1.1566 - dist_relev
# 100/100 [==============================] - 3s 34ms/step - loss: 0.3468 - prob_loss: 0.1158 - dist_loss: 1.1555 - prob_kld: 0.0501 - dist_relevant_mae: 1.1552 - dist_relevant_mse: 3.4423 - dist_dist_iou_metric: 0.6728 - val_loss: 0.5280 - val_prob_loss: 0.2360 - val_dist_loss: 1.4599 - val_prob_kld: 0.1167 - val_dist_relevant_mae: 1.4596 - val_dist_relevant_mse: 5.5202 - val_dist_dist_iou_metric: 0.5902 - lr: 1.2500e-05
# Epoch 62/150
#  98/100 [============================>.] - ETA: 0s - loss: 0.3449 - prob_loss: 0.1164 - dist_loss: 1.1428 - prob_kld: 0.0502 - dist_relevant_mae: 1.1425 - dist_relevant_mse: 3.3386 - dist_dist_iou_metric: 0.6760
# Epoch 62: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 2/2 [==============================] - 0s 3ms/step
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3447 - prob_loss: 0.1162 - dist_loss: 1.1426 - prob_kld: 0.0501 - dist_relevant_mae: 1.1423 - dist_relevant_mse: 3.3396 - dist_dist_iou_metric: 0.6760 - val_loss: 0.5332 - val_prob_loss: 0.2392 - val_dist_loss: 1.4701 - val_prob_kld: 0.1199 - val_dist_relevant_mae: 1.4698 - val_dist_relevant_mse: 5.6172 - val_dist_dist_iou_metric: 0.5876 - lr: 1.2500e-05
# Epoch 63/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3497 - prob_loss: 0.1166 - dist_loss: 1.1657 - prob_kld: 0.0508 - dist_relevant_mae: 1.1654 - dist_relev
# 100/100 [==============================] - 4s 35ms/step - loss: 0.3497 - prob_loss: 0.1166 - dist_loss: 1.1657 - prob_kld: 0.0508 - dist_relevant_mae: 1.1654 - dist_relevant_mse: 3.4992 - dist_dist_iou_metric: 0.6705 - val_loss: 0.5283 - val_prob_loss: 0.2361 - val_dist_loss: 1.4612 - val_prob_kld: 0.1168 - val_dist_relevant_mae: 1.4610 - val_dist_relevant_mse: 5.5312 - val_dist_dist_iou_metric: 0.5901 - lr: 6.2500e-06
# Epoch 64/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3474 - prob_loss: 0.1159 - dist_loss: 1.1577 - prob_kld: 0.0503 - dist_relevant_mae: 1.1574 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3481 - prob_loss: 0.1160 - dist_loss: 1.1605 - prob_kld: 0.0504 - dist_relevant_mae: 1.1602 - dist_relevant_mse: 3.4739 - dist_dist_iou_metric: 0.6716 - val_loss: 0.5307 - val_prob_loss: 0.2368 - val_dist_loss: 1.4699 - val_prob_kld: 0.1175 - val_dist_relevant_mae: 1.4696 - val_dist_relevant_mse: 5.6053 - val_dist_dist_iou_metric: 0.5871 - lr: 6.2500e-06
# Epoch 65/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3424 - prob_loss: 0.1144 - dist_loss: 1.1398 - prob_kld: 0.0498 - dist_relevant_mae: 1.1396 - dist_relev
# 100/100 [==============================] - 3s 35ms/step - loss: 0.3428 - prob_loss: 0.1145 - dist_loss: 1.1419 - prob_kld: 0.0500 - dist_relevant_mae: 1.1416 - dist_relevant_mse: 3.3338 - dist_dist_iou_metric: 0.6726 - val_loss: 0.5311 - val_prob_loss: 0.2363 - val_dist_loss: 1.4735 - val_prob_kld: 0.1171 - val_dist_relevant_mae: 1.4733 - val_dist_relevant_mse: 5.6183 - val_dist_dist_iou_metric: 0.5866 - lr: 6.2500e-06
# Epoch 66/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3456 - prob_loss: 0.1152 - dist_loss: 1.1521 - prob_kld: 0.0496 - dist_relevant_mae: 1.1518 - dist_relev
# 100/100 [==============================] - 4s 36ms/step - loss: 0.3463 - prob_loss: 0.1153 - dist_loss: 1.1553 - prob_kld: 0.0498 - dist_relevant_mae: 1.1550 - dist_relevant_mse: 3.4406 - dist_dist_iou_metric: 0.6717 - val_loss: 0.5318 - val_prob_loss: 0.2375 - val_dist_loss: 1.4715 - val_prob_kld: 0.1182 - val_dist_relevant_mae: 1.4712 - val_dist_relevant_mse: 5.6082 - val_dist_dist_iou_metric: 0.5874 - lr: 6.2500e-06
# Epoch 67/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3473 - prob_loss: 0.1157 - dist_loss: 1.1580 - prob_kld: 0.0504 - dist_relevant_mae: 1.1578 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3473 - prob_loss: 0.1157 - dist_loss: 1.1580 - prob_kld: 0.0504 - dist_relevant_mae: 1.1578 - dist_relevant_mse: 3.4370 - dist_dist_iou_metric: 0.6699 - val_loss: 0.5313 - val_prob_loss: 0.2374 - val_dist_loss: 1.4693 - val_prob_kld: 0.1182 - val_dist_relevant_mae: 1.4690 - val_dist_relevant_mse: 5.5859 - val_dist_dist_iou_metric: 0.5878 - lr: 6.2500e-06
# Epoch 68/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3477 - prob_loss: 0.1157 - dist_loss: 1.1601 - prob_kld: 0.0501 - dist_relevant_mae: 1.1598 - dist_relev
# 100/100 [==============================] - 3s 35ms/step - loss: 0.3477 - prob_loss: 0.1157 - dist_loss: 1.1601 - prob_kld: 0.0501 - dist_relevant_mae: 1.1598 - dist_relevant_mse: 3.4517 - dist_dist_iou_metric: 0.6707 - val_loss: 0.5273 - val_prob_loss: 0.2349 - val_dist_loss: 1.4619 - val_prob_kld: 0.1156 - val_dist_relevant_mae: 1.4616 - val_dist_relevant_mse: 5.5351 - val_dist_dist_iou_metric: 0.5897 - lr: 6.2500e-06
# Epoch 69/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3489 - prob_loss: 0.1175 - dist_loss: 1.1571 - prob_kld: 0.0506 - dist_relevant_mae: 1.1568 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3491 - prob_loss: 0.1176 - dist_loss: 1.1573 - prob_kld: 0.0507 - dist_relevant_mae: 1.1570 - dist_relevant_mse: 3.4053 - dist_dist_iou_metric: 0.6720 - val_loss: 0.5276 - val_prob_loss: 0.2352 - val_dist_loss: 1.4619 - val_prob_kld: 0.1160 - val_dist_relevant_mae: 1.4616 - val_dist_relevant_mse: 5.5440 - val_dist_dist_iou_metric: 0.5901 - lr: 6.2500e-06
# Epoch 70/150
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3470 - prob_loss: 0.1169 - dist_loss: 1.1506 - prob_kld: 0.0497 - dist_relevant_mae: 1.1503 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3476 - prob_loss: 0.1170 - dist_loss: 1.1526 - prob_kld: 0.0499 - dist_relevant_mae: 1.1523 - dist_relevant_mse: 3.3859 - dist_dist_iou_metric: 0.6739 - val_loss: 0.5278 - val_prob_loss: 0.2351 - val_dist_loss: 1.4634 - val_prob_kld: 0.1159 - val_dist_relevant_mae: 1.4631 - val_dist_relevant_mse: 5.5461 - val_dist_dist_iou_metric: 0.5896 - lr: 6.2500e-06
# Epoch 71/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3450 - prob_loss: 0.1147 - dist_loss: 1.1518 - prob_kld: 0.0497 - dist_relevant_mae: 1.1516 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3446 - prob_loss: 0.1147 - dist_loss: 1.1496 - prob_kld: 0.0496 - dist_relevant_mae: 1.1493 - dist_relevant_mse: 3.4074 - dist_dist_iou_metric: 0.6717 - val_loss: 0.5294 - val_prob_loss: 0.2368 - val_dist_loss: 1.4631 - val_prob_kld: 0.1175 - val_dist_relevant_mae: 1.4628 - val_dist_relevant_mse: 5.5490 - val_dist_dist_iou_metric: 0.5896 - lr: 6.2500e-06
# Epoch 72/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3430 - prob_loss: 0.1142 - dist_loss: 1.1441 - prob_kld: 0.0492 - dist_relevant_mae: 1.1439 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3430 - prob_loss: 0.1142 - dist_loss: 1.1441 - prob_kld: 0.0492 - dist_relevant_mae: 1.1439 - dist_relevant_mse: 3.3339 - dist_dist_iou_metric: 0.6728 - val_loss: 0.5347 - val_prob_loss: 0.2393 - val_dist_loss: 1.4770 - val_prob_kld: 0.1200 - val_dist_relevant_mae: 1.4768 - val_dist_relevant_mse: 5.6269 - val_dist_dist_iou_metric: 0.5862 - lr: 6.2500e-06
# Epoch 73/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3436 - prob_loss: 0.1161 - dist_loss: 1.1376 - prob_kld: 0.0498 - dist_relevant_mae: 1.1373 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3436 - prob_loss: 0.1161 - dist_loss: 1.1376 - prob_kld: 0.0498 - dist_relevant_mae: 1.1373 - dist_relevant_mse: 3.2983 - dist_dist_iou_metric: 0.6752 - val_loss: 0.5318 - val_prob_loss: 0.2377 - val_dist_loss: 1.4706 - val_prob_kld: 0.1184 - val_dist_relevant_mae: 1.4703 - val_dist_relevant_mse: 5.5826 - val_dist_dist_iou_metric: 0.5878 - lr: 6.2500e-06
# Epoch 74/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3453 - prob_loss: 0.1155 - dist_loss: 1.1489 - prob_kld: 0.0497 - dist_relevant_mae: 1.1486 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3453 - prob_loss: 0.1155 - dist_loss: 1.1489 - prob_kld: 0.0497 - dist_relevant_mae: 1.1486 - dist_relevant_mse: 3.3831 - dist_dist_iou_metric: 0.6742 - val_loss: 0.5297 - val_prob_loss: 0.2363 - val_dist_loss: 1.4674 - val_prob_kld: 0.1170 - val_dist_relevant_mae: 1.4672 - val_dist_relevant_mse: 5.5705 - val_dist_dist_iou_metric: 0.5885 - lr: 6.2500e-06
# Epoch 75/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3420 - prob_loss: 0.1143 - dist_loss: 1.1386 - prob_kld: 0.0495 - dist_relevant_mae: 1.1383 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3419 - prob_loss: 0.1142 - dist_loss: 1.1382 - prob_kld: 0.0494 - dist_relevant_mae: 1.1379 - dist_relevant_mse: 3.3161 - dist_dist_iou_metric: 0.6742 - val_loss: 0.5345 - val_prob_loss: 0.2391 - val_dist_loss: 1.4767 - val_prob_kld: 0.1198 - val_dist_relevant_mae: 1.4764 - val_dist_relevant_mse: 5.6482 - val_dist_dist_iou_metric: 0.5860 - lr: 6.2500e-06
# Epoch 76/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3486 - prob_loss: 0.1159 - dist_loss: 1.1638 - prob_kld: 0.0504 - dist_relevant_mae: 1.1635 - dist_relev
# ...
# Epoch 127/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3446 - prob_loss: 0.1146 - dist_loss: 1.1500 - prob_kld: 0.0494 - dist_relevant_mae: 1.1497 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3446 - prob_loss: 0.1146 - dist_loss: 1.1500 - prob_kld: 0.0494 - dist_relevant_mae: 1.1497 - dist_relevant_mse: 3.4087 - dist_dist_iou_metric: 0.6733 - val_loss: 0.5334 - val_prob_loss: 0.2384 - val_dist_loss: 1.4749 - val_prob_kld: 0.1191 - val_dist_relevant_mae: 1.4746 - val_dist_relevant_mse: 5.6295 - val_dist_dist_iou_metric: 0.5869 - lr: 3.9062e-07
# Epoch 128/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3419 - prob_loss: 0.1134 - dist_loss: 1.1425 - prob_kld: 0.0486 - dist_relevant_mae: 1.1422 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3415 - prob_loss: 0.1134 - dist_loss: 1.1406 - prob_kld: 0.0486 - dist_relevant_mae: 1.1404 - dist_relevant_mse: 3.3388 - dist_dist_iou_metric: 0.6749 - val_loss: 0.5322 - val_prob_loss: 0.2376 - val_dist_loss: 1.4728 - val_prob_kld: 0.1184 - val_dist_relevant_mae: 1.4725 - val_dist_relevant_mse: 5.6159 - val_dist_dist_iou_metric: 0.5874 - lr: 3.9062e-07
# Epoch 129/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3439 - prob_loss: 0.1147 - dist_loss: 1.1460 - prob_kld: 0.0491 - dist_relevant_mae: 1.1457 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3439 - prob_loss: 0.1147 - dist_loss: 1.1460 - prob_kld: 0.0491 - dist_relevant_mae: 1.1457 - dist_relevant_mse: 3.3553 - dist_dist_iou_metric: 0.6740 - val_loss: 0.5316 - val_prob_loss: 0.2372 - val_dist_loss: 1.4720 - val_prob_kld: 0.1179 - val_dist_relevant_mae: 1.4717 - val_dist_relevant_mse: 5.6109 - val_dist_dist_iou_metric: 0.5876 - lr: 3.9062e-07
# Epoch 130/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3443 - prob_loss: 0.1151 - dist_loss: 1.1459 - prob_kld: 0.0493 - dist_relevant_mae: 1.1456 - dist_relev
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3443 - prob_loss: 0.1151 - dist_loss: 1.1459 - prob_kld: 0.0493 - dist_relevant_mae: 1.1456 - dist_relevant_mse: 3.3856 - dist_dist_iou_metric: 0.6746 - val_loss: 0.5317 - val_prob_loss: 0.2373 - val_dist_loss: 1.4716 - val_prob_kld: 0.1181 - val_dist_relevant_mae: 1.4713 - val_dist_relevant_mse: 5.6076 - val_dist_dist_iou_metric: 0.5878 - lr: 3.9062e-07
# Epoch 131/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3433 - prob_loss: 0.1143 - dist_loss: 1.1451 - prob_kld: 0.0497 - dist_relevant_mae: 1.1448 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3438 - prob_loss: 0.1144 - dist_loss: 1.1469 - prob_kld: 0.0499 - dist_relevant_mae: 1.1466 - dist_relevant_mse: 3.3653 - dist_dist_iou_metric: 0.6713 - val_loss: 0.5317 - val_prob_loss: 0.2373 - val_dist_loss: 1.4719 - val_prob_kld: 0.1180 - val_dist_relevant_mae: 1.4716 - val_dist_relevant_mse: 5.6090 - val_dist_dist_iou_metric: 0.5877 - lr: 3.9062e-07
# Epoch 132/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3421 - prob_loss: 0.1145 - dist_loss: 1.1381 - prob_kld: 0.0493 - dist_relevant_mae: 1.1378 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3421 - prob_loss: 0.1145 - dist_loss: 1.1381 - prob_kld: 0.0493 - dist_relevant_mae: 1.1378 - dist_relevant_mse: 3.3089 - dist_dist_iou_metric: 0.6743 - val_loss: 0.5325 - val_prob_loss: 0.2377 - val_dist_loss: 1.4739 - val_prob_kld: 0.1184 - val_dist_relevant_mae: 1.4736 - val_dist_relevant_mse: 5.6240 - val_dist_dist_iou_metric: 0.5872 - lr: 3.9062e-07
# Epoch 133/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3436 - prob_loss: 0.1154 - dist_loss: 1.1411 - prob_kld: 0.0495 - dist_relevant_mae: 1.1408 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3437 - prob_loss: 0.1153 - dist_loss: 1.1419 - prob_kld: 0.0495 - dist_relevant_mae: 1.1416 - dist_relevant_mse: 3.3213 - dist_dist_iou_metric: 0.6756 - val_loss: 0.5309 - val_prob_loss: 0.2368 - val_dist_loss: 1.4708 - val_prob_kld: 0.1175 - val_dist_relevant_mae: 1.4706 - val_dist_relevant_mse: 5.6024 - val_dist_dist_iou_metric: 0.5879 - lr: 3.9062e-07
# Epoch 134/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3432 - prob_loss: 0.1155 - dist_loss: 1.1386 - prob_kld: 0.0491 - dist_relevant_mae: 1.1383 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3437 - prob_loss: 0.1156 - dist_loss: 1.1402 - prob_kld: 0.0492 - dist_relevant_mae: 1.1400 - dist_relevant_mse: 3.3383 - dist_dist_iou_metric: 0.6761 - val_loss: 0.5308 - val_prob_loss: 0.2368 - val_dist_loss: 1.4701 - val_prob_kld: 0.1175 - val_dist_relevant_mae: 1.4698 - val_dist_relevant_mse: 5.5952 - val_dist_dist_iou_metric: 0.5882 - lr: 3.9062e-07
# Epoch 135/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3409 - prob_loss: 0.1143 - dist_loss: 1.1330 - prob_kld: 0.0498 - dist_relevant_mae: 1.1328 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3411 - prob_loss: 0.1143 - dist_loss: 1.1342 - prob_kld: 0.0499 - dist_relevant_mae: 1.1339 - dist_relevant_mse: 3.2939 - dist_dist_iou_metric: 0.6735 - val_loss: 0.5307 - val_prob_loss: 0.2367 - val_dist_loss: 1.4703 - val_prob_kld: 0.1174 - val_dist_relevant_mae: 1.4701 - val_dist_relevant_mse: 5.5954 - val_dist_dist_iou_metric: 0.5881 - lr: 3.9062e-07
# Epoch 136/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3442 - prob_loss: 0.1159 - dist_loss: 1.1412 - prob_kld: 0.0493 - dist_relevant_mae: 1.1410 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3455 - prob_loss: 0.1160 - dist_loss: 1.1472 - prob_kld: 0.0495 - dist_relevant_mae: 1.1469 - dist_relevant_mse: 3.3940 - dist_dist_iou_metric: 0.6748 - val_loss: 0.5318 - val_prob_loss: 0.2374 - val_dist_loss: 1.4721 - val_prob_kld: 0.1181 - val_dist_relevant_mae: 1.4718 - val_dist_relevant_mse: 5.6076 - val_dist_dist_iou_metric: 0.5876 - lr: 3.9062e-07
# Epoch 137/150
#  99/100 [============================>.] - ETA: 0s - loss: 0.3444 - prob_loss: 0.1142 - dist_loss: 1.1509 - prob_kld: 0.0488 - dist_relevant_mae: 1.1506 - dist_relevant_mse: 3.4155 - dist_dist_iou_metric: 0.6736
# Epoch 137: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 2/2 [==============================] - 0s 4ms/step
# 100/100 [==============================] - 3s 35ms/step - loss: 0.3449 - prob_loss: 0.1143 - dist_loss: 1.1527 - prob_kld: 0.0490 - dist_relevant_mae: 1.1524 - dist_relevant_mse: 3.4231 - dist_dist_iou_metric: 0.6730 - val_loss: 0.5320 - val_prob_loss: 0.2375 - val_dist_loss: 1.4725 - val_prob_kld: 0.1182 - val_dist_relevant_mae: 1.4722 - val_dist_relevant_mse: 5.6110 - val_dist_dist_iou_metric: 0.5874 - lr: 3.9062e-07
# Epoch 138/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3420 - prob_loss: 0.1153 - dist_loss: 1.1333 - prob_kld: 0.0488 - dist_relevant_mae: 1.1330 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3420 - prob_loss: 0.1153 - dist_loss: 1.1333 - prob_kld: 0.0488 - dist_relevant_mae: 1.1330 - dist_relevant_mse: 3.2812 - dist_dist_iou_metric: 0.6773 - val_loss: 0.5310 - val_prob_loss: 0.2369 - val_dist_loss: 1.4705 - val_prob_kld: 0.1177 - val_dist_relevant_mae: 1.4703 - val_dist_relevant_mse: 5.5975 - val_dist_dist_iou_metric: 0.5879 - lr: 1.9531e-07
# Epoch 139/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3438 - prob_loss: 0.1157 - dist_loss: 1.1403 - prob_kld: 0.0493 - dist_relevant_mae: 1.1400 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3451 - prob_loss: 0.1161 - dist_loss: 1.1451 - prob_kld: 0.0496 - dist_relevant_mae: 1.1449 - dist_relevant_mse: 3.3511 - dist_dist_iou_metric: 0.6734 - val_loss: 0.5308 - val_prob_loss: 0.2367 - val_dist_loss: 1.4707 - val_prob_kld: 0.1174 - val_dist_relevant_mae: 1.4705 - val_dist_relevant_mse: 5.5996 - val_dist_dist_iou_metric: 0.5878 - lr: 1.9531e-07
# Epoch 140/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3410 - prob_loss: 0.1157 - dist_loss: 1.1267 - prob_kld: 0.0488 - dist_relevant_mae: 1.1265 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3421 - prob_loss: 0.1160 - dist_loss: 1.1305 - prob_kld: 0.0491 - dist_relevant_mae: 1.1302 - dist_relevant_mse: 3.2546 - dist_dist_iou_metric: 0.6779 - val_loss: 0.5310 - val_prob_loss: 0.2368 - val_dist_loss: 1.4711 - val_prob_kld: 0.1175 - val_dist_relevant_mae: 1.4708 - val_dist_relevant_mse: 5.6021 - val_dist_dist_iou_metric: 0.5877 - lr: 1.9531e-07
# Epoch 141/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3400 - prob_loss: 0.1141 - dist_loss: 1.1298 - prob_kld: 0.0489 - dist_relevant_mae: 1.1295 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3400 - prob_loss: 0.1141 - dist_loss: 1.1298 - prob_kld: 0.0489 - dist_relevant_mae: 1.1295 - dist_relevant_mse: 3.2934 - dist_dist_iou_metric: 0.6770 - val_loss: 0.5318 - val_prob_loss: 0.2374 - val_dist_loss: 1.4720 - val_prob_kld: 0.1181 - val_dist_relevant_mae: 1.4717 - val_dist_relevant_mse: 5.6089 - val_dist_dist_iou_metric: 0.5875 - lr: 1.9531e-07
# Epoch 142/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3426 - prob_loss: 0.1144 - dist_loss: 1.1411 - prob_kld: 0.0489 - dist_relevant_mae: 1.1408 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3424 - prob_loss: 0.1143 - dist_loss: 1.1408 - prob_kld: 0.0489 - dist_relevant_mae: 1.1405 - dist_relevant_mse: 3.3244 - dist_dist_iou_metric: 0.6739 - val_loss: 0.5322 - val_prob_loss: 0.2376 - val_dist_loss: 1.4728 - val_prob_kld: 0.1183 - val_dist_relevant_mae: 1.4726 - val_dist_relevant_mse: 5.6145 - val_dist_dist_iou_metric: 0.5874 - lr: 1.9531e-07
# Epoch 143/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3451 - prob_loss: 0.1166 - dist_loss: 1.1427 - prob_kld: 0.0492 - dist_relevant_mae: 1.1424 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3451 - prob_loss: 0.1166 - dist_loss: 1.1427 - prob_kld: 0.0492 - dist_relevant_mae: 1.1424 - dist_relevant_mse: 3.3673 - dist_dist_iou_metric: 0.6766 - val_loss: 0.5312 - val_prob_loss: 0.2370 - val_dist_loss: 1.4707 - val_prob_kld: 0.1178 - val_dist_relevant_mae: 1.4705 - val_dist_relevant_mse: 5.5994 - val_dist_dist_iou_metric: 0.5879 - lr: 1.9531e-07
# Epoch 144/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3410 - prob_loss: 0.1140 - dist_loss: 1.1348 - prob_kld: 0.0488 - dist_relevant_mae: 1.1345 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3413 - prob_loss: 0.1140 - dist_loss: 1.1361 - prob_kld: 0.0489 - dist_relevant_mae: 1.1358 - dist_relevant_mse: 3.3073 - dist_dist_iou_metric: 0.6752 - val_loss: 0.5321 - val_prob_loss: 0.2375 - val_dist_loss: 1.4729 - val_prob_kld: 0.1182 - val_dist_relevant_mae: 1.4727 - val_dist_relevant_mse: 5.6168 - val_dist_dist_iou_metric: 0.5873 - lr: 1.9531e-07
# Epoch 145/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3437 - prob_loss: 0.1148 - dist_loss: 1.1448 - prob_kld: 0.0497 - dist_relevant_mae: 1.1445 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3437 - prob_loss: 0.1148 - dist_loss: 1.1448 - prob_kld: 0.0497 - dist_relevant_mae: 1.1445 - dist_relevant_mse: 3.3543 - dist_dist_iou_metric: 0.6731 - val_loss: 0.5324 - val_prob_loss: 0.2377 - val_dist_loss: 1.4736 - val_prob_kld: 0.1184 - val_dist_relevant_mae: 1.4734 - val_dist_relevant_mse: 5.6218 - val_dist_dist_iou_metric: 0.5871 - lr: 1.9531e-07
# Epoch 146/150
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3404 - prob_loss: 0.1124 - dist_loss: 1.1398 - prob_kld: 0.0486 - dist_relevant_mae: 1.1395 - dist_relev
# 100/100 [==============================] - 3s 28ms/step - loss: 0.3404 - prob_loss: 0.1124 - dist_loss: 1.1398 - prob_kld: 0.0486 - dist_relevant_mae: 1.1395 - dist_relevant_mse: 3.3260 - dist_dist_iou_metric: 0.6733 - val_loss: 0.5313 - val_prob_loss: 0.2370 - val_dist_loss: 1.4714 - val_prob_kld: 0.1178 - val_dist_relevant_mae: 1.4711 - val_dist_relevant_mse: 5.6050 - val_dist_dist_iou_metric: 0.5877 - lr: 1.9531e-07
# Epoch 147/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3416 - prob_loss: 0.1159 - dist_loss: 1.1283 - prob_kld: 0.0496 - dist_relevant_mae: 1.1281 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3412 - prob_loss: 0.1158 - dist_loss: 1.1272 - prob_kld: 0.0495 - dist_relevant_mae: 1.1269 - dist_relevant_mse: 3.2577 - dist_dist_iou_metric: 0.6775 - val_loss: 0.5322 - val_prob_loss: 0.2375 - val_dist_loss: 1.4733 - val_prob_kld: 0.1183 - val_dist_relevant_mae: 1.4730 - val_dist_relevant_mse: 5.6191 - val_dist_dist_iou_metric: 0.5871 - lr: 1.9531e-07
# Epoch 148/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3408 - prob_loss: 0.1139 - dist_loss: 1.1342 - prob_kld: 0.0487 - dist_relevant_mae: 1.1339 - dist_relev
# 100/100 [==============================] - 3s 32ms/step - loss: 0.3413 - prob_loss: 0.1140 - dist_loss: 1.1365 - prob_kld: 0.0488 - dist_relevant_mae: 1.1362 - dist_relevant_mse: 3.3175 - dist_dist_iou_metric: 0.6751 - val_loss: 0.5325 - val_prob_loss: 0.2378 - val_dist_loss: 1.4738 - val_prob_kld: 0.1185 - val_dist_relevant_mae: 1.4736 - val_dist_relevant_mse: 5.6228 - val_dist_dist_iou_metric: 0.5870 - lr: 1.9531e-07
# Epoch 149/150
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3464 - prob_loss: 0.1160 - dist_loss: 1.1522 - prob_kld: 0.0501 - dist_relevant_mae: 1.1519 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3464 - prob_loss: 0.1160 - dist_loss: 1.1522 - prob_kld: 0.0501 - dist_relevant_mae: 1.1519 - dist_relevant_mse: 3.4185 - dist_dist_iou_metric: 0.6725 - val_loss: 0.5324 - val_prob_loss: 0.2377 - val_dist_loss: 1.4734 - val_prob_kld: 0.1185 - val_dist_relevant_mae: 1.4732 - val_dist_relevant_mse: 5.6203 - val_dist_dist_iou_metric: 0.5872 - lr: 1.9531e-07
# Epoch 150/150
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3405 - prob_loss: 0.1146 - dist_loss: 1.1294 - prob_kld: 0.0491 - dist_relevant_mae: 1.1292 - dist_relev
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3405 - prob_loss: 0.1146 - dist_loss: 1.1294 - prob_kld: 0.0491 - dist_relevant_mae: 1.1292 - dist_relevant_mse: 3.2738 - dist_dist_iou_metric: 0.6767 - val_loss: 0.5324 - val_prob_loss: 0.2377 - val_dist_loss: 1.4737 - val_prob_kld: 0.1184 - val_dist_relevant_mae: 1.4734 - val_dist_relevant_mse: 5.6208 - val_dist_dist_iou_metric: 0.5871 - lr: 1.9531e-07
#
# Loading network weights from 'weights_best.h5'.
# NMS threshold = 0.3:  80%|████████  | 16/20 [00:02<00:00,  5.75it/s, 0.486 -> 0.600]
# NMS threshold = 0.4:  80%|████████  | 16/20 [00:02<00:00,  7.70it/s, 0.486 -> 0.598]
# NMS threshold = 0.5:  80%|████████  | 16/20 [00:02<00:00,  7.76it/s, 0.486 -> 0.596]
# Using optimized values: prob_thresh=0.486318, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# WARNING:tensorflow:From C:\Users\Donald\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\tensorflow\python\summary\summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow | From C:\Users\Donald\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\tensorflow\python\summary\summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
# pthHE= fr'\\10.99.68.178\andreex\data\Stardist\Testing\monkey\tiles'
# pthmasks= fr'\\10.99.68.178\andreex\data\Stardist\Testing\monkey\qupath\ground_truth\masks'

HE_tiles_pths = sorted(glob(os.path.join(pthHE_testing,'*.tif')))
mask_tiles_pths = sorted(glob(os.path.join(pthmasks_testing,'*.tif')))

HE_tiles_val = list(map(imread,HE_tiles_pths))
mask_tiles_val = list(map(imread,mask_tiles_pths))

HE_tiles_val = [x/255 for x in HE_tiles_val]  # just divide by 255 to get into (0,1) range
mask_tiles_val = [fill_label_holes(y) for y in mask_tiles_val]  # fills holes in annotations if there are any

# %%
#Predict on validation images
mask_val_pred = [model.predict_instances(x, n_tiles=model._guess_n_tiles(x), show_tile_progress=False)[0]
              for x in tqdm(HE_tiles_val)]
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]

# %%
X_val = HE_tiles_val
Y_val_pred = mask_val_pred
Y_val = mask_tiles_val

ind = 0

cropped_img = X_val[ind]
cropped_lbl = Y_val_pred[ind]
cropped_lbl_gt = Y_val[ind]

fig, ax = plt.subplots(1,3,figsize = (16, 8))
ax[0].imshow(cropped_img)
ax[0].axis('off')
ax[0].set_title('H&E')

ax[1].imshow(cropped_img)
ax[1].imshow(cropped_lbl_gt, cmap=lbl_cmap, alpha=0.5)
ax[1].axis('off')
ax[1].set_title('Ground Truth')

ax[2].imshow(cropped_img)
ax[2].imshow(cropped_lbl, cmap=lbl_cmap, alpha=0.5)
ax[2].axis('off')
ax[2].set_title('Predicted')
plt.show()
