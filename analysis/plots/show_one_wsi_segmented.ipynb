# %%
import numpy as np
import matplotlib.pyplot as plt

from tifffile import imread, imwrite
from csbdeep.utils import Path, normalize
from csbdeep.utils.tf import keras_import
keras = keras_import()

from stardist import export_imagej_rois, random_label_cmap
from stardist.models import StarDist2D

np.random.seed(0)
cmap = random_label_cmap()

# %%
import os
from glob import glob

# CHANGE PATH

pth = r'\\10.99.68.178\andreex\data\monkey fetus\gestational 40'  # path of ndpi files
WSIs = sorted(glob(f'{pth}\*.ndpi'))

# %%
WSIs[:20]
# Out:
# ['\\\\10.162.80.16\\Andre_expansion\\data\\PDAC purity\\PDAC PURITY Final Analysis\\LCM_H&Es_10x\\czi\\ometiff20xv2\\PD_21 5M-2 LCM.tif']

# %%
def show_image(img, crop_x, crop_y, tile_size, **kwargs):
    """Plot large image at different resolutions."""
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))

    # Plot the original image on the left
    ax[0].imshow(img, **kwargs)

    # Crop the image
    cropped_img = img[crop_y:crop_y+tile_size, crop_x:crop_x+tile_size]

    # Plot the cropped image on the right
    ax[1].imshow(cropped_img, **kwargs)

    ax[0].axis('off')
    ax[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
def show_image_overlay(img, labels, crop_x, crop_y, tile_size, lbl_cmap):
    """Plot large image at different resolutions."""
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))

    # Crop the image
    cropped_img = img[crop_y:crop_y+tile_size, crop_x:crop_x+tile_size]
    cropped_labels = labels[crop_y:crop_y+tile_size, crop_x:crop_x+tile_size]

    # Plot the original image on the left
    ax[0].imshow(cropped_img)

    # Plot the cropped image on the right
    ax[1].imshow(cropped_img)
    ax[1].imshow(cropped_labels, cmap=lbl_cmap, alpha=0.5)

    ax[0].axis('off')
    ax[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
ind = 200  # which image in directory list you are loading

# you might need to run "pip install imagecodecs" if you get jpeg compression error

img = imread(WSIs[ind])
n_channel = 1 if img[0].ndim == 2 else img[0].shape[-1]  #If no third

img = img/255

# %%
# fallopian tube:
fallopian_tube_pth = r'\\10.99.68.178\andre\data\Ashleigh fallopian tube\fallopian tubes\AJF232\fallopian_tubes_AJLF232_0135.ndpi'

img = imread(fallopian_tube_pth)
n_channel = 1 if img[0].ndim == 2 else img[0].shape[-1]  #If no third

img = img/255

# %%
import json
from stardist.models import Config2D, StarDist2D

def load_model(model_path: str) -> StarDist2D:
    # Load StarDist model weights, configurations, and thresholds
    with open(model_path + '\\config.json', 'r') as f:
        config = json.load(f)
    with open(model_path + '\\thresholds.json', 'r') as f:
        thresh = json.load(f)
    model = StarDist2D(config=Config2D(**config), basedir=model_path, name='offshoot_model')
    model.thresholds = thresh
    print('Overriding defaults:', model.thresholds, '\n')
    model.load_weights(model_path + '\\weights_best.h5')
    return model

#
# CHANGE RIGHT MODEL
model = load_model(r'\\10.99.68.178\andreex\data\Stardist\12_12_hyperparameter_models\monkey_12_12_2023_lr_0.001_epochs_400_pt_10_gaus_ratio_0')
# Out:
# base_model.py (149): output path for model already exists, files may be overwritten: \\10.99.68.178\andreex\data\Stardist\12_12_hyperparameter_models\monkey_12_12_2023_lr_0.001_epochs_400_pt_10_gaus_ratio_0\offshoot_model
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# Overriding defaults: Thresholds(prob=0.6883699162882626, nms=0.3)

# %%
labels, polys = model.predict_instances_big(img, axes='YXC', block_size=4096, min_overlap=128, context=128, n_tiles=(4,4,1))
# Out:
# effective: block_size=(4096, 4096, 3), min_overlap=(128, 128, 0), context=(128, 128, 0)
# 100%|██████████| 260/260 [08:35<00:00,  1.98s/it]

# %%
img.size
# Out:
# 10202480640

# %%
labels.size
# Out:
# 3400826880

# %%
show_image_overlay(img, labels, crop_x=44839, crop_y=24803, tile_size=1024, lbl_cmap=cmap)
# show_image(img, crop_x=10000, crop_y=10000, tile_size=1024)

# %%
show_image(img, crop_x=44639, crop_y=24603, tile_size=1024)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 show_image(img, crop_x=44639, crop_y=24603, tile_size=1024)
#
# Cell In[4], line 6, in show_image(img, crop_x, crop_y, tile_size, **kwargs)
#       3 fig, ax = plt.subplots(1, 2, figsize=(16, 8))
#       5 # Plot the original image on the left
# ----> 6 ax[0].imshow(img, **kwargs)
#       8 # Crop the image
#       9 cropped_img = img[crop_y:crop_y+tile_size, crop_x:crop_x+tile_size]
#
# File ~\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\matplotlib\__init__.py:1492, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1489 @functools.wraps(func)
#    1490 def inner(ax, *args, data=None, **kwargs):
#    1491     if data is None:
# -> 1492         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1494     bound = new_sig.bind(ax, *args, **kwargs)
#    1495     auto_label = (bound.arguments.get(label_namer)
#    1496                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\matplotlib\axes\_axes.py:5751, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5748 if aspect is not None:
#    5749     self.set_aspect(aspect)
# -> 5751 im.set_data(X)
#    5752 im.set_alpha(alpha)
#    5753 if im.get_clip_path() is None:
#    5754     # image does not already have clipping set, clip to axes patch
#
# File ~\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\matplotlib\image.py:723, in _ImageBase.set_data(self, A)
#     721 if isinstance(A, PIL.Image.Image):
#     722     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723 self._A = self._normalize_image_array(A)
#     724 self._imcache = None
#     725 self.stale = True
#
# File ~\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\matplotlib\image.py:686, in _ImageBase._normalize_image_array(A)
#     680 @staticmethod
#     681 def _normalize_image_array(A):
#     682     """
#     683     Check validity of image-like input *A* and normalize it to a format suitable for
#     684     Image subclasses.
#     685     """
# --> 686     A = cbook.safe_masked_invalid(A, copy=True)
#     687     if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
#     688         raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     689                         f"converted to float")
#
# File ~\anaconda3\envs\monkey_nuc_segment_v6\lib\site-packages\matplotlib\cbook.py:733, in safe_masked_invalid(x, copy)
#     732 def safe_masked_invalid(x, copy=False):
# --> 733     x = np.array(x, subok=True, copy=copy)
#     734     if not x.dtype.isnative:
#     735         # If we have already made a copy, do the byteswap in place, else make a
#     736         # copy with the byte order swapped.
#     737         # Swap to native order.
#     738         x = x.byteswap(inplace=copy).view(x.dtype.newbyteorder('N'))
#
# MemoryError: Unable to allocate 76.0 GiB for an array with shape (47872, 71040, 3) and data type float64

# %%
show_image_2(labels, crop_x=44639, crop_y=24603, tile_size=1024, cmap=cmap)

# %%
def show_image_2(img, crop_x, crop_y, tile_size, cmap):
    """Plot large image at different resolutions."""
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))

    # Plot the original image on the left
    ax[0].imshow(img, cmap)

    # Crop the image
    cropped_img = img[crop_y:crop_y+tile_size, crop_x:crop_x+tile_size]

    # Plot the cropped image on the right
    ax[1].imshow(cropped_img, cmap)

    ax[0].axis('off')
    ax[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
WSIs[200]
